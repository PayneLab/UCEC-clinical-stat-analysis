# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import re
import seaborn as sns
import sys
import urllib3
import json
import operator
import collections

import CPTAC.Endometrial as CPTAC
# Out:
# Welcome to the CPTAC data service package. Available datasets may be
# viewed using CPTAC.list(). In order to access a specific data set,
# import a CPTAC subfolder using either 'import CPTAC.Dataset' or 'from
# CPTAC import Dataset'.
# ******
# Version: 0.2.5
# ******
# Loading Endometrial CPTAC data:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Acetylation Proteomics Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter embargo() to open the webpage for more details.

# %%
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %% [markdown]
# ## Step 1: Enter gene name

# %%
gene = "PTEN" #Name of any gene of which you are interested in examing the effects of mutation

# %% [markdown]
# ## Step 2: Select type of data
# Set "data_type" to "proteomics" for proteomic abundance data <br><br>
# Set "data_type" to "phosphoproteomics" for phosphoproteomic data <br><br>
# Set "data_type" to "transcriptomics" for transcription data

# %%
data_type = "phosphoproteomics" #Options are "proteomics", "phosphoproteomics", "transcriptomics"

# %% [markdown]
# ## Step 3: Select scope of data analysis
# Set "scope" to "cis" to examine cis effect of gene mutation on the protein it codes for <br> <br>
# Set "scope" to "interacting" to examine the effect of gene mutation on known interacting proteins (interacting proteins are automatically generated through interacting with STRING database API). If using scope, set "number_of_interacting_proteins" to the number of interacting proteins you want to pull from the STRING database <br><br>
# Set "scope" to "all" to look at the effect on all proteins in our dataset

# %%
scope = "interacting" #Options are "cis", "interacting", "all"
number_of_interacting_proteins = 25 #Parameter only necessary if examining "interacting", else set to 0

# %% [markdown]
# ## Step 4: Select Question
# Set "question" to "mutated_vs_wildtype" to compare mutated and wildtype groups <br><br>
# Set "question" to "hotspot_vs_wildtype" to compare individuals with a hotspot mutation with wildtype <br><br>
# Set "question" to "truncation_vs_wildtype" to compare individuals with a truncating mutation with wildtype

# %%
question = "mutated_vs_wildtype" #Options are .....

# %% [markdown]
# ### Set dataframe to that of the seleted data type

# %%
if data_type == "proteomics":
    dataframe = CPTAC.get_proteomics()
    
elif data_type == "phosphoproteomics":
    dataframe = CPTAC.get_phosphoproteomics()
    
elif data_type == "transcriptomics":
    dataframe = CPTAC.get_transcriptomics()
    
else:
    print("Invalid data_type value entered! See step 2 above.")

# %% [markdown]
# ### Generate protein list based on the selected scope

# %%
protein_list = []    

'''Just add the gene itself if cis'''
if scope == "cis":
    protein_list = [gene]

elif scope == "interacting":
    '''Use urllib3 to access the string database api, gather list of interacting proteins'''
    urllib3.disable_warnings()
    string_api_url = "https://string-db.org/api"
    output_format = "json"
    method = "network"

    '''Use the specified gene and homo sapiens species code'''
    my_gene = [gene]
    species = "9606"

    '''Format the api request to collect the appropriate information'''
    request_url = string_api_url + "/" + output_format + "/" + method + "?"
    request_url += "identifiers=%s" % "%0d".join(my_gene)
    request_url += "&" + "species=" + species
    request_url += "&" + "limit=" + str(number_of_interacting_proteins)

    '''Send a request to the API, print the response status'''
    try:
        http = urllib3.PoolManager()
        response = http.request('GET',request_url)
        #print("Accessing String database, response status: ", response.status)
    except urllib3.HTTPError as err:
        error_message = err.read()
        print(error_message)
        sys.exit()

    interacting_proteins = []
    if response.status == 200: 
        '''Get the data from the API's response'''
        data = response.data
        y = json.loads(data)

        '''Make a list of the resulting interacting proteins'''
        for entry in y:
            if entry["preferredName_A"] not in interacting_proteins:
                interacting_proteins.append(entry["preferredName_A"])
            if entry["preferredName_B"] not in interacting_proteins:
                interacting_proteins.append(entry["preferredName_B"])
                
        for ip in interacting_proteins:
            protein_list.append(ip)
    else:
        print("\nSpecified gene was not found in String database, double check that you have it correctly!")
        protein_list.append(gene)

elif scope == "all":
    '''If all, add all proteins in our dataset'''
    protein_list = proteomics.columns

else:
    '''If none of these, invalid'''
    print("Invalid scope value entered! See step 3 above.")
    
'''Display list of proteins selected'''
print("Protein List: \n")
for pro in protein_list:
    print(pro)
# Out:
# Protein List:
#
# MDM2
# CSNK2A1
# PDGFRB
# PIK3R2
# PIK3C3
# CSNK2A2
# SLC9A3R1
# PIK3R3
# USP13
# PIK3CA
# TP53
# EGFR
# PIK3CB
# PTK2
# USP7
# XIAP
# PTEN
# PREX2
# MAST2
# PIK3CD
# ROCK1
# SHC1
# NEDD4
# INPP4B
# PIK3R1
# AKT1

# %% [markdown]
# ## Format dataframe for analysis of the question

# %%
if question == "mutated_vs_wildtype":
    genedf = pd.DataFrame()
    for i in range(0, len(protein_list)):
        try:
            protdf = CPTAC.compare_mutations(dataframe, protein_list[i], gene)
            protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
            if i == 0:
                genedf = protdf
            else:
                #print(protdf)
                protdf = protdf.drop(gene+"_Mutation", axis=1)
                protdf = protdf.drop('Sample_Status', axis=1)
                #print("PROTDF: \n", protdf)
                genedf = genedf.join(protdf)
        except:
            pass
        
    print(genedf)

elif question == "truncation_vs_wildtype":
    pass

elif question == "hotspot_vs_wildtype":
    pass
# Out:
# Gene CSNK2A1 not found in phosphoproteomics data
# Gene PIK3R3 not found in phosphoproteomics data
# Gene PIK3CB not found in phosphoproteomics data
#       MDM2-S172  MDM2-T174      PTEN_Mutation Sample_Status  PDGFRB-S705  \
# S001    -0.4020        NaN  Nonsense_Mutation         Tumor          NaN
# S002        NaN        NaN  Missense_Mutation         Tumor       -0.369
# S003        NaN        NaN  Nonsense_Mutation         Tumor          NaN
# S005     0.2410        NaN  Missense_Mutation         Tumor          NaN
# S006        NaN    -0.2070     Wildtype_Tumor         Tumor       -1.860
# S007        NaN        NaN  Missense_Mutation         Tumor       -0.743
# S008     0.4880        NaN    Frame_Shift_Ins         Tumor          NaN
# S009        NaN     0.3110     Wildtype_Tumor         Tumor          NaN
# S010        NaN    -0.1350  Missense_Mutation         Tumor       -0.147
# S011        NaN        NaN    Frame_Shift_Ins         Tumor       -0.743
# S012     0.4360        NaN  Nonsense_Mutation         Tumor          NaN
# S014        NaN    -0.1580    Frame_Shift_Del         Tumor          NaN
# S016        NaN        NaN     Wildtype_Tumor         Tumor          NaN
# S017        NaN        NaN     Wildtype_Tumor         Tumor          NaN
# S018    -0.2280        NaN     Wildtype_Tumor         Tumor          NaN
# S019        NaN     0.4870    Frame_Shift_Del         Tumor          NaN
# S020    -0.5740        NaN  Missense_Mutation         Tumor          NaN
# S021        NaN     0.8310  Nonsense_Mutation         Tumor          NaN
# S022     0.3540        NaN  Nonsense_Mutation         Tumor          NaN
# S023     0.5210        NaN  Nonsense_Mutation         Tumor          NaN
# S024     0.3630        NaN  Nonsense_Mutation         Tumor          NaN
# S025    -0.2180        NaN    Frame_Shift_Del         Tumor          NaN
# S026     0.0153        NaN    Frame_Shift_Del         Tumor          NaN
# S027        NaN        NaN  Missense_Mutation         Tumor       -0.891
# S028        NaN     0.4280  Nonsense_Mutation         Tumor          NaN
# S029        NaN        NaN    Frame_Shift_Del         Tumor          NaN
# S030        NaN        NaN    Frame_Shift_Del         Tumor       -0.467
# S031    -0.3400        NaN     Wildtype_Tumor         Tumor          NaN
# S032        NaN        NaN  Nonsense_Mutation         Tumor          NaN
# S033    -0.1870        NaN  Nonsense_Mutation         Tumor          NaN
# ...         ...        ...                ...           ...          ...
# S073        NaN     0.1570  Missense_Mutation         Tumor       -3.010
# S074        NaN        NaN  Missense_Mutation         Tumor       -0.555
# S075        NaN        NaN  Missense_Mutation         Tumor          NaN
# S076        NaN        NaN    Frame_Shift_Del         Tumor       -0.369
# S077        NaN    -0.2140  Missense_Mutation         Tumor          NaN
# S078        NaN        NaN    Frame_Shift_Ins         Tumor          NaN
# S079     0.3320        NaN  Missense_Mutation         Tumor          NaN
# S080     0.1570        NaN    Frame_Shift_Ins         Tumor          NaN
# S081    -0.5500        NaN        Splice_Site         Tumor          NaN
# S082    -0.1790        NaN     Wildtype_Tumor         Tumor          NaN
# S083        NaN        NaN  Missense_Mutation         Tumor       -1.180
# S084     0.8020        NaN    Frame_Shift_Del         Tumor          NaN
# S085    -0.0487        NaN     Wildtype_Tumor         Tumor          NaN
# S086    -0.1840        NaN  Nonsense_Mutation         Tumor          NaN
# S087     0.6100        NaN  Missense_Mutation         Tumor          NaN
# S088     1.3900        NaN  Nonsense_Mutation         Tumor          NaN
# S090        NaN        NaN     Wildtype_Tumor         Tumor        2.100
# S091     0.0923        NaN  Nonsense_Mutation         Tumor          NaN
# S092     0.5310        NaN  Nonsense_Mutation         Tumor          NaN
# S093        NaN        NaN    Frame_Shift_Del         Tumor          NaN
# S094     0.1830        NaN  Missense_Mutation         Tumor          NaN
# S095    -0.0131        NaN  Nonsense_Mutation         Tumor          NaN
# S096        NaN     0.0109     Wildtype_Tumor         Tumor          NaN
# S097        NaN    -0.4500  Nonsense_Mutation         Tumor       -1.050
# S098        NaN     0.4700  Nonsense_Mutation         Tumor       -3.440
# S099     0.7670        NaN    Frame_Shift_Ins         Tumor          NaN
# S100        NaN     0.1480     Wildtype_Tumor         Tumor       -0.860
# S101        NaN     0.5590     Wildtype_Tumor         Tumor          NaN
# S102        NaN        NaN     Wildtype_Tumor         Tumor       -0.977
# S103    -0.1470        NaN     Wildtype_Tumor         Tumor          NaN
#
#       PDGFRB-S748  PDGFRB-Y751  PIK3R2-S263  PIK3R2-S688  PIK3R2-Y449  \
# S001     -0.95300          NaN     -0.31400          NaN          NaN
# S002      0.00000          NaN      1.31000          NaN          NaN
# S003          NaN          NaN      0.12900          NaN          NaN
# S005          NaN          NaN     -0.08400          NaN          NaN
# S006     -3.03000       -0.495     -1.04000          NaN          NaN
# S007     -0.27600          NaN      0.10200          NaN          NaN
# S008     -0.81100       -0.735      1.25000          NaN          NaN
# S009          NaN          NaN      0.27300          NaN       0.0000
# S010     -1.49000       -0.464     -0.01660          NaN          NaN
# S011          NaN          NaN     -0.55200          NaN          NaN
# S012     -2.13000       -0.853      0.12000          NaN          NaN
# S014     -0.24700       -0.926      0.48300          NaN          NaN
# S016          NaN          NaN     -0.13300          NaN          NaN
# S017          NaN          NaN      0.10600          NaN          NaN
# S018     -0.46600          NaN      0.16200          NaN          NaN
# S019      0.57100       -0.702      0.27800          NaN          NaN
# S020     -0.00449          NaN      1.03000          NaN          NaN
# S021          NaN          NaN      0.41400          NaN      -0.0893
# S022          NaN          NaN      0.40000          NaN          NaN
# S023          NaN          NaN      0.89800          NaN          NaN
# S024          NaN          NaN     -0.21800          NaN          NaN
# S025          NaN          NaN      0.00021          NaN          NaN
# S026     -0.31500          NaN     -0.00176          NaN          NaN
# S027          NaN          NaN     -0.34800          NaN          NaN
# S028          NaN          NaN     -0.52700          NaN      -0.3730
# S029          NaN          NaN      0.77500       1.1000          NaN
# S030     -1.36000          NaN      0.39700          NaN          NaN
# S031          NaN          NaN      0.42700          NaN          NaN
# S032          NaN          NaN      0.56200      -0.0368          NaN
# S033     -1.19000       -0.671      0.58000          NaN          NaN
# ...           ...          ...          ...          ...          ...
# S073      0.24800       -0.311     -0.90500          NaN          NaN
# S074          NaN          NaN     -0.87400          NaN          NaN
# S075          NaN          NaN     -0.02040          NaN          NaN
# S076          NaN          NaN     -0.84500          NaN          NaN
# S077      0.20300       -0.370      0.78500          NaN          NaN
# S078          NaN          NaN      0.18900          NaN          NaN
# S079          NaN          NaN     -0.54900          NaN          NaN
# S080          NaN          NaN          NaN          NaN          NaN
# S081          NaN          NaN     -0.44000          NaN          NaN
# S082          NaN          NaN      0.24300          NaN          NaN
# S083     -1.40000          NaN     -0.10500          NaN          NaN
# S084     -1.13000       -0.701      0.41500          NaN          NaN
# S085          NaN          NaN          NaN          NaN          NaN
# S086          NaN          NaN          NaN          NaN          NaN
# S087     -0.20400          NaN      1.15000          NaN          NaN
# S088          NaN          NaN      0.39200          NaN          NaN
# S090          NaN          NaN     -0.50500          NaN          NaN
# S091          NaN          NaN     -0.41000          NaN          NaN
# S092          NaN          NaN      1.38000          NaN          NaN
# S093          NaN          NaN     -0.01220      -0.3110          NaN
# S094          NaN          NaN     -0.45000          NaN          NaN
# S095          NaN          NaN     -0.30200          NaN          NaN
# S096     -0.03700       -0.381      0.25600          NaN          NaN
# S097     -0.41200       -0.209      0.56600          NaN          NaN
# S098     -1.33000       -0.696      0.39600          NaN          NaN
# S099          NaN          NaN      0.24600          NaN          NaN
# S100     -1.15000       -0.758     -0.55100          NaN          NaN
# S101     -0.06680       -0.636      0.05180          NaN          NaN
# S102     -0.10700          NaN      0.31900          NaN          NaN
# S103          NaN          NaN     -0.16900          NaN          NaN
#
#          ...      AKT1S1-S223  AKT1S1-S231  AKT1S1-S232  AKT1S1-S241  \
# S001     ...         0.260000     -0.09330     0.201500          NaN
# S002     ...        -0.169500      0.54900     0.927000          NaN
# S003     ...         0.128000          NaN    -0.844000          NaN
# S005     ...         0.365000     -0.10500    -0.264500          NaN
# S006     ...        -0.016840     -0.29165    -0.057300          NaN
# S007     ...        -0.088450      0.00000    -0.122000          NaN
# S008     ...         0.243000     -0.00950     0.352000          NaN
# S009     ...         0.265000      0.23600     0.250500          NaN
# S010     ...        -0.333000     -0.98500    -0.346000          NaN
# S011     ...         0.018150      0.06780     0.195000          NaN
# S012     ...         0.042100      0.69150     0.101700          NaN
# S014     ...        -0.246000     -0.36500    -0.177500     0.000067
# S016     ...         0.314000      0.76750     0.039500          NaN
# S017     ...        -0.440000          NaN    -2.100000          NaN
# S018     ...        -0.253000     -0.04300    -0.053600          NaN
# S019     ...         0.033000      0.03300     0.051950    -0.212000
# S020     ...        -0.250000      0.04810    -0.248500          NaN
# S021     ...        -0.303000      0.50000     0.080550          NaN
# S022     ...        -0.043150     -0.14015    -0.055950          NaN
# S023     ...        -0.124250     -0.27900    -0.124250          NaN
# S024     ...        -0.067650     -0.39200    -0.440000          NaN
# S025     ...        -0.274500      0.07020    -0.749500          NaN
# S026     ...         0.040500     -0.19600    -0.119250          NaN
# S027     ...        -0.110000      0.30100    -0.110000          NaN
# S028     ...         0.059700     -0.22300    -0.017665          NaN
# S029     ...         0.072100      0.40300     0.212000          NaN
# S030     ...         0.092050      0.25800    -0.087900          NaN
# S031     ...        -0.332000     -0.43000     0.017400          NaN
# S032     ...        -0.003580      0.17000    -0.003580          NaN
# S033     ...         0.001300      0.54800    -0.551000          NaN
# ...      ...              ...          ...          ...          ...
# S073     ...         0.116750      0.18600     0.065500          NaN
# S074     ...         0.168400      0.08680     0.031000          NaN
# S075     ...         0.496000          NaN     0.192000          NaN
# S076     ...        -0.206500      0.01730    -0.114750          NaN
# S077     ...        -0.066200     -0.06620     0.171500     0.744000
# S078     ...        -0.883000     -0.01011     0.072500          NaN
# S079     ...         0.222500      0.23700     0.156500          NaN
# S080     ...         0.345000      0.19555     0.047500          NaN
# S081     ...        -0.065700      0.00621    -0.612000          NaN
# S082     ...        -0.094850     -0.37535    -0.134000          NaN
# S083     ...         0.115250      0.17400     0.463000          NaN
# S084     ...        -0.046050      0.22415    -0.092750          NaN
# S085     ...        -0.000266     -0.40915     0.062000          NaN
# S086     ...         0.041500     -0.08750    -0.128500          NaN
# S087     ...        -0.070850      0.36700    -0.070850          NaN
# S088     ...         0.359500      0.05560     0.202000          NaN
# S090     ...         0.314500     -0.16100     0.332000          NaN
# S091     ...         0.774500     -0.03360     0.007200          NaN
# S092     ...         0.242500      0.29615     0.266500          NaN
# S093     ...         0.133000      0.33500     0.166000          NaN
# S094     ...         0.430500      0.67300    -0.083666          NaN
# S095     ...        -0.010050      0.06200     0.119000          NaN
# S096     ...         0.071300      0.34000    -0.136500    -0.174000
# S097     ...         0.016800     -0.12400    -0.044300          NaN
# S098     ...        -0.349000     -0.18700    -0.303000          NaN
# S099     ...        -0.305000     -0.26100    -0.640000          NaN
# S100     ...        -0.432000     -0.08000    -0.152000          NaN
# S101     ...        -0.002950      0.21900    -0.029875    -0.516000
# S102     ...        -0.168500      0.20000    -0.212000          NaN
# S103     ...         0.194850     -0.26900     0.079700          NaN
#
#       AKT1S1-S267  AKT1S1-T110  AKT1S1-T117  AKT1S1-T218  AKT1S1-T266  \
# S001    -0.000555     -0.22700          NaN          NaN          NaN
# S002          NaN      0.10250          NaN      -0.1520      2.17000
# S003          NaN      0.11000          NaN          NaN      1.77000
# S005          NaN      0.25300    -0.662000          NaN      1.09000
# S006     0.107000      0.21600          NaN          NaN     -1.91000
# S007          NaN      0.34450          NaN       0.1080     -0.57400
# S008          NaN     -0.16600     0.014100          NaN      0.89200
# S009          NaN     -0.56200    -0.114000          NaN     -0.25500
# S010    -0.415000     -0.62900          NaN          NaN     -0.59600
# S011     0.396000      0.00942     0.076150          NaN          NaN
# S012          NaN     -0.22500    -0.516000          NaN     -1.71000
# S014          NaN          NaN     0.560000          NaN     -1.83000
# S016          NaN      0.23000          NaN          NaN     -2.35000
# S017          NaN     -0.18800          NaN          NaN     -0.97200
# S018    -0.341000     -0.34300          NaN          NaN          NaN
# S019          NaN          NaN    -0.181000          NaN      1.35000
# S020     0.493000     -0.22700          NaN          NaN          NaN
# S021          NaN      0.09770    -0.083000          NaN     -0.19900
# S022          NaN     -0.46700     0.064500          NaN     -0.78000
# S023          NaN     -0.55100     0.246000          NaN      1.60000
# S024          NaN     -0.04500    -0.068050          NaN      0.17100
# S025          NaN      0.06070     0.193500          NaN     -0.33700
# S026     0.410000      0.00656          NaN          NaN          NaN
# S027     0.406000      0.51500    -0.182150          NaN          NaN
# S028          NaN     -0.06610    -0.015800          NaN      0.22700
# S029     0.169000          NaN          NaN          NaN      0.83500
# S030          NaN      0.55540          NaN       0.5610      0.64700
# S031    -1.730000      0.00622    -0.175890          NaN     -1.37000
# S032    -0.057500          NaN          NaN          NaN      0.43700
# S033          NaN     -0.08135    -0.537000          NaN     -0.83500
# ...           ...          ...          ...          ...          ...
# S073     0.100000      0.90400          NaN          NaN     -0.18200
# S074    -1.280000      0.45200     0.003000          NaN          NaN
# S075          NaN      0.45100          NaN          NaN      0.89100
# S076    -0.146000      0.27100     0.139335          NaN          NaN
# S077          NaN          NaN     0.264000          NaN      0.82900
# S078          NaN     -0.02040          NaN          NaN      0.52400
# S079          NaN      0.20500     0.482000          NaN     -1.82000
# S080          NaN          NaN     0.914000       0.4770     -1.77000
# S081          NaN      0.00057     0.149500          NaN     -2.20000
# S082          NaN     -0.07930     0.075900          NaN     -1.13000
# S083          NaN      0.28400          NaN       0.0871      0.24400
# S084          NaN     -0.11685    -0.038000          NaN     -0.48900
# S085          NaN          NaN     0.084700      -0.0903      0.36300
# S086          NaN          NaN    -0.000649       0.0000      0.78200
# S087          NaN     -1.18000     0.611000       0.2110     -1.22000
# S088          NaN      0.14000    -0.170000          NaN      1.42000
# S090     0.332000      0.50600     0.375000          NaN          NaN
# S091    -0.843000      0.58200     0.350500          NaN     -0.68000
# S092          NaN      0.96600    -0.163000          NaN      1.49000
# S093     0.049100          NaN          NaN          NaN      0.71100
# S094          NaN      0.32500     0.155000          NaN      0.71900
# S095     0.098300     -0.20700    -0.355500          NaN      0.32900
# S096          NaN          NaN    -0.460000          NaN     -0.00877
# S097     0.016000     -0.22800          NaN          NaN      0.22400
# S098    -0.063600     -0.75300          NaN          NaN     -2.36000
# S099          NaN     -0.01230    -0.102500          NaN      0.19900
# S100    -0.546000     -0.51800          NaN          NaN     -1.47000
# S101          NaN          NaN    -0.113000          NaN     -0.70400
# S102          NaN      0.95850          NaN       0.0000      0.04490
# S103    -0.859000      0.36300     0.099500          NaN     -0.38600
#
#       AKT1S1-T93
# S001         NaN
# S002         NaN
# S003         NaN
# S005   -0.353000
# S006         NaN
# S007         NaN
# S008         NaN
# S009   -0.545000
# S010         NaN
# S011         NaN
# S012         NaN
# S014         NaN
# S016         NaN
# S017         NaN
# S018         NaN
# S019         NaN
# S020         NaN
# S021   -0.290000
# S022    0.064500
# S023    0.246000
# S024   -0.115000
# S025   -0.000053
# S026         NaN
# S027         NaN
# S028   -0.062900
# S029   -0.065400
# S030         NaN
# S031         NaN
# S032   -0.128000
# S033         NaN
# ...          ...
# S073         NaN
# S074         NaN
# S075         NaN
# S076         NaN
# S077         NaN
# S078         NaN
# S079    0.482000
# S080         NaN
# S081    0.080000
# S082    0.075900
# S083         NaN
# S084         NaN
# S085         NaN
# S086         NaN
# S087   -0.272000
# S088    0.319000
# S090         NaN
# S091         NaN
# S092   -0.163000
# S093   -0.053800
# S094    0.297000
# S095         NaN
# S096         NaN
# S097         NaN
# S098         NaN
# S099   -0.037200
# S100         NaN
# S101         NaN
# S102         NaN
# S103         NaN
#
# [95 rows x 445 columns]
