# %% [markdown]
# # TP53: Effects of mutation in the hotspot compared to other mutations

# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
import math
import seaborn as sns
import CPTAC

# %%
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()
gene = 'TP53'
protein = 'TP53'

# %%
#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.P250L', 'p.R248W', 'p.S241C', 'p.S241del', 'p.K164E', 'p.R249S', 'p.R273H', 'p.R282W',
                    'p.S127Y', 'p.G244D', 'p.A159P']
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']
hotspot_patients
# Out:
# 586      S001
# 1318     S006
# 1404     S008
# 4019     S015
# 4089     S016
# 4736     S020
# 21307    S031
# 44973    S071
# 45005    S072
# 46785    S082
# 49867    S096
# 49948    S097
# Name: Clinical_Patient_Key, dtype: object

# %%
p53_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
p53_mutations['Within_Hotspot'] = False
p53_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
p53_mutations.loc[p53_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p53_mutations = p53_mutations.loc[p53_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)

# %% [markdown]
# ## Patients with mutation and patients with mutation in the hotspot

# %%
print(len(p53_mutations.loc[p53_mutations['Within_Hotspot'] != 'Wildtype']))
print(len(p53_mutations.loc[p53_mutations['Within_Hotspot'] == True]))
# Out:
# 22
# 12

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
mutated = p53_mutations.loc[p53_mutations['Within_Hotspot'] == True]
wt = p53_mutations.loc[p53_mutations['Within_Hotspot'] == False]
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=3.6073617624601573, pvalue=0.001758018256659298)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
mutated = p53_mutations.loc[p53_mutations['Within_Hotspot'] == True]
wt = p53_mutations.loc[p53_mutations['Within_Hotspot'] != True]
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=8.854794158768678, pvalue=9.722321381617046e-14)

# %% [markdown]
# ## All mutations vs wildtype

# %%
mutated = p53_mutations.loc[p53_mutations['Within_Hotspot'] != 'Wildtype']
wt = p53_mutations.loc[p53_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=5.68914108135854, pvalue=1.7272440363208252e-07)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p53_mutations, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = p53_mutations, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on TP53 abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %% [markdown]
# ### List of proteins that interact with TP53 (according to Uniprot and String)

# %%
protList = ['AIMP2', 'ARIH2', 'ARRB1', 'ASH2L', 'ATG7', 'AXIN1', 'BANP', 'BCL2', 'BCL2L1', 'BCR', 'BHLHE40', 'BRCA2',
           'BRD7', 'BTBD2', 'BTRC', 'CABLES1', 'CARM1', 'CCDC106', 'CDKN1A', 'CEBPB', 'CHD8', 'CREBBP', 'CSE1L', 'CSNK2A1', 'CUL7',
           'CUL9', 'CXXC1', 'DAXX', 'DDX17', 'DDX5', 'DROSHA', 'DUSP26', 'DVL2', 'E6', 'EP300', 'ETS2', 'FBXO11',
           'FOXO3', 'GSK3B', 'GTF2H1', 'HDAC1', 'HIPK1', 'HIPK2', 'HMGB1', 'HNRNPK', 'HRMT1L2', 'HSP82', 'HSPA1L', 'HSPA9', 'HSPB1',
           'HTT', 'HUWE1', 'IFI16', 'IFI205B', 'ING4', 'IKBKB', 'IP6K2', 'JMJD6', 'KAT5', 'KAT8', 'KDM1A', 'KMT2E', 'LAMA4',
           'MAGEA2B', 'MAGEC2', 'MAP1B', 'MAPK11', 'MAPKAPK5', 'MDM2', 'MDM4', 'MKRN1', 'MPDZ', 'MT1A', 'NCL', 'NCOR2',
           'NFYA', 'NFYB', 'NOC2L', 'NOL3', 'NPM1', 'NR0B2', 'NR4A1', 'NRDC', 'NSP1', 'NUAK1', 'NUMB', 'OTUB1', 
           'PARD3', 'PARP1', 'PBK', 'PHB', 'PIAS1', 'PIAS2', 'PIAS4', 'PIN1', 'PLK1', 'PML', 'PPIF', 'PPP1CC',
           'PPP1R13L', 'PPP2R1A', 'PPP2R5C', 'PRKCD', 'PSME3', 'PTK2', 'RAD51', 'RBPJ', 'RCHY1', 'RFWD3', 'RING1',
           'RPS3', 'RYBP', 'S100A1', 'S100A2', 'S100A4', 'S100B', 'SAFB', 'SETD7', 'SFN', 'SIN3A', 'SIRT1', 'SMAD2',
           'SMYD2', 'SNAT1', 'SOX4', 'SP1', 'SREBF2', 'SRPK1', 'SUMO1', 'SYVN1', 'TAF1', 'TBP', 'TCF4', 'TOE1', 'TP53BP1',
           'TP53BP2', 'TP53INP1', 'TP63', 'TPT1', 'TRIM24', 'TWIST1', 'UBC', 'UBE3A', 'UHRF2', 'USP42', 'USP7', 'VDR', 'VRK1',
           'WRN', 'WWOX', 'XPO1', 'XRCC6', 'YWHAG', 'YWHAZ', 'ZNF420', 'ATM', 'BAX', 'BCL2L11', 'CCNA1', 'CCNA2', 'CCNB1', 
           'CCNB2', 'CCND1', 'CCND3', 'CCNE1', 'CCNE2', 'CDC25A', 'CDC6', 'CDK2', 'CDKN1B', 'CDKN2A', 'CHEK1', 
           'CHEK2', 'CITED2', 'CKS1B', 'MCM5', 'MRE11A', 'PCNA', 'RB1', 'ARMC10', 'BANP', 'CDKN2AIP', 'NUAK1', 'STK11',
           'LKB1', 'UHRF2', 'E4F1', 'MAML1', 'MKRN1', 'PML', 'FBXO42', 'ATM', 'PP2A', 'PPP2R5C', 'PPP2R2A', 'AURKA', 'DAXX',
           'BRD7', 'TRIM24', 'L3MBTL1', 'GRK5', 'CAK', 'CDK7', 'MAT1', 'CDK5', 'AURKB', 'SETD2', 'UHRF2', 'NOC2L', 'PTK2',
           'FAK1', 'PTK2B', 'PYK2', 'PRKCG', 'PPIF', 'SNAI1', 'KAT6A', 'ANKRD2', 'RFFL', 'RNF34', 'MTA1', 'COP1', 'CCAR2',
           'MORC3', 'POU4F2', 'NOP53', 'AFG1L', 'UBD', 'TAF6', 'FATS', 'C10ORF90']

#Remove possible duplicates
protList = list(set(protList))

# %% [markdown]
# ## Mutations vs. wildtype

# %%
tested = [];
p_vals = [];
for protein in protList: 
    if protein in proteomics.columns:
        tested.append(protein)
        p53_mutations_protein = CPTAC.compare_mutations(proteomics, protein, gene)
        p53_mutations_protein['Within_Hotspot'] = False
        p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
        p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].dropna(axis=0)
        mutated = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] != 'Wildtype']
        wt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Wildtype']
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        p_vals.append(ttest[1])

# %%
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_vals)[0]
pvals = statsmodels.stats.multitest.fdrcorrection(p_vals)[1]
significant_proteins = np.array(tested)[np.array(areSignificant)]
significant_pvals = np.array(pvals)[np.array(areSignificant)]
significant_vals = dict(zip(significant_proteins, significant_pvals))
significant_vals
# Out:
# {'USP42': 0.03732795391764716,
#  'CCNA2': 0.00044117836853076555,
#  'CDK2': 0.006565715167679745,
#  'XPO1': 1.6340143799818682e-06,
#  'RFFL': 0.035578654732906154,
#  'CCNE1': 0.022618534907462202,
#  'DDX5': 0.03585343761111996,
#  'CCNB2': 0.015122549839890908,
#  'SETD2': 0.03954112730506962,
#  'BTBD2': 0.034969893846152775,
#  'CUL7': 0.03732795391764716,
#  'CHEK2': 0.002807990890903566,
#  'PIAS2': 0.03346436584593866,
#  'TP53BP2': 0.009680311531361712,
#  'MCM5': 0.00044117836853076555,
#  'NCL': 5.799392849153053e-05,
#  'SMYD2': 0.0034956131177343638,
#  'KAT8': 0.034969893846152775,
#  'CDKN2A': 0.0013795649700997779,
#  'CABLES1': 0.0002544087466645205,
#  'CKS1B': 0.003020832456121515,
#  'CCNB1': 0.0003127821533492124,
#  'CDKN1A': 0.007130554445348712,
#  'YWHAZ': 0.012992666372014754,
#  'CHEK1': 0.022187541659109165,
#  'AFG1L': 0.009680311531361712,
#  'CSNK2A1': 0.0019587351416321176,
#  'NOC2L': 0.00018362789160292323,
#  'PPP2R1A': 0.03585343761111996,
#  'PARP1': 0.009826767698999659,
#  'HUWE1': 0.0270946586175148,
#  'SFN': 0.017680091243939277,
#  'SETD7': 0.022618534907462202,
#  'PCNA': 0.0035065682715342016,
#  'SIN3A': 0.017680091243939277,
#  'CHD8': 0.00021061785946048498,
#  'AURKA': 0.000308746594768738,
#  'AURKB': 0.0016297855726348353,
#  'STK11': 0.00044117836853076555,
#  'DAXX': 0.00044117836853076555,
#  'PLK1': 0.00021035436952991212,
#  'VRK1': 4.5461247272489286e-05,
#  'ARIH2': 0.007214607237733933,
#  'CSE1L': 1.6340143799818682e-06,
#  'SUMO1': 0.005621544422381696,
#  'PPIF': 0.03732795391764716,
#  'PPP2R2A': 0.002590920138176642}

# %% [markdown]
# ## Mutations outside of hotspot vs. wildtype

# %%
tested = [];
p_vals = [];
for protein in protList: 
    if protein in proteomics.columns:
        p53_mutations_protein = CPTAC.compare_mutations(proteomics, protein, gene)
        p53_mutations_protein['Within_Hotspot'] = False
        p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
        p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].dropna(axis=0)
        mutated = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == False]
        wt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Wildtype']
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(math.isnan(ttest[0]) == False):
            print(ttest)
            print(protein)
            p_vals.append(ttest[1])
            tested.append(protein)
# Out:
# Ttest_indResult(statistic=0.932296438951492, pvalue=0.35379335280111834)
# LAMA4
# Ttest_indResult(statistic=-0.09659460363570012, pvalue=0.9233243664354203)
# BCL2L11
# Ttest_indResult(statistic=2.0778238490149636, pvalue=0.04070728994183849)
# ASH2L
# Ttest_indResult(statistic=0.016007513803884085, pvalue=0.9872654756450063)
# NCOR2
# Ttest_indResult(statistic=-0.19621805665651237, pvalue=0.8449024188037776)
# S100A4
# Ttest_indResult(statistic=-0.04720094945596443, pvalue=0.962462510103646)
# SMAD2
# Ttest_indResult(statistic=-0.8856962610785387, pvalue=0.37825107739463193)
# ATG7
# Ttest_indResult(statistic=-1.667653702594793, pvalue=0.09902206030274201)
# S100B
# Ttest_indResult(statistic=1.9024387049160203, pvalue=0.06100497100247946)
# USP42
# Ttest_indResult(statistic=0.511092490184502, pvalue=0.6105959313491418)
# IFI16
# Ttest_indResult(statistic=1.122000967225082, pvalue=0.26498494448338406)
# NFYA
# Ttest_indResult(statistic=-3.364842714970979, pvalue=0.001146016143392567)
# BCR
# Ttest_indResult(statistic=0.028374754587208957, pvalue=0.9774290016666444)
# NOL3
# Ttest_indResult(statistic=-2.563710650429921, pvalue=0.012093771322086255)
# TP53BP1
# Ttest_indResult(statistic=3.033432198008333, pvalue=0.003196611458506456)
# CCNA2
# Ttest_indResult(statistic=1.0381668568750273, pvalue=0.30210252500129614)
# CEBPB
# Ttest_indResult(statistic=-1.0422818820855662, pvalue=0.30020217711278546)
# PPP2R5C
# Ttest_indResult(statistic=2.465057240430557, pvalue=0.015687248110016712)
# CDK2
# Ttest_indResult(statistic=4.111323869279848, pvalue=8.96208216680376e-05)
# XPO1
# Ttest_indResult(statistic=-0.6202071758985502, pvalue=0.536761407500328)
# PPP1R13L
# Ttest_indResult(statistic=-0.5323466610914847, pvalue=0.5958586490841997)
# NFYB
# Ttest_indResult(statistic=0.8929850416864458, pvalue=0.3743572046839)
# HMGB1
# Ttest_indResult(statistic=-0.2563309818210862, pvalue=0.7983074573671382)
# BANP
# Ttest_indResult(statistic=2.008208196327799, pvalue=0.047759266120191504)
# KDM1A
# Ttest_indResult(statistic=1.232959552619629, pvalue=0.22095054412868004)
# TCF4
# Ttest_indResult(statistic=1.2812509610366594, pvalue=0.20354959559250446)
# TOE1
# Ttest_indResult(statistic=-0.7955414141597761, pvalue=0.42848894843386387)
# ING4
# Ttest_indResult(statistic=-2.239402132277492, pvalue=0.02770984637963307)
# CDKN2AIP
# Ttest_indResult(statistic=0.34775300318645974, pvalue=0.7289623832986506)
# GRK5
# Ttest_indResult(statistic=-0.516057935797714, pvalue=0.6071382613171226)
# MPDZ
# Ttest_indResult(statistic=-2.050294386788325, pvalue=0.043380802816823515)
# RFFL
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3157: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Ttest_indResult(statistic=-2.090780465668596, pvalue=0.0394989885942468)
# RCHY1
# Ttest_indResult(statistic=1.1329667129751408, pvalue=0.2603769862002375)
# CXXC1
# Ttest_indResult(statistic=1.828797195843383, pvalue=0.0711566873778732)
# CCNE1
# Ttest_indResult(statistic=2.084455065042965, pvalue=0.04008495419332045)
# DDX5
# Ttest_indResult(statistic=2.0517890919349324, pvalue=0.04487719760166331)
# CCNB2
# Ttest_indResult(statistic=0.9797082589303986, pvalue=0.32997818786606903)
# MTA1
# Ttest_indResult(statistic=0.38974515704758583, pvalue=0.6986944416811328)
# BTRC
# Ttest_indResult(statistic=2.2638788393610554, pvalue=0.026097898774567488)
# SETD2
# Ttest_indResult(statistic=-3.321789951219907, pvalue=0.0013144689813417865)
# UBE3A
# Ttest_indResult(statistic=0.004405453440929657, pvalue=0.9964951712668826)
# IKBKB
# Ttest_indResult(statistic=-2.3259145495645894, pvalue=0.022376380073996106)
# BTBD2
# Ttest_indResult(statistic=1.8676883775180397, pvalue=0.06521158041665771)
# CUL7
# Ttest_indResult(statistic=-0.08009214943278593, pvalue=0.9363500518309316)
# ATM
# Ttest_indResult(statistic=-0.1993730554988469, pvalue=0.84244157337333)
# AIMP2
# Ttest_indResult(statistic=0.6111634860354531, pvalue=0.5427034334125476)
# RNF34
# Ttest_indResult(statistic=0.5090996678953567, pvalue=0.6119861213076278)
# BCL2L1
# Ttest_indResult(statistic=-0.06340456279450458, pvalue=0.9495914934034444)
# HDAC1
# Ttest_indResult(statistic=2.2899074932416745, pvalue=0.02447478722697683)
# CHEK2
# Ttest_indResult(statistic=1.4463806961324497, pvalue=0.15170533264967287)
# ARRB1
# Ttest_indResult(statistic=-1.7496963779078918, pvalue=0.08373781399358513)
# ARMC10
# Ttest_indResult(statistic=-1.5905896480843247, pvalue=0.11537146607461887)
# HNRNPK
# Ttest_indResult(statistic=0.5531128887423687, pvalue=0.5816211202562052)
# KAT6A
# Ttest_indResult(statistic=-0.7671726522331247, pvalue=0.4452656244091564)
# NOP53
# Ttest_indResult(statistic=-0.8859944771095256, pvalue=0.3780912656532218)
# TRIM24
# Ttest_indResult(statistic=-0.3798966394559204, pvalue=0.704958706964596)
# HSPA1L
# Ttest_indResult(statistic=0.25276247951864705, pvalue=0.8010549420483319)
# GTF2H1
# Ttest_indResult(statistic=0.8112355844980295, pvalue=0.4194699118644891)
# PIAS2
# Ttest_indResult(statistic=1.1697220131239696, pvalue=0.2453444785760312)
# S100A1
# Ttest_indResult(statistic=3.088626730043581, pvalue=0.0027076747952961607)
# TP53BP2
# Ttest_indResult(statistic=2.649696684866083, pvalue=0.009586621913807427)
# MCM5
# Ttest_indResult(statistic=2.21477772049054, pvalue=0.029419021338022683)
# TAF6
# Ttest_indResult(statistic=-1.1267683853234562, pvalue=0.265013372141945)
# VDR
# Ttest_indResult(statistic=0.5297842791259312, pvalue=0.5976265930064082)
# USP7
# Ttest_indResult(statistic=0.622355856344578, pvalue=0.5353545579113685)
# DROSHA
# Ttest_indResult(statistic=-0.03371474354519916, pvalue=0.973182750005496)
# YWHAG
# Ttest_indResult(statistic=2.2373487579660165, pvalue=0.027848964846173985)
# MORC3
# Ttest_indResult(statistic=3.4283046395858974, pvalue=0.0009343362905735961)
# NCL
# Ttest_indResult(statistic=2.200002918119616, pvalue=0.030488244841323845)
# JMJD6
# Ttest_indResult(statistic=-0.5242692802726483, pvalue=0.6014399319912249)
# CUL9
# Ttest_indResult(statistic=-1.138965624389683, pvalue=0.2581165742175269)
# SOX4
# Ttest_indResult(statistic=-0.16110609129628448, pvalue=0.8723877050706358)
# SP1
# Ttest_indResult(statistic=0.19368478025172192, pvalue=0.8468794478107564)
# GSK3B
# Ttest_indResult(statistic=-1.605660932803338, pvalue=0.11201439974302642)
# CCAR2
# Ttest_indResult(statistic=0.6051386140740105, pvalue=0.5466804184568388)
# PTK2
# Ttest_indResult(statistic=-1.2805985148809216, pvalue=0.20377772763029858)
# PIN1
# Ttest_indResult(statistic=-2.2229265684257546, pvalue=0.028843463358245936)
# SMYD2
# Ttest_indResult(statistic=-0.485318883325245, pvalue=0.6286842299761952)
# S100A2
# Ttest_indResult(statistic=0.9151017464776936, pvalue=0.3626969657310568)
# EP300
# Ttest_indResult(statistic=3.038453231810936, pvalue=0.0031489588863922633)
# KAT8
# Ttest_indResult(statistic=-1.6136759426854794, pvalue=0.1102612806120927)
# MKRN1
# Ttest_indResult(statistic=1.060391227893115, pvalue=0.29193565861450044)
# CDK7
# Ttest_indResult(statistic=2.8283249938819695, pvalue=0.005820846762478147)
# CDKN2A
# Ttest_indResult(statistic=-4.423968731387337, pvalue=2.8235387818559618e-05)
# CABLES1
# Ttest_indResult(statistic=-1.153860062373439, pvalue=0.25991906722308744)
# CCDC106
# Ttest_indResult(statistic=1.366071191036664, pvalue=0.17547830031485362)
# SIRT1
# Ttest_indResult(statistic=-1.6478330615228516, pvalue=0.10303597454233772)
# NUMB
# Ttest_indResult(statistic=1.3467905700171976, pvalue=0.18158619121193942)
# WRN
# Ttest_indResult(statistic=2.2602359954028235, pvalue=0.026524710828102482)
# CKS1B
# Ttest_indResult(statistic=-0.26108126773315626, pvalue=0.7946540316675723)
# RBPJ
# Ttest_indResult(statistic=-0.9881435721393703, pvalue=0.3258543650509229)
# COP1
# Ttest_indResult(statistic=-1.63150251171324, pvalue=0.10644114519953532)
# CDK5
# Ttest_indResult(statistic=1.1553676529638681, pvalue=0.2511398628379626)
# CREBBP
# Ttest_indResult(statistic=-2.052162234980983, pvalue=0.04319474882686739)
# XRCC6
# Ttest_indResult(statistic=1.191541451452575, pvalue=0.23671905274006735)
# PPP1CC
# Ttest_indResult(statistic=3.1794584828554013, pvalue=0.0020516556219254737)
# CCNB1
# Ttest_indResult(statistic=-2.4943049400997253, pvalue=0.014680663557222758)
# CDKN1A
# Ttest_indResult(statistic=-0.7852082072658548, pvalue=0.43653925979187425)
# NR4A1
# Ttest_indResult(statistic=1.5634396334253724, pvalue=0.12162172902584413)
# YWHAZ
# Ttest_indResult(statistic=0.509826849886185, pvalue=0.611478675065263)
# E4F1
# Ttest_indResult(statistic=0.7189867734556521, pvalue=0.47409817624443296)
# NPM1
# Ttest_indResult(statistic=0.7504837474732404, pvalue=0.4550118602614417)
# SYVN1
# Ttest_indResult(statistic=0.4326518140649409, pvalue=0.6663507853175478)
# DDX17
# Ttest_indResult(statistic=0.03661216612526489, pvalue=0.9708790937421125)
# PSME3
# Ttest_indResult(statistic=0.6143291482949312, pvalue=0.5406196916712971)
# HSPA9
# Ttest_indResult(statistic=2.042742533594202, pvalue=0.04414007272138252)
# CHEK1
# Ttest_indResult(statistic=0.09033177370905178, pvalue=0.9282336277132255)
# HSPB1
# Ttest_indResult(statistic=-0.6020452192264392, pvalue=0.5487280424740224)
# RING1
# Ttest_indResult(statistic=-0.5090243715914241, pvalue=0.6120386758302689)
# PTK2B
# Ttest_indResult(statistic=0.33914092423791414, pvalue=0.738223226520861)
# MT1A
# Ttest_indResult(statistic=1.8865239132818739, pvalue=0.06259890039473413)
# RYBP
# Ttest_indResult(statistic=-0.60652172458589, pvalue=0.5546128555911549)
# ANKRD2
# Ttest_indResult(statistic=-2.0173056908030715, pvalue=0.046975657460174174)
# AFG1L
# Ttest_indResult(statistic=3.0359483734721553, pvalue=0.0031726485068450123)
# CSNK2A1
# Ttest_indResult(statistic=3.7457765581055766, pvalue=0.00032458742394252533)
# NOC2L
# Ttest_indResult(statistic=-0.4603052991476021, pvalue=0.6465458208016726)
# BCL2
# Ttest_indResult(statistic=-1.752881247852129, pvalue=0.0831860316593041)
# PPP2R1A
# Ttest_indResult(statistic=2.1207196835205018, pvalue=0.036824848548101155)
# PARP1
# Ttest_indResult(statistic=1.7710761747258963, pvalue=0.08009093668760074)
# PBK
# Ttest_indResult(statistic=1.347730321440532, pvalue=0.18128481378051853)
# HUWE1
# Ttest_indResult(statistic=-0.6812555884204133, pvalue=0.4984683075933263)
# BHLHE40
# Ttest_indResult(statistic=-2.754466421993031, pvalue=0.007173405974802093)
# SFN
# Ttest_indResult(statistic=-0.6393047678041172, pvalue=0.5243239336939182)
# MAP1B
# Ttest_indResult(statistic=-1.010590680258693, pvalue=0.3150472914055887)
# SETD7
# Ttest_indResult(statistic=-0.7685906039451941, pvalue=0.44615147118908804)
# CCND1
# Ttest_indResult(statistic=-1.4577099856618232, pvalue=0.1485626200926232)
# BAX
# Ttest_indResult(statistic=-0.32391459535978007, pvalue=0.7467891341378098)
# FBXO42
# Ttest_indResult(statistic=1.01624915665145, pvalue=0.3123612921308272)
# NRDC
# Ttest_indResult(statistic=-1.821670672498962, pvalue=0.07198162403645232)
# PIAS1
# Ttest_indResult(statistic=1.0987513058600227, pvalue=0.27494308518406685)
# WWOX
# Ttest_indResult(statistic=0.5607486713264614, pvalue=0.5764269417751986)
# CARM1
# Ttest_indResult(statistic=2.4234344856792576, pvalue=0.017470992731544753)
# PCNA
# Ttest_indResult(statistic=-0.9741512837189361, pvalue=0.3327135667441117)
# UHRF2
# Ttest_indResult(statistic=-0.0792626206854341, pvalue=0.9370078830802546)
# PIAS4
# Ttest_indResult(statistic=1.430881825260471, pvalue=0.15608781418356174)
# SIN3A
# Ttest_indResult(statistic=4.664238375466207, pvalue=1.1265288049536583e-05)
# CHD8
# Ttest_indResult(statistic=1.2612099581410856, pvalue=0.21064373400006048)
# PRKCD
# Ttest_indResult(statistic=1.0394155484180976, pvalue=0.30152501147393596)
# TBP
# Ttest_indResult(statistic=2.0739848149758835, pvalue=0.04245395436748278)
# AURKA
# Ttest_indResult(statistic=3.0221157646435066, pvalue=0.003625930075232975)
# AURKB
# Ttest_indResult(statistic=-0.8036494987022784, pvalue=0.4238151831561249)
# CDKN1B
# Ttest_indResult(statistic=0.8538334590499241, pvalue=0.3955693292407412)
# HTT
# Ttest_indResult(statistic=0.4135620384838742, pvalue=0.6802243567176927)
# SRPK1
# Ttest_indResult(statistic=-1.3475941872841537, pvalue=0.1813284484684133)
# KMT2E
# Ttest_indResult(statistic=1.923759732855545, pvalue=0.05769260796391119)
# PHB
# Ttest_indResult(statistic=1.1788667038996343, pvalue=0.2417025669771827)
# BRD7
# Ttest_indResult(statistic=0.585231084674539, pvalue=0.5599248228834911)
# TPT1
# Ttest_indResult(statistic=-2.8075139508557374, pvalue=0.006269643728671678)
# STK11
# Ttest_indResult(statistic=2.5702205803317737, pvalue=0.011885061439082363)
# TAF1
# Ttest_indResult(statistic=2.506668739589993, pvalue=0.014068708746926074)
# DAXX
# Ttest_indResult(statistic=2.0219535854743937, pvalue=0.04628941909160449)
# FBXO11
# Ttest_indResult(statistic=3.5721587701355477, pvalue=0.00058290128486444)
# PLK1
# Ttest_indResult(statistic=0.6315330292848393, pvalue=0.5293671601106429)
# KAT5
# Ttest_indResult(statistic=-0.2478149200386671, pvalue=0.8048683386902415)
# MAPKAPK5
# Ttest_indResult(statistic=0.1700301087920335, pvalue=0.8653858078249727)
# RB1
# Ttest_indResult(statistic=-0.5336921810040695, pvalue=0.5949312651458339)
# RPS3
# Ttest_indResult(statistic=1.0032294596238043, pvalue=0.3185646081817696)
# PARD3
# Ttest_indResult(statistic=-1.322154040995003, pvalue=0.19089724145210185)
# AXIN1
# Ttest_indResult(statistic=3.7334596002458036, pvalue=0.00033854382718073934)
# VRK1
# Ttest_indResult(statistic=2.859509985753311, pvalue=0.005323451620756408)
# ARIH2
# Ttest_indResult(statistic=2.5229193722981287, pvalue=0.013478468091871101)
# OTUB1
# Ttest_indResult(statistic=-1.4856832513483855, pvalue=0.14101962441947669)
# SAFB
# Ttest_indResult(statistic=5.175179651778699, pvalue=1.4724145887007936e-06)
# CSE1L
# Ttest_indResult(statistic=0.6528108300956078, pvalue=0.5164139667623782)
# SREBF2
# Ttest_indResult(statistic=2.3731876327614803, pvalue=0.019863828481871803)
# SUMO1
# Ttest_indResult(statistic=0.3991121258815286, pvalue=0.6907999415851782)
# FOXO3
# Ttest_indResult(statistic=1.7906055095977338, pvalue=0.07687542152812782)
# PPIF
# Ttest_indResult(statistic=-3.6120046569639226, pvalue=0.0005103925428113893)
# PPP2R2A
# Ttest_indResult(statistic=0.84574995241479, pvalue=0.400039293315811)
# DVL2
# Ttest_indResult(statistic=-2.285581454399608, pvalue=0.024738227069548323)
# PML
# Ttest_indResult(statistic=2.520370359803996, pvalue=0.013569553632386494)
# MAML1

# %%
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_vals)[0]
pvals = statsmodels.stats.multitest.fdrcorrection(p_vals)[1]
significant_proteins = np.array(tested)[np.array(areSignificant)]
significant_pvals = np.array(pvals)[np.array(areSignificant)]
significant_vals = dict(zip(significant_proteins, significant_pvals))
significant_vals
# Out:
# {'BCR': 0.019596876052012897,
#  'CCNA2': 0.034163784962787755,
#  'XPO1': 0.003831290126308608,
#  'UBE3A': 0.020434017800858684,
#  'TP53BP2': 0.034163784962787755,
#  'NCL': 0.01775238952089833,
#  'KAT8': 0.034163784962787755,
#  'CABLES1': 0.0016094171056578984,
#  'CCNB1': 0.029236092612438,
#  'CSNK2A1': 0.034163784962787755,
#  'NOC2L': 0.009648499074651071,
#  'CHD8': 0.0009631821282353779,
#  'AURKB': 0.03647259075675522,
#  'PLK1': 0.012459514963977406,
#  'VRK1': 0.009648499074651071,
#  'CSE1L': 0.00025178289466783573,
#  'PPP2R2A': 0.012459514963977406}

# %% [markdown]
# ## Mutations within the hotspot vs. wildtype

# %%
tested = [];
p_vals = [];
for protein in protList: 
    if protein in proteomics.columns:
        tested.append(protein)
        p53_mutations_protein = CPTAC.compare_mutations(proteomics, protein, gene)
        p53_mutations_protein['Within_Hotspot'] = False
        p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
        p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].dropna(axis=0)
        mutated = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == True]
        wt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Wildtype']
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        p_vals.append(ttest[1])

# %%
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_vals)[0]
pvals = statsmodels.stats.multitest.fdrcorrection(p_vals)[1]
significant_proteins = np.array(tested)[np.array(areSignificant)]
significant_pvals = np.array(pvals)[np.array(areSignificant)]
significant_vals = dict(zip(significant_proteins, significant_pvals))
significant_vals
# Out:
# {'CCNA2': 0.011088052992706597,
#  'CDK2': 0.030836516442258894,
#  'XPO1': 0.0001542832619132732,
#  'CHEK2': 0.008982748870779272,
#  'PIAS2': 0.009305591376536596,
#  'MCM5': 0.0046684867754829195,
#  'NCL': 0.00048127530150969474,
#  'SMYD2': 0.019118786418129596,
#  'CDKN2A': 0.008837525079927331,
#  'CABLES1': 0.025814447810164422,
#  'CKS1B': 0.011370919861456392,
#  'CCNB1': 0.008982748870779272,
#  'YWHAZ': 0.008982748870779272,
#  'AFG1L': 0.025814447810164422,
#  'CSNK2A1': 0.019418357139259077,
#  'NOC2L': 0.008982748870779272,
#  'PARP1': 0.0409995250286024,
#  'HUWE1': 0.025814447810164422,
#  'SETD7': 0.008982748870779272,
#  'PCNA': 0.025814447810164422,
#  'SIN3A': 0.019418357139259077,
#  'CHD8': 0.025814447810164422,
#  'AURKA': 0.0001542832619132732,
#  'AURKB': 0.019956228495787647,
#  'STK11': 0.007243389519709484,
#  'DAXX': 0.0014712262797893973,
#  'PLK1': 0.007593084040583257,
#  'VRK1': 0.0006042042654633952,
#  'SAFB': 0.01841825152793894,
#  'CSE1L': 0.0006042042654633952,
#  'SUMO1': 0.019956228495787647}

# %% [markdown]
# ## Mutations within the hotspot vs. other mutations

# %%
tested = [];
p_vals = [];
for protein in protList: 
    if protein in proteomics.columns:
        tested.append(protein)
        p53_mutations_protein = CPTAC.compare_mutations(proteomics, protein, gene)
        p53_mutations_protein['Within_Hotspot'] = False
        p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
        p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].dropna(axis=0)
        mutated = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == True]
        wt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == False]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        p_vals.append(ttest[1])
# Out:
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3157: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_vals)[0]
pvals = statsmodels.stats.multitest.fdrcorrection(p_vals)[1]
significant_proteins = np.array(tested)[np.array(areSignificant)]
significant_pvals = np.array(pvals)[np.array(areSignificant)]
significant_vals = dict(zip(significant_proteins, significant_pvals))
significant_vals
# Out:
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/statsmodels/stats/multitest.py:320: RuntimeWarning: invalid value encountered in less_equal
#   reject = pvals_sorted <= ecdffactor*alpha
# {}

# %% [markdown]
# ## Single protein plot

# %%
plt_protein = 'AURKA'
pltdf = CPTAC.compare_mutations(proteomics, plt_protein, gene)
pltdf['Within_Hotspot'] = False
pltdf.loc[hotspot_patients, 'Within_Hotspot'] = True
pltdf.loc[pltdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
pltdf = pltdf.loc[pltdf['Patient_Type'] == 'Tumor'].dropna(axis=0)

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = pltdf, x = 'Within_Hotspot', y = plt_protein, ax = ax)
boxplt = sns.stripplot(data = pltdf, x = 'Within_Hotspot', y = plt_protein, jitter = True, color = '.3')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
boxplt.set_title("Effect of TP53 mutation on " + plt_protein + " protein levels", fontsize='22')
plt.show()

# %% [markdown]
# ## Plot all significant proteins

# %%
proteins_to_plot = ['HSP90AB1', 'STK11', 'YWHAZ', 'AURKA', 'DAXX', 'AFG1L', 'CDK2', 'CABLES1', 'CHD8', 'CDKN2AIP', 
                    'FAS', 'CDKN2A', 'CCNB1', 'TAF1']

plotdf = CPTAC.compare_mutations(proteomics, gene)
plotdf = plotdf.loc[plotdf['Patient_Type'] == 'Tumor'][[gene, 'Mutation']]
for protein in proteins_to_plot:
    proteindf = CPTAC.compare_mutations(proteomics, protein, gene)[[protein]]
    plotdf = plotdf.join(proteindf)

plotdf['Within_Hotspot'] = False
plotdf.loc[hotspot_patients, 'Within_Hotspot'] = True
plotdf.loc[plotdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
plotdf = pd.melt(plotdf, id_vars = ['Mutation', 'Within_Hotspot'], var_name = 'Protein', value_name = 'Proteomics')
plotdf = plotdf.dropna(axis = 0)

# %%
a4_dims = (23.4, 16.54)
fig, ax = plt.subplots(figsize=a4_dims)
my_pal = {True: "#6C906D", "Wildtype": "#596B94", False: "#A35857"}

#Create the plot
boxplt = sns.boxplot(x='Protein', y='Proteomics', hue='Within_Hotspot', data=plotdf, palette = my_pal)
boxplt = sns.stripplot(data=plotdf, x='Protein', y='Proteomics', hue='Within_Hotspot', dodge=True, jitter=True, color='.3')

#Add styling
boxplt.set_xlabel('')
boxplt.set_ylabel('Protein Level', fontsize='40')
boxplt.tick_params(labelsize='20')

#Adjust legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], [True, 'Wildtype', False], title='Mutation Within Hotspot', fontsize='20', frameon=False)
boxplt.get_legend().get_title().set_fontsize('20')
#boxplt.get_legend().set_bbox_to_anchor((0.15, 0.15, 0, 0))

# %% [markdown]
# ## Clean up the figure

# %%
proteins_to_plot = ['AURKA', 'CDK2', 'CABLES1', 'STK11']

plotdf = CPTAC.compare_mutations(proteomics, gene)
plotdf = plotdf.loc[plotdf['Patient_Type'] == 'Tumor'][[gene, 'Mutation']]
for protein in proteins_to_plot:
    proteindf = CPTAC.compare_mutations(proteomics, protein, gene)[[protein]]
    plotdf = plotdf.join(proteindf)

plotdf['Within_Hotspot'] = 'Outside Hotspot'
plotdf.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
plotdf.loc[plotdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
plotdf = pd.melt(plotdf, id_vars = ['Mutation', 'Within_Hotspot'], var_name = 'Protein', value_name = 'Proteomics')
plotdf = plotdf.dropna(axis = 0)

a4_dims = (23.4, 16.54)
fig, ax = plt.subplots(figsize=a4_dims)
my_pal = {'Within Hotspot': "#6C906D", "Wildtype": "#596B94", 'Outside Hotspot': "#A35857"}

#Create the plot
boxplt = sns.boxplot(x='Protein', y='Proteomics', hue='Within_Hotspot', data=plotdf, palette = my_pal)
boxplt = sns.stripplot(data=plotdf, x='Protein', y='Proteomics', hue='Within_Hotspot', dodge=True, jitter=True, color='.3')

#Add styling
boxplt.set_xlabel('Protein Name', fontsize='35')
boxplt.set_ylabel('Expression Level', fontsize='35')
boxplt.tick_params(labelsize='20')

#Adjust legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], ['Within Hotspot', 'Wildtype', 'Outside Hotspot'], title='Location of TP53 Mutation', fontsize='20', frameon=False)
boxplt.get_legend().get_title().set_fontsize('23')
plt.show()

fig = boxplt.get_figure()
fig.savefig('p53_hotspot.pdf', dpi=300)

# %% [markdown]
# # Phosphoproteomic Analysis

# %% [markdown]
# ## All mutations vs wildtype

# %%
sites = phos.columns
p_values = []
site_names = []

for protein in protList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
        phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis=1)
        phosphositesdf['Within_Hotspot'] = False
        phosphositesdf.loc[hotspot_patients, 'Within_Hotspot'] = True
        phosphositesdf.loc[phosphositesdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        phosphositesdf.drop('Mutation', axis=1)
        for site in phosphositesdf.columns:
            if (site != 'Within_Hotspot' and site != 'Mutation'):
                sitedf = phosphositesdf[[site, 'Within_Hotspot']].dropna(axis=0)
                mutated = sitedf.loc[sitedf['Within_Hotspot'] != 'Wildtype']
                wt = sitedf.loc[sitedf['Within_Hotspot'] == 'Wildtype']
                ttest = scipy.stats.ttest_ind(mutated[site], wt[site])
                p_values.append(ttest[1])
                site_names.append(site)
                
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvals = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_proteins = np.array(site_names)[np.array(areSignificant)]
significant_pvals = np.array(pvals)[np.array(areSignificant)]
significant_vals = dict(zip(significant_proteins, significant_pvals))
significant_vals
# Out:
# {'BCL2L12-S273': 0.01595262598239566,
#  'CLASP1-S572': 0.012982087946777021,
#  'CTDSP1-T74': 0.032625891703090396,
#  'LASP1-T104': 0.032933589316956446,
#  'SP100-S157': 0.00010674105443492965,
#  'SP100-S223': 0.004112207588010277,
#  'SP100-S228': 0.0026881513503528814,
#  'SP100-S231': 4.679164997306459e-05,
#  'SP110-S244': 0.0026881513503528814,
#  'SP110-S380': 0.004112207588010277,
#  'USP11-S648': 0.009217027484735641,
#  'RYBP-S193': 0.020067029266601363,
#  'NOC2L-S49': 0.0009882801246996684,
#  'NOC2L-S56': 0.006364124261150357,
#  'FOXO3-S43': 0.0016182401268920261,
#  'CHD8-S549': 0.030286647174017287,
#  'NPM1-S70': 0.038878505182900966,
#  'TP53BP1-S1004': 0.032625891703090396,
#  'TP53BP1-S1431': 0.0008643140003929224,
#  'TP53BP1-S1435': 0.0008643140003929224,
#  'TP53BP1-S1683': 0.0009882801246996684,
#  'TP53BP1-S1706': 7.899210519341453e-05,
#  'TP53BP1-S1763': 6.901183518862966e-07,
#  'TP53BP1-S1764': 0.0026881513503528814,
#  'TP53BP1-S403': 0.032625891703090396,
#  'TP53BP1-S640': 0.04139829057587989,
#  'TP53BP1-S867': 0.0030048347848826654,
#  'PLK1-T210': 0.0026881513503528814,
#  'CREBBP-T974': 0.009217027484735641,
#  'NCL-S619': 0.00012500884984881675,
#  'NCL-S67': 9.942767345260665e-06,
#  'PARP1-S782': 0.014140455703340167}

# %% [markdown]
# ## Mutations within hotspot vs wildtype

# %%
sites = phos.columns
p_values = []
site_names = []

for protein in protList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
        phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis=1)
        phosphositesdf['Within_Hotspot'] = False
        phosphositesdf.loc[hotspot_patients, 'Within_Hotspot'] = True
        phosphositesdf.loc[phosphositesdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        phosphositesdf.drop('Mutation', axis=1)
        for site in phosphositesdf.columns:
            if (site != 'Within_Hotspot' and site != 'Mutation'):
                sitedf = phosphositesdf[[site, 'Within_Hotspot']].dropna(axis=0)
                mutated = sitedf.loc[sitedf['Within_Hotspot'] == True]
                wt = sitedf.loc[sitedf['Within_Hotspot'] == 'Wildtype']
                ttest = scipy.stats.ttest_ind(mutated[site], wt[site])
                p_values.append(ttest[1])
                site_names.append(site)
                
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvals = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_proteins = np.array(site_names)[np.array(areSignificant)]
significant_pvals = np.array(pvals)[np.array(areSignificant)]
significant_vals = dict(zip(significant_proteins, significant_pvals))
significant_vals
# Out:
# {'PIAS2-S499': 0.04594812104477181,
#  'CLASP1-S572': 0.005185397859035873,
#  'SP100-S157': 0.009311601609255192,
#  'SP100-S223': 0.001681146675364001,
#  'SP100-S228': 0.01084611970435412,
#  'SP100-S231': 0.0002414574679697111,
#  'SP110-S244': 0.00022715594852941022,
#  'SP110-S380': 0.013026843951616126,
#  'USP11-S648': 0.0219367226210614,
#  'RYBP-S190': 0.003466463721526021,
#  'RYBP-S193': 0.007259414870953549,
#  'NOC2L-S49': 0.03537019612696443,
#  'FOXO3-S43': 0.019025958067335855,
#  'HUWE1-S3808': 0.023035547134485423,
#  'HUWE1-S3818': 0.022558704623591275,
#  'TP53BP1-S1431': 0.0011162671079661052,
#  'TP53BP1-S1435': 0.001501726880253013,
#  'TP53BP1-S1683': 0.021475996183742276,
#  'TP53BP1-S1706': 0.0002414574679697111,
#  'TP53BP1-S1763': 0.0005262666326208138,
#  'TP53BP1-S227': 0.01490006977908907,
#  'TP53BP1-S867': 0.005189706313447883,
#  'CREBBP-T974': 0.040748452536135515,
#  'NCL-S619': 2.8857022530986562e-05,
#  'NCL-S67': 0.0002414574679697111}

# %% [markdown]
# ## Mutations outside of hotspot vs wildtype

# %%
sites = phos.columns
p_values = []
site_names = []

for protein in protList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
        phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis=1)
        phosphositesdf['Within_Hotspot'] = False
        phosphositesdf.loc[hotspot_patients, 'Within_Hotspot'] = True
        phosphositesdf.loc[phosphositesdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        phosphositesdf.drop('Mutation', axis=1)
        for site in phosphositesdf.columns:
            if (site != 'Within_Hotspot' and site != 'Mutation'):
                sitedf = phosphositesdf[[site, 'Within_Hotspot']].dropna(axis=0)
                mutated = sitedf.loc[sitedf['Within_Hotspot'] == False]
                wt = sitedf.loc[sitedf['Within_Hotspot'] == 'Wildtype']
                ttest = scipy.stats.ttest_ind(mutated[site], wt[site])
                p_values.append(ttest[1])
                site_names.append(site)
                
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvals = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_proteins = np.array(site_names)[np.array(areSignificant)]
significant_pvals = np.array(pvals)[np.array(areSignificant)]
significant_vals = dict(zip(significant_proteins, significant_pvals))
significant_vals
# Out:
# {'SP100-S157': 0.01926525300150349,
#  'TP53BP1-S1763': 3.730212327832176e-05,
#  'NCL-S67': 0.01926525300150349}

# %% [markdown]
# ## Mutations outside of hotspot vs mutations within hotspot

# %%
sites = phos.columns
p_values = []
site_names = []

for protein in protList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
        phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis=1)
        phosphositesdf['Within_Hotspot'] = False
        phosphositesdf.loc[hotspot_patients, 'Within_Hotspot'] = True
        phosphositesdf.loc[phosphositesdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        phosphositesdf.drop('Mutation', axis=1)
        for site in phosphositesdf.columns:
            if (site != 'Within_Hotspot' and site != 'Mutation'):
                sitedf = phosphositesdf[[site, 'Within_Hotspot']].dropna(axis=0)
                mutated = sitedf.loc[sitedf['Within_Hotspot'] == False]
                wt = sitedf.loc[sitedf['Within_Hotspot'] == True]
                ttest = scipy.stats.ttest_ind(mutated[site], wt[site])
                p_values.append(ttest[1])
                site_names.append(site)
                
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvals = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_proteins = np.array(site_names)[np.array(areSignificant)]
significant_pvals = np.array(pvals)[np.array(areSignificant)]
significant_vals = dict(zip(significant_proteins, significant_pvals))
significant_vals
# Out:
# {}
