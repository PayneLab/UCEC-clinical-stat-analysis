# %% [markdown]
# # TP53: Poster Figures for UCUR 2018

# %% [markdown]
# ### Standard imports and loading data

# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import CPTAC.Endometrial as CPTAC
# Out:
# Loading Endometrial CPTAC data:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter embargo() to open the webpage for more details.

# %%
somatic_mutations = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()
gene = 'TP53'

# %% [markdown]
# ### Identify patients with mutation within the hotspt

# %%
hotspot_mutations = ['p.P250L', 'p.R248W', 'p.S241C', 'p.241del','p.K164E', 'p.R249S', 'p.R273H', 'p.R282W',
                    'p.S127Y', 'p.G244D', 'p.A159P']
mutated_hotspot = somatic_mutations.loc[(somatic_mutations['Location'].isin(hotspot_mutations)) & (somatic_mutations['Gene'] == gene)]
# Get a list of patient identifiers for those who have mutations in the hotspot
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

# %% [markdown]
# ## TP53 Hotspot Cis Effects

# %% [markdown]
# ### Build dataframe for plotting

# %%
proteomicsdf = CPTAC.compare_mutations(proteomics, gene)
proteomicsdf = proteomicsdf.loc[proteomicsdf['Patient_Type'] == 'Tumor'][[gene, 'Mutation']]
phosdf = CPTAC.compare_mutations(phos, gene)
phosdf = phosdf.loc[phosdf['Patient_Type'] == 'Tumor'][['TP53-S315']]
plotdf = proteomicsdf.join(phosdf)
plotdf['TP53 Mutation Location'] = 'Outside Hotspot'
plotdf.loc[hotspot_patients, 'TP53 Mutation Location'] = 'Within Hotspot'
plotdf.loc[plotdf['Mutation'] == 'Wildtype', 'TP53 Mutation Location'] = 'Wildtype'
plotdf = pd.melt(plotdf, id_vars=['TP53 Mutation Location'], value_vars=['TP53', 'TP53-S315'], var_name='Type', value_name='Reading')
plotdf = plotdf.dropna(axis = 0)
plotdf.head(5)
# Out:
#   TP53 Mutation Location  Type  Reading
# 0         Within Hotspot  TP53    0.295
# 1               Wildtype  TP53    0.277
# 2               Wildtype  TP53   -0.871
# 3        Outside Hotspot  TP53    1.430
# 4               Wildtype  TP53   -0.343

# %% [markdown]
# ### Create and style figure

# %%
a4_dims = (23.4, 18.4)
fig, ax = plt.subplots(figsize=a4_dims)
my_pal = {"Within Hotspot": "#007acc", "Wildtype": "#ac3973", "Outside Hotspot": "#29a329"}

#Create the plot
boxplt = sns.boxplot(x='Type', y='Reading', hue='TP53 Mutation Location', data=plotdf, palette = my_pal)
boxplt = sns.stripplot(data=plotdf, x='Type', y='Reading', hue='TP53 Mutation Location', dodge=True, jitter=True, color='.3', size=7)

#Add styling
boxplt.set_title("Effect of TP53 mutation on p53", fontsize='40')
boxplt.set_xlabel('')
boxplt.set_ylabel('Relative Abundance', fontsize='30')
boxplt.set_xticklabels(['p53 Protein', 'p53-S315 Phosphorylation'])
boxplt.tick_params(labelsize='20')

#Adjust legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], ['Within Hotspot', 'Wildtype', 'Outside Hotspot'], title='TP53 Status', fontsize='20', frameon=False)
boxplt.get_legend().get_title().set_fontsize('20')
boxplt.get_legend().set_bbox_to_anchor((1, 1, 0, 0))

#Add significance indicators: hotspot protein abundance
x1, x2 = -0.25, -0.05
y, h, col = 4.25, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='25')

#Add significance indicators: non-hotspot protein abundance
x1, x2 = 0.05, 0.25
y, h, col = 2.25, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "n.s.", ha='center', va='bottom', color=col, fontsize='25')

#Add significance indicators: hotspot phosphorylation
x1, x2 = 0.75, 0.95
y, h, col = 4.75, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='25')

#Add significance indicators: non-hotspot phosphorylation
x1, x2 = 1.05, 1.25
y, h, col = 2.25, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "n.s.", ha='center', va='bottom', color=col, fontsize='25')

fig = boxplt.get_figure()
fig.savefig('p53_cis.png', dpi=300)
plt.show()

# %% [markdown]
# ## XPO1

# %% [markdown]
# ### Build dataframe for plotting

# %%
protein = 'XPO1'
xpo1_plotdf = CPTAC.compare_mutations(proteomics, protein, gene)
xpo1_plotdf = xpo1_plotdf.loc[xpo1_plotdf['Patient_Type'] == 'Tumor'][[protein, 'Mutation']]
xpo1_plotdf['TP53 Mutation Location'] = 'Outside Hotspot'
xpo1_plotdf.loc[hotspot_patients, 'TP53 Mutation Location'] = 'Within Hotspot'
xpo1_plotdf.loc[xpo1_plotdf['Mutation'] == 'Wildtype', 'TP53 Mutation Location'] = 'Wildtype'
xpo1_plotdf = xpo1_plotdf.dropna(axis = 0)
xpo1_plotdf.head(5)
# Out:
#           XPO1           Mutation TP53 Mutation Location
# S001  0.107000  Missense_Mutation         Within Hotspot
# S002 -0.037500           Wildtype               Wildtype
# S003 -0.000832           Wildtype               Wildtype
# S004  0.272000  Missense_Mutation        Outside Hotspot
# S005  0.056100           Wildtype               Wildtype

# %% [markdown]
# ### Create and style figure

# %%
a4_dims = (23.4, 18.4)
fig, ax = plt.subplots(figsize = a4_dims)
my_pal = {"Within Hotspot": "#007acc", "Wildtype": "#ac3973", "Outside Hotspot": "#29a329"}

boxplt = sns.boxplot(data = xpo1_plotdf, x = 'TP53 Mutation Location', y = protein, ax = ax, palette = my_pal)
boxplt = sns.stripplot(data = xpo1_plotdf, x = 'TP53 Mutation Location', y = protein, jitter = True, color = '.3', size=7)
boxplt.set_xlabel('TP53 Mutation Location', fontsize='30')
boxplt.tick_params(labelsize='20')
boxplt.set_ylabel(protein + ' Relative Protein Abundance', fontsize='30')
boxplt.set_title("Effect of " + gene + " mutation on " + protein + " expression", fontsize='40')

#Add significance indicators: hotspot protein abundance
x1, x2 = 0.15, 0.75
y, h, col = 0.65, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='25')

#Add significance indicators: non-hotspot protein abundance
x1, x2 = 1.25, 1.85
y, h, col = 0.55, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='25')

fig = boxplt.get_figure()
fig.savefig('xpo1.png', dpi=300)
plt.show()

plt.show()

# %% [markdown]
# ## AURKA

# %% [markdown]
# ### Build dataframe for plotting

# %%
protein = 'AURKA'
aurka_plotdf = CPTAC.compare_mutations(proteomics, protein, gene)
aurka_plotdf = aurka_plotdf.loc[aurka_plotdf['Patient_Type'] == 'Tumor'][[protein, 'Mutation']]
aurka_plotdf['TP53 Mutation Location'] = 'Outside Hotspot'
aurka_plotdf.loc[hotspot_patients, 'TP53 Mutation Location'] = 'Within Hotspot'
aurka_plotdf.loc[aurka_plotdf['Mutation'] == 'Wildtype', 'TP53 Mutation Location'] = 'Wildtype'
aurka_plotdf = aurka_plotdf.dropna(axis = 0)
aurka_plotdf.head(5)
# Out:
#       AURKA           Mutation TP53 Mutation Location
# S002  0.311           Wildtype               Wildtype
# S004  2.410  Missense_Mutation        Outside Hotspot
# S005 -0.798           Wildtype               Wildtype
# S006  3.110  Missense_Mutation         Within Hotspot
# S007 -1.650           Wildtype               Wildtype

# %% [markdown]
# ### Create and style figure

# %%
a4_dims = (23.4, 18.4)
fig, ax = plt.subplots(figsize = a4_dims)
my_pal = {"Within Hotspot": "#007acc", "Wildtype": "#ac3973", "Outside Hotspot": "#29a329"}

boxplt = sns.boxplot(data = aurka_plotdf, x = 'TP53 Mutation Location', y = protein, order = ['Within Hotspot', 'Wildtype', 'Outside Hotspot'], ax = ax, palette = my_pal)
boxplt = sns.stripplot(data = aurka_plotdf, x = 'TP53 Mutation Location', y = protein, order = ['Within Hotspot', 'Wildtype', 'Outside Hotspot'], jitter = True, color = '.3', size=7)
boxplt.set_xlabel('TP53 Mutation Location', fontsize='30')
boxplt.tick_params(labelsize='20')
boxplt.set_ylabel(protein + ' Relative Protein Abundance', fontsize='30')
boxplt.set_title("Effect of " + gene + " mutation on " + protein + " expression", fontsize='40')

#Add significance indicators: hotspot protein abundance
x1, x2 = 0.15, 0.75
y, h, col = 3.25, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='25')

#Add significance indicators: non-hotspot protein abundance
x1, x2 = 1.25, 1.85
y, h, col = 3, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col, fontsize='25')

fig = boxplt.get_figure()
fig.savefig('aurka.png', dpi=300)
plt.show()

plt.show()

# %% [markdown]
# ## TPX2

# %% [markdown]
# ### Build dataframe for plotting

# %%
protein = 'TPX2'
proteomicsdf = CPTAC.compare_mutations(proteomics, protein, gene)
proteomicsdf = proteomicsdf.loc[proteomicsdf['Patient_Type'] == 'Tumor'][[protein, 'Mutation']]
phosdf = CPTAC.compare_mutations(phos, protein, gene)
phosdf = phosdf.loc[phosdf['Patient_Type'] == 'Tumor'][['TPX2-S486', 'TPX2-T369']]
tpxdf = proteomicsdf.join(phosdf)
tpxdf['TP53 Mutation Location'] = 'Outside Hotspot'
tpxdf.loc[hotspot_patients, 'TP53 Mutation Location'] = 'Within Hotspot'
tpxdf.loc[tpxdf['Mutation'] == 'Wildtype', 'TP53 Mutation Location'] = 'Wildtype'
tpxdf = pd.melt(tpxdf, id_vars=['TP53 Mutation Location'], value_vars=['TPX2', 'TPX2-S486', 'TPX2-T369'], var_name='Type', value_name='Reading')
tpxdf = tpxdf.dropna(axis = 0)
tpxdf.head(5)
# Out:
#   TP53 Mutation Location  Type  Reading
# 0         Within Hotspot  TPX2    0.925
# 1               Wildtype  TPX2    0.717
# 2               Wildtype  TPX2   -0.786
# 3        Outside Hotspot  TPX2    1.530
# 4               Wildtype  TPX2   -0.290

# %% [markdown]
# ### Create and style figure

# %%
a4_dims = (23.4, 18.4)
fig, ax = plt.subplots(figsize=a4_dims)
my_pal = {"Within Hotspot": "#007acc", "Wildtype": "#ac3973", "Outside Hotspot": "#29a329"}

#Create the plot
boxplt = sns.boxplot(x='Type', y='Reading', hue='TP53 Mutation Location', data=tpxdf, palette = my_pal)
boxplt = sns.stripplot(data=tpxdf, x='Type', y='Reading', hue='TP53 Mutation Location', dodge=True, jitter=True, color='.3', size=7)

#Add styling
boxplt.set_title("Effect of " + gene + " mutation on " + protein, fontsize='40')
boxplt.set_xlabel('')
boxplt.set_ylabel('Relative Abundance', fontsize='30')
boxplt.set_xticklabels(['TPX2 Protein', 'TPX2-S486 Phosphorylation', 'TPX2-S369 Phosphorylation'])
boxplt.tick_params(labelsize='20')

#Adjust legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], ['Within Hotspot', 'Wildtype', 'Outside Hotspot'], title='TP53 Status', fontsize='20', frameon=False)
boxplt.get_legend().get_title().set_fontsize('20')
boxplt.get_legend().set_bbox_to_anchor((1, 1, 0, 0))

#Add significance indicators: hotspot protein abundance
x1, x2 = -0.15, 0.2
y, h, col = 3, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='25')

#Add significance indicators: phosphorylation 486
x1, x2 = 0.85, 1.2
y, h, col = 3.85, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='25')

#Add significance indicators: phosphorylation369
x1, x2 = 1.85, 2.2
y, h, col = 2.9, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='25')

fig = boxplt.get_figure()
fig.savefig('tpx2.png', dpi=300)
plt.show()

# %% [markdown]
# ## Interacting Proteins Plot (hotspot no difference)

# %%
proteins_to_plot = ['CDK1', 'STK11', 'CABLES1', 'ZCCHC17']
my_pal = {"Within Hotspot": "#007acc", "Wildtype": "#ac3973", "Outside Hotspot": "#29a329"}

interactingplotdf = CPTAC.compare_mutations(proteomics, gene)
interactingplotdf = interactingplotdf.loc[interactingplotdf['Patient_Type'] == 'Tumor'][['Mutation']]
for protein in proteins_to_plot:
    proteindf = CPTAC.compare_mutations(proteomics, protein, gene)[[protein]]
    interactingplotdf = interactingplotdf.join(proteindf)

interactingplotdf['Within_Hotspot'] = 'Outside Hotspot'
interactingplotdf.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
interactingplotdf.loc[interactingplotdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
interactingplotdf = pd.melt(interactingplotdf, id_vars = ['Mutation', 'Within_Hotspot'], var_name = 'Protein', value_name = 'Proteomics')
interactingplotdf = interactingplotdf.dropna(axis = 0)

a4_dims = (23.4, 18.4)
fig, ax = plt.subplots(figsize=a4_dims)

#Create the plot
boxplt = sns.boxplot(x='Protein', y='Proteomics', hue='Within_Hotspot', data=interactingplotdf, palette = my_pal)
boxplt = sns.stripplot(data=interactingplotdf, x='Protein', y='Proteomics', hue='Within_Hotspot', dodge=True, jitter=True, color='.3')

#Add styling
boxplt.set_title("Effect of " + gene + " mutation on other proteins", fontsize='40')
boxplt.set_xlabel('Protein Name', fontsize='30')
boxplt.set_ylabel('Relative Protein Abundance', fontsize='30')
boxplt.tick_params(labelsize='20')

#Adjust legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], ['Within Hotspot', 'Wildtype', 'Outside Hotspot'], title='TP53 Status', fontsize='20', frameon=False)
boxplt.get_legend().get_title().set_fontsize('20')
boxplt.get_legend().set_bbox_to_anchor((1, 1, 0, 0))

fig = boxplt.get_figure()
fig.savefig('no_diff_htspt.png', dpi=300)
plt.show()

# %% [markdown]
# ## Interacting Proteins Plot (hotspot makes a difference)

# %%
proteins_to_plot = ['NOL7', 'PRPF39', 'XRN2', 'PIAS2']
my_pal = {"Within Hotspot": "#007acc", "Wildtype": "#ac3973", "Outside Hotspot": "#29a329"}

interactingplotdf = CPTAC.compare_mutations(proteomics, gene)
interactingplotdf = interactingplotdf.loc[interactingplotdf['Patient_Type'] == 'Tumor'][['Mutation']]
for protein in proteins_to_plot:
    proteindf = CPTAC.compare_mutations(proteomics, protein, gene)[[protein]]
    interactingplotdf = interactingplotdf.join(proteindf)

interactingplotdf['Within_Hotspot'] = 'Outside Hotspot'
interactingplotdf.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
interactingplotdf.loc[interactingplotdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
interactingplotdf = pd.melt(interactingplotdf, id_vars = ['Mutation', 'Within_Hotspot'], var_name = 'Protein', value_name = 'Proteomics')
interactingplotdf = interactingplotdf.dropna(axis = 0)

a4_dims = (23.4, 18.4)
fig, ax = plt.subplots(figsize=a4_dims)

#Create the plot
boxplt = sns.boxplot(x='Protein', y='Proteomics', hue='Within_Hotspot', data=interactingplotdf, palette = my_pal)
boxplt = sns.stripplot(data=interactingplotdf, x='Protein', y='Proteomics', hue='Within_Hotspot', dodge=True, jitter=True, color='.3')

#Add styling
boxplt.set_title("Effect of " + gene + " mutation on other proteins", fontsize='40')
boxplt.set_xlabel('Protein Name', fontsize='30')
boxplt.set_ylabel('Relative Protein Abundance', fontsize='30')
boxplt.tick_params(labelsize='20')

#Adjust legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], ['Within Hotspot', 'Wildtype', 'Outside Hotspot'], title='TP53 Status', fontsize='20', frameon=False)
plt.ylim(-1.1, 1.55)
boxplt.get_legend().get_title().set_fontsize('20')
boxplt.get_legend().set_bbox_to_anchor((1, 1, 0, 0))

fig = boxplt.get_figure()
fig.savefig('diff_htspt.png', dpi=300)
plt.show()
