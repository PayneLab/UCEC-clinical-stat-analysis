# %% [markdown]
# # TP53 Exploratory Notebook

# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
import seaborn as sns
import CPTAC.Endometrial as CPTAC
# Out:
# Loading Endometrial CPTAC data:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter embargo() to open the webpage for more details.

# %% [markdown]
# ## Set up initial dataframes and variables

# %%
gene='TP53'
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()
transcriptomics = CPTAC.get_transcriptomics()

#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.P250L', 'p.R248W', 'p.S241C', 'p.K164E', 'p.R249S', 'p.R273H', 'p.R282W',
                    'p.S127Y', 'p.G244D', 'p.A159P']
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients_both_keys = mutated_hotspot[['Clinical_Patient_Key', 'Patient_Id']]
hotspot_patients = hotspot_patients_both_keys['Clinical_Patient_Key']

# %%
hotspot_patients
# Out:
# 586      S001
# 1318     S006
# 1404     S008
# 4019     S015
# 4089     S016
# 4736     S020
# 44973    S071
# 45005    S072
# 46785    S082
# 49867    S096
# 49948    S097
# Name: Clinical_Patient_Key, dtype: object

# %% [markdown]
# ## Test and plot a single protein (proteomics)

# %%
gene = 'TP53'
protein = 'TP53'

p53_mutations_protein = CPTAC.compare_mutations(proteomics, protein, gene)
print(p53_mutations_protein)
p53_mutations_protein['Within_Hotspot'] = False
p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].dropna(axis=0)
mutated = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == True]
wt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Wildtype']
print(len(mutated))
if len(mutated) > 2:
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        print(protein + ": " + str(ttest[1]))
else:
    print("There are not enough mutations within the hotspot to do a t-test")
    
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p53_mutations_protein, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = p53_mutations_protein, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
boxplt.set_title("Effect of " + gene + " mutation on " + protein + " protein levels", fontsize='22')
plt.show()
# Out:
#           TP53           Mutation Patient_Type
# S001  0.295000  Missense_Mutation        Tumor
# S002  0.277000           Wildtype        Tumor
# S003 -0.871000           Wildtype        Tumor
# S004  1.430000  Missense_Mutation        Tumor
# S005 -0.343000           Wildtype        Tumor
# S006  3.010000  Missense_Mutation        Tumor
# S007 -0.148000           Wildtype        Tumor
# S008  0.441000  Missense_Mutation        Tumor
# S009 -1.220000  Nonsense_Mutation        Tumor
# S010 -0.082500           Wildtype        Tumor
# S011 -0.181000           Wildtype        Tumor
# S012 -0.000425           Wildtype        Tumor
# S013  0.489000    Frame_Shift_Del        Tumor
# S014 -0.203000           Wildtype        Tumor
# S015  3.310000  Missense_Mutation        Tumor
# S016  2.120000  Missense_Mutation        Tumor
# S017 -0.243000           Wildtype        Tumor
# S018 -0.000950           Wildtype        Tumor
# S019  0.021300           Wildtype        Tumor
# S020  0.353000  Missense_Mutation        Tumor
# S021 -0.403000           Wildtype        Tumor
# S022 -0.154000  Nonsense_Mutation        Tumor
# S023 -0.056600           Wildtype        Tumor
# S024 -0.280000           Wildtype        Tumor
# S025 -0.519000           Wildtype        Tumor
# S026 -0.455000           Wildtype        Tumor
# S027  0.098000           Wildtype        Tumor
# S028 -0.209000           Wildtype        Tumor
# S029 -0.081900           Wildtype        Tumor
# S030  0.709000           Wildtype        Tumor
# ...        ...                ...          ...
# S124 -0.237000           Wildtype       Normal
# S125 -0.729000           Wildtype       Normal
# S126  0.112000           Wildtype       Normal
# S127       NaN           Wildtype       Normal
# S128       NaN           Wildtype       Normal
# S129 -0.078800           Wildtype       Normal
# S130 -0.688000           Wildtype       Normal
# S131 -0.747000           Wildtype       Normal
# S132 -0.333000           Wildtype       Normal
# S133 -0.174000           Wildtype       Normal
# S134 -1.010000           Wildtype       Normal
# S135  0.024300           Wildtype       Normal
# S136 -1.080000           Wildtype       Normal
# S137 -0.256000           Wildtype       Normal
# S138  0.105000           Wildtype       Normal
# S139 -0.819000           Wildtype       Normal
# S140 -0.530000           Wildtype       Normal
# S141 -0.899000           Wildtype       Normal
# S142 -0.809000           Wildtype       Normal
# S143 -0.124000           Wildtype       Normal
# S144  0.071900           Wildtype       Normal
# S145       NaN           Wildtype       Normal
# S146       NaN           Wildtype       Normal
# S147       NaN           Wildtype       Normal
# S148       NaN           Wildtype       Normal
# S149       NaN           Wildtype       Normal
# S150       NaN           Wildtype       Normal
# S151       NaN           Wildtype       Normal
# S152       NaN           Wildtype       Normal
# S153       NaN           Wildtype       Normal
#
# [153 rows x 3 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-07292345ff3b> in <module>()
#       5 print(p53_mutations_protein)
#       6 p53_mutations_protein['Within_Hotspot'] = False
# ----> 7 p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
#       8 p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
#       9 p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].dropna(axis=0)
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     186         else:
#     187             key = com._apply_if_callable(key, self.obj)
# --> 188         indexer = self._get_setitem_indexer(key)
#     189         self._setitem_with_indexer(indexer, value)
#     190
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     164         if isinstance(key, tuple):
#     165             try:
# --> 166                 return self._convert_tuple(key, is_setter=True)
#     167             except IndexingError:
#     168                 pass
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_tuple(self, key, is_setter)
#     245                 if i >= self.obj.ndim:
#     246                     raise IndexingError('Too many indexers')
# --> 247                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     248                 keyidx.append(idx)
#     249         return tuple(keyidx)
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "[('C', 'l', 'i', 'n', 'i', 'c', 'a', 'l', '_', 'P', 'a', 't', 'i', 'e', 'n', 't', '_', 'K', 'e', 'y')\n ('P', 'a', 't', 'i', 'e', 'n', 't', '_', 'I', 'd')] not in index"

# %% [markdown]
# ## Test and plot a single protein (phosphoproteomics)

# %%
gene = 'TP53'
protein = 'TP53'

pattern = re.compile(protein)

p53_mutations_protein = CPTAC.compare_mutations(phos, protein, gene)
p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis=1)
p53_mutations_protein['Within_Hotspot'] = False
p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p53_mutations_protein.drop('Mutation', axis=1)

plotdf = p53_mutations_protein[['Within_Hotspot']]

pcutoff = 0.05/len(p53_mutations_protein.columns)

for site in p53_mutations_protein.columns:
    if (site != 'Within_Hotspot' and site != 'Mutation'):
        sitedf = p53_mutations_protein[[site, 'Within_Hotspot']].dropna(axis=0)
        mutated = sitedf.loc[sitedf['Within_Hotspot'] != 'Wildtype']
        wt = sitedf.loc[sitedf['Within_Hotspot'] == 'Wildtype']
        if mutated.empty:
            print("Not enough mutated values for site " + site)
            continue
        if wt.empty:
            print("Not enough wildtype values for site " + site)
            continue
        if len(mutated[site]) < 2:
            print("Not enough mutated values for site " + site)
            continue
        ttest = scipy.stats.ttest_ind(mutated[site], wt[site])
        if ttest[1] < pcutoff:
            print("Site " + site + ": " + str(ttest[1]))
            plotdf = plotdf.join(p53_mutations_protein[site])
        else:
            print(site + " not significant")
            
plotdf = pd.melt(plotdf, id_vars = ['Within_Hotspot'], var_name = 'Site', value_name = 'Phos')
plotdf = plotdf.dropna(axis = 0)
            
a4_dims = (23.4, 16.54)
fig, ax = plt.subplots(figsize=a4_dims)

#Create the plot
boxplt = sns.boxplot(x='Site', y='Phos', hue='Within_Hotspot', data=plotdf)
boxplt = sns.stripplot(data=plotdf, x='Site', y='Phos', hue='Within_Hotspot', dodge=True, jitter=True, color='.3')

#Add styling
boxplt.set_xlabel('')
boxplt.set_ylabel('Phosphoproteome Level', fontsize='40')
boxplt.tick_params(labelsize='10')
# Out:
# Site TP53-S315: 5.572977461429709e-07
# TP53-T150 not significant
# Site TP53BP1-S1004: 0.00023718676327426296
# TP53BP1-S1007 not significant
# TP53BP1-S101 not significant
# TP53BP1-S1030 not significant
# TP53BP1-S1033 not significant
# TP53BP1-S1039 not significant
# TP53BP1-S1042 not significant
# Not enough mutated values for site TP53BP1-S1055
# Site TP53BP1-S1072: 3.2377180202142466e-05
# TP53BP1-S1073 not significant
# TP53BP1-S108 not significant
# TP53BP1-S1099 not significant
# TP53BP1-S110 not significant
# TP53BP1-S1106 not significant
# TP53BP1-S1109 not significant
# TP53BP1-S1118 not significant
# TP53BP1-S1119 not significant
# TP53BP1-S1221 not significant
# TP53BP1-S1224 not significant
# TP53BP1-S123 not significant
# TP53BP1-S124 not significant
# TP53BP1-S129 not significant
# TP53BP1-S1295 not significant
# TP53BP1-S1300 not significant
# TP53BP1-S1301 not significant
# TP53BP1-S132 not significant
# TP53BP1-S1322 not significant
# TP53BP1-S1325 not significant
# Not enough mutated values for site TP53BP1-S1327
# TP53BP1-S1347 not significant
# Site TP53BP1-S1431: 2.463478679990096e-06
# Site TP53BP1-S1435: 7.640585235424019e-07
# TP53BP1-S1465 not significant
# TP53BP1-S1467 not significant
# TP53BP1-S1479 not significant
# TP53BP1-S1485 not significant
# TP53BP1-S1486 not significant
# TP53BP1-S1553 not significant
# TP53BP1-S1570 not significant
# TP53BP1-S162 not significant
# Site TP53BP1-S1623: 2.4980774713870834e-06
# TP53BP1-S1636 not significant
# TP53BP1-S1639 not significant
# TP53BP1-S1640 not significant
# TP53BP1-S1648 not significant
# TP53BP1-S1649 not significant
# TP53BP1-S1650 not significant
# TP53BP1-S1651 not significant
# TP53BP1-S1661 not significant
# Site TP53BP1-S1678: 2.3821396424666186e-06
# Site TP53BP1-S1683: 1.4573952328626148e-05
# TP53BP1-S1691 not significant
# Site TP53BP1-S1706: 4.199597146197028e-05
# Not enough mutated values for site TP53BP1-S171
# TP53BP1-S1710 not significant
# Site TP53BP1-S1763: 3.307433804821374e-11
# Site TP53BP1-S1764: 2.3686027832938366e-07
# Not enough mutated values for site TP53BP1-S183
# Not enough mutated values for site TP53BP1-S207
# TP53BP1-S213 not significant
# TP53BP1-S227 not significant
# TP53BP1-S264 not significant
# TP53BP1-S270 not significant
# Not enough mutated values for site TP53BP1-S285
# TP53BP1-S299 not significant
# TP53BP1-S306 not significant
# TP53BP1-S315 not significant
# TP53BP1-S320 not significant
# TP53BP1-S321 not significant
# Not enough mutated values for site TP53BP1-S325
# TP53BP1-S328 not significant
# TP53BP1-S335 not significant
# TP53BP1-S338 not significant
# TP53BP1-S354 not significant
# TP53BP1-S361 not significant
# TP53BP1-S364 not significant
# TP53BP1-S365 not significant
# TP53BP1-S371 not significant
# TP53BP1-S377 not significant
# TP53BP1-S384 not significant
# TP53BP1-S385 not significant
# TP53BP1-S400 not significant
# TP53BP1-S403 not significant
# TP53BP1-S488 not significant
# TP53BP1-S489 not significant
# TP53BP1-S505 not significant
# TP53BP1-S512 not significant
# TP53BP1-S517 not significant
# TP53BP1-S523 not significant
# TP53BP1-S525 not significant
# TP53BP1-S528 not significant
# TP53BP1-S530 not significant
# TP53BP1-S535 not significant
# TP53BP1-S538 not significant
# TP53BP1-S557 not significant
# TP53BP1-S562 not significant
# TP53BP1-S571 not significant
# TP53BP1-S585 not significant
# TP53BP1-S603 not significant
# TP53BP1-S635 not significant
# TP53BP1-S640 not significant
# TP53BP1-S644 not significant
# TP53BP1-S645 not significant
# TP53BP1-S664 not significant
# TP53BP1-S665 not significant
# TP53BP1-S667 not significant
# Not enough mutated values for site TP53BP1-S679
# TP53BP1-S68 not significant
# TP53BP1-S729 not significant
# TP53BP1-S732 not significant
# TP53BP1-S756 not significant
# TP53BP1-S759 not significant
# TP53BP1-S760 not significant
# TP53BP1-S770 not significant
# TP53BP1-S776 not significant
# TP53BP1-S787 not significant
# TP53BP1-S789 not significant
# TP53BP1-S791 not significant
# TP53BP1-S814 not significant
# TP53BP1-S83 not significant
# TP53BP1-S835 not significant
# TP53BP1-S836 not significant
# TP53BP1-S839 not significant
# Site TP53BP1-S867: 5.724544767802891e-05
# TP53BP1-S882 not significant
# TP53BP1-S980 not significant
# TP53BP1-S998 not significant
# TP53BP1-T1025 not significant
# TP53BP1-T1060 not significant
# TP53BP1-T1061 not significant
# Not enough mutated values for site TP53BP1-T1127
# TP53BP1-T1219 not significant
# TP53BP1-T122 not significant
# TP53BP1-T1290 not significant
# TP53BP1-T1297 not significant
# TP53BP1-T1324 not significant
# Not enough mutated values for site TP53BP1-T1346
# TP53BP1-T1349 not significant
# TP53BP1-T1377 not significant
# TP53BP1-T1455 not significant
# TP53BP1-T1550 not significant
# TP53BP1-T1614 not significant
# TP53BP1-T1643 not significant
# TP53BP1-T1645 not significant
# TP53BP1-T1652 not significant
# TP53BP1-T1653 not significant
# TP53BP1-T1655 not significant
# TP53BP1-T1761 not significant
# TP53BP1-T190 not significant
# TP53BP1-T205 not significant
# TP53BP1-T307 not significant
# TP53BP1-T326 not significant
# TP53BP1-T339 not significant
# TP53BP1-T362 not significant
# TP53BP1-T378 not significant
# TP53BP1-T387 not significant
# TP53BP1-T399 not significant
# TP53BP1-T514 not significant
# TP53BP1-T524 not significant
# TP53BP1-T548 not significant
# TP53BP1-T553 not significant
# TP53BP1-T591 not significant
# TP53BP1-T596 not significant
# TP53BP1-T598 not significant
# TP53BP1-T675 not significant
# Not enough mutated values for site TP53BP1-T699
# TP53BP1-T73 not significant
# TP53BP1-T860 not significant
# Not enough mutated values for site TP53BP1-T924
# TP53BP1-T927 not significant
# TP53BP2-S302 not significant
# TP53BP2-S367 not significant
# TP53BP2-S486 not significant
# TP53BP2-S487 not significant
# Not enough mutated values for site TP53BP2-S562
# TP53BP2-S564 not significant
# TP53BP2-S575 not significant
# TP53BP2-S582 not significant
# Not enough mutated values for site TP53BP2-S671
# TP53BP2-S673 not significant
# TP53BP2-S679 not significant
# TP53BP2-S704 not significant
# TP53BP2-S720 not significant
# TP53BP2-S742 not significant
# TP53BP2-S743 not significant
# TP53BP2-S789 not significant
# TP53BP2-T573 not significant
# TP53BP2-T592 not significant
# TP53BP2-T745 not significant
# TP53I11-S14 not significant
# TP53INP1-S153 not significant
# TP53INP1-S155 not significant
# TP53INP1-S156 not significant
# TP53INP2-S14 not significant
# Not enough mutated values for site TP53INP2-S7
# TP53RK-T7 not significant
# TP53RK-T8 not significant

# %% [markdown]
# ## Transcriptome differences

# %%
gene = 'TP53'
protein = 'MDM2'

p53_transcript_mut = CPTAC.compare_mutations(proteomics, gene)
p53_transcript_mut['Within_Hotspot'] = False
p53_transcript_mut.loc[hotspot_patients, 'Within_Hotspot'] = True
p53_transcript_mut.loc[p53_transcript_mut['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p53_transcript_mut = p53_transcript_mut.loc[p53_transcript_mut['Patient_Type'] == 'Tumor'].dropna(axis=0)
prot_transcript = pd.DataFrame(transcriptomics[protein])
prot_transcript.columns = [protein + '_transcript']
protein = protein + '_transcript'

transcript_analysis = p53_transcript_mut.join(prot_transcript).drop(gene, axis=1).dropna(axis=0)
transcript_analysis = transcript_analysis.loc[transcript_analysis['Patient_Type'] == 'Tumor']

in_hotspot = transcript_analysis.loc[transcript_analysis['Within_Hotspot'] != 'Wildtype']
outside_hotspot = transcript_analysis.loc[transcript_analysis['Within_Hotspot'] == 'Wildtype']
print(scipy.stats.ttest_ind(in_hotspot[protein], outside_hotspot[protein]))

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = transcript_analysis, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = transcript_analysis, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
boxplt.set_title("Effect of " + gene + " mutation on " + protein, fontsize='22')
plt.show()
# Out:
# Ttest_indResult(statistic=-6.5389792687128505, pvalue=4.568704702162206e-09)

# %% [markdown]
# ## Census of p53 target genes
# PMID: 28288132

# %%
target_genes = ['ABCA12', 'ABCB1', 'ACAD11', 'ACTA2', 'AEN', 'AFP', 'AGT', 'AGTR1', 'AIFM1', 'AIFM2', 'ALOX5', 'ANLN', 'ANXA1', 'APAF1', 'APC', 'APEX1', 'APOB', 'APOBEC1', 'AR', 'ARID3A', 'ARNT2', 'ATF3', 'ATR', 'BAK1', 'BANP', 'BAX', 'BBC3', 'BCL2', 'BCL2L14', 'BCL6', 'BDKRB2', 'BID', 'BIRC5', 'BNIP3', 'BNIP3L', 'BRCA2', 'BTG2', 'BTG3', 'C10orf54', 'CASP1', 'CASP10', 'CASP6', 'CAV1', 'CBL', 'CCNB1', 'CCNB2', 'CCNG1', 'CCNK', 'CD44', 'CD82', 'CDC20', 'CDC25B', 'CDC25C', 'CDIP1', 'CDK1', 'CDKN1A', 'CDKN2A', 'CEL', 'CERS6', 'CES2', 'CGB7', 'CHEK1', 'CHMP4C', 'CKM', 'CKS2', 'COL18A1', 'COMT', 'CPT1C', 'CRYZ', 'CSF1', 'CST3', 'CST5', 'CTF1', 'CTSD', 'CX3CL1', 'CYFIP2', 'CYP21A2', 'NSG1', 'DAPK1', 'DDB2', 'DDR1', 'DEC1', 'DEF6', 'DGKZ', 'DHRS3', 'DKK1', 'DNMT1', 'DRAM1', 'DSP', 'DUSP1', 'DUSP2', 'DUSP4', 'DUSP5', 'DUSP6', 'DUT', 'E2F7', 'ECT2', 'EDA2R', 'EDN2', 'EGFR', 'EGR2', 'EPCAM', 'EPHA2', 'ERAP1', 'ERCC1', 'ESR1', 'F2R', 'FANCC', 'FAS', 'FBXO22', 'FDFT1', 'FDPS', 'FDXR', 'FLT1', 'FOS', 'FOXF1', 'FOXP3', 'FUCA1', 'FZD2', 'GAD2', 'GADD45A', 'GAMT', 'GBP1', 'GCH1', 'GDF15', 'GDF9', 'GFI1', 'GLS2', 'GPR87', 'GPX1', 'GSTP1', 'HAMP', 'HDC', 'HIC1', 'HMGCLL1', 'HMGCR', 'HNF4A', 'HPSE', 'HRAS', 'HSP90AB1', 'HSPA8', 'HTT', 'ID2', 'IER3', 'IER5', 'IFI16', 'IGF1R', 'IGFBP3', 'IRF2BP2', 'IRF5', 'IRF9', 'ISCU', 'KIAA0513', 'KITLG', 'KLLN', 'KRT14', 'KRT8', 'LARP1', 'LASP1', 'LDLR', 'LGALS3', 'LIF', 'LIMK2', 'LMNA', 'LONP1', 'LPIN1', 'MAD1L1', 'MAP4', 'MAP4K4', 'MAPK8', 'MB', 'MDM2', 'ME1', 'ME2', 'ME3', 'MET', 'MFN2', 'MLH1', 'MMP2', 'MPZL2', 'MSH2', 'MTA1', 'MVK', 'MYC', 'MYOG', 'NANOG', 'NCF2', 'NDRG1', 'NEK2', 'NINJ1', 'NLRC4', 'NOL3', 'NOS3', 'NOTCH1', 'NOV', 'NR0B2', 'ODC1', 'OGN', 'ORM2', 'PADI4', 'PANK1', 'PARK2', 'PAX2', 'PCBP4', 'PCDH10', 'PCNA', 'PEBP1', 'PERP', 'PGF', 'PHF1', 'PHLDA3', 'PIDD1', 'PIK3CA', 'PKD1', 'PLAGL1', 'PLK1', 'PLK2', 'PLK3', 'PLTP', 'PMAIP1', 'PML', 'PMS2', 'POLD1', 'POLH', 'POMC', 'PPARGC1A', 'PPARGC1B', 'PPM1D', 'PPM1J', 'PRAP1', 'PRC1', 'PRDM1', 'PRKAB1', 'PRODH', 'PROM1', 'PSRC1', 'PTCHD4', 'PTEN', 'PTGS2', 'PTK2', 'PTP4A1', 'PTPN6', 'PTPRVP', 'PTTG1', 'PYCARD', 'RAB6C', 'RABGGTA', 'RAD17', 'RAD23A', 'RAD51', 'RAP2B', 'RARA', 'RARRES3', 'RB1', 'RBM38', 'RBPJ', 'RECQL4', 'RFC4', 'RGCC', 'RHOC', 'RND3', 'RNF144B', 'RPS27L', 'RRAD', 'RRM2B', 'RTN4', 'RCHY1', 'S100A2', 'S100A9', 'SALL2', 'SCD', 'SCN3B', 'SEMA3B', 'SEMA3F', 'SERPINA6', 'SERPINB5', 'SERPINE1', 'SESN1', 'SGK1', 'SH2D1A', 'SHBG', 'SIAH1', 'SIVA1', 'SLC2A4', 'SLC38A2', 'SLC6A6', 'SLC7A11', 'SOD2', 'SPATA18', 'STAG1', 'STX6', 'SUB1', 'SULF2', 'SUSD6', 'SYK', 'TBXAS1', 'TDG', 'TFAP2A', 'TFAP2C', 'TFF2', 'TGFA', 'TGM2', 'TIGAR', 'TLR10', 'TLR2', 'TLR3', 'TLR4', 'TLR5', 'TLR6', 'TLR8', 'RP11-330H6.5', 'TNFRSF10A', 'TNFRSF10B', 'TNFSF9', 'TP53AIP1', 'TP53BP1', 'TP53I3', 'TP53INP1', 'TP63', 'TP73', 'TPT1', 'TRAF4', 'TRIAP1', 'TRIM22', 'TRIM32', 'TRPC7', 'TSC2', 'TYRP1', 'UBD', 'UBTD1', 'ULK1', 'ULK2', 'UNC5A', 'UTF1', 'VCAN', 'VDR', 'XPC', 'XPO1', 'YPEL3', 'YWHAG', 'ZFP36', 'ZMAT3', 'ZNF79']

# %% [markdown]
# ### Proteomic analysis

# %%
proteomic_significant = []
proteomic_nochange = []
for protein in target_genes:
    if protein in proteomics.columns:
        p53_mutations_protein = CPTAC.compare_mutations(proteomics, protein, gene)
        p53_mutations_protein['Within_Hotspot'] = False
        p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
        p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].dropna(axis=0)
        mutated = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] != 'Wildtype']
        wt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Wildtype']
        if len(mutated) > 2:
                ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
                if(ttest[1] < 0.001):
                    proteomic_significant.append(protein)
                else:
                    proteomic_nochange.append(protein)

# %%
transcript_significant = []
transcript_nochange = []
for protein in target_genes:
    if protein in transcriptomics.columns:
        p53_transcript_mut = CPTAC.compare_mutations(proteomics, gene)
        p53_transcript_mut['Within_Hotspot'] = False
        p53_transcript_mut.loc[hotspot_patients, 'Within_Hotspot'] = True
        p53_transcript_mut.loc[p53_transcript_mut['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p53_transcript_mut = p53_transcript_mut.loc[p53_transcript_mut['Patient_Type'] == 'Tumor'].dropna(axis=0)
        prot_transcript = transcriptomics[protein]

        transcript_analysis = p53_transcript_mut.join(prot_transcript).drop(gene, axis=1).dropna(axis=0)
        transcript_analysis = transcript_analysis.loc[transcript_analysis['Patient_Type'] == 'Tumor']

        in_hotspot = transcript_analysis.loc[transcript_analysis['Within_Hotspot'] != 'Wildtype']
        outside_hotspot = transcript_analysis.loc[transcript_analysis['Within_Hotspot'] == 'Wildtype']
        if len(in_hotspot) > 2:
            ttest = scipy.stats.ttest_ind(in_hotspot[protein], outside_hotspot[protein])
            if(ttest[1] < 0.001):
                transcript_significant.append(protein)
            else:
                transcript_nochange.append(protein)

# %%
proteomic_significant
# Out:
# ['ANLN',
#  'BIRC5',
#  'CCNB1',
#  'CCNK',
#  'CDC20',
#  'CDK1',
#  'CDKN2A',
#  'DDB2',
#  'ECT2',
#  'ESR1',
#  'FAS',
#  'FBXO22',
#  'FDXR',
#  'FUCA1',
#  'HSP90AB1',
#  'IRF9',
#  'MB',
#  'MSH2',
#  'PCNA',
#  'PLK1',
#  'PROM1',
#  'RFC4',
#  'RPS27L',
#  'SALL2',
#  'SLC38A2',
#  'SPATA18',
#  'TRIM32',
#  'XPC',
#  'XPO1']

# %%
transcript_significant
# Out:
# ['AEN',
#  'APC',
#  'BAK1',
#  'BBC3',
#  'BIRC5',
#  'CDC20',
#  'CDC25B',
#  'CDC25C',
#  'CDKN1A',
#  'CDKN2A',
#  'DDB2',
#  'ECT2',
#  'ESR1',
#  'FAS',
#  'FDXR',
#  'GBP1',
#  'HSP90AB1',
#  'ID2',
#  'IRF9',
#  'MB',
#  'MDM2',
#  'MPZL2',
#  'MSH2',
#  'PIK3CA',
#  'PLK1',
#  'PLTP',
#  'POLD1',
#  'PRAP1',
#  'PRKAB1',
#  'PSRC1',
#  'RB1',
#  'RBM38',
#  'RECQL4',
#  'RFC4',
#  'RPS27L',
#  'SESN1',
#  'SPATA18',
#  'SYK',
#  'TLR3',
#  'TNFRSF10B',
#  'TP53AIP1',
#  'TPT1',
#  'TRIM32',
#  'ULK2',
#  'XPC',
#  'XPO1',
#  'ZMAT3']

# %% [markdown]
# ## Proteins where both the proteome and the transcriptome are affected

# %%
list(set(transcript_significant) & set(proteomic_significant))
# Out:
# ['TRIM32',
#  'CDC20',
#  'DDB2',
#  'FAS',
#  'BIRC5',
#  'ESR1',
#  'SPATA18',
#  'HSP90AB1',
#  'ECT2',
#  'RFC4',
#  'CDKN2A',
#  'MSH2',
#  'XPC',
#  'FDXR',
#  'PLK1',
#  'XPO1',
#  'IRF9',
#  'MB',
#  'RPS27L']

# %% [markdown]
# ## Proteome affected, transcriptome not

# %%
list(set(proteomic_significant) - set(transcript_significant))
# Out:
# ['CCNB1',
#  'FUCA1',
#  'SLC38A2',
#  'PROM1',
#  'FBXO22',
#  'CCNK',
#  'ANLN',
#  'PCNA',
#  'SALL2',
#  'CDK1']

# %% [markdown]
# ## Transcriptome affected, proteome not

# %%
list(set(transcript_significant) - set(proteomic_significant))
# Out:
# ['TLR3',
#  'TNFRSF10B',
#  'CDKN1A',
#  'MPZL2',
#  'APC',
#  'PLTP',
#  'RBM38',
#  'MDM2',
#  'BAK1',
#  'PIK3CA',
#  'GBP1',
#  'CDC25C',
#  'BBC3',
#  'PRKAB1',
#  'TP53AIP1',
#  'RECQL4',
#  'ULK2',
#  'ZMAT3',
#  'PSRC1',
#  'AEN',
#  'TPT1',
#  'POLD1',
#  'PRAP1',
#  'RB1',
#  'CDC25B',
#  'SESN1',
#  'SYK',
#  'ID2']

# %% [markdown]
# # Hotspot/transcriptome analysis

# %%
hp_proteomic_significant = []
hp_proteomic_nochange = []
for protein in target_genes:
    if protein in proteomics.columns:
        p53_mutations_protein = CPTAC.compare_mutations(proteomics, protein, gene)
        p53_mutations_protein['Within_Hotspot'] = False
        p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = True
        p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Patient_Type'] == 'Tumor'].dropna(axis=0)
        mutated = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == True]
        wt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Wildtype']
        if len(mutated) > 2:
                ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
                if(ttest[1] < 0.001):
                    hp_proteomic_significant.append(protein)
                else:
                    hp_proteomic_nochange.append(protein)

# %%
hp_transcript_significant = []
hp_transcript_nochange = []
for protein in target_genes:
    if protein in transcriptomics.columns:
        p53_transcript_mut = CPTAC.compare_mutations(proteomics, gene)
        p53_transcript_mut['Within_Hotspot'] = False
        p53_transcript_mut.loc[hotspot_patients, 'Within_Hotspot'] = True
        p53_transcript_mut.loc[p53_transcript_mut['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p53_transcript_mut = p53_transcript_mut.loc[p53_transcript_mut['Patient_Type'] == 'Tumor'].dropna(axis=0)
        prot_transcript = transcriptomics[protein]

        transcript_analysis = p53_transcript_mut.join(prot_transcript).drop(gene, axis=1).dropna(axis=0)
        transcript_analysis = transcript_analysis.loc[transcript_analysis['Patient_Type'] == 'Tumor']

        in_hotspot = transcript_analysis.loc[transcript_analysis['Within_Hotspot'] == True]
        outside_hotspot = transcript_analysis.loc[transcript_analysis['Within_Hotspot'] == 'Wildtype']
        if len(in_hotspot) > 2:
            ttest = scipy.stats.ttest_ind(in_hotspot[protein], outside_hotspot[protein])
            if(ttest[1] < 0.001):
                hp_transcript_significant.append(protein)
            else:
                hp_transcript_nochange.append(protein)

# %%
hp_proteomic_significant
# Out:
# ['ANLN',
#  'CCNB1',
#  'CCNK',
#  'CDC20',
#  'CDK1',
#  'CDKN2A',
#  'DDB2',
#  'ECT2',
#  'FAS',
#  'FBXO22',
#  'FDXR',
#  'GBP1',
#  'HSP90AB1',
#  'IRF9',
#  'MSH2',
#  'PLK1',
#  'RFC4',
#  'SLC38A2',
#  'SPATA18',
#  'TRIM32',
#  'XPC',
#  'XPO1']

# %%
hp_transcript_significant
# Out:
# ['AEN',
#  'APC',
#  'BAK1',
#  'CDKN1A',
#  'DDB2',
#  'ERCC1',
#  'ESR1',
#  'FDXR',
#  'GBP1',
#  'GSTP1',
#  'HSP90AB1',
#  'ID2',
#  'IRF9',
#  'MDM2',
#  'MPZL2',
#  'MSH2',
#  'PIK3CA',
#  'PLK1',
#  'RAD23A',
#  'RBM38',
#  'RECQL4',
#  'RFC4',
#  'RPS27L',
#  'SESN1',
#  'SPATA18',
#  'TPT1',
#  'TRIM32',
#  'ULK2',
#  'XPC',
#  'XPO1']
