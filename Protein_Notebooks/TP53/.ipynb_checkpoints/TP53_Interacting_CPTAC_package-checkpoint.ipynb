# %% [markdown]
#    # TP53: Effects of Mutation on Interacting Proteins

# %% [markdown]
# <b>Standard imports for playing with and plotting data frames.</b>

# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <b>Import CPTAC data</b>

# %%
import CPTAC
# Out:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter CPTAC.embargo() to open the webpage for more details.

# %%
somatic_mutations = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %% [markdown]
# ### List of proteins that interact with TP53 (according to Uniprot and String)

# %%
gene = 'TP53'
protList = ['AXIN1', 'EP300', 'HRMT1L2', 'CARM1', 'TAF1', 'ING4', 'CABLES1', 
            'TP73', 'HIPK1', 'HIPK2', 'TP53INP1', 'TP53BP', 'WWOX', 'HCV', 'USP7', 'SYVN1', 'HSP90AB1',
           'CHD8', 'ARMC10', 'BANP', 'CDKN2AIP', 'NUAK1', 'STK11', 'LKB1', 'UHRF2', 'E4F1', 'YWHAZ',
           'MAML1', 'MKRN1', 'PML', 'MDM2', 'FBXO42', 'ATM', 'PP2R2A', 'AURKA', 'DAXX', 'BRD7', 'TRIM24',
           'L3MBTL1', 'GRK5', 'CAK', 'PTK2B', 'PYK2', 'MDM2', 'PRKCG', 'PPIF', 'KAT6A', 'UBC9', 'ZNF385B',
           'ZNF385A', 'ANKRD2', 'RFFL', 'RNF34', 'MTA1', 'COP1', 'CCAR2', 'MORC3', 'POU4F2', 'AFG1L', 'UBD',
           'TAF6', 'HPV', 'UL123', 'E1B-55K', 'BAX', 'FAS', 'BCL2', 'CREBBP', 'CDK2', 'MDM2', 'CDKN2A', 
            'CDKN1A', 'ATM', 'MDM4']

# %% [markdown]
# ### t-test for proteome abundance of these proteins when TP53 is mutated
# <b>Note: We are only interested in looking at proteins whose abundance is significantly affected by TP53 mutation, and we must do a Bonferroni correction on our p-value</b>

# %%
pcutoff = 0.05 / len(protList)

# %%
significantResults = [];
for protein in protList: 
    if protein in proteomics.columns:
        cross = CPTAC.merge_mutations(proteomics, protein, gene)
        cross = cross[["Mutation", protein]].dropna(axis=0)
        mutated = cross.loc[cross["Mutation"] == "Missense_Mutation"]
        wt = cross.loc[cross["Mutation"] == "Wildtype"]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(ttest[1] <= pcutoff):
            significantResults.append(protein)
            print("Test for " + protein + ": ")
            print(ttest)
# Out:
# Test for CABLES1:
# Ttest_indResult(statistic=-3.929885671934063, pvalue=0.0001378458722101749)
# Test for HSP90AB1:
# Ttest_indResult(statistic=4.297997992864394, pvalue=3.367565381594231e-05)
# Test for CHD8:
# Ttest_indResult(statistic=4.2478330401531235, pvalue=4.10099109905482e-05)
# Test for UHRF2:
# Ttest_indResult(statistic=-4.113642044468606, pvalue=6.894129428035211e-05)
# Test for AURKA:
# Ttest_indResult(statistic=4.660432733263899, pvalue=1.26014474892994e-05)

# %% [markdown]
# ### List of significantly affected proteins

# %%
print(significantResults)
# Out:
# ['CABLES1', 'HSP90AB1', 'CHD8', 'UHRF2', 'AURKA']

# %% [markdown]
# ### Build the dataframe for plotting

# %%
plotdf = CPTAC.merge_mutations(proteomics, gene)[['Mutation', gene]]

for protein in significantResults:
    proteindf = CPTAC.merge_mutations(proteomics, protein, gene)[[protein]]
    plotdf = plotdf.join(proteindf)

# %%
plotdf = plotdf.replace({'Mutation': {'Frame_Shift_Del': 'Truncating',
                                      'Frame_Shift_Ins': 'Truncating',
                                      'Nonsense_Mutation': 'Truncating',
                                      'Wildtype': 'Control',
                                      'Missense_Mutation': 'Missense'
                                     }})

# %%
plotdf = pd.melt(plotdf, id_vars=['Mutation'], var_name='Protein', value_name='Proteomics')
plotdf = plotdf.loc[(plotdf["Mutation"] == "Control") | (plotdf["Mutation"] == "Missense") | (plotdf["Mutation"] == "Truncating")]
plotdf = plotdf.dropna(axis=0)

# %%
a4_dims = (23.4, 16.54)
fig, ax = plt.subplots(figsize=a4_dims)
my_pal = {"Missense": "#6C906D", "Control": "#596B94", "Truncating": "#A35857"}

#Create the plot
boxplt = sns.boxplot(x='Protein', y='Proteomics', hue='Mutation', data=plotdf, palette=my_pal)
boxplt = sns.stripplot(data=plotdf, x='Protein', y='Proteomics', hue='Mutation', dodge=True, jitter=True, color='.3')

#Add styling
boxplt.set_xlabel('')
boxplt.set_ylabel('Protein Level', fontsize='40')
boxplt.tick_params(labelsize='20')

#Adjust legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], ['Missense', 'Control', 'Truncating'], title='TP53 Status', fontsize='20', frameon=False)
boxplt.get_legend().get_title().set_fontsize('20')
boxplt.get_legend().set_bbox_to_anchor((0.15, 0.15, 0, 0))

#Add significance indicator: TP53
x1, x2 = -0.25, 0.25
y, h, col = 4 + .45, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='30')

#Add significance indicator: CABLES1
x1, x2 = 0.75, 1.25
y, h, col = 1 + .3, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col, fontsize='30')

#Add significance indicator: HSP90AB1
x1, x2 = 1.75, 2.25
y, h, col = 1 + .3, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='30')

#Add significance indicator: CHD8
x1, x2 = 2.75, 3.25
y, h, col = 1 + .3, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='30')

#Add significance indicator: UHRF2
x1, x2 = 3.75, 4.25
y, h, col = 1 + .3, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='30')

#Add significance indicator: AURKA
x1, x2 = 4.75, 5.25
y, h, col = 3 + .3, .3, 'k'
plt.plot([x1, x1, x2, x2], [y+h, y+h, y+h, y+h], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col, fontsize='30')

#plt.savefig('delme.png', dpi=300)
plt.show()

# %% [markdown]
# ## Phosphoproteome abundance of interacting proteins

# %% [markdown]
# ### This is the same list as before, with some of the end numbers of the proteins removed; less specificity in protein names captures more potentially significant results in the phosphoproteomic data

# %%
phosProtList = ['AXIN1', 'EP300', 'HRMT1L2', 'CARM1', 'TAF1', 'ING4', 'CABLES1', 
            'TP73', 'HIPK1', 'HIPK2', 'TP53INP1', 'TP53BP', 'WWOX', 'HCV', 'USP7', 'SYVN1', 'HSP90AB1',
           'CHD8', 'ARMC10', 'BANP', 'CDKN2AIP', 'NUAK1', 'STK11', 'LKB1', 'UHRF2', 'E4F1', 'YWHAZ',
           'MAML1', 'MKRN1', 'PML', 'MDM2', 'FBXO42', 'ATM', 'PP2R2A', 'AURKA', 'DAXX', 'BRD7', 'TRIM24',
           'L3MBTL1', 'GRK5', 'CAK', 'PTK2B', 'PYK2', 'MDM2', 'PRKCG', 'PPIF', 'KAT6A', 'UBC9', 'ZNF385B',
           'ZNF385A', 'ANKRD2', 'RFFL', 'RNF34', 'MTA1', 'COP1', 'CCAR2', 'MORC3', 'POU4F2', 'AFG1L', 'UBD',
           'TAF6', 'HPV', 'UL123', 'E1B-55K', 'BAX', 'FAS', 'BCL2', 'CREBBP', 'CDK2', 'MDM2', 'CDKN2A', 
            'CDKN1A', 'ATM', 'MDM4']

# %%
sites = phos.columns;
significantPhosResults = [];
totalSites = 0

for protein in phosProtList:
    matchesdf = phos.filter(regex=protein)
    totalSites += len(matchesdf.columns)

print(totalSites)
    
    

for protein in phosProtList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.merge_mutations(phos, protein, gene)
        for site in phosphositesdf.columns:
            if (site is not 'Mutation'):
                sitedf = CPTAC.merge_mutations(phos, site, gene)
                mutateddf = sitedf.loc[sitedf['Mutation'] == 'Missense_Mutation'].dropna(axis=0)
                wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
                ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
                #if(ttest[1] <= pcutoff):
                significantResults.append(site)
                print("Test for " + site + ": ")
                print(ttest)
# Out:
# 286
# Test for AXIN1-S493:
# Ttest_indResult(statistic=0.14440418939981944, pvalue=0.8855738687567891)
# Test for AXIN1-S77:
# Ttest_indResult(statistic=0.554895409892803, pvalue=0.5801810093363553)
# Test for AXIN1-T79:
# Ttest_indResult(statistic=-0.27451430357344575, pvalue=0.7844647875839688)
# Test for EP300-S1033:
# Ttest_indResult(statistic=2.6365075765652595, pvalue=0.010254147946177477)
# Test for EP300-S1038:
# Ttest_indResult(statistic=1.5239810962239846, pvalue=0.12996124907823697)
# Test for EP300-S1726:
# Ttest_indResult(statistic=-2.284481426465399, pvalue=0.023989471302443232)
# Test for EP300-S2320:
# Ttest_indResult(statistic=-0.1056973202843518, pvalue=0.9161009887968975)
# Test for EP300-S2326:
# Ttest_indResult(statistic=-0.28855887073094566, pvalue=0.7735681220734565)
# Test for EP300-S2328:
# Ttest_indResult(statistic=0.18913926127720362, pvalue=0.8505310025533043)
# Test for EP300-T887:
# Ttest_indResult(statistic=0.8573324165672057, pvalue=0.39351345529274606)
# Test for EP300-T890:
# Ttest_indResult(statistic=2.6948568983368526, pvalue=0.008328001299508682)
# Test for BTAF1-S224:
# Ttest_indResult(statistic=-0.22317222122800634, pvalue=0.8240423102295719)
# Test for TAF1-S328:
# Ttest_indResult(statistic=-1.406355001795475, pvalue=0.16364171777354686)
# Test for TAF1-T1703:
# Ttest_indResult(statistic=-1.2367043644078153, pvalue=0.21900931232145143)
# Test for TAF10-S44:
# Ttest_indResult(statistic=1.526924852891221, pvalue=0.1292663838472235)
# Test for TAF12-S51:
# Ttest_indResult(statistic=-1.1052213209015462, pvalue=0.2711207714677778)
# Test for TAF12-T43:
# Ttest_indResult(statistic=-1.6702575821398744, pvalue=0.0980594570264776)
# Test for TAF15-S226:
# Ttest_indResult(statistic=-1.1027673734190573, pvalue=0.2731012302458142)
# Test for TAF15-S228:
# Ttest_indResult(statistic=-0.9213577352322014, pvalue=0.3591975798333684)
# Test for TAF15-S375:
# Ttest_indResult(statistic=-1.7841528547311627, pvalue=0.0769908778062023)
# Test for TAF15-S433:
# Ttest_indResult(statistic=-0.6680648022467387, pvalue=0.506039392437978)
# Test for TAF15-S97:
# Ttest_indResult(statistic=1.354111545013464, pvalue=0.17942085807456037)
# Test for TAF1D-S206:
# Ttest_indResult(statistic=0.7338039019576689, pvalue=0.4655189896272398)
# Test for CABLES1-S109:
# Ttest_indResult(statistic=-1.9378770593626502, pvalue=0.05698443941035626)
# Test for CABLES1-S290:
# Ttest_indResult(statistic=-2.8992625458884373, pvalue=0.0044490598821727055)
# Test for CABLES1-S291:
# Ttest_indResult(statistic=-1.8971159447974522, pvalue=0.060613603951573)
# Test for CABLES1-S373:
# Ttest_indResult(statistic=-3.0707852050942472, pvalue=0.002679683456145554)
# Test for CABLES1-S418:
# Ttest_indResult(statistic=-2.587616190063678, pvalue=0.010955631073934342)
# Test for CABLES1-T415:
# Ttest_indResult(statistic=-2.4014136681381175, pvalue=0.0178666325049398)
# Test for HIPK1-S1200:
# Ttest_indResult(statistic=-2.7024116849019157, pvalue=0.008276085621119924)
# Test for HIPK1-T1027:
# Ttest_indResult(statistic=-2.920971239478343, pvalue=0.004443866853877588)
# Test for TP53BP1-S1004:
# Ttest_indResult(statistic=1.8852157847538171, pvalue=0.06221900478646072)
# Test for TP53BP1-S1033:
# Ttest_indResult(statistic=1.5809526336681414, pvalue=0.11652113391921134)
# Test for TP53BP1-S1072:
# Ttest_indResult(statistic=-0.9319275046543759, pvalue=0.3537363667782133)
# Test for TP53BP1-S1073:
# Ttest_indResult(statistic=1.4709480178382606, pvalue=0.14374029138314445)
# Test for TP53BP1-S1099:
# Ttest_indResult(statistic=2.378771423622834, pvalue=0.018836669340194276)
# Test for TP53BP1-S1106:
# Ttest_indResult(statistic=1.4136922552128384, pvalue=0.15986096441973843)
# Test for TP53BP1-S1109:
# Ttest_indResult(statistic=2.93878757472185, pvalue=0.00394713537588201)
# Test for TP53BP1-S1119:
# Ttest_indResult(statistic=-0.2520450068460492, pvalue=0.8014601158176788)
# Test for TP53BP1-S1221:
# Ttest_indResult(statistic=-0.07252294653551937, pvalue=0.9423561261647107)
# Test for TP53BP1-S1224:
# Ttest_indResult(statistic=-0.00689496250913162, pvalue=0.9945148162372618)
# Test for TP53BP1-S124:
# Ttest_indResult(statistic=-0.8588086689734572, pvalue=0.392158331184598)
# Test for TP53BP1-S129:
# Ttest_indResult(statistic=-0.994806702501376, pvalue=0.3228676292966516)
# Test for TP53BP1-S1295:
# Ttest_indResult(statistic=0.16889350620549443, pvalue=0.8661534030400452)
# Test for TP53BP1-S1300:
# Ttest_indResult(statistic=1.627307852685565, pvalue=0.1070919997251637)
# Test for TP53BP1-S132:
# Ttest_indResult(statistic=0.26095721787440423, pvalue=0.7946090370511716)
# Test for TP53BP1-S1325:
# Ttest_indResult(statistic=0.190048111521249, pvalue=0.8497469038223386)
# Test for TP53BP1-S1347:
# Ttest_indResult(statistic=0.08005829789147878, pvalue=0.9363768958512364)
# Test for TP53BP1-S1431:
# Ttest_indResult(statistic=4.852950138011537, pvalue=4.293671725527522e-06)
# Test for TP53BP1-S1435:
# Ttest_indResult(statistic=4.476757994264482, pvalue=1.666655004690184e-05)
# Test for TP53BP1-S1467:
# Ttest_indResult(statistic=-0.9551885885627122, pvalue=0.34128281946768957)
# Test for TP53BP1-S1486:
# Ttest_indResult(statistic=-0.624375043749411, pvalue=0.5336180424864342)
# Test for TP53BP1-S1640:
# Ttest_indResult(statistic=0.8132255573416053, pvalue=0.4175871608022712)
# Test for TP53BP1-S1683:
# Ttest_indResult(statistic=4.066136647783265, pvalue=8.581541095546293e-05)
# Test for TP53BP1-S1691:
# Ttest_indResult(statistic=0.18262457201838275, pvalue=0.8555326450695402)
# Test for TP53BP1-S1706:
# Ttest_indResult(statistic=6.168517158673339, pvalue=2.0477792811110273e-08)
# Test for TP53BP1-S1763:
# Ttest_indResult(statistic=4.9505951084825925, pvalue=3.12019940885796e-06)
# Test for TP53BP1-S1764:
# Ttest_indResult(statistic=3.395190235043654, pvalue=0.000975106571108118)
# Test for TP53BP1-S213:
# Ttest_indResult(statistic=-0.3757973032990155, pvalue=0.7077784325406995)
# Test for TP53BP1-S227:
# Ttest_indResult(statistic=2.952758139141674, pvalue=0.0038938808108306697)
# Test for TP53BP1-S299:
# Ttest_indResult(statistic=1.4898512649372126, pvalue=0.13870429410476565)
# Test for TP53BP1-S315:
# Ttest_indResult(statistic=1.2659599853545778, pvalue=0.21011631311876647)
# Test for TP53BP1-S321:
# Ttest_indResult(statistic=1.4937699254441896, pvalue=0.14014986795140533)
# Test for TP53BP1-S335:
# Ttest_indResult(statistic=0.28334323208858203, pvalue=0.7775868808051892)
# Test for TP53BP1-S338:
# Ttest_indResult(statistic=-1.2915736876300368, pvalue=0.20027092210325695)
# Test for TP53BP1-S354:
# Ttest_indResult(statistic=-0.431099423033478, pvalue=0.6675701416901663)
# Test for TP53BP1-S365:
# Ttest_indResult(statistic=-0.5563594961795726, pvalue=0.5799359921186638)
# Test for TP53BP1-S371:
# Ttest_indResult(statistic=0.6625906102286228, pvalue=0.5087748867926212)
# Test for TP53BP1-S385:
# Ttest_indResult(statistic=-0.5472492549377597, pvalue=0.5851530111604097)
# Test for TP53BP1-S400:
# Ttest_indResult(statistic=2.8152277369931022, pvalue=0.006303991126761004)
# Test for TP53BP1-S403:
# Ttest_indResult(statistic=2.892265353978627, pvalue=0.0045962698149979685)
# Test for TP53BP1-S505:
# Ttest_indResult(statistic=0.1923281244091446, pvalue=0.8477876294944149)
# Test for TP53BP1-S512:
# Ttest_indResult(statistic=-0.5093601945819934, pvalue=0.6116809176659707)
# Test for TP53BP1-S525:
# Ttest_indResult(statistic=-2.1293991656953235, pvalue=0.03524748517520922)
# Test for TP53BP1-S528:
# Ttest_indResult(statistic=0.6215217624767705, pvalue=0.5355082396578681)
# Test for TP53BP1-S530:
# Ttest_indResult(statistic=0.260730037828018, pvalue=0.7947476004723528)
# Test for TP53BP1-S557:
# Ttest_indResult(statistic=-1.942043481980425, pvalue=0.054311316531636185)
# Test for TP53BP1-S571:
# Ttest_indResult(statistic=0.02354378030659731, pvalue=0.981275884276169)
# Test for TP53BP1-S585:
# Ttest_indResult(statistic=1.3983622914817986, pvalue=0.16446070480418926)
# Test for TP53BP1-S640:
# Ttest_indResult(statistic=-2.5873498136981037, pvalue=0.011171343523699218)
# Test for TP53BP1-S644:
# Ttest_indResult(statistic=-2.1153740229893874, pvalue=0.037014369410155165)
# Test for TP53BP1-S645:
# Ttest_indResult(statistic=-2.1997890693450888, pvalue=0.029875830600601592)
# Test for TP53BP1-S664:
# Ttest_indResult(statistic=-0.6971885342596462, pvalue=0.48701124562835885)
# Test for TP53BP1-S665:
# Ttest_indResult(statistic=-1.3594660458476124, pvalue=0.17650640124485256)
# Test for TP53BP1-S667:
# Ttest_indResult(statistic=-0.8773115156435889, pvalue=0.38204180845643654)
# Test for TP53BP1-S68:
# Ttest_indResult(statistic=0.990599427202295, pvalue=0.3246927892159859)
# Test for TP53BP1-S732:
# Ttest_indResult(statistic=-0.18886858428047765, pvalue=0.8504926345286443)
# Test for TP53BP1-S776:
# Ttest_indResult(statistic=2.3602152403836794, pvalue=0.019978765417670196)
# Test for TP53BP1-S789:
# Ttest_indResult(statistic=-1.8364391560730433, pvalue=0.06914904068913517)
# Test for TP53BP1-S791:
# Ttest_indResult(statistic=-0.5623442047723389, pvalue=0.5749760454577796)
# Test for TP53BP1-S814:
# Ttest_indResult(statistic=0.1463298295937624, pvalue=0.8840643608267621)
# Test for TP53BP1-S836:
# Ttest_indResult(statistic=2.1151683570248765, pvalue=0.036338719493198016)
# Test for TP53BP1-S839:
# Ttest_indResult(statistic=1.7321477284804867, pvalue=0.08799046591491774)
# Test for TP53BP1-S867:
# Ttest_indResult(statistic=4.867393433754865, pvalue=5.7819035391457175e-06)
# Test for TP53BP1-S998:
# Ttest_indResult(statistic=-3.0355920575624653, pvalue=0.0029749109124274312)
# Test for TP53BP1-T1061:
# Ttest_indResult(statistic=-0.25721323394108275, pvalue=0.7974239883567354)
# Test for TP53BP1-T1377:
# Ttest_indResult(statistic=-1.375614564102444, pvalue=0.1729295490680793)
# Test for TP53BP1-T1614:
# Ttest_indResult(statistic=-0.2546739423202329, pvalue=0.7996204105325446)
# Test for TP53BP1-T1643:
# Ttest_indResult(statistic=0.14456232492923285, pvalue=0.8852838160478358)
# Test for TP53BP1-T1645:
# Ttest_indResult(statistic=1.1851306662448484, pvalue=0.2397578164436118)
# Test for TP53BP1-T1653:
# Ttest_indResult(statistic=2.7823305842137405, pvalue=0.006220771282605373)
# Test for TP53BP1-T307:
# Ttest_indResult(statistic=1.6122565302784562, pvalue=0.1095114313227012)
# Test for TP53BP1-T326:
# Ttest_indResult(statistic=-1.1856559936469875, pvalue=0.23871535738763472)
# Test for TP53BP1-T339:
# Ttest_indResult(statistic=-1.425626401098552, pvalue=0.15718635410902065)
# Test for TP53BP1-T362:
# Ttest_indResult(statistic=0.6814222019034547, pvalue=0.4979185792364681)
# Test for TP53BP1-T387:
# Ttest_indResult(statistic=-0.6286512644076847, pvalue=0.5313461736344909)
# Test for TP53BP1-T675:
# Ttest_indResult(statistic=-1.0571379660466373, pvalue=0.293711748492244)
# Test for TP53BP1-T927:
# Ttest_indResult(statistic=1.3180669898847681, pvalue=0.19055383610791715)
# Test for TP53BP2-S367:
# Ttest_indResult(statistic=-0.3388010676976071, pvalue=0.7355666912697201)
# Test for TP53BP2-S486:
# Ttest_indResult(statistic=0.5118488755062269, pvalue=0.6100686515035969)
# Test for TP53BP2-S487:
# Ttest_indResult(statistic=-0.9646577652794096, pvalue=0.33702032274790084)
# Test for TP53BP2-S564:
# Ttest_indResult(statistic=-2.1986596475589266, pvalue=0.029977018414588556)
# Test for TP53BP2-S575:
# Ttest_indResult(statistic=-2.1791918958777052, pvalue=0.03135675193159457)
# Test for TP53BP2-S582:
# Ttest_indResult(statistic=0.5352076631139698, pvalue=0.5935579770780117)
# Test for TP53BP2-S679:
# Ttest_indResult(statistic=0.33295677835496534, pvalue=0.7397893560033708)
# Test for TP53BP2-S704:
# Ttest_indResult(statistic=-0.41969977147077525, pvalue=0.675642566722688)
# Test for TP53BP2-S720:
# Ttest_indResult(statistic=0.1149991771334439, pvalue=0.9086675133746415)
# Test for TP53BP2-S743:
# Ttest_indResult(statistic=-1.2494905064274207, pvalue=0.21374803542009707)
# Test for TP53BP2-S789:
# Ttest_indResult(statistic=-0.41607849454094586, pvalue=0.6783009936223782)
# Test for TP53BP2-T745:
# Ttest_indResult(statistic=-0.05347432135201704, pvalue=0.9574565744304951)
# Test for WWOX-S14:
# Ttest_indResult(statistic=0.8806812477750805, pvalue=0.38014096507445416)
# Test for WWOX-T12:
# Ttest_indResult(statistic=0.24759158403174514, pvalue=0.8048471440917518)
# Test for USP7-S18:
# Ttest_indResult(statistic=1.0666459643817756, pvalue=0.2885103675332649)
# Test for USP7-S963:
# Ttest_indResult(statistic=-0.2501691530986228, pvalue=0.8032336196452751)
# Test for HSP90AB1-S226:
# Ttest_indResult(statistic=3.916793403740175, pvalue=0.00014470172438066657)
# Test for HSP90AB1-S255:
# Ttest_indResult(statistic=5.173190674082099, pvalue=8.566835587079394e-07)
# Test for HSP90AB1-S261:
# Ttest_indResult(statistic=3.9556285365046655, pvalue=0.0001252576661745065)
# Test for HSP90AB1-S445:
# Ttest_indResult(statistic=3.5946166836502997, pvalue=0.0006102364761412454)
# Test for HSP90AB1-S587:
# Ttest_indResult(statistic=-0.30184262548253105, pvalue=0.7635964640619638)
# Test for CHD8-S1420:
# Ttest_indResult(statistic=2.8987886571194164, pvalue=0.004461561565164313)
# Test for CHD8-S1424:
# Ttest_indResult(statistic=1.025609550259609, pvalue=0.30700997956081044)
# Test for CHD8-S1995:
# Ttest_indResult(statistic=2.8043804820720077, pvalue=0.005944512294645707)
# Test for CHD8-S2008:
# Ttest_indResult(statistic=2.496231717827037, pvalue=0.013909205972584203)
# Test for CHD8-S2046:
# Ttest_indResult(statistic=-0.8761833241059903, pvalue=0.38255902095260885)
# Test for CHD8-S2069:
# Ttest_indResult(statistic=0.3039507944194008, pvalue=0.7618995762021393)
# Test for CHD8-S2071:
# Ttest_indResult(statistic=0.5168873502617567, pvalue=0.6070447100115245)
# Test for CHD8-S549:
# Ttest_indResult(statistic=2.1984012250588827, pvalue=0.03132721615586226)
# Test for CHD8-S550:
# Ttest_indResult(statistic=1.3327938194182045, pvalue=0.18530448555780316)
# Test for CHD8-S553:
# Ttest_indResult(statistic=1.0572795155868737, pvalue=0.2926591573922532)
# Test for CHD8-S562:
# Ttest_indResult(statistic=3.066116565455308, pvalue=0.0029907031414937303)
# Test for CHD8-T1982:
# Ttest_indResult(statistic=2.423423952312144, pvalue=0.018001936962920687)
# Test for CHD8-T278:
# Ttest_indResult(statistic=-0.08202950788332414, pvalue=0.9348333825321777)
# Test for ARMC10-S45:
# Ttest_indResult(statistic=1.7556957515167266, pvalue=0.0835148985204187)
# Test for BANP-S100:
# Ttest_indResult(statistic=-1.5436316536449142, pvalue=0.12571508106220683)
# Test for BANP-S90:
# Ttest_indResult(statistic=-1.4884154225780588, pvalue=0.13969674287970638)
# Test for CDKN2AIP-S131:
# Ttest_indResult(statistic=-3.563013778743383, pvalue=0.000617782087391446)
# Test for CDKN2AIP-S133:
# Ttest_indResult(statistic=-0.6249530568605464, pvalue=0.5340631936426233)
# Test for CDKN2AIP-S201:
# Ttest_indResult(statistic=-2.137424620073379, pvalue=0.035435792680462944)
# Test for CDKN2AIP-S415:
# Ttest_indResult(statistic=-0.19951038686695713, pvalue=0.8424259020387378)
# Test for NUAK1-S445:
# Ttest_indResult(statistic=-0.332458395255354, pvalue=0.740352153626411)
# Test for STK11IP-S387:
# Ttest_indResult(statistic=1.301685091132312, pvalue=0.19551739538523555)
# Test for STK11IP-S599:
# Ttest_indResult(statistic=-2.173419427438294, pvalue=0.03246582882910094)
# Test for STK11IP-S761:
# Ttest_indResult(statistic=0.10770405375290648, pvalue=0.9144149312769059)
# Test for UHRF2-S667:
# Ttest_indResult(statistic=-1.2597949907263237, pvalue=0.21016778189939914)
# Test for YWHAZ-S110:
# Ttest_indResult(statistic=0.36565386802470656, pvalue=0.715613147810781)
# Test for YWHAZ-S114:
# Ttest_indResult(statistic=1.9195414108957558, pvalue=0.05905162338326308)
# Test for YWHAZ-S207:
# Ttest_indResult(statistic=-0.5558531888419378, pvalue=0.5793548159087261)
# Test for YWHAZ-S64:
# Ttest_indResult(statistic=1.3323861551960414, pvalue=0.18699402308676402)
# Test for YWHAZ-T232:
# Ttest_indResult(statistic=1.7328306500768471, pvalue=0.08765893075709667)
# Test for MAML1-S314:
# Ttest_indResult(statistic=-1.986029141631156, pvalue=0.04916667167417739)
# Test for MAML1-S360:
# Ttest_indResult(statistic=1.437923764228991, pvalue=0.15370754863287356)
# Test for MAML1-S45:
# Ttest_indResult(statistic=-2.3038472196648714, pvalue=0.023076028378069706)
# Test for MAML1-S529:
# Ttest_indResult(statistic=0.4790775419862105, pvalue=0.6330718076836868)
# Test for PML-S30:
# Ttest_indResult(statistic=1.1033719510214484, pvalue=0.272774954143923)
# Test for PML-S36:
# Ttest_indResult(statistic=-0.4265048993307076, pvalue=0.6706215157946906)
# Test for PML-S38:
# Ttest_indResult(statistic=0.9127532159280792, pvalue=0.36320248895904816)
# Test for PML-S40:
# Ttest_indResult(statistic=-0.11109640058300935, pvalue=0.9117125698654818)
# Test for PML-S403:
# Ttest_indResult(statistic=0.3277695971104212, pvalue=0.7436172329207942)
# Test for PML-S408:
# Ttest_indResult(statistic=-0.7164659668839843, pvalue=0.4751949945094026)
# Test for PML-S463:
# Ttest_indResult(statistic=-0.9836235780310604, pvalue=0.32830353931728107)
# Test for PML-S480:
# Ttest_indResult(statistic=0.011178081647970375, pvalue=0.9910987704404217)
# Test for PML-S493:
# Ttest_indResult(statistic=-1.620733419001731, pvalue=0.10788695941749599)
# Test for PML-S504:
# Ttest_indResult(statistic=1.982024859450696, pvalue=0.04960202451343888)
# Test for PML-S505:
# Ttest_indResult(statistic=1.2257377855844789, pvalue=0.22253039747210623)
# Test for PML-S512:
# Ttest_indResult(statistic=0.6663699816528318, pvalue=0.5063646390687144)
# Test for PML-S518:
# Ttest_indResult(statistic=0.3096338578234942, pvalue=0.7573390068689855)
# Test for PML-S527:
# Ttest_indResult(statistic=1.2759237263187622, pvalue=0.20427509105212827)
# Test for PML-S530:
# Ttest_indResult(statistic=-1.850066599123386, pvalue=0.0666099733849738)
# Test for PML-S535:
# Ttest_indResult(statistic=-0.3097355367762628, pvalue=0.7572992948129462)
# Test for PML-S542:
# Ttest_indResult(statistic=0.2546162791703066, pvalue=0.79977680490274)
# Test for PML-S565:
# Ttest_indResult(statistic=-1.9475415295382923, pvalue=0.053805507255704654)
# Test for PML-S579:
# Ttest_indResult(statistic=1.8514629889858687, pvalue=0.0674568654945293)
# Test for PML-S580:
# Ttest_indResult(statistic=1.5875207877898863, pvalue=0.1154305164664479)
# Test for PML-S583:
# Ttest_indResult(statistic=0.028484340996231417, pvalue=0.9773396324107466)
# Test for PML-S8:
# Ttest_indResult(statistic=-0.23331457272370898, pvalue=0.8160715862357452)
# Test for PML-T22:
# Ttest_indResult(statistic=1.145876027744663, pvalue=0.25452769919673435)
# Test for PML-T28:
# Ttest_indResult(statistic=0.6212209791181955, pvalue=0.5364720071399762)
# Test for PML-T409:
# Ttest_indResult(statistic=-1.0421463389357914, pvalue=0.29929298790576025)
# Test for PML-T42:
# Ttest_indResult(statistic=1.3601846025469178, pvalue=0.17614373025077135)
# Test for PML-T513:
# Ttest_indResult(statistic=-0.9628163254376617, pvalue=0.3378730557133629)
# Test for FBXO42-S370:
# Ttest_indResult(statistic=-0.1659674703621637, pvalue=0.868535252574153)
# Test for FBXO42-S373:
# Ttest_indResult(statistic=-0.47280178918268895, pvalue=0.6373849233033193)
# Test for FBXO42-S488:
# Ttest_indResult(statistic=-1.6844161880405306, pvalue=0.09481350336773811)
# Test for FBXO42-S552:
# Ttest_indResult(statistic=-2.2764803642316553, pvalue=0.025878330690201713)
# Test for FBXO42-S587:
# Ttest_indResult(statistic=-2.72204253314338, pvalue=0.00788719011509179)
# Test for FBXO42-T539:
# Ttest_indResult(statistic=-2.2764803642316553, pvalue=0.025878330690201713)
# Test for ATM-S1981:
# Ttest_indResult(statistic=-0.2718505817740406, pvalue=0.7865371052901633)
# Test for ATM-T1885:
# Ttest_indResult(statistic=0.10472089634269192, pvalue=0.9168383327150235)
# Test for DAXX-S507:
# Ttest_indResult(statistic=-0.8442555866898322, pvalue=0.4001926942990123)
# Test for DAXX-S680:
# Ttest_indResult(statistic=-2.1130745877003223, pvalue=0.03666628613734984)
# Test for DAXX-S683:
# Ttest_indResult(statistic=-1.7410511974536298, pvalue=0.08407738318313543)
# Test for DAXX-S700:
# Ttest_indResult(statistic=0.5464985358418244, pvalue=0.5859781959634727)
# Test for DAXX-S702:
# Ttest_indResult(statistic=0.9517454582232293, pvalue=0.3439246311195744)
# Test for DAXX-S714:
# Ttest_indResult(statistic=0.47929948517660975, pvalue=0.6329421601898422)
# Test for BRD7-S622:
# Ttest_indResult(statistic=-0.3532671266589337, pvalue=0.7247526653862275)
# Test for TRIM24-S1025:
# Ttest_indResult(statistic=2.0927680048167048, pvalue=0.038329116423488754)
# Test for TRIM24-S1028:
# Ttest_indResult(statistic=1.9555708188778056, pvalue=0.052677387530681304)
# Test for TRIM24-S687:
# Ttest_indResult(statistic=-0.014063377549880981, pvalue=0.9888188615505149)
# Test for TRIM24-S744:
# Ttest_indResult(statistic=1.790680145129165, pvalue=0.07712743995774833)
# Test for TRIM24-S811:
# Ttest_indResult(statistic=0.7072632125120499, pvalue=0.4806786530301541)
# Test for PTK2B-S375:
# Ttest_indResult(statistic=0.6489811476936164, pvalue=0.5176791317663272)
# Test for KAT6A-S1001:
# Ttest_indResult(statistic=-1.328099177827674, pvalue=0.1867982288417645)
# Test for KAT6A-S1089:
# Ttest_indResult(statistic=0.4779839907509832, pvalue=0.6336015929762361)
# Test for KAT6A-S1090:
# Ttest_indResult(statistic=-0.5522849713454062, pvalue=0.5823322519244458)
# Test for KAT6A-S1113:
# Ttest_indResult(statistic=-1.6751360825307076, pvalue=0.09818643787813651)
# Test for KAT6A-S448:
# Ttest_indResult(statistic=0.4976320473997191, pvalue=0.6197190335943408)
# Test for KAT6A-S450:
# Ttest_indResult(statistic=-0.43476838345252145, pvalue=0.6647829315816456)
# Test for KAT6A-S941:
# Ttest_indResult(statistic=-0.6689806881824355, pvalue=0.5052791300938579)
# Test for ZNF385A-S162:
# Ttest_indResult(statistic=-0.026215853496177388, pvalue=0.9791529952398776)
# Test for ANKRD26-S530:
# Ttest_indResult(statistic=1.1556592585524714, pvalue=0.25087934793397476)
# Test for ANKRD26-S631:
# Ttest_indResult(statistic=-2.8471236889147784, pvalue=0.005573047769750765)
# Test for ANKRD27-S418:
# Ttest_indResult(statistic=1.111046817871962, pvalue=0.2695075929080992)
# Test for ANKRD27-T1023:
# Ttest_indResult(statistic=-1.0061275412853925, pvalue=0.3179211048118296)
# Test for RFFL-S226:
# Ttest_indResult(statistic=1.700529239246963, pvalue=0.09175791826312522)
# Test for RFFL-S229:
# Ttest_indResult(statistic=1.2978739539606003, pvalue=0.19677911917063354)
# Test for RFFL-S240:
# Ttest_indResult(statistic=-0.9044530703726769, pvalue=0.3680674293326186)
# Test for RFFL-S39:
# Ttest_indResult(statistic=-0.5649644933158162, pvalue=0.5738540601431896)
# Test for RNF34-S255:
# Ttest_indResult(statistic=-1.8560017932527875, pvalue=0.06634010514729914)
# Test for MTA1-S386:
# Ttest_indResult(statistic=-1.341969584690773, pvalue=0.1836014359776394)
# Test for MTA1-S449:
# Ttest_indResult(statistic=-1.2698209643162803, pvalue=0.20675713502093682)
# Test for MTA1-S522:
# Ttest_indResult(statistic=-1.2754865774778381, pvalue=0.2055323493166315)
# Test for MTA1-S576:
# Ttest_indResult(statistic=0.38588001659291093, pvalue=0.700286288459318)
# Test for MTA1-T564:
# Ttest_indResult(statistic=2.7930580502228146, pvalue=0.006496677914505765)
# Test for CCAR2-S124:
# Ttest_indResult(statistic=-2.031894254983794, pvalue=0.04423394134657837)
# Test for CCAR2-S569:
# Ttest_indResult(statistic=-1.7872586841145373, pvalue=0.07624386625249407)
# Test for CCAR2-S626:
# Ttest_indResult(statistic=-0.6759096246107313, pvalue=0.5003079709406126)
# Test for CCAR2-S627:
# Ttest_indResult(statistic=0.47129609376702875, pvalue=0.6382253796874768)
# Test for CCAR2-S675:
# Ttest_indResult(statistic=-2.307941027548082, pvalue=0.022594247085845447)
# Test for CCAR2-S678:
# Ttest_indResult(statistic=-1.3528729179032275, pvalue=0.17846259979245566)
# Test for CCAR2-S681:
# Ttest_indResult(statistic=-1.7980478346123792, pvalue=0.07450817810659612)
# Test for CCAR2-S687:
# Ttest_indResult(statistic=1.0138491712598803, pvalue=0.312941822066279)
# Test for CCAR2-T35:
# Ttest_indResult(statistic=0.4235796829297786, pvalue=0.6731710856796737)
# Test for CCAR2-T454:
# Ttest_indResult(statistic=1.0549222041918718, pvalue=0.2947597683418977)
# Test for CCAR2-T484:
# Ttest_indResult(statistic=0.6238170379141807, pvalue=0.5341403719596733)
# Test for MORC3-S514:
# Ttest_indResult(statistic=-0.6891343756851287, pvalue=0.49217672509430943)
# Test for MORC3-S560:
# Ttest_indResult(statistic=-1.2545207833393526, pvalue=0.21224144909009815)
# Test for MORC3-S765:
# Ttest_indResult(statistic=1.443710618452479, pvalue=0.1533455862592123)
# Test for TAF6-S569:
# Ttest_indResult(statistic=0.11949528071116394, pvalue=0.9051863366019767)
# Test for TAF6-S663:
# Ttest_indResult(statistic=1.8189600565386241, pvalue=0.07143201726571012)
# Test for TAF6-S670:
# Ttest_indResult(statistic=-0.46817403731627955, pvalue=0.6410942104642054)
# Test for TAF6-S671:
# Ttest_indResult(statistic=1.5587401559099983, pvalue=0.12234858599042588)
# Test for TAF6-S673:
# Ttest_indResult(statistic=2.8011670594529265, pvalue=0.0060085487636661545)
# Test for TAF6-S690:
# Ttest_indResult(statistic=1.267266161653085, pvalue=0.2075139313071103)
# Test for TAF6-T697:
# Ttest_indResult(statistic=-0.15061441785192234, pvalue=0.8805744537134752)
# Test for FAS-T214:
# Ttest_indResult(statistic=-1.393462908340169, pvalue=0.16720017883055768)
# Test for FASN-S1174:
# Ttest_indResult(statistic=0.6275726544660387, pvalue=0.5321650209021511)
# Test for FASN-S207:
# Ttest_indResult(statistic=2.560283041564289, pvalue=0.011895173394646453)
# Test for FASN-S2198:
# Ttest_indResult(statistic=0.7853604436628631, pvalue=0.4345620431869067)
# Test for FASN-T2204:
# Ttest_indResult(statistic=1.77217764298928, pvalue=0.07941066199074144)
# Test for BCL2L11-S104:
# Ttest_indResult(statistic=1.586192747919616, pvalue=0.11770260322960407)
# Test for BCL2L11-S77:
# Ttest_indResult(statistic=-0.2725024377006913, pvalue=0.7859558161719036)
# Test for BCL2L11-Y96:
# Ttest_indResult(statistic=1.7886541976980486, pvalue=0.07799731835256912)
# Test for BCL2L12-S195:
# Ttest_indResult(statistic=0.18845402095070674, pvalue=0.8510739264391884)
# Test for BCL2L12-S242:
# Ttest_indResult(statistic=1.24278080394135, pvalue=0.2164766394486541)
# Test for BCL2L12-S273:
# Ttest_indResult(statistic=2.902589358247638, pvalue=0.004544501658568895)
# Test for BCL2L13-S315:
# Ttest_indResult(statistic=1.4723499282272101, pvalue=0.14375619986354063)
# Test for BCL2L13-S327:
# Ttest_indResult(statistic=1.5481990976395976, pvalue=0.1260838885516715)
# Test for BCL2L13-S329:
# Ttest_indResult(statistic=1.023495353844786, pvalue=0.3084715222597549)
# Test for BCL2L13-S395:
# Ttest_indResult(statistic=1.2249337757297434, pvalue=0.22308173729814615)
# Test for BCL2L13-S444:
# Ttest_indResult(statistic=2.666169160701655, pvalue=0.008862211537789514)
# Test for BCL2L13-S450:
# Ttest_indResult(statistic=0.651025339357946, pvalue=0.516351817580686)
# Test for BCL2L13-S468:
# Ttest_indResult(statistic=0.0668505444234812, pvalue=0.946818821558082)
# Test for CREBBP-S1076:
# Ttest_indResult(statistic=-0.1317756381729848, pvalue=0.8955193866080194)
# Test for CREBBP-S121:
# Ttest_indResult(statistic=-2.0652349220072708, pvalue=0.04090340760497404)
# Test for CREBBP-S2063:
# Ttest_indResult(statistic=-1.856810027708225, pvalue=0.06643689510438655)
# Test for CREBBP-S274:
# Ttest_indResult(statistic=-0.8616652865224343, pvalue=0.39121363188429026)
# Test for CREBBP-T1075:
# Ttest_indResult(statistic=0.9963056981787828, pvalue=0.3228537191878599)
# Test for CREBBP-T974:
# Ttest_indResult(statistic=-3.4603126370611945, pvalue=0.0009048741243595442)
# Test for CDKN2AIP-S131:
# Ttest_indResult(statistic=-3.563013778743383, pvalue=0.000617782087391446)
# Test for CDKN2AIP-S133:
# Ttest_indResult(statistic=-0.6249530568605464, pvalue=0.5340631936426233)
# Test for CDKN2AIP-S201:
# Ttest_indResult(statistic=-2.137424620073379, pvalue=0.035435792680462944)
# Test for CDKN2AIP-S415:
# Ttest_indResult(statistic=-0.19951038686695713, pvalue=0.8424259020387378)
# Test for CDKN1A-S164:
# Ttest_indResult(statistic=0.714113618334854, pvalue=0.4772615936423258)
# Test for ATM-S1981:
# Ttest_indResult(statistic=-0.2718505817740406, pvalue=0.7865371052901633)
# Test for ATM-T1885:
# Ttest_indResult(statistic=0.10472089634269192, pvalue=0.9168383327150235)
# Test for MDM4-S342:
# Ttest_indResult(statistic=-1.755117001740668, pvalue=0.08410081698153782)

# %% [markdown]
# ### List of significantly affected phosphorylation sites

# %%
print(sigPhosResults)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-eee2ad86a4c9> in <module>()
# ----> 1 print(sigPhosResults)
#
# NameError: name 'sigPhosResults' is not defined
