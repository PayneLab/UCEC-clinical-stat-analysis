# %%
import pandas as pd
import numpy as np
import scipy.stats
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import re 
#import altair as alt

#alt.renderers.enable('notebook')

# %% [markdown]
# Import CPTAC data

# %%
import CPTAC

# %%
somatic_mutations = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

print(proteomics.iloc[90:110])
# Out:
# idx     A1BG     A2M   A2ML1  A4GALT    AAAS    AACS    AADAT   AAED1   AAGAB  \
# S091 -0.6360 -0.3710  0.9730     NaN  0.6370 -0.1660 -0.12200  0.2320  0.3790
# S092  0.0308 -0.1420     NaN     NaN  0.2110  0.9270  0.49200 -0.4160  0.4000
# S093 -0.7430 -1.3700     NaN     NaN -0.1930  0.6940  0.33800  0.0989 -0.0137
# S094 -0.2950 -0.0589  0.4900 -0.1090 -0.0495  0.0374  0.10200 -0.3210  0.1830
# S095 -1.3000 -1.2900  0.3040     NaN -0.1610 -0.3390 -0.08490 -0.0563 -0.4790
# S096 -0.6700 -1.1100  2.1900 -1.0700  0.3440 -0.1730      NaN -0.6540  0.3860
# S097  0.6870  1.4400 -0.2260  0.2400  0.2790 -0.0530 -0.59300     NaN -0.3120
# S098 -0.2690  0.9440  1.2000 -0.1550  0.2660 -0.5480 -0.10500     NaN  0.4010
# S099 -1.0700 -0.7120  0.0462 -0.0471  0.2270  1.3500  1.21000  0.0048  0.6820
# S100 -1.2800 -0.7360 -0.5520  0.1140  0.2730  1.0700  0.85000     NaN -0.5360
# S101 -0.2900 -0.3200  3.1700 -0.9070  0.0317 -0.0425      NaN -0.2730 -0.0747
# S102  0.2660  1.3900 -0.0655  0.4700  0.3980 -0.1340  0.46100  1.0400  0.3630
# S103  0.6920  0.5890  0.5870     NaN -0.0835  0.1720 -0.21500  0.0140 -0.1460
# S104  0.8030  0.7310 -0.3270 -0.3660 -0.4210 -0.2080 -0.41900  0.0749 -0.1080
# S105  1.7000  1.4200  0.4440  0.3980 -0.0394 -0.6040 -0.19500  0.2090 -0.5550
# S106  0.1090 -0.5790  0.2260     NaN -0.1350 -0.3630 -0.10400  0.3280 -1.1100
# S107  0.4370  0.4560     NaN     NaN -0.0377 -0.7200  0.02180  0.4880 -0.4690
# S108  0.9370  0.2830     NaN     NaN  0.1950 -0.7980  0.00836  1.2700 -0.8500
# S109  0.5810 -0.7840  0.4180 -0.1230 -0.2490 -0.8450 -0.12100  0.3520 -0.4820
# S110  0.8860  0.8540     NaN     NaN -0.5170 -0.8410 -0.14100  0.8110 -0.1790
#
# idx     AAK1   ...     ZSWIM8  ZSWIM9     ZW10  ZWILCH   ZWINT   ZXDC  ZYG11B  \
# S091 -0.1950   ...    -0.4160 -0.7510  0.17900   0.658  0.4700  0.270 -0.1480
# S092 -0.2520   ...     0.0406     NaN  0.09240   0.121  0.4330 -1.050 -0.3160
# S093 -0.0570   ...     0.1810     NaN  0.19600   0.274     NaN -0.501 -0.0468
# S094 -0.1620   ...    -0.2900  0.0457  0.24600   0.589  0.3930 -0.199 -0.1590
# S095  0.3500   ...     0.0689 -0.5670  0.23500  -0.903 -0.7930  0.178 -0.1330
# S096  0.2770   ...    -0.1200  0.1050  0.27700   0.601  1.0700  0.637  0.5370
# S097  0.1590   ...    -0.1370     NaN -0.80300   0.650  0.4120 -0.230  0.1530
# S098 -0.0773   ...    -0.2040     NaN -0.58300   0.913  0.2490 -0.515 -0.1510
# S099 -0.2240   ...    -0.0699 -0.4010  0.55700   0.827  0.3480 -0.187 -0.1070
# S100 -0.2660   ...     0.1310     NaN -0.00364   0.763  0.0784 -0.203  0.0132
# S101  0.1240   ...    -0.1790 -0.5210  0.05230   0.515  0.5850  0.138 -0.1900
# S102  0.0940   ...    -0.1400     NaN -0.01220   0.250  0.5530  0.387  0.0642
# S103  0.8570   ...    -0.0225  0.2980 -0.12400   0.178  0.1470 -0.114  0.1370
# S104  0.9720   ...     0.2140     NaN -0.29600  -0.418  1.0600 -0.111  0.4280
# S105  0.1790   ...    -0.2520     NaN -0.29700  -0.130     NaN  0.721  0.3090
# S106  0.5550   ...     0.0236  0.2830 -0.13500   0.189     NaN  0.340  0.2750
# S107  0.6180   ...     0.0162     NaN -0.28100  -0.551 -0.2960  0.258  0.3460
# S108  0.2400   ...    -0.0741     NaN -0.35200  -0.499 -0.0512  0.562  0.3140
# S109  0.3270   ...     0.1450     NaN -0.28300  -0.454     NaN  0.557  0.1860
# S110  0.7850   ...     0.2270     NaN -0.31800  -0.587     NaN -0.391  0.4260
#
# idx      ZYX    ZZEF1     ZZZ3
# S091 -0.1390 -0.02990  0.13100
# S092 -0.4000  0.12300 -0.39100
# S093  0.6530 -0.04640 -0.16000
# S094 -1.0900  0.06270 -0.37900
# S095  0.3470 -0.14100 -0.05950
# S096 -0.3380 -0.21400 -0.07170
# S097 -0.0199  0.19200  0.27100
# S098 -1.3900 -0.12100 -0.42600
# S099 -0.8300  0.06200 -0.52800
# S100 -1.2000 -0.35700  0.02990
# S101 -0.9660 -0.00627 -0.24900
# S102 -0.4370  0.10400 -0.49800
# S103  1.2400  0.00682 -0.02330
# S104  2.2400  0.13700 -0.05430
# S105  1.0800 -0.13700  0.14400
# S106  1.8700  0.15300  0.47800
# S107  1.5700  0.13000  0.00555
# S108  1.2300 -0.02850  0.46100
# S109  1.5800 -0.15900  0.40000
# S110  2.3700  0.32400 -0.01810
#
# [20 rows x 10999 columns]

# %% [markdown]
# # Difference in protein abundance between mutated and non-mutated protein

# %%
protList = ['PTEN']
pcutoff = 0.05 / len(protList)
gene = 'PTEN'

proteomics = proteomics[:100]

sigResults = [];
for protein in protList: 
    if protein in proteomics.columns:
        cross = CPTAC.compare_mutations(proteomics, protein, gene)
        cross = cross[["Mutation", protein]].dropna(axis=0)
        mutated = cross.loc[cross["Mutation"] == "Missense_Mutation"]
        wt = cross.loc[cross["Mutation"] == "Wildtype"]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(ttest[1] <= pcutoff):
            sigResults.append(protein)
            print("Test for " + protein + ": ")
            print(ttest) 
#print(cross)

# %% [markdown]
# <b> Plot the data </b>

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
somatic_boxplot = sns.boxplot(data=cross, x="Mutation",y=protein, ax = ax)
somatic_boxplot.set_title("PTEN gene mutation PTEN protein abundance")
somatic_boxplot = sns.stripplot(data=cross, x="Mutation", y=protein,jitter=True, color=".3")
somatic_boxplot.set(xlabel="Somatic Gene Mutation",ylabel="Proteomics")
plt.show()

# %% [markdown]
# # Difference in phosphoproteomics between mutated and non-mutated protein

# %%
sites = phos.columns
p_values = []
site_names = []
protein = 'PTEN'

pcutoff = 0.05/len(phos.columns)

pattern = re.compile(protein)
isInList = filter(pattern.search, sites)
if next(isInList, None) is not None:
    phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
    print(phosphositesdf.iloc[90:110])
    phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis = 1)
    for site in phosphositesdf.columns:
        if (site is not 'Mutation'):
            sitedf = CPTAC.compare_mutations(phos, site, gene)
            mutateddf = sitedf.loc[sitedf['Mutation'] != 'Wildtype'].dropna(axis=0)
            wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
            ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
            if ttest[1] < pcutoff:
                p_values.append(ttest[1])
                print(site, p_values)
                site_names.append(site)     
                
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

#pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1] 
#print("Adjusted p values: " + str(pvalues))
#areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]


#significant_sites = np.array(site_names)[np.array(areSignificant)]
#significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

#significant_vals = dict(zip(significant_sites, significant_pvalues))

#print(significant_sites)
#print(significant_pvalues)
#print(significant_vals)
# Out:
#       PTEN-S467  PTEN-S475  PTEN-S478  PTEN-S537  PTEN-S543  PTEN-S558  \
# S091   -0.53100        NaN        NaN        NaN        NaN    0.42200
# S092   -0.28500    0.07300     0.4310        NaN        NaN    0.01400
# S093   -0.80600        NaN        NaN        NaN        NaN    0.50850
# S094    0.33800        NaN        NaN        NaN        NaN    1.86000
# S095   -1.32000        NaN        NaN        NaN        NaN    0.71700
# S096    0.47900        NaN        NaN        NaN    -0.1080   -0.35400
# S097   -0.34800        NaN        NaN    -0.0206    -0.2023   -0.70100
# S098   -0.09180        NaN        NaN    -0.0430    -0.0215   -1.08000
# S099   -1.04000        NaN        NaN        NaN        NaN   -0.11350
# S100   -0.08900        NaN        NaN     0.7640     0.7265    1.40000
# S101    0.16000        NaN        NaN        NaN     0.8980    0.99100
# S102   -0.44450    0.68100        NaN        NaN     0.0000   -0.23600
# S103    0.58400        NaN        NaN        NaN        NaN    1.39000
# S104    0.09735    0.06570        NaN        NaN     0.4340    0.30800
# S105   -0.07410   -0.08565    -0.1110        NaN        NaN   -0.68635
# S106   -0.98000        NaN        NaN        NaN        NaN   -0.39350
# S107   -0.03050   -0.21225    -0.3940        NaN        NaN    0.01350
# S108    0.03760    0.02208     0.0376        NaN        NaN   -0.36700
# S109   -0.20950   -0.20950    -0.3060        NaN        NaN   -0.70700
# S110    0.03670        NaN        NaN        NaN        NaN    0.00850
#
#       PTEN-T539  PTEN-T555  PTEN-T556           Mutation Patient_Type
# S091        NaN        NaN    0.42200  Nonsense_Mutation        Tumor
# S092    -0.7630        NaN   -0.07000  Nonsense_Mutation        Tumor
# S093        NaN        NaN    0.83600    Frame_Shift_Del        Tumor
# S094        NaN        NaN    1.33000  Missense_Mutation        Tumor
# S095        NaN        NaN    0.71700  Nonsense_Mutation        Tumor
# S096        NaN        NaN   -0.35400           Wildtype        Tumor
# S097    -0.2023        NaN   -0.92600  Nonsense_Mutation        Tumor
# S098    -0.0215        NaN   -1.39000  Nonsense_Mutation        Tumor
# S099        NaN        NaN   -0.22700    Frame_Shift_Ins        Tumor
# S100     0.7265        NaN    1.35000           Wildtype        Tumor
# S101        NaN        NaN    0.99100           Wildtype       Normal
# S102        NaN        NaN   -0.06500           Wildtype       Normal
# S103        NaN        NaN    1.39000           Wildtype       Normal
# S104        NaN        NaN    0.49950           Wildtype       Normal
# S105        NaN        NaN        NaN           Wildtype       Normal
# S106        NaN        NaN   -0.26500           Wildtype       Normal
# S107    -0.5130        NaN    0.33475           Wildtype       Normal
# S108    -1.7900        NaN   -0.32900           Wildtype       Normal
# S109        NaN        NaN        NaN           Wildtype       Normal
# S110        NaN        NaN    0.37600           Wildtype       Normal

# %% [markdown]
# <b> Plot the data </b>

# %%
somatic_boxplot = sns.boxplot(data=cross, x=gene ,y=sigResults[0])
somatic_boxplot.set_title(gene + " gene mutation and " + sigResults[0] + " phosphorylation levels")
somatic_boxplot = sns.stripplot(data=cross, x=gene, y=sigResults[0],jitter=True, color=".3")
somatic_boxplot.set(xlabel="Somatic Gene Mutation",ylabel="Phosphoproteomics")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-e84b6796a119> in <module>
# ----> 1 somatic_boxplot = sns.boxplot(data=cross, x=gene ,y=sigResults[0])
#       2 somatic_boxplot.set_title(gene + " gene mutation and " + sigResults[0] + " phosphorylation levels")
#       3 somatic_boxplot = sns.stripplot(data=cross, x=gene, y=sigResults[0],jitter=True, color=".3")
#       4 somatic_boxplot.set(xlabel="Somatic Gene Mutation",ylabel="Phosphoproteomics")
#
# IndexError: list index out of range

# %% [markdown]
# ## Patients who have a mutation on PTEN

# %%
p10_mutations = somatic_mutations.loc[somatic_mutations['Gene'] == 'PTEN']
mutated = p10_mutations.loc[p10_mutations['Mutation'] != 'Wildtype']
mutated_patients = p10_mutations['Patient_Id']
mutated_list = mutated_patients.tolist()

#get the number of unique patients in the list
unique_list = list()
for person in mutated_list:
    if person not in unique_list:
        unique_list.append(person)
    


print(len(unique_list))
# Out:
# 78

# %% [markdown]
# ## Patients who have both PTEN and PIK3CA mutations

# %%
#create a dataframe with both mutations included 

mutation_1 = 'PIK3CA'
mutation_2 = 'PTEN'
common_mutated = somatic_mutations.loc[(somatic_mutations['Gene'] == mutation_1) | (somatic_mutations['Gene'] == mutation_2)]

mutations_first = somatic_mutations.loc[(somatic_mutations['Gene'] == mutation_1)]
print(mutations_first['Clinical_Patient_Key'])

patients_first = mutations_first['Patient_Id']
first_list = patients_first.tolist()
mutations_second = somatic_mutations.loc[somatic_mutations['Gene'] == mutation_2]
#print(mutations_second)
patients_second = mutations_second['Patient_Id']
second_list = patients_second.tolist()

#get the number of unique patients in the pik3ca mutation list
unique_1 = list()
for person in first_list:
    if person not in unique_1:
        unique_1.append(person)

#check for the overlaps 
common_list = list()
for person in second_list:
    if person in unique_1:
        if person not in common_list:
            common_list.append(person)

print(len(common_list))
print(common_list)
# Out:
# 160      S001
# 1147     S003
# 1426     S009
# 1574     S010
# 2260     S012
# 2261     S012
# 3417     S014
# 3418     S014
# 4648     S018
# 4756     S021
# 4757     S021
# 7216     S022
# 7217     S022
# 7218     S022
# 7219     S022
# 16613    S023
# 16614    S023
# 19188    S024
# 19290    S026
# 19525    S027
# 19526    S027
# 20178    S028
# 20505    S030
# 21286    S031
# 21386    S032
# 21643    S033
# 21849    S036
# 22656    S038
# 22746    S040
# 22747    S040
#          ...
# 37617    S061
# 37618    S061
# 38352    S063
# 38401    S064
# 38445    S065
# 39718    S066
# 39719    S066
# 43587    S067
# 43588    S067
# 43687    S068
# 44911    S070
# 44912    S070
# 45433    S074
# 45469    S075
# 45590    S077
# 46555    S081
# 46858    S084
# 46859    S084
# 47303    S086
# 47557    S088
# 48112    S089
# 48398    S090
# 48845    S092
# 49828    S095
# 49849    S096
# 49902    S097
# 49903    S097
# 50016    S098
# 50841    S099
# 53076      NA
# Name: Clinical_Patient_Key, Length: 64, dtype: object
# 41
# ['C3L-00006', 'C3L-00032', 'C3L-00143', 'C3L-00156', 'C3L-00161', 'C3L-00563', 'C3L-00586', 'C3L-00601', 'C3L-00605', 'C3L-00769', 'C3L-00770', 'C3L-00771', 'C3L-00781', 'C3L-00918', 'C3L-00921', 'C3L-00942', 'C3L-00961', 'C3L-01304', 'C3L-01311', 'C3N-00200', 'C3N-00321', 'C3N-00323', 'C3N-00324', 'C3N-00326', 'C3N-00328', 'C3N-00333', 'C3N-00334', 'C3N-00337', 'C3N-00379', 'C3N-00383', 'C3N-00388', 'C3N-00743', 'C3N-00848', 'C3N-00858', 'C3N-00880', 'C3N-01001', 'C3N-01212', 'C3N-01267', 'C3N-01349', 'C3N-01510', 'C3N-01520']

# %% [markdown]
# ## Get dataframe with patients who have both mutations

# %%
#common_mutations = common_mutated.loc[common_mutated['Patient_Id'] == common_list]
 #df[df['A'].isin([3, 6])]
common_mutated = common_mutated[common_mutated['Patient_Id'].isin(common_list)]
print(common_mutated)

# %%
# Out:
#       AKT1-S122  AKT1-S124  AKT1-S126  AKT1-S129  AKT1-T450  AKT1S1-S108  \
# S001        NaN   -0.04605   0.148100   -0.04605        NaN      0.08790
# S002   -0.25000   -0.26300  -0.121000   -0.18550   -0.00876      0.45250
# S003        NaN    0.21400   0.050500    0.03195        NaN          NaN
# S004        NaN   -0.36800   0.320000   -0.36800        NaN      0.34800
# S005        NaN   -0.00300  -0.028200    0.04540        NaN      0.78900
# S006        NaN   -0.18965  -0.039300   -0.07715   -0.30100      0.05250
# S007    0.21700    0.16500   0.228000    0.06200   -0.33000     -0.25150
# S008        NaN    0.08425  -0.020100    0.08425    0.35100      0.01410
# S009        NaN   -0.04670   0.575000   -0.05300        NaN      0.17800
# S010        NaN    0.09905   0.245000    0.22750   -0.28800     -0.39620
# S011        NaN   -0.16100  -0.298000    0.17900        NaN      0.15370
# S012        NaN   -0.08310  -0.134100   -0.17400    0.25800     -0.21500
# S013    0.03000   -0.40100  -0.397000   -0.40100        NaN      0.08420
# S014    0.10800    0.10800  -0.115500   -0.10700        NaN     -0.11000
# S015        NaN   -0.20500   0.242000   -0.20500        NaN     -0.06010
# S016        NaN   -0.39000  -0.063300   -0.43665        NaN     -0.15500
# S017        NaN   -0.80400  -0.016000    0.60200        NaN          NaN
# S018        NaN    0.08430   0.069650   -0.05770        NaN     -0.24500
# S019    0.13000   -0.13000  -0.127000   -0.13000        NaN      0.04850
# S020        NaN   -0.04770  -0.072985   -0.18850        NaN     -0.05700
# S021        NaN   -0.22400   0.054800    0.05480        NaN      0.08700
# S022        NaN   -0.14100  -0.141000   -0.14100        NaN      0.53900
# S023        NaN    0.02710  -0.253000    0.02710        NaN     -0.04200
# S024        NaN   -0.31000  -0.420000   -0.26300        NaN      0.26300
# S025        NaN   -0.37050  -0.507000   -0.20850        NaN      0.41800
# S026        NaN    0.16750   0.170500    0.05440        NaN     -0.04280
# S027        NaN   -0.96400  -0.594000   -0.78600        NaN      0.02950
# S028        NaN    0.05530   0.344000   -0.06020        NaN     -0.01050
# S029    0.05100   -0.17450  -0.001090   -0.32700        NaN     -0.53800
# S030    0.02260   -0.05170  -0.006780   -0.06639   -0.06480      0.72450
# ...         ...        ...        ...        ...        ...          ...
# S124        NaN    0.30850   0.289000    0.30950        NaN     -0.13200
# S125        NaN    0.42900   0.388000    0.09000        NaN          NaN
# S126        NaN   -0.27000   0.114000   -0.22400        NaN      0.13310
# S127        NaN    0.54000   0.591000    0.38900        NaN      0.03950
# S128   -0.10900    0.04290   0.063000    0.21000        NaN     -0.04300
# S129    0.16400    0.17900   0.220000    0.27600        NaN     -0.38200
# S130        NaN   -0.07790  -0.077900   -0.07790        NaN      0.14800
# S131        NaN    0.05800  -0.223000   -0.08315        NaN     -0.01400
# S132        NaN    0.50400  -0.880000    0.10000        NaN     -0.66100
# S133        NaN    0.08790   0.160000   -0.12400        NaN     -0.05280
# S134        NaN    0.69800   0.698000    0.60100        NaN      0.39550
# S135    0.15100    0.39800   0.188000    0.31150        NaN     -0.27700
# S136    0.15000    0.15000   0.087300    0.25000        NaN     -0.38100
# S137   -0.18600   -0.18600  -0.149500   -0.25800        NaN     -0.71200
# S138        NaN    0.15340   0.109000    0.17800   -0.20600     -0.18850
# S139        NaN    0.22350   0.041700    0.12750   -0.26000     -0.06270
# S140        NaN    0.19350   0.231500    0.28950    0.37200     -0.12800
# S141        NaN    0.43150   0.310000    0.38500    0.44600     -0.18000
# S142        NaN    0.25250   0.035500    0.29900    0.39000     -0.49800
# S143   -0.16200    0.34450   0.142000    0.23550    0.17800      0.25900
# S144    0.00423    0.37100   0.292000    0.36150    0.11300      0.23075
# S145    0.22500    0.36500   0.225000    0.47800        NaN      0.09630
# S146   -0.10800    0.18100   0.008600    0.14800        NaN      0.17900
# S147    0.03750    0.09225   0.037500    0.14700        NaN     -0.10500
# S148    0.07710    0.13700   0.292000    0.29200        NaN     -0.01510
# S149   -0.08870    0.31350   0.020000    0.34700        NaN      0.23500
# S150   -0.03430    0.21850   0.234000    0.23400        NaN     -0.08410
# S151   -0.07610    0.34700   0.310000    0.36500        NaN     -0.02500
# S152   -0.23700    0.24500  -0.127000    0.21900        NaN     -0.43800
# S153   -0.13000    0.42450   0.292000    0.43300        NaN     -0.02980
#
#       AKT1S1-S112  AKT1S1-S203  AKT1S1-S222  AKT1S1-S223     ...       \
# S001      0.08790      -0.8580      0.56200     0.260000     ...
# S002      0.40700       3.4400     -0.16950    -0.169500     ...
# S003          NaN          NaN      0.68100     0.128000     ...
# S004     -0.13150      -0.4470      0.57100     0.234000     ...
# S005      0.63500       1.2400      0.28500     0.365000     ...
# S006      0.21600      -1.8400      0.26700    -0.016840     ...
# S007     -0.19400      -0.0384     -0.09460    -0.088450     ...
# S008     -0.21700       1.1300      0.20300     0.243000     ...
# S009     -0.03300       1.2100      0.26500     0.265000     ...
# S010     -0.57500       0.3600     -0.17584    -0.333000     ...
# S011      0.01130       0.2060     -0.03150     0.018150     ...
# S012      0.00393      -1.8300      0.11200     0.042100     ...
# S013      0.15410      -5.3600     -0.55700     0.015600     ...
# S014      0.23500      -1.3700     -0.87000    -0.246000     ...
# S015     -0.57450       0.3570     -0.08320    -0.073900     ...
# S016      0.03750      -1.2000      0.60200     0.314000     ...
# S017          NaN          NaN     -0.81500    -0.440000     ...
# S018     -0.24500      -0.1600     -0.13060    -0.253000     ...
# S019      0.11025      -0.2850     -0.04240     0.033000     ...
# S020     -0.32500      -1.1400     -0.26000    -0.250000     ...
# S021     -0.01615       0.7130     -0.51000    -0.303000     ...
# S022      0.28400      -0.2310     -0.13900    -0.043150     ...
# S023     -0.24900       1.8200     -0.27500    -0.124250     ...
# S024      0.19400       0.4570     -0.44100    -0.067650     ...
# S025      0.35600      -0.0904     -0.59200    -0.274500     ...
# S026     -0.20200       0.1610      0.07200     0.040500     ...
# S027     -0.08550      -2.3100     -0.32900    -0.110000     ...
# S028     -0.20675       1.1100      0.17200     0.059700     ...
# S029      0.17700      -1.3900     -0.23650     0.072100     ...
# S030      0.56000       0.5560     -0.08090     0.092050     ...
# ...           ...          ...          ...          ...     ...
# S124     -0.29000       1.8500      0.33900    -0.237000     ...
# S125          NaN          NaN      0.25900    -0.066500     ...
# S126     -0.04100       1.9000     -0.01310    -0.390050     ...
# S127     -0.35575       2.4200     -1.13000    -1.033500     ...
# S128      0.45900       0.4730     -0.07400    -0.262000     ...
# S129     -0.28000       2.5400      0.54300     0.125000     ...
# S130      0.00800       1.8700     -0.17900    -0.179000     ...
# S131      0.32300       1.0100     -0.25900    -0.225500     ...
# S132     -1.24150       1.4500     -0.27300    -0.200500     ...
# S133     -0.28690       1.2300     -0.07110    -0.118000     ...
# S134      0.33100       0.9370     -0.27900    -0.297500     ...
# S135     -0.09290       1.5300      0.08385     0.024350     ...
# S136     -0.37350      -0.3730      0.11400     0.117000     ...
# S137     -1.19600      -0.1830     -0.36900    -0.246000     ...
# S138     -0.03400       0.3390      0.28300    -0.011000     ...
# S139     -0.07700       0.6800      0.12115    -0.062350     ...
# S140     -0.33500       0.3530     -0.04190    -0.067800     ...
# S141     -0.18000       0.1550     -0.15200     0.102200     ...
# S142     -0.49800       0.0185      0.23100     0.079350     ...
# S143     -0.25500       0.4800      0.20150     0.182000     ...
# S144     -0.14300      -1.3200      0.08220     0.123700     ...
# S145     -0.18100       2.5000      0.24100     0.213500     ...
# S146      0.00833       1.1700      0.40400     0.250500     ...
# S147     -0.10500      -1.1200      0.09040     0.202500     ...
# S148      0.24900       1.3800      0.47800     0.347500     ...
# S149     -0.03140      -1.2600      0.25400     0.255000     ...
# S150      0.12500       0.4450      0.37900     0.236000     ...
# S151     -0.22600       1.2500      0.12600     0.061415     ...
# S152     -0.28200       0.7950      0.24700     0.151350     ...
# S153     -0.02980      -2.1600      0.33800     0.285000     ...
#
#       AKT1S1-S232  AKT1S1-S241  AKT1S1-S267  AKT1S1-T110  AKT1S1-T117  \
# S001     0.201500          NaN    -0.000555     -0.22700          NaN
# S002     0.927000          NaN          NaN      0.10250          NaN
# S003    -0.844000          NaN          NaN      0.11000          NaN
# S004     0.254000          NaN          NaN     -0.29900      0.01650
# S005    -0.264500          NaN          NaN      0.25300     -0.66200
# S006    -0.057300          NaN     0.107000      0.21600          NaN
# S007    -0.122000          NaN          NaN      0.34450          NaN
# S008     0.352000          NaN          NaN     -0.16600      0.01410
# S009     0.250500          NaN          NaN     -0.56200     -0.11400
# S010    -0.346000          NaN    -0.415000     -0.62900          NaN
# S011     0.195000          NaN     0.396000      0.00942      0.07615
# S012     0.101700          NaN          NaN     -0.22500     -0.51600
# S013     0.056000     0.480000          NaN          NaN      0.40300
# S014    -0.177500     0.000067          NaN          NaN      0.56000
# S015    -0.078550          NaN          NaN     -0.72300     -0.04650
# S016     0.039500          NaN          NaN      0.23000          NaN
# S017    -2.100000          NaN          NaN     -0.18800          NaN
# S018    -0.053600          NaN    -0.341000     -0.34300          NaN
# S019     0.051950    -0.212000          NaN          NaN     -0.18100
# S020    -0.248500          NaN     0.493000     -0.22700          NaN
# S021     0.080550          NaN          NaN      0.09770     -0.08300
# S022    -0.055950          NaN          NaN     -0.46700      0.06450
# S023    -0.124250          NaN          NaN     -0.55100      0.24600
# S024    -0.440000          NaN          NaN     -0.04500     -0.06805
# S025    -0.749500          NaN          NaN      0.06070      0.19350
# S026    -0.119250          NaN     0.410000      0.00656          NaN
# S027    -0.110000          NaN     0.406000      0.51500     -0.18215
# S028    -0.017665          NaN          NaN     -0.06610     -0.01580
# S029     0.212000          NaN     0.169000          NaN          NaN
# S030    -0.087900          NaN          NaN      0.55540          NaN
# ...           ...          ...          ...          ...          ...
# S124    -0.163000          NaN     0.650000     -0.39700          NaN
# S125    -0.689000          NaN          NaN      0.46000          NaN
# S126     0.013400          NaN          NaN     -0.04100     -0.23600
# S127     0.524000          NaN          NaN          NaN      0.04050
# S128    -0.169000          NaN          NaN      0.45900      1.07000
# S129     0.022350    -0.302000          NaN          NaN     -0.58900
# S130    -0.001000          NaN          NaN      0.30000     -0.13500
# S131    -0.353500          NaN          NaN     -0.34100     -0.17495
# S132    -0.200500          NaN     0.003430     -0.90300     -0.45285
# S133    -0.094550          NaN          NaN     -0.11500     -0.05665
# S134    -0.072500          NaN    -0.037400      0.11000      0.18450
# S135    -0.199000          NaN     0.655000      0.52300      0.09600
# S136     0.051375     0.201000          NaN          NaN     -0.70000
# S137    -0.288500     0.233000          NaN          NaN     -0.83800
# S138    -0.000806          NaN     0.570000      0.87800          NaN
# S139     0.046000          NaN     0.138000      0.04850          NaN
# S140     0.000000          NaN          NaN     -0.72500     -0.35800
# S141     0.102200          NaN          NaN     -0.36000     -0.48500
# S142    -0.073650          NaN          NaN     -0.51800     -1.27000
# S143     0.144000          NaN          NaN     -0.06650          NaN
# S144     0.027100          NaN          NaN     -0.07621          NaN
# S145     0.411500          NaN          NaN     -0.16920     -0.27500
# S146     0.443000          NaN          NaN     -0.37150     -0.26100
# S147     0.001950          NaN          NaN     -0.11750     -0.38600
# S148     0.503500          NaN          NaN     -0.09650     -0.24200
# S149     0.297000          NaN          NaN     -0.05800     -0.44000
# S150     0.366000          NaN          NaN     -0.06050     -0.45900
# S151     0.286000          NaN          NaN     -0.19685     -0.02500
# S152     0.458500          NaN          NaN     -0.30550     -0.43800
# S153     0.406000          NaN          NaN     -0.00950     -0.38200
#
#       AKT1S1-T218  AKT1S1-T266  AKT1S1-T93           Mutation Patient_Type
# S001          NaN          NaN         NaN  Missense_Mutation        Tumor
# S002      -0.1520       2.1700         NaN           Wildtype        Tumor
# S003          NaN       1.7700         NaN  Missense_Mutation        Tumor
# S004          NaN      -0.7540   -0.394000           Wildtype        Tumor
# S005          NaN       1.0900   -0.353000           Wildtype        Tumor
# S006          NaN      -1.9100         NaN           Wildtype        Tumor
# S007       0.1080      -0.5740         NaN           Wildtype        Tumor
# S008          NaN       0.8920         NaN           Wildtype        Tumor
# S009          NaN      -0.2550   -0.545000  Missense_Mutation        Tumor
# S010          NaN      -0.5960         NaN  Missense_Mutation        Tumor
# S011          NaN          NaN         NaN           Wildtype        Tumor
# S012          NaN      -1.7100         NaN  Missense_Mutation        Tumor
# S013          NaN       1.2500         NaN           Wildtype        Tumor
# S014          NaN      -1.8300         NaN  Missense_Mutation        Tumor
# S015          NaN      -1.1100   -0.388000           Wildtype        Tumor
# S016          NaN      -2.3500         NaN           Wildtype        Tumor
# S017          NaN      -0.9720         NaN           Wildtype        Tumor
# S018          NaN          NaN         NaN  Missense_Mutation        Tumor
# S019          NaN       1.3500         NaN           Wildtype        Tumor
# S020          NaN          NaN         NaN           Wildtype        Tumor
# S021          NaN      -0.1990   -0.290000  Missense_Mutation        Tumor
# S022          NaN      -0.7800    0.064500  Missense_Mutation        Tumor
# S023          NaN       1.6000    0.246000  Missense_Mutation        Tumor
# S024          NaN       0.1710   -0.115000  Missense_Mutation        Tumor
# S025          NaN      -0.3370   -0.000053           Wildtype        Tumor
# S026          NaN          NaN         NaN  Missense_Mutation        Tumor
# S027          NaN          NaN         NaN  Missense_Mutation        Tumor
# S028          NaN       0.2270   -0.062900  Missense_Mutation        Tumor
# S029          NaN       0.8350   -0.065400           Wildtype        Tumor
# S030       0.5610       0.6470         NaN  Missense_Mutation        Tumor
# ...           ...          ...         ...                ...          ...
# S124          NaN          NaN         NaN           Wildtype       Normal
# S125          NaN       0.2750         NaN           Wildtype       Normal
# S126          NaN       0.3710   -0.236000           Wildtype       Normal
# S127      -0.2840       0.6770         NaN           Wildtype       Normal
# S128      -0.0908       0.2170    0.411000           Wildtype       Normal
# S129          NaN       0.9290         NaN           Wildtype       Normal
# S130          NaN       0.2050   -0.418000           Wildtype       Normal
# S131          NaN      -0.3070    0.012800           Wildtype       Normal
# S132          NaN          NaN         NaN           Wildtype       Normal
# S133          NaN       0.3900   -0.070300           Wildtype       Normal
# S134          NaN          NaN         NaN           Wildtype       Normal
# S135          NaN       0.8330         NaN           Wildtype       Normal
# S136          NaN      -0.6230         NaN           Wildtype       Normal
# S137          NaN      -0.9170         NaN           Wildtype       Normal
# S138          NaN      -0.9370         NaN           Wildtype       Normal
# S139          NaN      -0.7150         NaN           Wildtype       Normal
# S140          NaN      -0.9770         NaN           Wildtype       Normal
# S141          NaN      -0.2640         NaN           Wildtype       Normal
# S142          NaN      -1.3700         NaN           Wildtype       Normal
# S143      -0.0218       0.0416         NaN           Wildtype       Normal
# S144      -0.0757       0.0397         NaN           Wildtype       Normal
# S145          NaN       0.1160         NaN           Wildtype       Normal
# S146          NaN       0.4700         NaN           Wildtype       Normal
# S147          NaN      -0.4010         NaN           Wildtype       Normal
# S148          NaN       0.4210         NaN           Wildtype       Normal
# S149          NaN      -0.2710         NaN           Wildtype       Normal
# S150          NaN       0.0387         NaN           Wildtype       Normal
# S151          NaN       0.0000         NaN           Wildtype       Normal
# S152          NaN      -0.4970         NaN           Wildtype       Normal
# S153          NaN      -0.6210         NaN           Wildtype       Normal
#
# [153 rows x 21 columns]
