# %% [markdown]
# # PIK3CA: Effects of Mutation on IRS1

# %% [markdown]
# <b> Standard imports for playing with and plotting data frames. </b>

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <b> Import CPTAC data

# %%
import CPTAC
# Out:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter CPTAC.embargo() to open the webpage for more details.

# %%
somatic_mutations = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %% [markdown]
# # PI3KCA mutation and IRS1 proteome abundance

# %% [markdown]
# ### Perform a t-test with mutated and non-mutated protein levels

# %%
protList = ['MTOR']
pcutoff = 0.05 / len(protList)
gene = 'PIK3CA'

sigResults = [];
for protein in protList: 
    if protein in proteomics.columns:
        cross = CPTAC.compare_mutations(proteomics, protein, gene)
        cross = cross[["Mutation", protein]].dropna(axis=0)
        mutated = cross.loc[cross["Mutation"] == "Missense_Mutation"]
        wt = cross.loc[cross["Mutation"] == "Wildtype"]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(ttest[1] <= pcutoff):
            sigResults.append(protein)
            print("Test for " + protein + ": ")
            print(ttest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c6596b643bd> in <module>
#       5 sigResults = [];
#       6 for protein in protList:
# ----> 7     if protein in proteomics.columns:
#       8         cross = CPTAC.compare_mutations(proteomics, protein, gene)
#       9         cross = cross[["Mutation", protein]].dropna(axis=0)
#
# NameError: name 'proteomics' is not defined

# %% [markdown]
#  ### We can now plot the data

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
somatic_boxplot = sns.boxplot(data=cross, x="Mutation",y='IRS1', ax = ax)
somatic_boxplot.set_title("PI3KCA gene mutation IRS1 protein abundance")
somatic_boxplot = sns.stripplot(data=cross, x="Mutation", y='IRS1',jitter=True, color=".3")
somatic_boxplot.set(xlabel="Somatic Gene Mutation",ylabel="Proteomics")
plt.show()

# %% [markdown]
# # PI3KCA mutation and IRS1 phosphoproteome abundance

# %%
phosProtList = ['IRS1']
sigResults = [];
pcutoff = 0.05/len(phosProtList)
print(pcutoff)

for protein in phosProtList: 
        cross = CPTAC.compare_mutations(phos, protein, gene)
        #print(cross.head())
        for loc in cross.columns:
            #print(loc)
            cross_site = cross[["Mutation", loc]].dropna(axis=0)
            #print(cross_site)
            mutated = cross_site.loc[cross_site["Mutation"] == "Missense_Mutation"]
            wt = cross_site.loc[cross_site["Mutation"] == "Wildtype"]
            ttest = scipy.stats.ttest_ind(mutated[loc], wt[loc])
            if(ttest[1] <= pcutoff):
                sigResults.append(loc)
                print("Test for " + loc + ": ")
                print(ttest)
# Out:
# 0.05
# Test for IRS1-S1005:
# Ttest_indResult(statistic=-3.6363762191848834, pvalue=0.00047303574626612497)
# Test for IRS1-S1100:
# Ttest_indResult(statistic=-4.8584238737530345, pvalue=3.840176909315442e-06)
# Test for IRS1-S1101:
# Ttest_indResult(statistic=-5.065504281640339, pvalue=1.6006637681340987e-06)
# Test for IRS1-S1134:
# Ttest_indResult(statistic=-3.0899242452815208, pvalue=0.0025256893869634324)
# Test for IRS1-S270:
# Ttest_indResult(statistic=-3.5576954142473682, pvalue=0.0005101046560626368)
# Test for IRS1-S323:
# Ttest_indResult(statistic=-3.4808173935784033, pvalue=0.0006942175734218259)
# Test for IRS1-S330:
# Ttest_indResult(statistic=-3.94235522237334, pvalue=0.00015618968862050566)
# Test for IRS1-S337:
# Ttest_indResult(statistic=-2.4733692816326767, pvalue=0.014738139987583122)
# Test for IRS1-S348:
# Ttest_indResult(statistic=-2.455146507528809, pvalue=0.015882299771147104)
# Test for IRS1-S374:
# Ttest_indResult(statistic=-2.759118092497603, pvalue=0.007049909221743694)
# Test for IRS1-S413:
# Ttest_indResult(statistic=-2.5167758170005934, pvalue=0.014071454480894249)
# Test for IRS1-S415:
# Ttest_indResult(statistic=-3.9165469385239104, pvalue=0.00017017081267402305)
# Test for IRS1-S419:
# Ttest_indResult(statistic=-2.3986050842205646, pvalue=0.017855829698115482)
# Test for IRS1-S421:
# Ttest_indResult(statistic=-3.088740692034591, pvalue=0.002489442917970644)
# Test for IRS1-S527:
# Ttest_indResult(statistic=-3.1953305888992727, pvalue=0.001747433169051716)
# Test for IRS1-S531:
# Ttest_indResult(statistic=-3.903307236334035, pvalue=0.0001505906818361514)
# Test for IRS1-S629:
# Ttest_indResult(statistic=-3.4729090677894376, pvalue=0.0007113079427995143)
# Test for IRS1-S636:
# Ttest_indResult(statistic=-2.2769026012584446, pvalue=0.025012327661328985)
# Test for IRS1-S672:
# Ttest_indResult(statistic=-3.260295767457261, pvalue=0.001692370739453088)
# /Users/emilyhosk/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-634b2d378243> in <module>()
#      11             cross_site = cross[["Mutation", loc]].dropna(axis=0)
#      12             #print(cross_site)
# ---> 13             mutated = cross_site.loc[cross_site["Mutation"] == "Missense_Mutation"]
#      14             wt = cross_site.loc[cross_site["Mutation"] == "Wildtype"]
#      15             ttest = scipy.stats.ttest_ind(mutated[loc], wt[loc])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1897
#    1898                 if hasattr(key, 'ndim') and key.ndim > 1:
# -> 1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
#    1901                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key
