# %% [markdown]
# # PIK3CA: Effects of Hotspot Mutation on IRS2

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.stats.multitest

# %% [markdown]
# ### Import CPTAC

# %%
import CPTAC
# Out:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter CPTAC.embargo() to open the webpage for more details.

# %%
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %%
protein = 'IRS1'
gene = 'PIK3CA'

# %% [markdown]
# ## Extract the data for hotspot mutations only

# %%
#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.E545A', 'p.E545K', 'p.E545V', 'p.Q546P', 'p.Q546R', 'p.E542K']
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

# %%
p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
#print(p10_mutations)
p10_mutations['Within_Hotspot'] = False
p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)
print(len(p10_mutations.loc[(p10_mutations['Within_Hotspot'] == True)]))
# Out:
# 19

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
out_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == False]
ttest = scipy.stats.ttest_ind(in_hotspot[protein], out_hotspot[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.1614090894467233, pvalue=0.8725837294345415)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] != True]
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.41605357417860345, pvalue=0.6782805142560057)

# %% [markdown]
# ## All mutations vs wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] != 'Wildtype']
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.5083089884962738, pvalue=0.6123789928887791)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.48786484982107525, pvalue=0.6270687631118381)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on PIK3CA abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %% [markdown]
# # Phosphoproteomic Abundance

# %%
phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
phos_mutations['Within_Hotspot'] = False
phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True

phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
print(phos_mutations)


phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
#phos_mutations = phos_mutations.dropna(axis = 0)
#print(phos_mutations)
phos_sites = list(phos_mutations)
phos_sites = phos_sites[:(len(phos_sites) - 3)]
# Out:
#       IRS1-S1005  IRS1-S1100  IRS1-S1101  IRS1-S1134  IRS1-S270  IRS1-S312  \
# S001         NaN         NaN       -0.44       -0.50       0.16        NaN
# S002        0.24       -0.41       -0.40       -0.20      -0.18      -0.49
# S003        0.19       -0.06        0.35        0.50       0.77        NaN
# S004       -0.18       -0.23       -0.68         NaN      -0.16        NaN
# S005       -0.54       -0.81       -1.04         NaN      -0.07      -0.51
# S006       -0.15        0.33        0.34        1.72       0.34      -0.11
# S007        0.26       -0.26       -0.44       -0.24       0.24       0.02
# S008         NaN       -0.48       -0.25       -0.40      -0.07        NaN
# S009        0.02        0.12        0.07         NaN       0.19      -0.08
# S010       -0.56       -0.06       -0.24        0.24      -0.01       0.07
# S011       -1.24       -1.08       -1.55       -0.12      -0.98       0.39
# S012         NaN       -0.95       -1.08       -0.38      -0.45      -0.39
# S013         NaN       -1.07       -1.21       -0.48      -0.40       0.23
# S014         NaN       -0.27        0.01        0.47       0.05        NaN
# S015       -0.77       -0.50       -0.37         NaN      -0.67      -1.75
# S016       -0.89       -1.32       -1.59       -0.78      -2.46        NaN
# S017         NaN         NaN        0.42        0.25      -0.62        NaN
# S018         NaN        0.73        1.63        0.66       1.92       0.71
# S019         NaN         NaN        0.48       -0.43       0.27        NaN
# S020         NaN       -0.45       -0.48       -0.86       0.09        NaN
# S021       -0.23         NaN         NaN       -0.21      -0.03        NaN
# S022       -0.38         NaN         NaN       -0.63      -0.59        NaN
# S023        0.04        0.07        0.53         NaN       0.36        NaN
# S024        0.00        0.42       -0.61         NaN      -0.07        NaN
# S025         NaN         NaN        0.71        0.09      -0.01        NaN
# S026       -0.32       -0.22       -0.71       -0.60       0.00      -0.10
# S027         NaN        0.52        0.18       -0.14      -0.12        NaN
# S028         NaN        0.10        0.23        0.13       0.36       0.61
# S029       -0.38        0.30        0.31       -0.56      -0.92      -1.03
# S030         NaN       -1.00       -1.00       -0.60      -0.20        NaN
# ...          ...         ...         ...         ...        ...        ...
# S111       -0.01        0.00        0.81        0.65       0.50        NaN
# S112        1.51        0.58         NaN       -1.25       0.48        NaN
# S113        0.71        0.85        0.67         NaN       0.76       1.01
# S114         NaN       -0.08        0.40        0.60       0.61       0.37
# S115        0.21        1.16        0.75        0.60       0.99        NaN
# S116        0.58        0.49        0.16        0.30       0.82        NaN
# S117        0.30        0.56        0.57        0.62       0.75        NaN
# S118        0.56        0.64        0.26         NaN       0.23      -0.06
# S119        0.96        0.44        0.45         NaN       0.20      -0.24
# S120         NaN         NaN        0.95       -0.04       0.57        NaN
# S121        1.07        0.53        0.46        0.38       0.54        NaN
# S122        0.14         NaN         NaN       -0.09       0.72        NaN
# S123         NaN        0.97         NaN        0.65       0.68        NaN
# S124         NaN         NaN         NaN       -0.27       0.69       0.44
# S125         NaN        0.51        0.51        0.16       0.44       0.13
# S126        0.01        0.36        0.36        0.55       0.01       0.24
# S127       -0.32        0.86        0.87        0.55       0.40       0.77
# S128        0.37        1.29        0.73         NaN       0.34       0.53
# S129         NaN        0.28        0.58        0.55       0.01       0.00
# S130         NaN       -0.36        0.03       -0.51       0.08      -0.20
# S131       -0.16        0.72        0.85        0.55       0.14      -0.42
# S132        0.48        1.30        0.96        0.81       0.88      -0.02
# S133        0.21        1.23        0.94        0.93       0.34       0.01
# S134        0.77        0.92        0.79         NaN       0.48       0.18
# S135         NaN        0.98        0.81        0.09       0.60        NaN
# S136        1.09        1.19        1.12         NaN       0.87        NaN
# S137       -0.32        0.85        0.98       -0.71       0.27       0.56
# S138         NaN        0.61        0.38       -0.09       0.25        NaN
# S139        0.61        0.31        0.11        0.26       0.42      -0.01
# S140         NaN       -0.27       -0.05        0.11       0.47        NaN
#
#       IRS1-S323  IRS1-S330  IRS1-S337  IRS1-S348       ...        IRS1-S419  \
# S001      -0.92       0.01       0.09      -0.11       ...            -0.31
# S002       0.08      -0.27      -0.69       0.12       ...            -0.31
# S003       0.33        NaN       0.32       0.30       ...            -0.90
# S004      -0.60        NaN      -0.29      -1.06       ...             0.19
# S005      -1.15      -2.90      -1.39      -0.64       ...             0.20
# S006       1.13       0.98       1.07       0.56       ...             0.86
# S007        NaN       0.16       0.21        NaN       ...            -0.54
# S008      -0.29      -0.11      -0.39      -0.09       ...              NaN
# S009      -0.03       0.04      -0.09       0.00       ...             0.19
# S010       0.76        NaN       0.17        NaN       ...            -0.29
# S011        NaN      -1.61      -0.18        NaN       ...            -0.70
# S012      -0.78        NaN      -0.73       0.04       ...            -0.23
# S013      -0.17        NaN      -0.10       0.05       ...            -0.90
# S014      -1.14      -0.30      -0.33       0.11       ...              NaN
# S015      -1.30        NaN      -1.33      -1.61       ...            -2.88
# S016      -2.40        NaN      -1.42      -0.01       ...            -1.74
# S017      -0.01       0.65       0.25       0.53       ...            -0.30
# S018       0.11       2.02       1.18       0.72       ...             0.71
# S019       0.21       1.08       0.07       0.95       ...            -0.34
# S020      -2.01      -0.94      -1.09      -0.85       ...              NaN
# S021      -0.38      -1.22      -0.86      -0.72       ...            -0.09
# S022      -0.31      -1.49      -1.23      -0.54       ...             0.08
# S023      -0.47        NaN       0.37       0.39       ...             1.29
# S024       0.01        NaN       0.23      -0.52       ...             1.83
# S025       0.60       0.50       0.47       0.38       ...             0.29
# S026      -0.10        NaN      -0.23        NaN       ...            -0.72
# S027       0.12       0.36       0.26       0.41       ...              NaN
# S028      -0.58      -0.31       1.36       0.46       ...             0.44
# S029      -0.05      -0.14      -0.51       0.27       ...            -0.47
# S030       0.71       0.29       0.12        NaN       ...            -0.50
# ...         ...        ...        ...        ...       ...              ...
# S111       1.38        NaN       0.32       0.72       ...            -0.50
# S112        NaN        NaN        NaN        NaN       ...            -0.16
# S113       1.45        NaN       1.24       2.02       ...             0.90
# S114       1.92       0.78      -0.07      -0.29       ...             1.00
# S115       1.47       1.60        NaN        NaN       ...            -0.55
# S116       0.36       0.85        NaN        NaN       ...            -0.34
# S117       1.52       0.65        NaN        NaN       ...            -0.29
# S118       1.27        NaN       1.25       1.11       ...             0.51
# S119       0.11        NaN       0.69      -0.86       ...             0.12
# S120       0.82       1.67       0.72       1.55       ...            -0.36
# S121       0.50        NaN       0.77       0.78       ...            -0.46
# S122      -0.03       0.80       0.88       0.62       ...             0.61
# S123        NaN        NaN        NaN        NaN       ...             0.98
# S124       1.11       0.39       0.35       0.01       ...             0.05
# S125       1.02       1.35       0.85       1.05       ...             0.13
# S126       0.46       0.02       0.37       0.18       ...             0.00
# S127       1.07       0.43       0.63       0.25       ...             0.15
# S128       1.30       0.78       1.08       1.09       ...             0.73
# S129       0.38       0.42       0.49       0.46       ...             0.04
# S130       0.48      -0.01       0.49       0.69       ...             0.05
# S131        NaN       0.58       0.38        NaN       ...             0.19
# S132        NaN       1.10       0.37        NaN       ...             0.81
# S133        NaN       1.02       0.92        NaN       ...             0.93
# S134       0.77       0.87       0.90       0.67       ...             0.52
# S135       0.66       0.40       0.77       0.34       ...              NaN
# S136       1.01        NaN       0.83       0.34       ...             1.10
# S137       1.24        NaN       0.61        NaN       ...             0.48
# S138       0.18       0.33       0.31       0.12       ...              NaN
# S139       1.04        NaN       0.54        NaN       ...             0.22
# S140       0.45      -0.25      -0.44        NaN       ...            -0.94
#
#       IRS1-S421  IRS1-S527  IRS1-S531  IRS1-S629  IRS1-S636  IRS1-S672  \
# S001       0.16      -0.14      -0.20       0.02      -0.06      -1.97
# S002       0.37        NaN        NaN      -0.12      -0.13      -0.51
# S003      -0.31       0.61       0.65       0.89       0.81        NaN
# S004        NaN       0.00      -0.29      -0.25      -0.33       0.12
# S005       0.02      -1.50      -1.46      -1.36      -1.23      -0.66
# S006       0.91        NaN        NaN       0.92       1.00       0.23
# S007      -0.21       0.43       0.38       0.58       0.87      -1.08
# S008      -0.40       0.63      -0.01       0.53       0.74       0.33
# S009       0.18       0.35       0.39       0.27       0.57      -0.20
# S010       0.05      -0.04       0.00        NaN        NaN        NaN
# S011      -1.63      -0.64      -1.01      -0.01      -0.94      -0.68
# S012      -0.71      -0.27      -0.62      -1.11        NaN      -1.02
# S013      -0.49      -0.56      -1.29      -0.28        NaN      -0.29
# S014      -0.25       0.30       0.15       0.21       0.34       0.62
# S015      -0.45      -2.12      -1.24        NaN        NaN        NaN
# S016      -1.27      -1.09      -1.05      -2.24      -2.32        NaN
# S017       0.19       0.64       0.90       0.39       0.86      -0.28
# S018       0.95       2.00       1.29       0.96        NaN       0.86
# S019      -0.02       0.63       0.84       0.71       1.33      -0.03
# S020      -0.82      -0.76      -1.01      -0.33      -0.12       0.18
# S021      -0.44      -0.72      -1.11       0.01      -0.07      -0.02
# S022      -0.75      -1.30      -1.35      -0.21      -0.29      -0.76
# S023        NaN      -0.06       0.37       0.33       0.26       0.93
# S024        NaN      -0.19       0.14      -0.65      -0.73       0.30
# S025       0.47       0.00       0.28       0.24       0.15      -0.82
# S026      -0.06      -0.73      -0.83        NaN        NaN        NaN
# S027      -0.60       0.37      -0.02       0.63       0.81      -0.19
# S028       0.09       0.72       0.76       0.07       1.58      -0.15
# S029      -0.26        NaN        NaN      -0.04        NaN        NaN
# S030       0.28       0.39       0.52      -0.24        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# S111      -0.40       0.34       0.38      -0.82      -0.89        NaN
# S112      -0.06       0.64       0.31       0.78       1.13        NaN
# S113       0.59       0.65       0.93        NaN        NaN        NaN
# S114       0.47       0.50       0.54       1.28       0.65       0.29
# S115        NaN       1.33       1.37       2.34        NaN        NaN
# S116        NaN       0.97       1.01       0.42        NaN        NaN
# S117        NaN       0.27       0.31       2.15        NaN        NaN
# S118       0.28       0.78       0.96        NaN        NaN        NaN
# S119       0.61       0.15       0.28        NaN        NaN        NaN
# S120       0.19       0.96       1.12       0.42       1.23       1.20
# S121      -0.33       0.68       0.73       0.31       0.24        NaN
# S122       0.17       1.23       1.93       1.06       2.56       1.04
# S123       1.23       0.35      -0.01       1.68       1.53        NaN
# S124       0.34       0.84       1.00       0.86       1.27        NaN
# S125       0.57       1.13       1.05       2.02        NaN       0.02
# S126       0.47        NaN        NaN       0.49      -0.01       0.40
# S127       0.41        NaN        NaN       1.09       0.11       1.00
# S128       0.89       0.96       1.00       1.78       1.41       0.76
# S129       0.22       1.09       1.34       0.97        NaN       0.62
# S130      -0.16       0.41       0.50      -0.12        NaN       0.00
# S131      -0.04       0.36       0.16       0.49       0.11       0.39
# S132       0.38       1.05       1.14       2.02       1.94       0.55
# S133       0.53       0.41       0.33       1.39       1.38       0.15
# S134       0.62       0.82       0.86       1.43       1.22       0.50
# S135      -0.10       1.07       1.11       1.12       1.44        NaN
# S136        NaN       1.14       0.85       1.61       1.53       2.47
# S137        NaN       0.46       0.50        NaN        NaN        NaN
# S138      -0.34       0.18       0.13       0.63       0.67       0.50
# S139       0.03       0.67       0.87        NaN        NaN        NaN
# S140      -0.09       0.06       0.08      -0.64        NaN        NaN
#
#                Mutation  Patient_Type  Within_Hotspot
# S001  Missense_Mutation         Tumor            True
# S002           Wildtype         Tumor        Wildtype
# S003  Missense_Mutation         Tumor            True
# S004           Wildtype         Tumor        Wildtype
# S005           Wildtype         Tumor        Wildtype
# S006           Wildtype         Tumor        Wildtype
# S007           Wildtype         Tumor        Wildtype
# S008  Missense_Mutation         Tumor            True
# S009           Wildtype         Tumor        Wildtype
# S010           Wildtype         Tumor        Wildtype
# S011  Missense_Mutation         Tumor           False
# S012           Wildtype         Tumor        Wildtype
# S013  Missense_Mutation         Tumor           False
# S014           Wildtype         Tumor        Wildtype
# S015           Wildtype         Tumor        Wildtype
# S016           Wildtype         Tumor        Wildtype
# S017  Missense_Mutation         Tumor           False
# S018           Wildtype         Tumor        Wildtype
# S019           Wildtype         Tumor        Wildtype
# S020  Missense_Mutation         Tumor            True
# S021  Missense_Mutation         Tumor           False
# S022  Missense_Mutation         Tumor            True
# S023  Missense_Mutation         Tumor            True
# S024           Wildtype         Tumor        Wildtype
# S025           Wildtype         Tumor        Wildtype
# S026  Missense_Mutation         Tumor           False
# S027  Missense_Mutation         Tumor           False
# S028           Wildtype         Tumor        Wildtype
# S029           Wildtype         Tumor        Wildtype
# S030  Missense_Mutation         Tumor           False
# ...                 ...           ...             ...
# S111           Wildtype        Normal        Wildtype
# S112           Wildtype        Normal        Wildtype
# S113           Wildtype        Normal        Wildtype
# S114           Wildtype        Normal        Wildtype
# S115           Wildtype        Normal        Wildtype
# S116           Wildtype        Normal        Wildtype
# S117           Wildtype        Normal        Wildtype
# S118           Wildtype        Normal        Wildtype
# S119           Wildtype        Normal        Wildtype
# S120           Wildtype        Normal        Wildtype
# S121           Wildtype        Normal        Wildtype
# S122           Wildtype        Normal        Wildtype
# S123           Wildtype        Normal        Wildtype
# S124           Wildtype        Normal        Wildtype
# S125           Wildtype        Normal        Wildtype
# S126           Wildtype        Normal        Wildtype
# S127           Wildtype        Normal        Wildtype
# S128           Wildtype        Normal        Wildtype
# S129           Wildtype        Normal        Wildtype
# S130           Wildtype        Normal        Wildtype
# S131           Wildtype        Normal        Wildtype
# S132           Wildtype        Normal        Wildtype
# S133           Wildtype        Normal        Wildtype
# S134           Wildtype        Normal        Wildtype
# S135           Wildtype        Normal        Wildtype
# S136           Wildtype        Normal        Wildtype
# S137           Wildtype        Normal        Wildtype
# S138           Wildtype        Normal        Wildtype
# S139           Wildtype        Normal        Wildtype
# S140           Wildtype        Normal        Wildtype
#
# [140 rows x 23 columns]

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == False]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for IRS1-S1005 Ttest_indResult(statistic=-1.3064176491257797, pvalue=0.20623555695581944)
# Test for IRS1-S1100 Ttest_indResult(statistic=0.5704788397540956, pvalue=0.5722172412186742)
# Test for IRS1-S1101 Ttest_indResult(statistic=1.5632118414883178, pvalue=0.12726384667516544)
# Test for IRS1-S1134 Ttest_indResult(statistic=-0.17188621942146887, pvalue=0.8646094130537407)
# Test for IRS1-S270 Ttest_indResult(statistic=2.0072698279818657, pvalue=0.05151089925938861)
# Test for IRS1-S312 Ttest_indResult(statistic=0.19310553365646718, pvalue=0.8493063115636919)
# Test for IRS1-S323 Ttest_indResult(statistic=-1.480506261931961, pvalue=0.1476846924251742)
# Test for IRS1-S330 Ttest_indResult(statistic=-0.6434167243424851, pvalue=0.5258123657475271)
# Test for IRS1-S337 Ttest_indResult(statistic=-0.7483286169993663, pvalue=0.4591232286639154)
# Test for IRS1-S348 Ttest_indResult(statistic=0.20695977445416264, pvalue=0.8377871605674864)
# Test for IRS1-S374 Ttest_indResult(statistic=0.8934366533974721, pvalue=0.37923859177350683)
# Test for IRS1-S413 Ttest_indResult(statistic=-1.7142585933952275, pvalue=0.10274817630609655)
# Test for IRS1-S415 Ttest_indResult(statistic=1.2478576481729453, pvalue=0.22463863320757538)
# Test for IRS1-S419 Ttest_indResult(statistic=1.3644228811789592, pvalue=0.18114375070374725)
# Test for IRS1-S421 Ttest_indResult(statistic=-0.39030287675202685, pvalue=0.6987472650149789)
# Test for IRS1-S527 Ttest_indResult(statistic=0.3830264293359841, pvalue=0.7037282046485906)
# Test for IRS1-S531 Ttest_indResult(statistic=0.9231078845709197, pvalue=0.3614860433360494)
# Test for IRS1-S629 Ttest_indResult(statistic=0.225290277066115, pvalue=0.823063758320874)
# Test for IRS1-S636 Ttest_indResult(statistic=0.14810034653243082, pvalue=0.8834516393381191)
# Test for IRS1-S672 Ttest_indResult(statistic=1.174135132975547, pvalue=0.25413298992987327)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] != True]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for IRS1-S1005 Ttest_indResult(statistic=-1.8347890043498212, pvalue=0.07166701942854645)
# Test for IRS1-S1100 Ttest_indResult(statistic=-0.7425698169451787, pvalue=0.4599170363323163)
# Test for IRS1-S1101 Ttest_indResult(statistic=0.04580782960792198, pvalue=0.9635775729552464)
# Test for IRS1-S1134 Ttest_indResult(statistic=-1.0364618601250604, pvalue=0.3032307621626944)
# Test for IRS1-S270 Ttest_indResult(statistic=0.905226114980503, pvalue=0.36756572664453324)
# Test for IRS1-S312 Ttest_indResult(statistic=0.8914207295296072, pvalue=0.3771503365705554)
# Test for IRS1-S323 Ttest_indResult(statistic=-1.5817186826697398, pvalue=0.11738477474307568)
# Test for IRS1-S330 Ttest_indResult(statistic=-1.1404614428771658, pvalue=0.258411191708947)
# Test for IRS1-S337 Ttest_indResult(statistic=-0.2169748616085276, pvalue=0.8287418430005219)
# Test for IRS1-S348 Ttest_indResult(statistic=0.05296014054628668, pvalue=0.9579260976245949)
# Test for IRS1-S374 Ttest_indResult(statistic=0.6184399989178402, pvalue=0.5385508019115808)
# Test for IRS1-S413 Ttest_indResult(statistic=-1.7251588636293325, pvalue=0.09093282466487775)
# Test for IRS1-S415 Ttest_indResult(statistic=-0.13962362190392189, pvalue=0.8894027849651824)
# Test for IRS1-S419 Ttest_indResult(statistic=0.20213127261867656, pvalue=0.8402652998621346)
# Test for IRS1-S421 Ttest_indResult(statistic=-0.9064991150170733, pvalue=0.3672647658265199)
# Test for IRS1-S527 Ttest_indResult(statistic=0.3015428681616715, pvalue=0.7636811033482227)
# Test for IRS1-S531 Ttest_indResult(statistic=0.4184108930438669, pvalue=0.6766218328413731)
# Test for IRS1-S629 Ttest_indResult(statistic=-0.27478514320325004, pvalue=0.7841480980436778)
# Test for IRS1-S636 Ttest_indResult(statistic=0.4142116539533518, pvalue=0.68010408393184)
# Test for IRS1-S672 Ttest_indResult(statistic=0.260722507616503, pvalue=0.7953991278896196)

# %% [markdown]
# ## All mutations vs wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] != 'Wildtype']
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for IRS1-S1005 Ttest_indResult(statistic=-0.9690977556578986, pvalue=0.3365203953002731)
# Test for IRS1-S1100 Ttest_indResult(statistic=-2.144151151356816, pvalue=0.035056594434805)
# Test for IRS1-S1101 Ttest_indResult(statistic=-2.098899731593709, pvalue=0.038979458432090074)
# Test for IRS1-S1134 Ttest_indResult(statistic=-1.770797347381606, pvalue=0.08055195840145042)
# Test for IRS1-S270 Ttest_indResult(statistic=-0.7860248714648148, pvalue=0.4337493578683552)
# Test for IRS1-S312 Ttest_indResult(statistic=1.3429173455723695, pvalue=0.18561470344519224)
# Test for IRS1-S323 Ttest_indResult(statistic=-0.5485686919133093, pvalue=0.5847228047850945)
# Test for IRS1-S330 Ttest_indResult(statistic=-1.093938678842869, pvalue=0.27814694985592836)
# Test for IRS1-S337 Ttest_indResult(statistic=0.4798182866151812, pvalue=0.6325746861136163)
# Test for IRS1-S348 Ttest_indResult(statistic=-0.14935866809247728, pvalue=0.881733079425064)
# Test for IRS1-S374 Ttest_indResult(statistic=-0.10191057508786826, pvalue=0.9191565374601931)
# Test for IRS1-S413 Ttest_indResult(statistic=-0.43227024778175394, pvalue=0.6674808458992423)
# Test for IRS1-S415 Ttest_indResult(statistic=-1.8418771356736203, pvalue=0.07020092773381807)
# Test for IRS1-S419 Ttest_indResult(statistic=-1.184904276685606, pvalue=0.23914057981493891)
# Test for IRS1-S421 Ttest_indResult(statistic=-0.9846121562463936, pvalue=0.32764219023746255)
# Test for IRS1-S527 Ttest_indResult(statistic=0.020008118223419125, pvalue=0.9840802262632453)
# Test for IRS1-S531 Ttest_indResult(statistic=-0.6797082767342767, pvalue=0.4983959003978983)
# Test for IRS1-S629 Ttest_indResult(statistic=-0.7425871881562727, pvalue=0.45977894043451784)
# Test for IRS1-S636 Ttest_indResult(statistic=0.45170761264623555, pvalue=0.6530067422791852)
# Test for IRS1-S672 Ttest_indResult(statistic=-1.0221910151234592, pvalue=0.3117108171458467)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for IRS1-S1005 Ttest_indResult(statistic=-1.8390096154420452, pvalue=0.07210407448276862)
# Test for IRS1-S1100 Ttest_indResult(statistic=-1.3157134734611506, pvalue=0.19319381891260304)
# Test for IRS1-S1101 Ttest_indResult(statistic=-0.7065709858771181, pvalue=0.4825233989627652)
# Test for IRS1-S1134 Ttest_indResult(statistic=-1.3387461101198534, pvalue=0.18606291130642055)
# Test for IRS1-S270 Ttest_indResult(statistic=0.4238874020377327, pvalue=0.6728612243896865)
# Test for IRS1-S312 Ttest_indResult(statistic=1.0224489215752472, pvalue=0.3130338107643985)
# Test for IRS1-S323 Ttest_indResult(statistic=-1.3943473871193723, pvalue=0.1679605566134864)
# Test for IRS1-S330 Ttest_indResult(statistic=-1.2221999048114711, pvalue=0.22747886713099452)
# Test for IRS1-S337 Ttest_indResult(statistic=-0.003658301080957065, pvalue=0.9970921397447137)
# Test for IRS1-S348 Ttest_indResult(statistic=-0.0061973081095461745, pvalue=0.9950785635660884)
# Test for IRS1-S374 Ttest_indResult(statistic=0.3927867666869004, pvalue=0.6962528452256311)
# Test for IRS1-S413 Ttest_indResult(statistic=-1.4876876085925312, pvalue=0.14487476754026077)
# Test for IRS1-S415 Ttest_indResult(statistic=-0.6922789016353742, pvalue=0.491964864943787)
# Test for IRS1-S419 Ttest_indResult(statistic=-0.18508981586713452, pvalue=0.8536863012669682)
# Test for IRS1-S421 Ttest_indResult(statistic=-1.1031649411259206, pvalue=0.2740864052986449)
# Test for IRS1-S527 Ttest_indResult(statistic=0.23066404656632508, pvalue=0.8182583628265063)
# Test for IRS1-S531 Ttest_indResult(statistic=0.08892437436464352, pvalue=0.9293996145312261)
# Test for IRS1-S629 Ttest_indResult(statistic=-0.4525684575167107, pvalue=0.6523436575782026)
# Test for IRS1-S636 Ttest_indResult(statistic=0.4568056926855069, pvalue=0.6496430049370658)
# Test for IRS1-S672 Ttest_indResult(statistic=-0.20281485970289145, pvalue=0.840282892148313)
