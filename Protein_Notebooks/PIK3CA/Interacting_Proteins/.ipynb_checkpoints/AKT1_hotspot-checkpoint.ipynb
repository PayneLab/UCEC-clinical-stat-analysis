# %% [markdown]
# # PIK3CA: Effects of Hotspot Mutation on IRS2

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.stats.multitest

# %% [markdown]
# ### Import CPTAC

# %%
import CPTAC

# %%
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %%
protein = 'IRS2'
gene = 'PIK3CA'

# %% [markdown]
# ## Extract the data for hotspot mutations only

# %%
#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.E545A', 'p.E545K', 'p.E545V', 'p.Q546P', 'p.Q546R', 'p.E542K']
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

# %%
p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
#print(p10_mutations)
p10_mutations['Within_Hotspot'] = False
p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)
print(len(p10_mutations.loc[(p10_mutations['Within_Hotspot'] == True)]))
# Out:
# 18

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
out_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == False]
ttest = scipy.stats.ttest_ind(in_hotspot[protein], out_hotspot[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.5878377126949157, pvalue=0.12106850179611806)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] != True]
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-2.3028571242435536, pvalue=0.023672749210673937)

# %% [markdown]
# ## All mutations vs wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] != 'Wildtype']
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.968743995892205, pvalue=0.052165788180294895)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-2.3058441496545665, pvalue=0.02422166186950158)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on PIK3CA abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %% [markdown]
# # Phosphoproteomic Abundance

# %%
phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
phos_mutations['Within_Hotspot'] = False
phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True

phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
print(phos_mutations)


phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
#phos_mutations = phos_mutations.dropna(axis = 0)
#print(phos_mutations)
phos_sites = list(phos_mutations)
phos_sites = sites[:(len(sites) - 3)]
# Out:
#       IRS2-S1100  IRS2-S365  IRS2-S388  IRS2-S391  IRS2-S560  IRS2-S577  \
# S001       -0.94      -0.66        NaN        NaN        NaN       0.64
# S002         NaN      -1.18      -1.08        NaN        NaN       0.09
# S003         NaN      -0.22      -0.72       0.35      -0.39        NaN
# S004       -2.14      -0.21        NaN      -1.12      -0.61      -1.95
# S005        0.23      -0.62       0.38        NaN        NaN        NaN
# S006         NaN      -0.37      -0.53        NaN        NaN       0.60
# S007         NaN      -0.73      -0.17      -0.93      -0.36      -2.04
# S008        0.73      -0.13       0.55       0.03        NaN       0.45
# S009        1.11       1.30       0.54        NaN        NaN        NaN
# S010       -0.23       0.19        NaN       0.07        NaN      -0.34
# S011         NaN      -0.78      -0.08      -0.78      -0.31      -3.16
# S012         NaN       0.79       0.75      -0.11        NaN      -0.48
# S013         NaN      -0.14       0.06      -0.37        NaN       0.91
# S014        0.56      -0.17       0.49       0.19        NaN       1.13
# S015        1.93       0.38       0.53        NaN       0.85        NaN
# S016         NaN      -3.65      -0.48      -0.32      -1.35        NaN
# S017       -0.33      -0.07        NaN        NaN        NaN       0.92
# S018         NaN       0.09       0.00       0.28        NaN      -1.36
# S019       -0.47      -0.79        NaN        NaN        NaN       0.00
# S020       -0.36      -0.34      -0.25      -0.53        NaN       0.05
# S021       -0.52      -0.69       0.00       0.12       0.46        NaN
# S022       -0.89      -1.25      -0.19      -0.49      -0.07        NaN
# S023        0.01       0.46        NaN      -0.30       0.15      -0.02
# S024       -1.65       0.02        NaN      -1.07      -0.49      -1.88
# S025       -0.46      -0.92        NaN        NaN        NaN       0.32
# S026       -0.54       0.18        NaN       0.36        NaN      -0.47
# S027        1.08       0.24      -0.10       0.09        NaN       0.57
# S028       -0.69      -0.54       0.38        NaN        NaN      -0.57
# S029         NaN      -0.98        NaN        NaN        NaN       0.35
# S030         NaN      -0.56      -0.19      -0.43      -1.05      -1.02
# ...          ...        ...        ...        ...        ...        ...
# S111         NaN      -0.98      -0.21       0.29       0.26        NaN
# S112        1.34        NaN      -0.44       0.22       0.92        NaN
# S113        1.23       1.35      -0.22        NaN       1.53        NaN
# S114        0.15      -0.45       0.26        NaN        NaN      -0.06
# S115        0.99       0.50        NaN        NaN       1.15        NaN
# S116        1.01       1.44        NaN        NaN       0.45        NaN
# S117        1.11       0.26        NaN        NaN       1.23        NaN
# S118        0.55       0.11       0.08        NaN       0.03        NaN
# S119        0.37       0.37        NaN        NaN       0.87        NaN
# S120        1.78       1.85        NaN        NaN        NaN       1.12
# S121         NaN       0.16      -0.67       0.04       0.60        NaN
# S122        1.45       2.67       0.20       0.57       1.10        NaN
# S123        1.29        NaN      -0.01       0.21       1.44        NaN
# S124        1.89       0.10       0.57       0.53       1.84       1.51
# S125         NaN       0.12       0.60       0.64        NaN       0.30
# S126         NaN       1.10      -0.53        NaN        NaN       1.26
# S127         NaN       1.92       0.53        NaN        NaN       2.10
# S128        0.82       0.08       0.52        NaN        NaN        NaN
# S129         NaN       0.80      -0.35       1.20        NaN       0.19
# S130         NaN      -0.14      -0.32       1.34        NaN      -1.02
# S131         NaN       1.93       0.93       0.10       1.37       2.20
# S132         NaN       0.61      -0.01       0.31       1.27       1.20
# S133         NaN       0.16      -0.16      -0.21       0.99      -0.11
# S134        0.13       0.04       0.43        NaN        NaN        NaN
# S135        0.75       0.31       0.22      -0.32        NaN       0.96
# S136        0.70       0.43        NaN      -0.25       0.65       0.57
# S137        0.31        NaN        NaN       1.03        NaN      -0.48
# S138        1.20       0.39       0.23       0.17        NaN       1.00
# S139       -0.08       0.96        NaN       0.80        NaN      -0.09
# S140         NaN      -0.62       0.21      -0.17      -0.48      -0.04
#
#       IRS2-S620  IRS2-S679  IRS2-S731  IRS2-S736  IRS2-S915  IRS2-S973  \
# S001      -2.41      -0.35        NaN      -1.78        NaN      -0.48
# S002       0.29      -0.62      -1.79      -1.35      -0.55      -0.66
# S003        NaN        NaN        NaN        NaN       0.27       0.19
# S004      -1.36      -1.91      -1.69        NaN      -0.74        NaN
# S005       0.10       0.46      -0.45      -0.62      -0.10      -0.11
# S006       0.74      -0.80      -0.98      -0.01      -0.33      -0.29
# S007      -0.43      -0.61      -0.22      -0.03        NaN      -0.18
# S008        NaN       1.24       0.39       0.53        NaN       0.94
# S009       0.96       0.74       0.08       0.59       0.77       0.88
# S010        NaN       0.09      -0.56      -0.29      -0.07      -0.44
# S011      -0.81      -0.20      -0.02       0.14        NaN      -0.54
# S012       0.63       0.00      -1.69      -0.52        NaN       0.19
# S013       1.34       0.92       0.56       1.56        NaN       1.11
# S014        NaN       0.36       0.64       0.95        NaN       0.84
# S015       2.61        NaN       0.74       2.71        NaN       2.55
# S016        NaN        NaN        NaN        NaN       0.17      -0.86
# S017      -0.23       0.53        NaN      -0.94        NaN      -0.06
# S018       0.18      -0.88      -2.25      -1.19        NaN      -1.06
# S019      -0.11       0.12        NaN      -0.36        NaN       0.20
# S020        NaN      -0.71      -1.61      -1.11        NaN      -0.73
# S021        NaN       0.27      -1.04      -0.24        NaN       0.03
# S022        NaN      -0.43      -2.34      -1.26        NaN      -1.11
# S023      -0.57       0.06      -0.29        NaN      -0.53        NaN
# S024      -0.96      -1.68      -1.68        NaN      -1.11        NaN
# S025      -1.53       0.05        NaN      -0.63        NaN      -0.38
# S026        NaN      -0.14      -0.83      -0.70       0.13      -0.79
# S027        NaN       1.25       0.93       0.92        NaN       1.09
# S028       0.18      -0.05        NaN      -0.93      -0.25      -0.90
# S029       0.41      -0.86      -1.39      -0.76       0.07      -0.74
# S030        NaN      -1.18      -0.62      -0.80        NaN      -1.12
# ...         ...        ...        ...        ...        ...        ...
# S111        NaN        NaN        NaN        NaN       0.48       0.11
# S112        NaN        NaN        NaN        NaN       0.74        NaN
# S113       1.06        NaN       0.21       1.08        NaN       0.74
# S114      -0.15       0.03        NaN      -0.01       0.65      -0.11
# S115        NaN        NaN        NaN        NaN       0.90        NaN
# S116        NaN        NaN        NaN        NaN       0.69        NaN
# S117        NaN        NaN        NaN        NaN       1.11        NaN
# S118      -0.06        NaN      -0.02       0.01        NaN      -0.01
# S119      -0.05        NaN       0.10      -0.08        NaN       0.09
# S120       1.95       0.49        NaN       0.38        NaN       1.02
# S121        NaN        NaN        NaN        NaN       0.48       0.74
# S122        NaN       0.87       0.49       1.08        NaN       0.27
# S123        NaN        NaN        NaN        NaN       0.83        NaN
# S124        NaN        NaN        NaN        NaN       0.05        NaN
# S125       1.38       0.38       0.21       0.10        NaN       0.67
# S126       1.25       0.55       0.77       1.58       0.19       1.29
# S127       1.87       1.27       1.62       2.48       1.14       2.14
# S128       0.51       0.01       0.34       0.50       0.52       0.21
# S129       2.24       1.71       0.85       1.72        NaN       1.38
# S130       0.87      -0.01      -1.04      -0.01        NaN      -0.01
# S131       1.98       1.02       1.02       0.94        NaN       1.92
# S132       0.86       0.32       0.20       0.32        NaN       0.42
# S133       0.45      -0.01       0.39       0.32        NaN       0.23
# S134      -0.01      -0.23       0.00       0.16       0.29      -0.18
# S135        NaN       1.30       1.50       0.45        NaN       1.20
# S136      -0.01       0.46       0.86        NaN       0.49        NaN
# S137        NaN       0.38       0.52       0.77       0.94      -1.06
# S138        NaN       1.46       1.23       0.94        NaN       1.06
# S139        NaN       0.21       0.57       0.45      -0.03       0.02
# S140        NaN       0.61       0.80       0.35        NaN      -0.60
#
#                Mutation Patient_Type Within_Hotspot
# S001  Missense_Mutation        Tumor           True
# S002           Wildtype        Tumor       Wildtype
# S003  Missense_Mutation        Tumor           True
# S004           Wildtype        Tumor       Wildtype
# S005           Wildtype        Tumor       Wildtype
# S006           Wildtype        Tumor       Wildtype
# S007           Wildtype        Tumor       Wildtype
# S008  Missense_Mutation        Tumor           True
# S009           Wildtype        Tumor       Wildtype
# S010           Wildtype        Tumor       Wildtype
# S011  Missense_Mutation        Tumor          False
# S012           Wildtype        Tumor       Wildtype
# S013  Missense_Mutation        Tumor          False
# S014           Wildtype        Tumor       Wildtype
# S015           Wildtype        Tumor       Wildtype
# S016           Wildtype        Tumor       Wildtype
# S017  Missense_Mutation        Tumor          False
# S018           Wildtype        Tumor       Wildtype
# S019           Wildtype        Tumor       Wildtype
# S020  Missense_Mutation        Tumor           True
# S021  Missense_Mutation        Tumor          False
# S022  Missense_Mutation        Tumor           True
# S023  Missense_Mutation        Tumor           True
# S024           Wildtype        Tumor       Wildtype
# S025           Wildtype        Tumor       Wildtype
# S026  Missense_Mutation        Tumor          False
# S027  Missense_Mutation        Tumor          False
# S028           Wildtype        Tumor       Wildtype
# S029           Wildtype        Tumor       Wildtype
# S030  Missense_Mutation        Tumor          False
# ...                 ...          ...            ...
# S111           Wildtype       Normal       Wildtype
# S112           Wildtype       Normal       Wildtype
# S113           Wildtype       Normal       Wildtype
# S114           Wildtype       Normal       Wildtype
# S115           Wildtype       Normal       Wildtype
# S116           Wildtype       Normal       Wildtype
# S117           Wildtype       Normal       Wildtype
# S118           Wildtype       Normal       Wildtype
# S119           Wildtype       Normal       Wildtype
# S120           Wildtype       Normal       Wildtype
# S121           Wildtype       Normal       Wildtype
# S122           Wildtype       Normal       Wildtype
# S123           Wildtype       Normal       Wildtype
# S124           Wildtype       Normal       Wildtype
# S125           Wildtype       Normal       Wildtype
# S126           Wildtype       Normal       Wildtype
# S127           Wildtype       Normal       Wildtype
# S128           Wildtype       Normal       Wildtype
# S129           Wildtype       Normal       Wildtype
# S130           Wildtype       Normal       Wildtype
# S131           Wildtype       Normal       Wildtype
# S132           Wildtype       Normal       Wildtype
# S133           Wildtype       Normal       Wildtype
# S134           Wildtype       Normal       Wildtype
# S135           Wildtype       Normal       Wildtype
# S136           Wildtype       Normal       Wildtype
# S137           Wildtype       Normal       Wildtype
# S138           Wildtype       Normal       Wildtype
# S139           Wildtype       Normal       Wildtype
# S140           Wildtype       Normal       Wildtype
#
# [140 rows x 15 columns]

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == False]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for IRS2-S1100 Ttest_indResult(statistic=1.2581485029059665, pvalue=0.21911001862276258)
# Test for IRS2-S365 Ttest_indResult(statistic=0.5781544425272238, pvalue=0.5665706199313898)
# Test for IRS2-S388 Ttest_indResult(statistic=1.098890069317561, pvalue=0.2815186150757412)
# Test for IRS2-S391 Ttest_indResult(statistic=-0.3174394560485842, pvalue=0.753184504329987)
# Test for IRS2-S560 Ttest_indResult(statistic=0.965636818952573, pvalue=0.3452155426570065)
# Test for IRS2-S577 Ttest_indResult(statistic=-0.21159497137452224, pvalue=0.8339556600886091)
# Test for IRS2-S620 Ttest_indResult(statistic=-0.3344627721974574, pvalue=0.7421213512511845)
# Test for IRS2-S679 Ttest_indResult(statistic=-0.6529905226270797, pvalue=0.5185762558216127)
# Test for IRS2-S731 Ttest_indResult(statistic=-0.7826695177305918, pvalue=0.4406321743527777)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] != True]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for IRS2-S1100 Ttest_indResult(statistic=0.26265175439907074, pvalue=0.7936249576279074)
# Test for IRS2-S365 Ttest_indResult(statistic=0.5865327188969761, pvalue=0.5589697730518817)
# Test for IRS2-S388 Ttest_indResult(statistic=0.2071651566064311, pvalue=0.8364823497512087)
# Test for IRS2-S391 Ttest_indResult(statistic=-1.3131615883800831, pvalue=0.19404691151719122)
# Test for IRS2-S560 Ttest_indResult(statistic=-0.5120888124138994, pvalue=0.6106769468663742)
# Test for IRS2-S577 Ttest_indResult(statistic=-0.6868402625498272, pvalue=0.49474443551205827)
# Test for IRS2-S620 Ttest_indResult(statistic=-0.5154076510372039, pvalue=0.6085858342904644)
# Test for IRS2-S679 Ttest_indResult(statistic=-0.12555647042750925, pvalue=0.900448136814622)
# Test for IRS2-S731 Ttest_indResult(statistic=-0.7492134192776231, pvalue=0.4565170118038431)

# %% [markdown]
# ## All mutations vs wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] != 'Wildtype']
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for IRS2-S1100 Ttest_indResult(statistic=-1.1228415172362924, pvalue=0.26551235764242587)
# Test for IRS2-S365 Ttest_indResult(statistic=0.38985281829235874, pvalue=0.6975563462560624)
# Test for IRS2-S388 Ttest_indResult(statistic=-0.6119418458313213, pvalue=0.5425588109981629)
# Test for IRS2-S391 Ttest_indResult(statistic=-2.176253606263746, pvalue=0.03341833321656063)
# Test for IRS2-S560 Ttest_indResult(statistic=-2.3097211799375055, pvalue=0.024755067981666396)
# Test for IRS2-S577 Ttest_indResult(statistic=-0.9262059196071508, pvalue=0.35793035131055373)
# Test for IRS2-S620 Ttest_indResult(statistic=-0.3642074443063041, pvalue=0.717270090953648)
# Test for IRS2-S679 Ttest_indResult(statistic=0.6439070830781372, pvalue=0.5217703298207741)
# Test for IRS2-S731 Ttest_indResult(statistic=-0.15079785621987576, pvalue=0.8806169797454081)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for IRS2-S1100 Ttest_indResult(statistic=-0.17960691146578195, pvalue=0.8581460957058462)
# Test for IRS2-S365 Ttest_indResult(statistic=0.558546915920515, pvalue=0.578279109004115)
# Test for IRS2-S388 Ttest_indResult(statistic=-0.019998588058488358, pvalue=0.9841182116407277)
# Test for IRS2-S391 Ttest_indResult(statistic=-1.9200565362048303, pvalue=0.061659203134459044)
# Test for IRS2-S560 Ttest_indResult(statistic=-1.067904575547338, pvalue=0.2919663837494855)
# Test for IRS2-S577 Ttest_indResult(statistic=-0.8772462310167592, pvalue=0.3850124148836366)
# Test for IRS2-S620 Ttest_indResult(statistic=-0.5034699711465974, pvalue=0.6172644041124613)
# Test for IRS2-S679 Ttest_indResult(statistic=0.14819956156958114, pvalue=0.882747686637892)
# Test for IRS2-S731 Ttest_indResult(statistic=-0.6246598285746462, pvalue=0.535215204447254)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S560', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S560', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on PIK3CA phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()
