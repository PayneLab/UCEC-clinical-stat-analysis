# %% [markdown]
# # PIK3CA: Effects of Hotspot Mutation on IRS1

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.stats.multitest

# %% [markdown]
# ### Import CPTAC

# %%
import CPTAC

# %%
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %%
protein = 'IRS1'
gene = 'PIK3CA'

# %% [markdown]
# ## Extract the data for hotspot mutations only

# %%
#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.E545A', 'p.E545K', 'p.E545V', 'p.Q546P', 'p.Q546R', 'p.E542K']
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

# %%
p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
#print(p10_mutations)
p10_mutations['Within_Hotspot'] = False
p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)
print(len(p10_mutations.loc[(p10_mutations['Within_Hotspot'] == True)]))
# Out:
# 19

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
out_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == False]
ttest = scipy.stats.ttest_ind(in_hotspot[protein], out_hotspot[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.1811143291128672, pvalue=0.8570734994915308)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] != True]
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.6714134122839353, pvalue=0.5035367810301701)

# %% [markdown]
# ## All mutations vs wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] != 'Wildtype']
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.03423533120962, pvalue=0.3035716066390899)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.890843404844897, pvalue=0.3761090199360049)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on PIK3CA abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %% [markdown]
# # Phosphoproteomic Abundance

# %%
phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
phos_mutations['Within_Hotspot'] = False
phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True

phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
#print(phos_mutations)


phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
#phos_mutations = phos_mutations.dropna(axis = 0)
#print(phos_mutations)
phos_sites = list(phos_mutations)
phos_sites = phos_sites[:(len(phos_sites) - 3)]

# %%
sitedf = CPTAC.compare_mutations(phos, 'IRS1-S1101', gene)
print(sitedf)
# Out:
#       IRS1-S1101           Mutation Patient_Type
# S001     -0.2040  Missense_Mutation        Tumor
# S002     -0.5840           Wildtype        Tumor
# S003      0.4380  Missense_Mutation        Tumor
# S004     -0.2660           Wildtype        Tumor
# S005     -0.4640           Wildtype        Tumor
# S006     -0.9885           Wildtype        Tumor
# S007      0.8265           Wildtype        Tumor
# S008     -0.3005           Wildtype        Tumor
# S009     -0.2190  Missense_Mutation        Tumor
# S010      0.1505  Missense_Mutation        Tumor
# S011     -0.1270           Wildtype        Tumor
# S012     -1.4150  Missense_Mutation        Tumor
# S013     -0.9170           Wildtype        Tumor
# S014     -1.0545  Missense_Mutation        Tumor
# S015      0.1050           Wildtype        Tumor
# S016     -0.2530           Wildtype        Tumor
# S017     -1.6345           Wildtype        Tumor
# S018      0.6350  Missense_Mutation        Tumor
# S019      1.5825           Wildtype        Tumor
# S020      0.6280           Wildtype        Tumor
# S021     -0.3800  Missense_Mutation        Tumor
# S022         NaN  Missense_Mutation        Tumor
# S023         NaN  Missense_Mutation        Tumor
# S024      0.6850  Missense_Mutation        Tumor
# S025     -0.3320           Wildtype        Tumor
# S026      0.9050  Missense_Mutation        Tumor
# S027     -0.5740  Missense_Mutation        Tumor
# S028      0.2280  Missense_Mutation        Tumor
# S029      0.2090           Wildtype        Tumor
# S030     -0.3635  Missense_Mutation        Tumor
# ...          ...                ...          ...
# S124      1.0600           Wildtype       Normal
# S125      0.5185           Wildtype       Normal
# S126         NaN           Wildtype       Normal
# S127     -0.6450           Wildtype       Normal
# S128         NaN           Wildtype       Normal
# S129      0.6595           Wildtype       Normal
# S130      0.8370           Wildtype       Normal
# S131      1.2600           Wildtype       Normal
# S132      1.1400           Wildtype       Normal
# S133      0.4170           Wildtype       Normal
# S134      0.1660           Wildtype       Normal
# S135      0.0212           Wildtype       Normal
# S136      0.1400           Wildtype       Normal
# S137      0.7165           Wildtype       Normal
# S138      0.8235           Wildtype       Normal
# S139      0.8910           Wildtype       Normal
# S140      1.0950           Wildtype       Normal
# S141      1.0005           Wildtype       Normal
# S142      1.1400           Wildtype       Normal
# S143      0.1215           Wildtype       Normal
# S144      0.4025           Wildtype       Normal
# S145      0.3400           Wildtype       Normal
# S146      0.0000           Wildtype       Normal
# S147     -0.3430           Wildtype       Normal
# S148      0.0596           Wildtype       Normal
# S149     -0.4790           Wildtype       Normal
# S150     -0.2050           Wildtype       Normal
# S151      0.7470           Wildtype       Normal
# S152      1.1500           Wildtype       Normal
# S153     -0.1170           Wildtype       Normal
#
# [153 rows x 3 columns]

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
p_values = []
site_names = []

for site in phos_sites:
    #mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = CPTAC.compare_mutations(phos, site, gene)

    if (site is not 'Mutation'):
        sitedf = CPTAC.compare_mutations(phos, site, gene)
        sitedf['Within_Hotspot'] = False
        sitedf.loc[hotspot_patients, 'Within_Hotspot'] = True

        sitedf.loc[sitedf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        #print(phos_mutations)
        sitedf = sitedf.loc[sitedf['Patient_Type'] == 'Tumor']
        print(sitedf)
        
        mutateddf = sitedf.loc[sitedf['Within_Hotspot'] != 'Wildtype' ].dropna(axis=0)
        wtdf = sitedf.loc[sitedf['Within_Hotspot'] == 'Wildtype'].dropna(axis=0)
        ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
        p_values.append(ttest[1])
        site_names.append(site) 
    
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1]         
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]

significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
#       IRS1-S1005           Mutation Patient_Type Within_Hotspot
# S001     -0.5010  Missense_Mutation        Tumor           True
# S002      0.1760           Wildtype        Tumor       Wildtype
# S003      0.0839  Missense_Mutation        Tumor           True
# S004      0.0448           Wildtype        Tumor       Wildtype
# S005     -0.2230           Wildtype        Tumor       Wildtype
# S006     -0.6490           Wildtype        Tumor       Wildtype
# S007     -0.2120           Wildtype        Tumor       Wildtype
# S008      0.2140           Wildtype        Tumor       Wildtype
# S009      0.5540  Missense_Mutation        Tumor           True
# S010     -0.0824  Missense_Mutation        Tumor          False
# S011     -0.6440           Wildtype        Tumor       Wildtype
# S012     -1.2900  Missense_Mutation        Tumor          False
# S013     -0.1250           Wildtype        Tumor       Wildtype
# S014     -0.3970  Missense_Mutation        Tumor          False
# S015      0.3790           Wildtype        Tumor       Wildtype
# S016     -0.7740           Wildtype        Tumor       Wildtype
# S017     -0.9090           Wildtype        Tumor       Wildtype
# S018     -0.2910  Missense_Mutation        Tumor          False
# S019      0.0167           Wildtype        Tumor       Wildtype
# S020      0.0408           Wildtype        Tumor       Wildtype
# S021     -0.1030  Missense_Mutation        Tumor           True
# S022     -0.2690  Missense_Mutation        Tumor          False
# S023     -0.4170  Missense_Mutation        Tumor           True
# S024     -0.0601  Missense_Mutation        Tumor           True
# S025      0.0147           Wildtype        Tumor       Wildtype
# S026      0.6700  Missense_Mutation        Tumor          False
# S027     -0.3810  Missense_Mutation        Tumor          False
# S028     -0.0574  Missense_Mutation        Tumor          False
# S029     -0.5840           Wildtype        Tumor       Wildtype
# S030     -0.4210  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071     -0.0895           Wildtype        Tumor       Wildtype
# S072     -0.8440           Wildtype        Tumor       Wildtype
# S073      0.2920           Wildtype        Tumor       Wildtype
# S074     -0.0450       In_Frame_Del        Tumor          False
# S075      0.0222  Missense_Mutation        Tumor          False
# S076     -0.2630           Wildtype        Tumor       Wildtype
# S077     -0.3490  Missense_Mutation        Tumor          False
# S078      0.0870           Wildtype        Tumor       Wildtype
# S079     -0.0833           Wildtype        Tumor       Wildtype
# S080     -1.7400           Wildtype        Tumor       Wildtype
# S081     -0.5680  Missense_Mutation        Tumor          False
# S082     -0.1810           Wildtype        Tumor       Wildtype
# S083      0.2430           Wildtype        Tumor       Wildtype
# S084     -0.7910  Missense_Mutation        Tumor           True
# S085     -1.3600           Wildtype        Tumor       Wildtype
# S086     -2.0500  Missense_Mutation        Tumor          False
# S087      0.0834           Wildtype        Tumor       Wildtype
# S088     -0.5640  Missense_Mutation        Tumor           True
# S089     -0.4040  Missense_Mutation        Tumor          False
# S090     -0.1160  Missense_Mutation        Tumor           True
# S091     -0.6340           Wildtype        Tumor       Wildtype
# S092      0.4280  Missense_Mutation        Tumor          False
# S093      0.2010           Wildtype        Tumor       Wildtype
# S094     -1.2700           Wildtype        Tumor       Wildtype
# S095     -0.3780  Missense_Mutation        Tumor          False
# S096     -0.2000  Missense_Mutation        Tumor          False
# S097     -0.3950  Missense_Mutation        Tumor           True
# S098     -0.2360  Missense_Mutation        Tumor           True
# S099     -1.0200  Missense_Mutation        Tumor          False
# S100     -0.1000           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1078           Mutation Patient_Type Within_Hotspot
# S001         NaN  Missense_Mutation        Tumor           True
# S002         NaN           Wildtype        Tumor       Wildtype
# S003         NaN  Missense_Mutation        Tumor           True
# S004   -0.028500           Wildtype        Tumor       Wildtype
# S005         NaN           Wildtype        Tumor       Wildtype
# S006         NaN           Wildtype        Tumor       Wildtype
# S007         NaN           Wildtype        Tumor       Wildtype
# S008    0.207000           Wildtype        Tumor       Wildtype
# S009    0.799000  Missense_Mutation        Tumor           True
# S010         NaN  Missense_Mutation        Tumor          False
# S011   -0.420000           Wildtype        Tumor       Wildtype
# S012   -0.186000  Missense_Mutation        Tumor          False
# S013    0.447000           Wildtype        Tumor       Wildtype
# S014    0.887000  Missense_Mutation        Tumor          False
# S015    0.335000           Wildtype        Tumor       Wildtype
# S016   -1.290000           Wildtype        Tumor       Wildtype
# S017         NaN           Wildtype        Tumor       Wildtype
# S018         NaN  Missense_Mutation        Tumor          False
# S019    1.560000           Wildtype        Tumor       Wildtype
# S020         NaN           Wildtype        Tumor       Wildtype
# S021    0.006010  Missense_Mutation        Tumor           True
# S022         NaN  Missense_Mutation        Tumor          False
# S023         NaN  Missense_Mutation        Tumor           True
# S024         NaN  Missense_Mutation        Tumor           True
# S025         NaN           Wildtype        Tumor       Wildtype
# S026         NaN  Missense_Mutation        Tumor          False
# S027    0.009250  Missense_Mutation        Tumor          False
# S028    0.002280  Missense_Mutation        Tumor          False
# S029         NaN           Wildtype        Tumor       Wildtype
# S030         NaN  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071         NaN           Wildtype        Tumor       Wildtype
# S072   -0.083300           Wildtype        Tumor       Wildtype
# S073         NaN           Wildtype        Tumor       Wildtype
# S074    0.761000       In_Frame_Del        Tumor          False
# S075         NaN  Missense_Mutation        Tumor          False
# S076   -1.230000           Wildtype        Tumor       Wildtype
# S077   -0.110000  Missense_Mutation        Tumor          False
# S078   -1.990000           Wildtype        Tumor       Wildtype
# S079         NaN           Wildtype        Tumor       Wildtype
# S080         NaN           Wildtype        Tumor       Wildtype
# S081         NaN  Missense_Mutation        Tumor          False
# S082         NaN           Wildtype        Tumor       Wildtype
# S083         NaN           Wildtype        Tumor       Wildtype
# S084   -0.000623  Missense_Mutation        Tumor           True
# S085         NaN           Wildtype        Tumor       Wildtype
# S086         NaN  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088         NaN  Missense_Mutation        Tumor           True
# S089         NaN  Missense_Mutation        Tumor          False
# S090   -0.566000  Missense_Mutation        Tumor           True
# S091   -0.784000           Wildtype        Tumor       Wildtype
# S092         NaN  Missense_Mutation        Tumor          False
# S093         NaN           Wildtype        Tumor       Wildtype
# S094         NaN           Wildtype        Tumor       Wildtype
# S095   -0.514000  Missense_Mutation        Tumor          False
# S096   -0.008720  Missense_Mutation        Tumor          False
# S097         NaN  Missense_Mutation        Tumor           True
# S098         NaN  Missense_Mutation        Tumor           True
# S099         NaN  Missense_Mutation        Tumor          False
# S100         NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1100           Mutation Patient_Type Within_Hotspot
# S001         NaN  Missense_Mutation        Tumor           True
# S002     -0.3400           Wildtype        Tumor       Wildtype
# S003     -0.1130  Missense_Mutation        Tumor           True
# S004     -0.6880           Wildtype        Tumor       Wildtype
# S005     -0.1900           Wildtype        Tumor       Wildtype
# S006     -0.7970           Wildtype        Tumor       Wildtype
# S007      0.3930           Wildtype        Tumor       Wildtype
# S008     -0.2440           Wildtype        Tumor       Wildtype
# S009     -0.6020  Missense_Mutation        Tumor           True
# S010     -0.1340  Missense_Mutation        Tumor          False
# S011     -0.1270           Wildtype        Tumor       Wildtype
# S012     -0.8270  Missense_Mutation        Tumor          False
# S013     -0.8420           Wildtype        Tumor       Wildtype
# S014     -0.9690  Missense_Mutation        Tumor          False
# S015     -0.3455           Wildtype        Tumor       Wildtype
# S016     -0.2530           Wildtype        Tumor       Wildtype
# S017     -1.2795           Wildtype        Tumor       Wildtype
# S018         NaN  Missense_Mutation        Tumor          False
# S019      0.7950           Wildtype        Tumor       Wildtype
# S020         NaN           Wildtype        Tumor       Wildtype
# S021     -0.4860  Missense_Mutation        Tumor           True
# S022     -0.0718  Missense_Mutation        Tumor          False
# S023     -0.1280  Missense_Mutation        Tumor           True
# S024      0.0438  Missense_Mutation        Tumor           True
# S025      0.5160           Wildtype        Tumor       Wildtype
# S026         NaN  Missense_Mutation        Tumor          False
# S027     -0.5740  Missense_Mutation        Tumor          False
# S028      0.4040  Missense_Mutation        Tumor          False
# S029     -0.1700           Wildtype        Tumor       Wildtype
# S030      0.3830  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071     -0.0392           Wildtype        Tumor       Wildtype
# S072      0.0257           Wildtype        Tumor       Wildtype
# S073     -0.9910           Wildtype        Tumor       Wildtype
# S074      0.0285       In_Frame_Del        Tumor          False
# S075      0.1860  Missense_Mutation        Tumor          False
# S076      0.0219           Wildtype        Tumor       Wildtype
# S077     -0.5220  Missense_Mutation        Tumor          False
# S078      0.1300           Wildtype        Tumor       Wildtype
# S079      0.0196           Wildtype        Tumor       Wildtype
# S080      0.2600           Wildtype        Tumor       Wildtype
# S081     -0.4660  Missense_Mutation        Tumor          False
# S082      0.1190           Wildtype        Tumor       Wildtype
# S083     -0.3480           Wildtype        Tumor       Wildtype
# S084     -0.3620  Missense_Mutation        Tumor           True
# S085     -0.2320           Wildtype        Tumor       Wildtype
# S086     -0.5080  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088     -0.6180  Missense_Mutation        Tumor           True
# S089     -0.4855  Missense_Mutation        Tumor          False
# S090      0.0253  Missense_Mutation        Tumor           True
# S091      0.1570           Wildtype        Tumor       Wildtype
# S092      0.0785  Missense_Mutation        Tumor          False
# S093     -0.3570           Wildtype        Tumor       Wildtype
# S094     -0.2580           Wildtype        Tumor       Wildtype
# S095     -0.1700  Missense_Mutation        Tumor          False
# S096     -0.1910  Missense_Mutation        Tumor          False
# S097     -0.2040  Missense_Mutation        Tumor           True
# S098     -0.6250  Missense_Mutation        Tumor           True
# S099     -0.5190  Missense_Mutation        Tumor          False
# S100     -0.0413           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1101           Mutation Patient_Type Within_Hotspot
# S001    -0.20400  Missense_Mutation        Tumor           True
# S002    -0.58400           Wildtype        Tumor       Wildtype
# S003     0.43800  Missense_Mutation        Tumor           True
# S004    -0.26600           Wildtype        Tumor       Wildtype
# S005    -0.46400           Wildtype        Tumor       Wildtype
# S006    -0.98850           Wildtype        Tumor       Wildtype
# S007     0.82650           Wildtype        Tumor       Wildtype
# S008    -0.30050           Wildtype        Tumor       Wildtype
# S009    -0.21900  Missense_Mutation        Tumor           True
# S010     0.15050  Missense_Mutation        Tumor          False
# S011    -0.12700           Wildtype        Tumor       Wildtype
# S012    -1.41500  Missense_Mutation        Tumor          False
# S013    -0.91700           Wildtype        Tumor       Wildtype
# S014    -1.05450  Missense_Mutation        Tumor          False
# S015     0.10500           Wildtype        Tumor       Wildtype
# S016    -0.25300           Wildtype        Tumor       Wildtype
# S017    -1.63450           Wildtype        Tumor       Wildtype
# S018     0.63500  Missense_Mutation        Tumor          False
# S019     1.58250           Wildtype        Tumor       Wildtype
# S020     0.62800           Wildtype        Tumor       Wildtype
# S021    -0.38000  Missense_Mutation        Tumor           True
# S022         NaN  Missense_Mutation        Tumor          False
# S023         NaN  Missense_Mutation        Tumor           True
# S024     0.68500  Missense_Mutation        Tumor           True
# S025    -0.33200           Wildtype        Tumor       Wildtype
# S026     0.90500  Missense_Mutation        Tumor          False
# S027    -0.57400  Missense_Mutation        Tumor          False
# S028     0.22800  Missense_Mutation        Tumor          False
# S029     0.20900           Wildtype        Tumor       Wildtype
# S030    -0.36350  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071         NaN           Wildtype        Tumor       Wildtype
# S072     0.20700           Wildtype        Tumor       Wildtype
# S073     0.27750           Wildtype        Tumor       Wildtype
# S074    -0.58500       In_Frame_Del        Tumor          False
# S075     0.02250  Missense_Mutation        Tumor          False
# S076     0.02190           Wildtype        Tumor       Wildtype
# S077    -0.73400  Missense_Mutation        Tumor          False
# S078     0.13000           Wildtype        Tumor       Wildtype
# S079         NaN           Wildtype        Tumor       Wildtype
# S080     0.29600           Wildtype        Tumor       Wildtype
# S081    -1.16000  Missense_Mutation        Tumor          False
# S082         NaN           Wildtype        Tumor       Wildtype
# S083    -0.74900           Wildtype        Tumor       Wildtype
# S084    -0.45050  Missense_Mutation        Tumor           True
# S085    -0.23200           Wildtype        Tumor       Wildtype
# S086    -0.21800  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088    -0.16500  Missense_Mutation        Tumor           True
# S089    -0.08150  Missense_Mutation        Tumor          False
# S090    -0.05500  Missense_Mutation        Tumor           True
# S091     0.15700           Wildtype        Tumor       Wildtype
# S092         NaN  Missense_Mutation        Tumor          False
# S093     0.39700           Wildtype        Tumor       Wildtype
# S094    -0.91800           Wildtype        Tumor       Wildtype
# S095    -0.06100  Missense_Mutation        Tumor          False
# S096    -0.52100  Missense_Mutation        Tumor          False
# S097    -0.66200  Missense_Mutation        Tumor           True
# S098    -0.62850  Missense_Mutation        Tumor           True
# S099    -1.60000  Missense_Mutation        Tumor          False
# S100    -0.08015           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1131           Mutation Patient_Type Within_Hotspot
# S001         NaN  Missense_Mutation        Tumor           True
# S002         NaN           Wildtype        Tumor       Wildtype
# S003         NaN  Missense_Mutation        Tumor           True
# S004         NaN           Wildtype        Tumor       Wildtype
# S005         NaN           Wildtype        Tumor       Wildtype
# S006         NaN           Wildtype        Tumor       Wildtype
# S007         NaN           Wildtype        Tumor       Wildtype
# S008         NaN           Wildtype        Tumor       Wildtype
# S009         NaN  Missense_Mutation        Tumor           True
# S010         NaN  Missense_Mutation        Tumor          False
# S011         NaN           Wildtype        Tumor       Wildtype
# S012         NaN  Missense_Mutation        Tumor          False
# S013         NaN           Wildtype        Tumor       Wildtype
# S014         NaN  Missense_Mutation        Tumor          False
# S015         NaN           Wildtype        Tumor       Wildtype
# S016         NaN           Wildtype        Tumor       Wildtype
# S017         NaN           Wildtype        Tumor       Wildtype
# S018         NaN  Missense_Mutation        Tumor          False
# S019         NaN           Wildtype        Tumor       Wildtype
# S020         NaN           Wildtype        Tumor       Wildtype
# S021         NaN  Missense_Mutation        Tumor           True
# S022         NaN  Missense_Mutation        Tumor          False
# S023         NaN  Missense_Mutation        Tumor           True
# S024         NaN  Missense_Mutation        Tumor           True
# S025         NaN           Wildtype        Tumor       Wildtype
# S026         NaN  Missense_Mutation        Tumor          False
# S027         NaN  Missense_Mutation        Tumor          False
# S028         NaN  Missense_Mutation        Tumor          False
# S029         NaN           Wildtype        Tumor       Wildtype
# S030         NaN  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071         NaN           Wildtype        Tumor       Wildtype
# S072     -0.4360           Wildtype        Tumor       Wildtype
# S073         NaN           Wildtype        Tumor       Wildtype
# S074         NaN       In_Frame_Del        Tumor          False
# S075         NaN  Missense_Mutation        Tumor          False
# S076         NaN           Wildtype        Tumor       Wildtype
# S077         NaN  Missense_Mutation        Tumor          False
# S078         NaN           Wildtype        Tumor       Wildtype
# S079         NaN           Wildtype        Tumor       Wildtype
# S080         NaN           Wildtype        Tumor       Wildtype
# S081         NaN  Missense_Mutation        Tumor          False
# S082         NaN           Wildtype        Tumor       Wildtype
# S083         NaN           Wildtype        Tumor       Wildtype
# S084         NaN  Missense_Mutation        Tumor           True
# S085         NaN           Wildtype        Tumor       Wildtype
# S086         NaN  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088         NaN  Missense_Mutation        Tumor           True
# S089         NaN  Missense_Mutation        Tumor          False
# S090         NaN  Missense_Mutation        Tumor           True
# S091     -0.0205           Wildtype        Tumor       Wildtype
# S092         NaN  Missense_Mutation        Tumor          False
# S093         NaN           Wildtype        Tumor       Wildtype
# S094         NaN           Wildtype        Tumor       Wildtype
# S095      0.0000  Missense_Mutation        Tumor          False
# S096         NaN  Missense_Mutation        Tumor          False
# S097         NaN  Missense_Mutation        Tumor           True
# S098         NaN  Missense_Mutation        Tumor           True
# S099         NaN  Missense_Mutation        Tumor          False
# S100         NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1132           Mutation Patient_Type Within_Hotspot
# S001         NaN  Missense_Mutation        Tumor           True
# S002         NaN           Wildtype        Tumor       Wildtype
# S003         NaN  Missense_Mutation        Tumor           True
# S004     -0.2310           Wildtype        Tumor       Wildtype
# S005         NaN           Wildtype        Tumor       Wildtype
# S006      0.4780           Wildtype        Tumor       Wildtype
# S007         NaN           Wildtype        Tumor       Wildtype
# S008         NaN           Wildtype        Tumor       Wildtype
# S009     -0.7120  Missense_Mutation        Tumor           True
# S010     -0.0480  Missense_Mutation        Tumor          False
# S011         NaN           Wildtype        Tumor       Wildtype
# S012         NaN  Missense_Mutation        Tumor          False
# S013         NaN           Wildtype        Tumor       Wildtype
# S014         NaN  Missense_Mutation        Tumor          False
# S015     -0.1780           Wildtype        Tumor       Wildtype
# S016         NaN           Wildtype        Tumor       Wildtype
# S017         NaN           Wildtype        Tumor       Wildtype
# S018         NaN  Missense_Mutation        Tumor          False
# S019         NaN           Wildtype        Tumor       Wildtype
# S020         NaN           Wildtype        Tumor       Wildtype
# S021     -1.0100  Missense_Mutation        Tumor           True
# S022         NaN  Missense_Mutation        Tumor          False
# S023         NaN  Missense_Mutation        Tumor           True
# S024         NaN  Missense_Mutation        Tumor           True
# S025         NaN           Wildtype        Tumor       Wildtype
# S026         NaN  Missense_Mutation        Tumor          False
# S027         NaN  Missense_Mutation        Tumor          False
# S028      0.0119  Missense_Mutation        Tumor          False
# S029         NaN           Wildtype        Tumor       Wildtype
# S030         NaN  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071         NaN           Wildtype        Tumor       Wildtype
# S072         NaN           Wildtype        Tumor       Wildtype
# S073      0.7650           Wildtype        Tumor       Wildtype
# S074         NaN       In_Frame_Del        Tumor          False
# S075         NaN  Missense_Mutation        Tumor          False
# S076         NaN           Wildtype        Tumor       Wildtype
# S077         NaN  Missense_Mutation        Tumor          False
# S078         NaN           Wildtype        Tumor       Wildtype
# S079         NaN           Wildtype        Tumor       Wildtype
# S080         NaN           Wildtype        Tumor       Wildtype
# S081         NaN  Missense_Mutation        Tumor          False
# S082         NaN           Wildtype        Tumor       Wildtype
# S083         NaN           Wildtype        Tumor       Wildtype
# S084         NaN  Missense_Mutation        Tumor           True
# S085         NaN           Wildtype        Tumor       Wildtype
# S086         NaN  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088         NaN  Missense_Mutation        Tumor           True
# S089         NaN  Missense_Mutation        Tumor          False
# S090         NaN  Missense_Mutation        Tumor           True
# S091         NaN           Wildtype        Tumor       Wildtype
# S092         NaN  Missense_Mutation        Tumor          False
# S093         NaN           Wildtype        Tumor       Wildtype
# S094         NaN           Wildtype        Tumor       Wildtype
# S095         NaN  Missense_Mutation        Tumor          False
# S096         NaN  Missense_Mutation        Tumor          False
# S097     -0.0355  Missense_Mutation        Tumor           True
# S098      0.4170  Missense_Mutation        Tumor           True
# S099         NaN  Missense_Mutation        Tumor          False
# S100      0.1250           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1133           Mutation Patient_Type Within_Hotspot
# S001    -0.10600  Missense_Mutation        Tumor           True
# S002         NaN           Wildtype        Tumor       Wildtype
# S003         NaN  Missense_Mutation        Tumor           True
# S004    -0.02000           Wildtype        Tumor       Wildtype
# S005         NaN           Wildtype        Tumor       Wildtype
# S006     0.47800           Wildtype        Tumor       Wildtype
# S007         NaN           Wildtype        Tumor       Wildtype
# S008    -0.67700           Wildtype        Tumor       Wildtype
# S009    -0.43250  Missense_Mutation        Tumor           True
# S010    -0.04800  Missense_Mutation        Tumor          False
# S011         NaN           Wildtype        Tumor       Wildtype
# S012    -0.48400  Missense_Mutation        Tumor          False
# S013         NaN           Wildtype        Tumor       Wildtype
# S014         NaN  Missense_Mutation        Tumor          False
# S015    -0.19950           Wildtype        Tumor       Wildtype
# S016         NaN           Wildtype        Tumor       Wildtype
# S017         NaN           Wildtype        Tumor       Wildtype
# S018     0.01590  Missense_Mutation        Tumor          False
# S019         NaN           Wildtype        Tumor       Wildtype
# S020    -0.01590           Wildtype        Tumor       Wildtype
# S021    -0.89200  Missense_Mutation        Tumor           True
# S022    -0.02830  Missense_Mutation        Tumor          False
# S023    -0.44300  Missense_Mutation        Tumor           True
# S024         NaN  Missense_Mutation        Tumor           True
# S025         NaN           Wildtype        Tumor       Wildtype
# S026    -0.20700  Missense_Mutation        Tumor          False
# S027         NaN  Missense_Mutation        Tumor          False
# S028     0.08595  Missense_Mutation        Tumor          False
# S029    -0.20900           Wildtype        Tumor       Wildtype
# S030         NaN  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071     0.00525           Wildtype        Tumor       Wildtype
# S072         NaN           Wildtype        Tumor       Wildtype
# S073     0.76500           Wildtype        Tumor       Wildtype
# S074         NaN       In_Frame_Del        Tumor          False
# S075         NaN  Missense_Mutation        Tumor          False
# S076         NaN           Wildtype        Tumor       Wildtype
# S077         NaN  Missense_Mutation        Tumor          False
# S078         NaN           Wildtype        Tumor       Wildtype
# S079    -0.20900           Wildtype        Tumor       Wildtype
# S080         NaN           Wildtype        Tumor       Wildtype
# S081         NaN  Missense_Mutation        Tumor          False
# S082    -0.11200           Wildtype        Tumor       Wildtype
# S083         NaN           Wildtype        Tumor       Wildtype
# S084    -0.42350  Missense_Mutation        Tumor           True
# S085         NaN           Wildtype        Tumor       Wildtype
# S086         NaN  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088         NaN  Missense_Mutation        Tumor           True
# S089         NaN  Missense_Mutation        Tumor          False
# S090         NaN  Missense_Mutation        Tumor           True
# S091         NaN           Wildtype        Tumor       Wildtype
# S092    -0.00191  Missense_Mutation        Tumor          False
# S093     0.31600           Wildtype        Tumor       Wildtype
# S094         NaN           Wildtype        Tumor       Wildtype
# S095         NaN  Missense_Mutation        Tumor          False
# S096         NaN  Missense_Mutation        Tumor          False
# S097    -0.03550  Missense_Mutation        Tumor           True
# S098     0.41700  Missense_Mutation        Tumor           True
# S099         NaN  Missense_Mutation        Tumor          False
# S100     0.12500           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1134           Mutation Patient_Type Within_Hotspot
# S001   -0.527000  Missense_Mutation        Tumor           True
# S002   -0.160000           Wildtype        Tumor       Wildtype
# S003    0.499000  Missense_Mutation        Tumor           True
# S004    0.661000           Wildtype        Tumor       Wildtype
# S005   -0.616000           Wildtype        Tumor       Wildtype
# S006   -0.389000           Wildtype        Tumor       Wildtype
# S007    1.760000           Wildtype        Tumor       Wildtype
# S008   -0.199875           Wildtype        Tumor       Wildtype
# S009   -0.387000  Missense_Mutation        Tumor           True
# S010   -0.359000  Missense_Mutation        Tumor          False
# S011    0.257000           Wildtype        Tumor       Wildtype
# S012   -0.169000  Missense_Mutation        Tumor          False
# S013   -0.303000           Wildtype        Tumor       Wildtype
# S014   -0.405000  Missense_Mutation        Tumor          False
# S015    0.546000           Wildtype        Tumor       Wildtype
# S016         NaN           Wildtype        Tumor       Wildtype
# S017   -0.701000           Wildtype        Tumor       Wildtype
# S018    0.258950  Missense_Mutation        Tumor          False
# S019    0.692000           Wildtype        Tumor       Wildtype
# S020   -0.587950           Wildtype        Tumor       Wildtype
# S021   -0.779000  Missense_Mutation        Tumor           True
# S022   -0.149000  Missense_Mutation        Tumor          False
# S023   -0.562000  Missense_Mutation        Tumor           True
# S024   -0.457000  Missense_Mutation        Tumor           True
# S025   -0.323000           Wildtype        Tumor       Wildtype
# S026    0.067000  Missense_Mutation        Tumor          False
# S027   -0.559000  Missense_Mutation        Tumor          False
# S028   -0.106000  Missense_Mutation        Tumor          False
# S029    0.116000           Wildtype        Tumor       Wildtype
# S030   -0.506000  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071   -0.106000           Wildtype        Tumor       Wildtype
# S072   -0.215000           Wildtype        Tumor       Wildtype
# S073   -0.284000           Wildtype        Tumor       Wildtype
# S074    0.026400       In_Frame_Del        Tumor          False
# S075    0.796000  Missense_Mutation        Tumor          False
# S076   -0.711000           Wildtype        Tumor       Wildtype
# S077   -0.123000  Missense_Mutation        Tumor          False
# S078         NaN           Wildtype        Tumor       Wildtype
# S079    0.016900           Wildtype        Tumor       Wildtype
# S080    0.104000           Wildtype        Tumor       Wildtype
# S081   -0.532000  Missense_Mutation        Tumor          False
# S082    0.175000           Wildtype        Tumor       Wildtype
# S083    0.005710           Wildtype        Tumor       Wildtype
# S084   -0.203000  Missense_Mutation        Tumor           True
# S085   -0.223000           Wildtype        Tumor       Wildtype
# S086   -0.713000  Missense_Mutation        Tumor          False
# S087    0.294000           Wildtype        Tumor       Wildtype
# S088   -0.920000  Missense_Mutation        Tumor           True
# S089    0.375000  Missense_Mutation        Tumor          False
# S090    0.810000  Missense_Mutation        Tumor           True
# S091   -0.124000           Wildtype        Tumor       Wildtype
# S092   -0.403000  Missense_Mutation        Tumor          False
# S093    0.271000           Wildtype        Tumor       Wildtype
# S094   -1.330000           Wildtype        Tumor       Wildtype
# S095   -0.524000  Missense_Mutation        Tumor          False
# S096   -0.645000  Missense_Mutation        Tumor          False
# S097   -0.485000  Missense_Mutation        Tumor           True
# S098   -0.108000  Missense_Mutation        Tumor           True
# S099   -1.140000  Missense_Mutation        Tumor          False
# S100   -0.518000           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1135           Mutation Patient_Type Within_Hotspot
# S001         NaN  Missense_Mutation        Tumor           True
# S002         NaN           Wildtype        Tumor       Wildtype
# S003         NaN  Missense_Mutation        Tumor           True
# S004         NaN           Wildtype        Tumor       Wildtype
# S005         NaN           Wildtype        Tumor       Wildtype
# S006         NaN           Wildtype        Tumor       Wildtype
# S007         NaN           Wildtype        Tumor       Wildtype
# S008         NaN           Wildtype        Tumor       Wildtype
# S009         NaN  Missense_Mutation        Tumor           True
# S010         NaN  Missense_Mutation        Tumor          False
# S011         NaN           Wildtype        Tumor       Wildtype
# S012         NaN  Missense_Mutation        Tumor          False
# S013         NaN           Wildtype        Tumor       Wildtype
# S014         NaN  Missense_Mutation        Tumor          False
# S015         NaN           Wildtype        Tumor       Wildtype
# S016         NaN           Wildtype        Tumor       Wildtype
# S017         NaN           Wildtype        Tumor       Wildtype
# S018         NaN  Missense_Mutation        Tumor          False
# S019         NaN           Wildtype        Tumor       Wildtype
# S020         NaN           Wildtype        Tumor       Wildtype
# S021         NaN  Missense_Mutation        Tumor           True
# S022         NaN  Missense_Mutation        Tumor          False
# S023         NaN  Missense_Mutation        Tumor           True
# S024         NaN  Missense_Mutation        Tumor           True
# S025         NaN           Wildtype        Tumor       Wildtype
# S026         NaN  Missense_Mutation        Tumor          False
# S027         NaN  Missense_Mutation        Tumor          False
# S028         NaN  Missense_Mutation        Tumor          False
# S029      -0.209           Wildtype        Tumor       Wildtype
# S030         NaN  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071         NaN           Wildtype        Tumor       Wildtype
# S072         NaN           Wildtype        Tumor       Wildtype
# S073         NaN           Wildtype        Tumor       Wildtype
# S074         NaN       In_Frame_Del        Tumor          False
# S075         NaN  Missense_Mutation        Tumor          False
# S076         NaN           Wildtype        Tumor       Wildtype
# S077         NaN  Missense_Mutation        Tumor          False
# S078         NaN           Wildtype        Tumor       Wildtype
# S079         NaN           Wildtype        Tumor       Wildtype
# S080         NaN           Wildtype        Tumor       Wildtype
# S081         NaN  Missense_Mutation        Tumor          False
# S082         NaN           Wildtype        Tumor       Wildtype
# S083         NaN           Wildtype        Tumor       Wildtype
# S084         NaN  Missense_Mutation        Tumor           True
# S085         NaN           Wildtype        Tumor       Wildtype
# S086         NaN  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088         NaN  Missense_Mutation        Tumor           True
# S089         NaN  Missense_Mutation        Tumor          False
# S090         NaN  Missense_Mutation        Tumor           True
# S091         NaN           Wildtype        Tumor       Wildtype
# S092         NaN  Missense_Mutation        Tumor          False
# S093       0.316           Wildtype        Tumor       Wildtype
# S094         NaN           Wildtype        Tumor       Wildtype
# S095         NaN  Missense_Mutation        Tumor          False
# S096         NaN  Missense_Mutation        Tumor          False
# S097         NaN  Missense_Mutation        Tumor           True
# S098         NaN  Missense_Mutation        Tumor           True
# S099         NaN  Missense_Mutation        Tumor          False
# S100         NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1143           Mutation Patient_Type Within_Hotspot
# S001         NaN  Missense_Mutation        Tumor           True
# S002         NaN           Wildtype        Tumor       Wildtype
# S003         NaN  Missense_Mutation        Tumor           True
# S004         NaN           Wildtype        Tumor       Wildtype
# S005         NaN           Wildtype        Tumor       Wildtype
# S006         NaN           Wildtype        Tumor       Wildtype
# S007         NaN           Wildtype        Tumor       Wildtype
# S008     -0.6470           Wildtype        Tumor       Wildtype
# S009         NaN  Missense_Mutation        Tumor           True
# S010         NaN  Missense_Mutation        Tumor          False
# S011     -0.0495           Wildtype        Tumor       Wildtype
# S012     -0.0265  Missense_Mutation        Tumor          False
# S013         NaN           Wildtype        Tumor       Wildtype
# S014         NaN  Missense_Mutation        Tumor          False
# S015         NaN           Wildtype        Tumor       Wildtype
# S016         NaN           Wildtype        Tumor       Wildtype
# S017         NaN           Wildtype        Tumor       Wildtype
# S018         NaN  Missense_Mutation        Tumor          False
# S019         NaN           Wildtype        Tumor       Wildtype
# S020         NaN           Wildtype        Tumor       Wildtype
# S021         NaN  Missense_Mutation        Tumor           True
# S022         NaN  Missense_Mutation        Tumor          False
# S023         NaN  Missense_Mutation        Tumor           True
# S024         NaN  Missense_Mutation        Tumor           True
# S025         NaN           Wildtype        Tumor       Wildtype
# S026         NaN  Missense_Mutation        Tumor          False
# S027     -0.6020  Missense_Mutation        Tumor          False
# S028         NaN  Missense_Mutation        Tumor          False
# S029         NaN           Wildtype        Tumor       Wildtype
# S030         NaN  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071         NaN           Wildtype        Tumor       Wildtype
# S072         NaN           Wildtype        Tumor       Wildtype
# S073         NaN           Wildtype        Tumor       Wildtype
# S074      0.0262       In_Frame_Del        Tumor          False
# S075         NaN  Missense_Mutation        Tumor          False
# S076      0.5280           Wildtype        Tumor       Wildtype
# S077         NaN  Missense_Mutation        Tumor          False
# S078         NaN           Wildtype        Tumor       Wildtype
# S079         NaN           Wildtype        Tumor       Wildtype
# S080         NaN           Wildtype        Tumor       Wildtype
# S081         NaN  Missense_Mutation        Tumor          False
# S082         NaN           Wildtype        Tumor       Wildtype
# S083         NaN           Wildtype        Tumor       Wildtype
# S084     -0.5170  Missense_Mutation        Tumor           True
# S085         NaN           Wildtype        Tumor       Wildtype
# S086         NaN  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088         NaN  Missense_Mutation        Tumor           True
# S089         NaN  Missense_Mutation        Tumor          False
# S090      0.3880  Missense_Mutation        Tumor           True
# S091         NaN           Wildtype        Tumor       Wildtype
# S092         NaN  Missense_Mutation        Tumor          False
# S093         NaN           Wildtype        Tumor       Wildtype
# S094         NaN           Wildtype        Tumor       Wildtype
# S095         NaN  Missense_Mutation        Tumor          False
# S096         NaN  Missense_Mutation        Tumor          False
# S097         NaN  Missense_Mutation        Tumor           True
# S098         NaN  Missense_Mutation        Tumor           True
# S099         NaN  Missense_Mutation        Tumor          False
# S100         NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1145           Mutation Patient_Type Within_Hotspot
# S001         NaN  Missense_Mutation        Tumor           True
# S002         NaN           Wildtype        Tumor       Wildtype
# S003         NaN  Missense_Mutation        Tumor           True
# S004         NaN           Wildtype        Tumor       Wildtype
# S005         NaN           Wildtype        Tumor       Wildtype
# S006         NaN           Wildtype        Tumor       Wildtype
# S007         NaN           Wildtype        Tumor       Wildtype
# S008     -0.6470           Wildtype        Tumor       Wildtype
# S009         NaN  Missense_Mutation        Tumor           True
# S010         NaN  Missense_Mutation        Tumor          False
# S011     -0.0495           Wildtype        Tumor       Wildtype
# S012     -0.0265  Missense_Mutation        Tumor          False
# S013         NaN           Wildtype        Tumor       Wildtype
# S014         NaN  Missense_Mutation        Tumor          False
# S015         NaN           Wildtype        Tumor       Wildtype
# S016         NaN           Wildtype        Tumor       Wildtype
# S017         NaN           Wildtype        Tumor       Wildtype
# S018         NaN  Missense_Mutation        Tumor          False
# S019         NaN           Wildtype        Tumor       Wildtype
# S020         NaN           Wildtype        Tumor       Wildtype
# S021         NaN  Missense_Mutation        Tumor           True
# S022         NaN  Missense_Mutation        Tumor          False
# S023         NaN  Missense_Mutation        Tumor           True
# S024         NaN  Missense_Mutation        Tumor           True
# S025         NaN           Wildtype        Tumor       Wildtype
# S026         NaN  Missense_Mutation        Tumor          False
# S027     -0.6020  Missense_Mutation        Tumor          False
# S028         NaN  Missense_Mutation        Tumor          False
# S029         NaN           Wildtype        Tumor       Wildtype
# S030         NaN  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071         NaN           Wildtype        Tumor       Wildtype
# S072         NaN           Wildtype        Tumor       Wildtype
# S073         NaN           Wildtype        Tumor       Wildtype
# S074      0.0262       In_Frame_Del        Tumor          False
# S075         NaN  Missense_Mutation        Tumor          False
# S076      0.5280           Wildtype        Tumor       Wildtype
# S077         NaN  Missense_Mutation        Tumor          False
# S078         NaN           Wildtype        Tumor       Wildtype
# S079         NaN           Wildtype        Tumor       Wildtype
# S080         NaN           Wildtype        Tumor       Wildtype
# S081         NaN  Missense_Mutation        Tumor          False
# S082         NaN           Wildtype        Tumor       Wildtype
# S083         NaN           Wildtype        Tumor       Wildtype
# S084     -0.5170  Missense_Mutation        Tumor           True
# S085         NaN           Wildtype        Tumor       Wildtype
# S086         NaN  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088         NaN  Missense_Mutation        Tumor           True
# S089         NaN  Missense_Mutation        Tumor          False
# S090      0.3880  Missense_Mutation        Tumor           True
# S091         NaN           Wildtype        Tumor       Wildtype
# S092         NaN  Missense_Mutation        Tumor          False
# S093         NaN           Wildtype        Tumor       Wildtype
# S094         NaN           Wildtype        Tumor       Wildtype
# S095         NaN  Missense_Mutation        Tumor          False
# S096         NaN  Missense_Mutation        Tumor          False
# S097         NaN  Missense_Mutation        Tumor           True
# S098         NaN  Missense_Mutation        Tumor           True
# S099         NaN  Missense_Mutation        Tumor          False
# S100         NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1222           Mutation Patient_Type Within_Hotspot
# S001         NaN  Missense_Mutation        Tumor           True
# S002         NaN           Wildtype        Tumor       Wildtype
# S003         NaN  Missense_Mutation        Tumor           True
# S004         NaN           Wildtype        Tumor       Wildtype
# S005     -0.2880           Wildtype        Tumor       Wildtype
# S006         NaN           Wildtype        Tumor       Wildtype
# S007         NaN           Wildtype        Tumor       Wildtype
# S008         NaN           Wildtype        Tumor       Wildtype
# S009         NaN  Missense_Mutation        Tumor           True
# S010         NaN  Missense_Mutation        Tumor          False
# S011      0.2260           Wildtype        Tumor       Wildtype
# S012         NaN  Missense_Mutation        Tumor          False
# S013         NaN           Wildtype        Tumor       Wildtype
# S014         NaN  Missense_Mutation        Tumor          False
# S015         NaN           Wildtype        Tumor       Wildtype
# S016         NaN           Wildtype        Tumor       Wildtype
# S017         NaN           Wildtype        Tumor       Wildtype
# S018         NaN  Missense_Mutation        Tumor          False
# S019         NaN           Wildtype        Tumor       Wildtype
# S020         NaN           Wildtype        Tumor       Wildtype
# S021         NaN  Missense_Mutation        Tumor           True
# S022         NaN  Missense_Mutation        Tumor          False
# S023         NaN  Missense_Mutation        Tumor           True
# S024     -0.2460  Missense_Mutation        Tumor           True
# S025     -0.0275           Wildtype        Tumor       Wildtype
# S026         NaN  Missense_Mutation        Tumor          False
# S027      0.0275  Missense_Mutation        Tumor          False
# S028         NaN  Missense_Mutation        Tumor          False
# S029         NaN           Wildtype        Tumor       Wildtype
# S030         NaN  Missense_Mutation        Tumor          False
# ...          ...                ...          ...            ...
# S071         NaN           Wildtype        Tumor       Wildtype
# S072         NaN           Wildtype        Tumor       Wildtype
# S073         NaN           Wildtype        Tumor       Wildtype
# S074      0.8490       In_Frame_Del        Tumor          False
# S075         NaN  Missense_Mutation        Tumor          False
# S076      0.4600           Wildtype        Tumor       Wildtype
# S077         NaN  Missense_Mutation        Tumor          False
# S078         NaN           Wildtype        Tumor       Wildtype
# S079         NaN           Wildtype        Tumor       Wildtype
# S080         NaN           Wildtype        Tumor       Wildtype
# S081     -0.2200  Missense_Mutation        Tumor          False
# S082         NaN           Wildtype        Tumor       Wildtype
# S083         NaN           Wildtype        Tumor       Wildtype
# S084         NaN  Missense_Mutation        Tumor           True
# S085         NaN           Wildtype        Tumor       Wildtype
# S086         NaN  Missense_Mutation        Tumor          False
# S087         NaN           Wildtype        Tumor       Wildtype
# S088     -0.3270  Missense_Mutation        Tumor           True
# S089         NaN  Missense_Mutation        Tumor          False
# S090      1.0900  Missense_Mutation        Tumor           True
# S091         NaN           Wildtype        Tumor       Wildtype
# S092         NaN  Missense_Mutation        Tumor          False
# S093         NaN           Wildtype        Tumor       Wildtype
# S094     -0.4610           Wildtype        Tumor       Wildtype
# S095         NaN  Missense_Mutation        Tumor          False
# S096         NaN  Missense_Mutation        Tumor          False
# S097         NaN  Missense_Mutation        Tumor           True
# S098         NaN  Missense_Mutation        Tumor           True
# S099     -0.5190  Missense_Mutation        Tumor          False
# S100         NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-S1223           Mutation Patient_Type Within_Hotspot
# ...
# S098        NaN  Missense_Mutation        Tumor           True
# S099        NaN  Missense_Mutation        Tumor          False
# S100        NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-Y582           Mutation Patient_Type Within_Hotspot
# S001        NaN  Missense_Mutation        Tumor           True
# S002        NaN           Wildtype        Tumor       Wildtype
# S003        NaN  Missense_Mutation        Tumor           True
# S004        NaN           Wildtype        Tumor       Wildtype
# S005     -0.169           Wildtype        Tumor       Wildtype
# S006        NaN           Wildtype        Tumor       Wildtype
# S007        NaN           Wildtype        Tumor       Wildtype
# S008        NaN           Wildtype        Tumor       Wildtype
# S009        NaN  Missense_Mutation        Tumor           True
# S010        NaN  Missense_Mutation        Tumor          False
# S011        NaN           Wildtype        Tumor       Wildtype
# S012        NaN  Missense_Mutation        Tumor          False
# S013        NaN           Wildtype        Tumor       Wildtype
# S014        NaN  Missense_Mutation        Tumor          False
# S015        NaN           Wildtype        Tumor       Wildtype
# S016        NaN           Wildtype        Tumor       Wildtype
# S017        NaN           Wildtype        Tumor       Wildtype
# S018        NaN  Missense_Mutation        Tumor          False
# S019        NaN           Wildtype        Tumor       Wildtype
# S020        NaN           Wildtype        Tumor       Wildtype
# S021        NaN  Missense_Mutation        Tumor           True
# S022        NaN  Missense_Mutation        Tumor          False
# S023        NaN  Missense_Mutation        Tumor           True
# S024     -0.433  Missense_Mutation        Tumor           True
# S025      0.303           Wildtype        Tumor       Wildtype
# S026        NaN  Missense_Mutation        Tumor          False
# S027        NaN  Missense_Mutation        Tumor          False
# S028        NaN  Missense_Mutation        Tumor          False
# S029        NaN           Wildtype        Tumor       Wildtype
# S030        NaN  Missense_Mutation        Tumor          False
# ...         ...                ...          ...            ...
# S071        NaN           Wildtype        Tumor       Wildtype
# S072        NaN           Wildtype        Tumor       Wildtype
# S073        NaN           Wildtype        Tumor       Wildtype
# S074        NaN       In_Frame_Del        Tumor          False
# S075        NaN  Missense_Mutation        Tumor          False
# S076        NaN           Wildtype        Tumor       Wildtype
# S077        NaN  Missense_Mutation        Tumor          False
# S078        NaN           Wildtype        Tumor       Wildtype
# S079        NaN           Wildtype        Tumor       Wildtype
# S080        NaN           Wildtype        Tumor       Wildtype
# S081      0.298  Missense_Mutation        Tumor          False
# S082        NaN           Wildtype        Tumor       Wildtype
# S083        NaN           Wildtype        Tumor       Wildtype
# S084        NaN  Missense_Mutation        Tumor           True
# S085        NaN           Wildtype        Tumor       Wildtype
# S086        NaN  Missense_Mutation        Tumor          False
# S087        NaN           Wildtype        Tumor       Wildtype
# S088     -0.232  Missense_Mutation        Tumor           True
# S089        NaN  Missense_Mutation        Tumor          False
# S090        NaN  Missense_Mutation        Tumor           True
# S091        NaN           Wildtype        Tumor       Wildtype
# S092        NaN  Missense_Mutation        Tumor          False
# S093        NaN           Wildtype        Tumor       Wildtype
# S094     -0.249           Wildtype        Tumor       Wildtype
# S095        NaN  Missense_Mutation        Tumor          False
# S096        NaN  Missense_Mutation        Tumor          False
# S097        NaN  Missense_Mutation        Tumor           True
# S098        NaN  Missense_Mutation        Tumor           True
# S099      0.454  Missense_Mutation        Tumor          False
# S100        NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-Y632           Mutation Patient_Type Within_Hotspot
# S001        NaN  Missense_Mutation        Tumor           True
# S002        NaN           Wildtype        Tumor       Wildtype
# S003      0.521  Missense_Mutation        Tumor           True
# S004        NaN           Wildtype        Tumor       Wildtype
# S005        NaN           Wildtype        Tumor       Wildtype
# S006        NaN           Wildtype        Tumor       Wildtype
# S007        NaN           Wildtype        Tumor       Wildtype
# S008     -0.543           Wildtype        Tumor       Wildtype
# S009        NaN  Missense_Mutation        Tumor           True
# S010        NaN  Missense_Mutation        Tumor          False
# S011        NaN           Wildtype        Tumor       Wildtype
# S012     -0.742  Missense_Mutation        Tumor          False
# S013        NaN           Wildtype        Tumor       Wildtype
# S014        NaN  Missense_Mutation        Tumor          False
# S015        NaN           Wildtype        Tumor       Wildtype
# S016        NaN           Wildtype        Tumor       Wildtype
# S017     -1.530           Wildtype        Tumor       Wildtype
# S018        NaN  Missense_Mutation        Tumor          False
# S019        NaN           Wildtype        Tumor       Wildtype
# S020        NaN           Wildtype        Tumor       Wildtype
# S021        NaN  Missense_Mutation        Tumor           True
# S022        NaN  Missense_Mutation        Tumor          False
# S023        NaN  Missense_Mutation        Tumor           True
# S024        NaN  Missense_Mutation        Tumor           True
# S025        NaN           Wildtype        Tumor       Wildtype
# S026        NaN  Missense_Mutation        Tumor          False
# S027        NaN  Missense_Mutation        Tumor          False
# S028        NaN  Missense_Mutation        Tumor          False
# S029        NaN           Wildtype        Tumor       Wildtype
# S030        NaN  Missense_Mutation        Tumor          False
# ...         ...                ...          ...            ...
# S071        NaN           Wildtype        Tumor       Wildtype
# S072        NaN           Wildtype        Tumor       Wildtype
# S073        NaN           Wildtype        Tumor       Wildtype
# S074        NaN       In_Frame_Del        Tumor          False
# S075     -0.122  Missense_Mutation        Tumor          False
# S076        NaN           Wildtype        Tumor       Wildtype
# S077        NaN  Missense_Mutation        Tumor          False
# S078        NaN           Wildtype        Tumor       Wildtype
# S079        NaN           Wildtype        Tumor       Wildtype
# S080        NaN           Wildtype        Tumor       Wildtype
# S081        NaN  Missense_Mutation        Tumor          False
# S082        NaN           Wildtype        Tumor       Wildtype
# S083        NaN           Wildtype        Tumor       Wildtype
# S084     -0.177  Missense_Mutation        Tumor           True
# S085        NaN           Wildtype        Tumor       Wildtype
# S086        NaN  Missense_Mutation        Tumor          False
# S087        NaN           Wildtype        Tumor       Wildtype
# S088        NaN  Missense_Mutation        Tumor           True
# S089     -0.377  Missense_Mutation        Tumor          False
# S090        NaN  Missense_Mutation        Tumor           True
# S091        NaN           Wildtype        Tumor       Wildtype
# S092        NaN  Missense_Mutation        Tumor          False
# S093        NaN           Wildtype        Tumor       Wildtype
# S094        NaN           Wildtype        Tumor       Wildtype
# S095        NaN  Missense_Mutation        Tumor          False
# S096        NaN  Missense_Mutation        Tumor          False
# S097        NaN  Missense_Mutation        Tumor           True
# S098        NaN  Missense_Mutation        Tumor           True
# S099        NaN  Missense_Mutation        Tumor          False
# S100        NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-Y662           Mutation Patient_Type Within_Hotspot
# S001    -0.5550  Missense_Mutation        Tumor           True
# S002    -0.9510           Wildtype        Tumor       Wildtype
# S003        NaN  Missense_Mutation        Tumor           True
# S004        NaN           Wildtype        Tumor       Wildtype
# S005        NaN           Wildtype        Tumor       Wildtype
# S006        NaN           Wildtype        Tumor       Wildtype
# S007    -0.8890           Wildtype        Tumor       Wildtype
# S008        NaN           Wildtype        Tumor       Wildtype
# S009        NaN  Missense_Mutation        Tumor           True
# S010        NaN  Missense_Mutation        Tumor          False
# S011     0.8060           Wildtype        Tumor       Wildtype
# S012        NaN  Missense_Mutation        Tumor          False
# S013    -0.7080           Wildtype        Tumor       Wildtype
# S014    -1.6280  Missense_Mutation        Tumor          False
# S015        NaN           Wildtype        Tumor       Wildtype
# S016        NaN           Wildtype        Tumor       Wildtype
# S017        NaN           Wildtype        Tumor       Wildtype
# S018    -0.7430  Missense_Mutation        Tumor          False
# S019    -0.0995           Wildtype        Tumor       Wildtype
# S020    -0.0352           Wildtype        Tumor       Wildtype
# S021        NaN  Missense_Mutation        Tumor           True
# S022        NaN  Missense_Mutation        Tumor          False
# S023        NaN  Missense_Mutation        Tumor           True
# S024        NaN  Missense_Mutation        Tumor           True
# S025        NaN           Wildtype        Tumor       Wildtype
# S026     0.4860  Missense_Mutation        Tumor          False
# S027    -0.1760  Missense_Mutation        Tumor          False
# S028        NaN  Missense_Mutation        Tumor          False
# S029    -1.2000           Wildtype        Tumor       Wildtype
# S030     0.2120  Missense_Mutation        Tumor          False
# ...         ...                ...          ...            ...
# S071        NaN           Wildtype        Tumor       Wildtype
# S072        NaN           Wildtype        Tumor       Wildtype
# S073        NaN           Wildtype        Tumor       Wildtype
# S074     0.5400       In_Frame_Del        Tumor          False
# S075        NaN  Missense_Mutation        Tumor          False
# S076     0.8300           Wildtype        Tumor       Wildtype
# S077    -1.5350  Missense_Mutation        Tumor          False
# S078        NaN           Wildtype        Tumor       Wildtype
# S079        NaN           Wildtype        Tumor       Wildtype
# S080        NaN           Wildtype        Tumor       Wildtype
# S081        NaN  Missense_Mutation        Tumor          False
# S082        NaN           Wildtype        Tumor       Wildtype
# S083    -0.7010           Wildtype        Tumor       Wildtype
# S084        NaN  Missense_Mutation        Tumor           True
# S085        NaN           Wildtype        Tumor       Wildtype
# S086        NaN  Missense_Mutation        Tumor          False
# S087        NaN           Wildtype        Tumor       Wildtype
# S088        NaN  Missense_Mutation        Tumor           True
# S089        NaN  Missense_Mutation        Tumor          False
# S090     2.3600  Missense_Mutation        Tumor           True
# S091        NaN           Wildtype        Tumor       Wildtype
# S092        NaN  Missense_Mutation        Tumor          False
# S093    -0.6850           Wildtype        Tumor       Wildtype
# S094        NaN           Wildtype        Tumor       Wildtype
# S095        NaN  Missense_Mutation        Tumor          False
# S096    -1.4420  Missense_Mutation        Tumor          False
# S097        NaN  Missense_Mutation        Tumor           True
# S098        NaN  Missense_Mutation        Tumor           True
# S099        NaN  Missense_Mutation        Tumor          False
# S100        NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
#       IRS1-Y750           Mutation Patient_Type Within_Hotspot
# S001        NaN  Missense_Mutation        Tumor           True
# S002        NaN           Wildtype        Tumor       Wildtype
# S003        NaN  Missense_Mutation        Tumor           True
# S004        NaN           Wildtype        Tumor       Wildtype
# S005        NaN           Wildtype        Tumor       Wildtype
# S006        NaN           Wildtype        Tumor       Wildtype
# S007        NaN           Wildtype        Tumor       Wildtype
# S008      0.000           Wildtype        Tumor       Wildtype
# S009        NaN  Missense_Mutation        Tumor           True
# S010        NaN  Missense_Mutation        Tumor          False
# S011        NaN           Wildtype        Tumor       Wildtype
# S012     -0.821  Missense_Mutation        Tumor          False
# S013        NaN           Wildtype        Tumor       Wildtype
# S014        NaN  Missense_Mutation        Tumor          False
# S015        NaN           Wildtype        Tumor       Wildtype
# S016        NaN           Wildtype        Tumor       Wildtype
# S017        NaN           Wildtype        Tumor       Wildtype
# S018        NaN  Missense_Mutation        Tumor          False
# S019        NaN           Wildtype        Tumor       Wildtype
# S020        NaN           Wildtype        Tumor       Wildtype
# S021        NaN  Missense_Mutation        Tumor           True
# S022        NaN  Missense_Mutation        Tumor          False
# S023        NaN  Missense_Mutation        Tumor           True
# S024        NaN  Missense_Mutation        Tumor           True
# S025        NaN           Wildtype        Tumor       Wildtype
# S026        NaN  Missense_Mutation        Tumor          False
# S027        NaN  Missense_Mutation        Tumor          False
# S028        NaN  Missense_Mutation        Tumor          False
# S029        NaN           Wildtype        Tumor       Wildtype
# S030        NaN  Missense_Mutation        Tumor          False
# ...         ...                ...          ...            ...
# S071        NaN           Wildtype        Tumor       Wildtype
# S072        NaN           Wildtype        Tumor       Wildtype
# S073        NaN           Wildtype        Tumor       Wildtype
# S074        NaN       In_Frame_Del        Tumor          False
# S075        NaN  Missense_Mutation        Tumor          False
# S076        NaN           Wildtype        Tumor       Wildtype
# S077        NaN  Missense_Mutation        Tumor          False
# S078        NaN           Wildtype        Tumor       Wildtype
# S079        NaN           Wildtype        Tumor       Wildtype
# S080        NaN           Wildtype        Tumor       Wildtype
# S081        NaN  Missense_Mutation        Tumor          False
# S082        NaN           Wildtype        Tumor       Wildtype
# S083        NaN           Wildtype        Tumor       Wildtype
# S084     -0.360  Missense_Mutation        Tumor           True
# S085        NaN           Wildtype        Tumor       Wildtype
# S086        NaN  Missense_Mutation        Tumor          False
# S087        NaN           Wildtype        Tumor       Wildtype
# S088        NaN  Missense_Mutation        Tumor           True
# S089        NaN  Missense_Mutation        Tumor          False
# S090        NaN  Missense_Mutation        Tumor           True
# S091        NaN           Wildtype        Tumor       Wildtype
# S092        NaN  Missense_Mutation        Tumor          False
# S093        NaN           Wildtype        Tumor       Wildtype
# S094        NaN           Wildtype        Tumor       Wildtype
# S095        NaN  Missense_Mutation        Tumor          False
# S096        NaN  Missense_Mutation        Tumor          False
# S097        NaN  Missense_Mutation        Tumor           True
# S098        NaN  Missense_Mutation        Tumor           True
# S099        NaN  Missense_Mutation        Tumor          False
# S100        NaN           Wildtype        Tumor       Wildtype
#
# [100 rows x 4 columns]
# []
# []
# {}

# %%
p_values = []
site_names = []

for site in phos_sites:
    #mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    #mutated_list = CPTAC.compare_mutations(phos, site, gene)

    if (site is not 'Mutation'):
        sitedf = CPTAC.compare_mutations(phos, site, gene)
        
        sitedf = sitedf.loc[sitedf['Patient_Type'] == 'Tumor']
        #print(sitedf)
        sitedf['Within_Hotspot'] = False
        sitedf.loc[hotspot_patients, 'Within_Hotspot'] = True

        sitedf.loc[sitedf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        #print(sitedf)
        #print(phos_mutations)
        
        
        mutateddf = sitedf.loc[sitedf['Within_Hotspot'] != 'Wildtype' ].dropna(axis=0)
        #print(mutateddf)
        wtdf = sitedf.loc[sitedf['Within_Hotspot'] == 'Wildtype'].dropna(axis=0)
        
        #print(mutateddf)
        ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
        print(site, " ", ttest)
        p_values.append(ttest[1])
        site_names.append(site) 
    
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1]         
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]

significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# IRS1-S1005   Ttest_indResult(statistic=-0.2775436626978782, pvalue=0.7819473288725783)
# IRS1-S1078   Ttest_indResult(statistic=1.0402525072811324, pvalue=0.30515890768146076)
# IRS1-S1100   Ttest_indResult(statistic=-1.8406518465404431, pvalue=0.0691212778717038)
# IRS1-S1101   Ttest_indResult(statistic=-1.8574747087121355, pvalue=0.06666618446177655)
# IRS1-S1131   Ttest_indResult(statistic=-0.3035930834793605, pvalue=0.7736649329685882)
# IRS1-S1132   Ttest_indResult(statistic=-1.7990835357405455, pvalue=0.09718424316781692)
# IRS1-S1133   Ttest_indResult(statistic=-1.4880127005860135, pvalue=0.14545548822799928)
# IRS1-S1134   Ttest_indResult(statistic=-2.3996985992555153, pvalue=0.01842380971388048)
# IRS1-S1135   Ttest_indResult(statistic=0.012921691776873948, pvalue=0.990309068267633)
# IRS1-S1143   Ttest_indResult(statistic=-0.5740007444587654, pvalue=0.5775155820495779)
# IRS1-S1145   Ttest_indResult(statistic=-0.5740007444587654, pvalue=0.5775155820495779)
# IRS1-S1222   Ttest_indResult(statistic=0.27708632367711467, pvalue=0.7860708090863354)
# IRS1-S1223   Ttest_indResult(statistic=1.0519629723367365, pvalue=0.3004589805764253)
# IRS1-S1227   Ttest_indResult(statistic=0.5336125684412181, pvalue=0.6218827782919412)
# IRS1-S270   Ttest_indResult(statistic=-0.8086557581487221, pvalue=0.420671984317987)
# IRS1-S274   Ttest_indResult(statistic=0.045158499000747226, pvalue=0.9647903506830796)
# IRS1-S303   Ttest_indResult(statistic=0.35176343535027915, pvalue=0.7283626107695754)
# IRS1-S307   Ttest_indResult(statistic=-0.24432627942131607, pvalue=0.8082270891230412)
# IRS1-S312   Ttest_indResult(statistic=1.165158849441641, pvalue=0.2499613521778002)
# IRS1-S315   Ttest_indResult(statistic=1.1334176095364163, pvalue=0.26545942828444247)
# IRS1-S323   Ttest_indResult(statistic=0.29200909480522297, pvalue=0.7709829313984945)
# IRS1-S330   Ttest_indResult(statistic=-0.8725387370485483, pvalue=0.3858151143468347)
# IRS1-S337   Ttest_indResult(statistic=0.16476138179324967, pvalue=0.8695184547496504)
# IRS1-S341   Ttest_indResult(statistic=-1.0126819291104923, pvalue=0.3181620291882854)
# IRS1-S345   Ttest_indResult(statistic=-0.44452537074707266, pvalue=0.65866071053438)
# IRS1-S348   Ttest_indResult(statistic=0.3275654367030456, pvalue=0.7442770458464575)
# IRS1-S374   Ttest_indResult(statistic=-0.3556289741282965, pvalue=0.7229238175206301)
# IRS1-S413   Ttest_indResult(statistic=-0.14756061892699507, pvalue=0.8832291579052458)
# IRS1-S415   Ttest_indResult(statistic=-1.2786696162992934, pvalue=0.2056308048713013)
# IRS1-S417   Ttest_indResult(statistic=-1.5987450368685647, pvalue=0.17077108977882471)
# IRS1-S419   Ttest_indResult(statistic=-0.6190975469252853, pvalue=0.5373989305330185)
# IRS1-S421   Ttest_indResult(statistic=-0.4755427651107657, pvalue=0.635552348374693)
# IRS1-S427   Ttest_indResult(statistic=-1.8814796001719083, pvalue=0.13305353413566445)
# IRS1-S428   Ttest_indResult(statistic=0.8523901788900151, pvalue=0.4161034757822041)
# IRS1-S434   Ttest_indResult(statistic=-0.18178606497689964, pvalue=0.8628905788747062)
# IRS1-S444   Ttest_indResult(statistic=-1.2428260495286978, pvalue=0.24228365877102787)
# IRS1-S449   Ttest_indResult(statistic=-0.9472327314560357, pvalue=0.36220544957079404)
# IRS1-S463   Ttest_indResult(statistic=0.5591675807433869, pvalue=0.578948234792874)
# IRS1-S503   Ttest_indResult(statistic=-0.6474600544954874, pvalue=0.5271200071957496)
# IRS1-S513   Ttest_indResult(statistic=nan, pvalue=nan)
# IRS1-S527   Ttest_indResult(statistic=-0.5127915343540426, pvalue=0.6092510914703817)
# IRS1-S531   Ttest_indResult(statistic=-0.8457727418054939, pvalue=0.39985040578777253)
# IRS1-S541   Ttest_indResult(statistic=-1.3000719125660203, pvalue=0.20417702279481476)
# IRS1-S543   Ttest_indResult(statistic=-1.3717170634551024, pvalue=0.18104384213256416)
# IRS1-S544   Ttest_indResult(statistic=-1.6758820079809431, pvalue=0.1690698816406835)
# IRS1-S547   Ttest_indResult(statistic=-2.096996225305059, pvalue=0.04514891863962221)
# IRS1-S574   Ttest_indResult(statistic=-0.20499321130565196, pvalue=0.8475863890636213)
# IRS1-S581   Ttest_indResult(statistic=-1.2978489761895817, pvalue=0.20422982070100695)
# IRS1-S629   Ttest_indResult(statistic=-1.315183587614717, pvalue=0.19171679282852586)
# IRS1-S636   Ttest_indResult(statistic=-0.961933596811487, pvalue=0.3393024773727117)
# IRS1-S641   Ttest_indResult(statistic=1.0003219644330115, pvalue=0.3737627611544142)
# IRS1-S668   Ttest_indResult(statistic=1.6045303108155806, pvalue=0.1396785121922768)
# IRS1-S672   Ttest_indResult(statistic=-1.1250673451506708, pvalue=0.26504105741642825)
# IRS1-S736   Ttest_indResult(statistic=0.20139793227850997, pvalue=0.8418434032609028)
# IRS1-S741   Ttest_indResult(statistic=1.145717714208296, pvalue=0.30377056594769186)
# IRS1-S744   Ttest_indResult(statistic=0.20097620029725263, pvalue=0.8505229385067927)
# IRS1-S745   Ttest_indResult(statistic=-0.3682119559849281, pvalue=0.7191285563778577)
# IRS1-S766   Ttest_indResult(statistic=-2.0976544875297147, pvalue=0.04418414702707116)
# IRS1-S925   Ttest_indResult(statistic=0.30787259897893204, pvalue=0.7639304153960518)
# IRS1-T1103   Ttest_indResult(statistic=-0.45497835572243894, pvalue=0.6800318468091282)
# IRS1-T305   Ttest_indResult(statistic=-0.08810798353366002, pvalue=0.9300256881321458)
# IRS1-T309   Ttest_indResult(statistic=-1.1511480041275088, pvalue=0.2587638652461182)
# IRS1-T311   Ttest_indResult(statistic=-1.8124620528237845, pvalue=0.10333090470050209)
# IRS1-T335   Ttest_indResult(statistic=1.9029968534247923, pvalue=0.0731600515198282)
# IRS1-T446   Ttest_indResult(statistic=-0.40364174871755965, pvalue=0.687781001180678)
# IRS1-T453   Ttest_indResult(statistic=-1.2140987333107947, pvalue=0.23220172339549075)
# IRS1-T525   Ttest_indResult(statistic=-0.9441929407524177, pvalue=0.3697265236975724)
# IRS1-T530   Ttest_indResult(statistic=-0.9539878468247353, pvalue=0.34663248223420295)
# IRS1-T533   Ttest_indResult(statistic=-1.0189433995770627, pvalue=0.31502900004882145)
# IRS1-T552   Ttest_indResult(statistic=-0.22841005754229235, pvalue=0.823930478490196)
# IRS1-T579   Ttest_indResult(statistic=nan, pvalue=nan)
# IRS1-T859   Ttest_indResult(statistic=-0.3519946576109979, pvalue=0.7291678244338053)
# IRS1-Y465   Ttest_indResult(statistic=-0.25891063641239015, pvalue=0.8015285844940992)
# IRS1-Y551   Ttest_indResult(statistic=0.7417753238011754, pvalue=0.4752841827670762)
# IRS1-Y582   Ttest_indResult(statistic=0.33316330791728394, pvalue=0.7503449376061446)
# IRS1-Y632   Ttest_indResult(statistic=1.5527086202313034, pvalue=0.1515415776970943)
# IRS1-Y662   Ttest_indResult(statistic=1.1536335298505915, pvalue=0.2587607270781149)
# IRS1-Y750   Ttest_indResult(statistic=-1.7394144157619773, pvalue=0.1569454238810905)
# []
# []
# {}

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
sites = phos.columns
p_values = []
site_names = []
phosProtList = ['IRS1']

alpha = 0.05
p_value = alpha/len(phosProtList)


for protein in phosProtList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
        phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis = 1)
        for site in phosphositesdf.columns:
            if (site is not 'Mutation'):
                sitedf = CPTAC.compare_mutations(phos, site, gene)
                mutateddf = sitedf.loc[sitedf['Mutation'] != 'Wildtype'].dropna(axis=0)
                wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
                ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
                p_values.append(ttest[1])
                site_names.append(site)     
                
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1]         
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]

significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# ['IRS1-S1005' 'IRS1-S1100' 'IRS1-S1101' 'IRS1-S1133' 'IRS1-S1134'
#  'IRS1-S270' 'IRS1-S307' 'IRS1-S323' 'IRS1-S330' 'IRS1-S337' 'IRS1-S341'
#  'IRS1-S374' 'IRS1-S415' 'IRS1-S527' 'IRS1-S531' 'IRS1-S629' 'IRS1-S636'
#  'IRS1-S672' 'IRS1-S766' 'IRS1-T305' 'IRS1-T309' 'IRS1-T530']
# [0.0094718  0.00020188 0.000523   0.01426172 0.0011596  0.00118185
#  0.0481304  0.01005825 0.0094718  0.02559819 0.0481304  0.00118185
#  0.00290455 0.01092095 0.00195889 0.00091668 0.00248824 0.0094718
#  0.00248824 0.00248824 0.0094718  0.02461594]
# {'IRS1-S1005': 0.0094717950390731, 'IRS1-S1100': 0.0002018777834901376, 'IRS1-S1101': 0.0005229979400382523, 'IRS1-S1133': 0.014261718949464484, 'IRS1-S1134': 0.0011595956105361492, 'IRS1-S270': 0.0011818527960791446, 'IRS1-S307': 0.04813039926788787, 'IRS1-S323': 0.010058250340791101, 'IRS1-S330': 0.0094717950390731, 'IRS1-S337': 0.02559819374662789, 'IRS1-S341': 0.04813039926788787, 'IRS1-S374': 0.0011818527960791446, 'IRS1-S415': 0.002904550128402398, 'IRS1-S527': 0.010920950683584235, 'IRS1-S531': 0.0019588868186355066, 'IRS1-S629': 0.000916683570795187, 'IRS1-S636': 0.0024882379379975645, 'IRS1-S672': 0.0094717950390731, 'IRS1-S766': 0.0024882379379975645, 'IRS1-T305': 0.0024882379379975645, 'IRS1-T309': 0.0094717950390731, 'IRS1-T530': 0.024615944039254573}

# %% [markdown]
# ## All mutations vs wildtype

# %%
sites = phos.columns
p_values = []
site_names = []
phosProtList = ['IRS1']

alpha = 0.05
p_value = alpha/len(phosProtList)


for protein in phosProtList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
        phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis = 1)
        for site in phosphositesdf.columns:
            if (site is not 'Mutation'):
                sitedf = CPTAC.compare_mutations(phos, site, gene)
                mutateddf = sitedf.loc[sitedf['Mutation'] != 'Wildtype'].dropna(axis=0)
                wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
                ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
                p_values.append(ttest[1])
                site_names.append(site)     
                
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1]         
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]

significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# ['IRS1-S1005' 'IRS1-S1100' 'IRS1-S1101' 'IRS1-S1133' 'IRS1-S1134'
#  'IRS1-S270' 'IRS1-S307' 'IRS1-S323' 'IRS1-S330' 'IRS1-S337' 'IRS1-S341'
#  'IRS1-S374' 'IRS1-S415' 'IRS1-S527' 'IRS1-S531' 'IRS1-S629' 'IRS1-S636'
#  'IRS1-S672' 'IRS1-S766' 'IRS1-T305' 'IRS1-T309' 'IRS1-T530']
# [0.0094718  0.00020188 0.000523   0.01426172 0.0011596  0.00118185
#  0.0481304  0.01005825 0.0094718  0.02559819 0.0481304  0.00118185
#  0.00290455 0.01092095 0.00195889 0.00091668 0.00248824 0.0094718
#  0.00248824 0.00248824 0.0094718  0.02461594]
# {'IRS1-S1005': 0.0094717950390731, 'IRS1-S1100': 0.0002018777834901376, 'IRS1-S1101': 0.0005229979400382523, 'IRS1-S1133': 0.014261718949464484, 'IRS1-S1134': 0.0011595956105361492, 'IRS1-S270': 0.0011818527960791446, 'IRS1-S307': 0.04813039926788787, 'IRS1-S323': 0.010058250340791101, 'IRS1-S330': 0.0094717950390731, 'IRS1-S337': 0.02559819374662789, 'IRS1-S341': 0.04813039926788787, 'IRS1-S374': 0.0011818527960791446, 'IRS1-S415': 0.002904550128402398, 'IRS1-S527': 0.010920950683584235, 'IRS1-S531': 0.0019588868186355066, 'IRS1-S629': 0.000916683570795187, 'IRS1-S636': 0.0024882379379975645, 'IRS1-S672': 0.0094717950390731, 'IRS1-S766': 0.0024882379379975645, 'IRS1-T305': 0.0024882379379975645, 'IRS1-T309': 0.0094717950390731, 'IRS1-T530': 0.024615944039254573}

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
p_values = []
site_names = []


for site in phos_sites:   
    if (site is not 'Mutation'):
        sitedf = CPTAC.compare_mutations(phos, site, gene)
        sitedf = sitedf.loc[sitedf['Patient_Type'] == 'Tumor']
        sitedf['Within_Hotspot'] = False
        sitedf.loc[hotspot_patients, 'Within_Hotspot'] = True
        sitedf.loc[sitedf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        mutateddf = sitedf.loc[sitedf['Within_Hotspot'] == True].dropna(axis=0)
        wtdf = sitedf.loc[sitedf['Within_Hotspot'] == 'Wildtype'].dropna(axis=0)
        ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
        p_values.append(ttest[1])
        site_names.append(site)
    
    
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1]         
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]

significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# []
# []
# {}
