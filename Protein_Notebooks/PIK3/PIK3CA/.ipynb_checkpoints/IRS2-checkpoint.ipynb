# %% [markdown]
# # PIK3CA: Effects of Mutation on IRS2

# %% [markdown]
# <b> Standard imports for playing with and plotting data frames. </b>

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <b> Import CPTAC data

# %%
import CPTAC
# Out:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter CPTAC.embargo() to open the webpage for more details.

# %%
somatic_mutations = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %% [markdown]
# # PI3KCA mutation and IRS2 proteome abundance

# %% [markdown]
# ### Perform a t-test with mutated and non-mutated protein levels

# %%
protList = ['IRS2']
pcutoff = 0.05 / len(protList)
gene = 'PIK3CA'

sigResults = [];
for protein in protList: 
    if protein in proteomics.columns:
        cross = CPTAC.merge_mutations(proteomics, protein, gene)
        cross = cross[["Mutation", protein]].dropna(axis=0)
        mutated = cross.loc[cross["Mutation"] != "Wildtype"]
        wt = cross.loc[cross["Mutation"] == "Wildtype"]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(ttest[1] <= pcutoff):
            sigResults.append(protein)
            print("Test for " + protein + ": ")
            print(ttest)
# Out:
# Test for IRS2:
# Ttest_indResult(statistic=-4.305242968682799, pvalue=3.4083077260524325e-05)

# %% [markdown]
#  ### We can now plot the data

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
somatic_boxplot = sns.boxplot(data=cross, x="Mutation",y='IRS2', ax = ax)
somatic_boxplot.set_title("PI3KCA gene mutation IRS2 protein abundance")
somatic_boxplot = sns.stripplot(data=cross, x="Mutation", y='IRS2',jitter=True, color=".3")
somatic_boxplot.set(xlabel="Somatic Gene Mutation",ylabel="Proteomics")
plt.show()

# %% [markdown]
# # PI3KCA mutation and IRS2 phosphoproteome abundance

# %%
phosProtList = ['IRS2']
sigResults = [];
pcutoff = 0.05/len(phosProtList)
print(pcutoff)


for protein in phosProtList: 
        cross = CPTAC.compare_mutations(phos, protein, gene)
        #print(cross.head())
        for loc in cross.columns:
            #print(loc)
            cross_site = cross[["Mutation", loc]].dropna(axis=0)
            #print(cross_site)
            mutated = cross_site.loc[cross_site["Mutation"] != "Wildtype"]
            wt = cross_site.loc[cross_site["Mutation"] == "Wildtype"]
            ttest = scipy.stats.ttest_ind(mutated[loc], wt[loc])
            if(ttest[1] <= pcutoff):
                sigResults.append(loc)
                print("Test for " + loc + ": ")
                print(ttest)
# Out:
# 0.05
# Test for IRS2-S1100:
# Ttest_indResult(statistic=-3.4924541034463927, pvalue=0.0007282370276814705)
# Test for IRS2-S391:
# Ttest_indResult(statistic=-3.3748296702043685, pvalue=0.0011148685421022008)
# Test for IRS2-S560:
# Ttest_indResult(statistic=-4.301902692500229, pvalue=4.918085161875682e-05)
# Test for IRS2-S577:
# Ttest_indResult(statistic=-2.5640214349846544, pvalue=0.01210479696361852)
# Test for IRS2-S736:
# Ttest_indResult(statistic=-2.2029858805704055, pvalue=0.030039697035754664)
# Test for IRS2-S915:
# Ttest_indResult(statistic=-2.639635773581673, pvalue=0.010042276535485423)
# Test for IRS2-S973:
# Ttest_indResult(statistic=-2.8362339822011617, pvalue=0.005506356209668165)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-9e6209365295> in <module>
#      13     cross_site = cross[["Mutation", loc]].dropna(axis=0)
#      14     #print(cross_site)
# ---> 15     mutated = cross_site.loc[cross_site["Mutation"] != "Wildtype"]
#      16     wt = cross_site.loc[cross_site["Mutation"] == "Wildtype"]
#      17     ttest = scipy.stats.ttest_ind(mutated[loc], wt[loc])
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1897
#    1898                 if hasattr(key, 'ndim') and key.ndim > 1:
# -> 1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
#    1901                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %% [markdown]
# ## Graph the data
