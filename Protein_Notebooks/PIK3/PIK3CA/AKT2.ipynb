# %% [markdown]
# # PIK3CA: Effects of Mutation on AKT2

# %% [markdown]
# <b> Standard imports for playing with and plotting data frames. </b>

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# <b> Import CPTAC data

# %%
import CPTAC

# %%
somatic_mutations = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %% [markdown]
# # PI3KCA mutation and AKT2 proteome abundance

# %% [markdown]
# ### Perform a t-test with mutated and non-mutated protein levels

# %%
protList = ['AKT2']
pcutoff = 0.05 / len(protList)
gene = 'PIK3CA'

sigResults = [];
for protein in protList: 
    if protein in proteomics.columns:
        cross = CPTAC.merge_mutations(proteomics, protein, gene)
        cross = cross[["Mutation", protein]].dropna(axis=0)
        mutated = cross.loc[cross["Mutation"] == "Missense_Mutation"]
        wt = cross.loc[cross["Mutation"] == "Wildtype"]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(ttest[1] <= pcutoff):
            sigResults.append(protein)
            print("Test for " + protein + ": ")
            print(ttest)
# Out:
# Test for AKT2:
# Ttest_indResult(statistic=-4.475870221783481, pvalue=1.602813329063142e-05)

# %% [markdown]
#  ### We can now plot the data

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
somatic_boxplot = sns.boxplot(data=cross, x="Mutation",y='AKT2', ax = ax)
somatic_boxplot.set_title("PI3KCA gene mutation AKT2 protein abundance")
somatic_boxplot = sns.stripplot(data=cross, x="Mutation", y='AKT2',jitter=True, color=".3")
somatic_boxplot.set(xlabel="Somatic Gene Mutation",ylabel="Proteomics")
plt.show()

# %% [markdown]
# # PI3KCA mutation and AKT2 phosphoproteome abundance

# %%
sites = phos.columns;
significantPhosResults = [];
totalSites = 0

for protein in phosProtList:
    matchesdf = phos.filter(regex=protein)
    totalSites += len(matchesdf.columns)

pcutoff = 0.05 / totalSites
pcutoff = 1
    

for protein in phosProtList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.merge_mutations(phos, protein, gene)
        for site in phosphositesdf.columns:
            if (site is not 'Mutation'):
                sitedf = CPTAC.merge_mutations(phos, site, gene)
                mutateddf = sitedf.loc[sitedf['Mutation'] == 'Missense_Mutation'].dropna(axis=0)
                wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
                ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
                if(ttest[1] <= pcutoff):
                    #significantResults.append(site)
                    print("Test for " + site + ": ")
                    print(ttest)
# Out:
# Test for AKT2-T451:
# Ttest_indResult(statistic=-0.5305719191973527, pvalue=0.5967385480615139)

# %% [markdown]
# ## PIK3CA mutation and AKT2 protein abundance (no control)

# %% [markdown]
# <b> Take out the conrol </b>

# %%
proteomics = proteomics[:100]

# %% [markdown]
# ### Perform a t-test with mutated and non-mutated protein levels

# %%
protList = ['AKT2']
pcutoff = 0.05 / len(protList)
gene = 'PIK3CA'


sigResults = [];
for protein in protList: 
    if protein in proteomics.columns:
        cross = CPTAC.merge_mutations(proteomics, protein, gene)
        cross = cross[["Mutation", protein]].dropna(axis=0)
        mutated = cross.loc[cross["Mutation"] == "Missense_Mutation"]
        wt = cross.loc[cross["Mutation"] == "Wildtype"]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(ttest[1] <= pcutoff):
            sigResults.append(protein)
            print("Test for " + protein + ": ")
            print(ttest) 
        else:
            print("Unsignificant result for " + protein + ":")
            print(ttest)
# Out:
# Unsignificant results for AKT2:
# Ttest_indResult(statistic=-1.78488195820731, pvalue=0.07747228952217859)

# %% [markdown]
# # PI3KCA mutation and AKT2 phosphoproteome abundance (no control)

# %%
sites = phos.columns;
significantPhosResults = [];
totalSites = 0

for protein in phosProtList:
    matchesdf = phos.filter(regex=protein)
    totalSites += len(matchesdf.columns)

pcutoff = 0.05 / totalSites
pcutoff = 1
    

for protein in phosProtList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.merge_mutations(phos, protein, gene)
        for site in phosphositesdf.columns:
            if (site is not 'Mutation'):
                sitedf = CPTAC.merge_mutations(phos, site, gene)
                mutateddf = sitedf.loc[sitedf['Mutation'] == 'Missense_Mutation'].dropna(axis=0)
                wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
                ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
                if(ttest[1] <= pcutoff):
                    #significantResults.append(site)
                    print("Test for " + site + ": ")
                    print(ttest)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-b3fe27c7ff46> in <module>
#      16     isInList = filter(pattern.search, sites)
#      17     if next(isInList, None) is not None:
# ---> 18         phosphositesdf = CPTAC.merge_mutations(phos, protein, gene)
#      19         for site in phosphositesdf.columns:
#      20             if (site is not 'Mutation'):
#
# ~/Documents/GitHub/CPTAC/CPTAC/__init__.py in merge_mutations(data, gene, somatic_gene)
#     341     if somatic_gene:
#     342         data_gene = gene
# --> 343         return Utilities().merge_mutations_trans(data, data_gene, somatic_maf, somatic_gene)
#     344     else:
#     345         return Utilities().merge_mutations(data, somatic_maf, gene)
#
# ~/Documents/GitHub/CPTAC/CPTAC/utilities.py in merge_mutations_trans(self, omics, omicsGene, somatic, somaticGene, duplicates)
#     158             else:
#     159                 return self.merge_somatic(somatic, somaticGene, omics_gene_df)[[omicsGene, "Mutation"]]
# --> 160         elif omics.name == "phosphoproteomics":
#     161             phosphosites = self.get_phosphosites(omics, omicsGene)
#     162             if len(phosphosites.columns) > 0:
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'name'
