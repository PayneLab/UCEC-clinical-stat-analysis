# %% [markdown]
# # PIK3CA trans effects on known interacting proteins

# %% [markdown]
# We first investigated the effects of PIK3CA mutation on the proteomics and phosphoproteomic of known interacting proteins. This list primarily included proteins in the PI3K/AKT/MTOR signaling cascade that plays a key role in cell survival and cell proliferation.

# %% [markdown]
# ## Standard Imports

# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
import seaborn as sns
import json

#import the Endometrial data from CPTAC package
import CPTAC.Endometrial as CPTAC

# %% [markdown]
# ### Set up initial dataframes and variables

# %%
gene = 'PIK3CA'
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.E545A', 'p.E545K', 'p.E545V', 'p.Q546P', 'p.Q546R', 'p.E542K']


mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

hotspot_patients_both_keys = mutated_hotspot[['Clinical_Patient_Key', 'Patient_Id']]
hotspot_patients = hotspot_patients_both_keys['Clinical_Patient_Key']
print(hotspot_patients)

#The pvalue cutoff used to find significance
pcutoff = 0.05
# Out:
# 160      S001
# 1147     S003
# 1426     S009
# 4757     S021
# 16613    S023
# 19188    S024
# 21386    S032
# 21643    S033
# 22656    S038
# 37618    S061
# 38352    S063
# 39719    S066
# 43588    S067
# 43687    S068
# 46859    S084
# 47557    S088
# 48398    S090
# 49903    S097
# 50016    S098
# Name: Clinical_Patient_Key, dtype: object

# %% [markdown]
# ## Find number of patients with PIK3CA mutations in/outside of the hotspot

# %%
print("Mutations inside hotspot: " + str(len(hotspot_patients)))
p110_mutated = somatic.loc[somatic['Gene'] == 'PIK3CA']
#note: the gene PIK3CA encodes for the protein p110α, hence the variable 'p110_mutated'

# This naturally includes a value that is 'NA' so we subtract 1
# Some people have more than one mutation so we need to grab the unique values
num_mutated = len(set(p110_mutated['Clinical_Patient_Key'])) - 1
print("Total number of patients with mutations: " + str(num_mutated))
# Out:
# Mutations inside hotspot: 19
# Total number of patients with mutations: 48

# %% [markdown]
# # Proteomic Abundance

# %% [markdown]
# ### List of proteins that interact with PIK3CA (according to Uniprot and STRING)

# %%
#Build the protein list; this may have only a single protein if desired
protList = ['IRS1', 'IRS2', 'RRAS', 'AKT2', 'NRAS', 'PTEN', 'AKT1', 'MRAS', 'HRAS', 'RPS6KB1', 'PIK3R1', 'PKC', 'MTOR', 'S6K', 'MAPK', 'ERBB3', 'P85A', 'P55G', 'CDK5']

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
print("Mutations inside hotspot: " + str(len(hotspot_patients)))
p110_mutated = somatic.loc[somatic['Gene'] == 'PIK3CA']

# 1. Use the Bonferonni correction to adjust the p-value by dividing alpha (0.05) by the number of tests. 
#   Because we are analyzing 19 proteins, we will have 19 tests. 
pcutoff = 0.05/len(protList)

# 2. Create a dictionary for significant proteins with their prespective pvalues
#    Create another dictionary for unsignificant results

sigResults = {}
unsigResults = {}

# 3. Loop through each protein to test for significant protein level
for protein in protList: 
    
    #Check to make sure that the protein is in the proteomics dataframe that we are reading from
    if protein in proteomics.columns:
        # 4. Set up a new column for mutations that are within the hotspot
        p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
        p10_mutations['Within_Hotspot'] = False
        p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
        p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)
        
        in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
        out_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == False]
        
        
        # 5. Perform a two-sample ttest for mutations in hotspot vs mutations outside of the hotspot
        ttest = scipy.stats.ttest_ind(in_hotspot[protein], out_hotspot[protein])
        
        if ttest[1] < pcutoff:
            sigResults[protein] = ttest[1]
        else:
            unsigResults[protein] = ttest[1]

# 5. Print the results
print('SIGNIFICANT RESULTS:')
# Json is a nice package that allows you to print items in the dictionary line by line
print(json.dumps(sigResults, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigResults, indent = 2))
# Out:
# Mutations inside hotspot: 19
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1": 0.8570734994915308,
#   "IRS2": 0.09674094347736001,
#   "RRAS": 0.025709117294969015,
#   "AKT2": 0.24486222824644044,
#   "NRAS": 0.579841867910798,
#   "PTEN": 0.0676976304099718,
#   "AKT1": 0.39764976429801524,
#   "MRAS": 0.17544373477828829,
#   "HRAS": 0.3114823476147295,
#   "RPS6KB1": 0.44079322936855947,
#   "PIK3R1": 0.9013685831466293,
#   "MTOR": 0.11458881422507551,
#   "ERBB3": 0.4097077317602019,
#   "CDK5": 0.6123211223904736
# }

# %% [markdown]
# ## Hotspot mutation vs other mutations and cancer wildtype

# %%
print("Mutations inside hotspot: " + str(len(hotspot_patients)))
p110_mutated = somatic.loc[somatic['Gene'] == 'PIK3CA']

# 1. Use the Bonferonni correction to adjust the p-value by dividing alpha (0.05) by the number of tests. 
#   Because we are analyzing 19 proteins, we will have 19 tests. 
pcutoff = 0.05/len(protList)

# 2. Create a dictionary for significant proteins with their prespective pvalues
#    Create another dictionary for unsignificant results

sigResults = {}
unsigResults = {}

# 3. Loop through each protein to test for significant protein level
for protein in protList: 
    
    #Check to make sure that the protein is in the proteomics dataframe that we are reading from
    if protein in proteomics.columns:
        # 4. Set up a new column for mutations that are within the hotspot
        p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
        p10_mutations['Within_Hotspot'] = False
        p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
        p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)

        in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
        wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] != True]
        
        # 5. Perform a two-sample ttest for mutations in hotspot vs mutations outside of the hotspot
        ttest = scipy.stats.ttest_ind(in_hotspot[protein], wt[protein])
        
        if ttest[1] < pcutoff:
            sigResults[protein] = ttest[1]
        else:
            unsigResults[protein] = ttest[1]

# 5. Print the results
print('SIGNIFICANT RESULTS:')
# Json is a nice package that allows you to print items in the dictionary line by line
print(json.dumps(sigResults, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigResults, indent = 2))
# Out:
# Mutations inside hotspot: 19
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1-S1005": 0.1538874422084835,
#   "IRS1-S270": 0.273498035871859,
#   "IRS1-S527": 0.6576950639533548,
#   "IRS2-S1100": 0.7932403796403827,
#   "IRS2-S365": 0.2190537914574149,
#   "RRAS2-S186": 0.06560223604200595,
#   "PTEN-S467": 0.5573473385330219,
#   "AKT1-S126": 0.7527767230674126,
#   "AKT1-S129": 0.6225282061459592,
#   "AKT1S1-S222": 0.40990754364672066,
#   "AKT1S1-S223": 0.5472780915404707,
#   "AKT1S1-S232": 0.890724203697261,
#   "LAMTOR1-S27": 0.8062980865678622,
#   "RPS6KA1-S372": 0.10432653425215277,
#   "RPS6KA3-S369": 0.44692002190398494,
#   "RPS6KA3-S415": 0.4922566425312921,
#   "RPS6KA3-T365": 0.5308755964582641,
#   "RPS6KA4-S343": 0.50715754989591,
#   "RPS6KA4-S347": 0.4913203854756516,
#   "RPS6KA4-S682": 0.12699833922172207,
#   "RPS6KA4-S745": 0.5186282931858306,
#   "RPS6KC1-S423": 0.004588149271431776,
#   "RPS6KC1-S667": 0.5232936781331718,
#   "MAPK1-Y187": 0.8677251063910387,
#   "MAPK14-Y182": 0.9778508055313739,
#   "MAPK3-Y204": 0.7530383051291035,
#   "MAPKAP1-S510": 0.745676335806206,
#   "MAPKAPK5-S212": 0.8845516379019593
# }

# %% [markdown]
# ## Hotspot mutations vs cancer wildtype

# %%
print("Mutations inside hotspot: " + str(len(hotspot_patients)))
p110_mutated = somatic.loc[somatic['Gene'] == 'PIK3CA']

# 1. Use the Bonferonni correction to adjust the p-value by dividing alpha (0.05) by the number of tests. 
#   Because we are analyzing 19 proteins, we will have 19 tests. 
pcutoff = 0.05/len(protList)

# 2. Create a dictionary for significant proteins with their prespective pvalues
#    Create another dictionary for unsignificant results

sigResults = {}
unsigResults = {}

# 3. Loop through each protein to test for significant protein level
for protein in protList: 
    
    #Check to make sure that the protein is in the proteomics dataframe that we are reading from
    if protein in proteomics.columns:
        # 4. Set up a new column for mutations that are within the hotspot
        p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
        p10_mutations['Within_Hotspot'] = False
        p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
        p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)

        in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
        wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
        
        # 5. Perform a two-sample ttest for mutations in hotspot vs mutations outside of the hotspot
        ttest = scipy.stats.ttest_ind(in_hotspot[protein], wt[protein])
        
        if ttest[1] < pcutoff:
            sigResults[protein] = ttest[1]
        else:
            unsigResults[protein] = ttest[1]

# 5. Print the results
print('SIGNIFICANT RESULTS:')
# Json is a nice package that allows you to print items in the dictionary line by line
print(json.dumps(sigResults, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigResults, indent = 2))
# Out:
# Mutations inside hotspot: 19
#          IRS1  Mutation Patient_Type Within_Hotspot
# S002 -0.79300  Wildtype        Tumor       Wildtype
# S004 -0.18000  Wildtype        Tumor       Wildtype
# S005 -0.51900  Wildtype        Tumor       Wildtype
# S006 -1.46000  Wildtype        Tumor       Wildtype
# S007  1.24000  Wildtype        Tumor       Wildtype
# S008 -0.03510  Wildtype        Tumor       Wildtype
# S011  0.18600  Wildtype        Tumor       Wildtype
# S013 -0.83500  Wildtype        Tumor       Wildtype
# S015  0.15000  Wildtype        Tumor       Wildtype
# S016 -1.01000  Wildtype        Tumor       Wildtype
# S017 -1.49000  Wildtype        Tumor       Wildtype
# S019  1.65000  Wildtype        Tumor       Wildtype
# S020  0.16900  Wildtype        Tumor       Wildtype
# S025  0.51300  Wildtype        Tumor       Wildtype
# S029 -0.08520  Wildtype        Tumor       Wildtype
# S034  0.61500  Wildtype        Tumor       Wildtype
# S035  0.45400  Wildtype        Tumor       Wildtype
# S037  0.13300  Wildtype        Tumor       Wildtype
# S039  0.23300  Wildtype        Tumor       Wildtype
# S041 -0.41300  Wildtype        Tumor       Wildtype
# S042  0.00639  Wildtype        Tumor       Wildtype
# S044 -0.01740  Wildtype        Tumor       Wildtype
# S045  0.05430  Wildtype        Tumor       Wildtype
# S046  0.37800  Wildtype        Tumor       Wildtype
# S047  0.67800  Wildtype        Tumor       Wildtype
# S048  0.40600  Wildtype        Tumor       Wildtype
# S049 -0.59100  Wildtype        Tumor       Wildtype
# S050  0.04810  Wildtype        Tumor       Wildtype
# S051 -0.26300  Wildtype        Tumor       Wildtype
# S052 -0.20500  Wildtype        Tumor       Wildtype
# S054 -0.64900  Wildtype        Tumor       Wildtype
# S056  0.18600  Wildtype        Tumor       Wildtype
# S057 -0.99700  Wildtype        Tumor       Wildtype
# S058 -0.31600  Wildtype        Tumor       Wildtype
# S059 -0.84300  Wildtype        Tumor       Wildtype
# S062 -0.43800  Wildtype        Tumor       Wildtype
# S069 -0.59600  Wildtype        Tumor       Wildtype
# S071 -0.85600  Wildtype        Tumor       Wildtype
# S072 -0.00749  Wildtype        Tumor       Wildtype
# S073 -0.86100  Wildtype        Tumor       Wildtype
# S076 -0.08840  Wildtype        Tumor       Wildtype
# S078 -0.67900  Wildtype        Tumor       Wildtype
# S079 -0.31100  Wildtype        Tumor       Wildtype
# S080 -0.33800  Wildtype        Tumor       Wildtype
# S082 -0.62800  Wildtype        Tumor       Wildtype
# S083 -0.50800  Wildtype        Tumor       Wildtype
# S085 -0.43200  Wildtype        Tumor       Wildtype
# S087 -0.55900  Wildtype        Tumor       Wildtype
# S091 -0.42000  Wildtype        Tumor       Wildtype
# S093  0.55900  Wildtype        Tumor       Wildtype
# S094 -1.10000  Wildtype        Tumor       Wildtype
# S100 -0.37300  Wildtype        Tumor       Wildtype
#         IRS2  Mutation Patient_Type Within_Hotspot
# S002 -1.0100  Wildtype        Tumor       Wildtype
# S004  0.8070  Wildtype        Tumor       Wildtype
# S005 -2.0500  Wildtype        Tumor       Wildtype
# S006 -0.4890  Wildtype        Tumor       Wildtype
# S007 -0.5560  Wildtype        Tumor       Wildtype
# S008 -0.8110  Wildtype        Tumor       Wildtype
# S011 -0.4940  Wildtype        Tumor       Wildtype
# S013  0.7080  Wildtype        Tumor       Wildtype
# S015  0.6740  Wildtype        Tumor       Wildtype
# S016  1.1900  Wildtype        Tumor       Wildtype
# S017 -1.2200  Wildtype        Tumor       Wildtype
# S019  0.0655  Wildtype        Tumor       Wildtype
# S020 -0.4200  Wildtype        Tumor       Wildtype
# S025 -1.4400  Wildtype        Tumor       Wildtype
# S029 -0.9470  Wildtype        Tumor       Wildtype
# S034  0.0351  Wildtype        Tumor       Wildtype
# S035  0.8280  Wildtype        Tumor       Wildtype
# S037 -0.5800  Wildtype        Tumor       Wildtype
# S039 -0.4220  Wildtype        Tumor       Wildtype
# S041  0.3740  Wildtype        Tumor       Wildtype
# S042  0.1380  Wildtype        Tumor       Wildtype
# S044  0.5260  Wildtype        Tumor       Wildtype
# S045  0.2930  Wildtype        Tumor       Wildtype
# S046 -0.6870  Wildtype        Tumor       Wildtype
# S047  1.1800  Wildtype        Tumor       Wildtype
# S048  0.3620  Wildtype        Tumor       Wildtype
# S049 -1.2500  Wildtype        Tumor       Wildtype
# S050 -0.1320  Wildtype        Tumor       Wildtype
# S051 -0.2180  Wildtype        Tumor       Wildtype
# S052  0.6880  Wildtype        Tumor       Wildtype
# S054 -0.7490  Wildtype        Tumor       Wildtype
# S056  0.2380  Wildtype        Tumor       Wildtype
# S057 -0.6490  Wildtype        Tumor       Wildtype
# S058  0.7860  Wildtype        Tumor       Wildtype
# S059 -0.6630  Wildtype        Tumor       Wildtype
# S062 -0.2130  Wildtype        Tumor       Wildtype
# S069 -0.0716  Wildtype        Tumor       Wildtype
# S071 -0.7690  Wildtype        Tumor       Wildtype
# S072  1.3400  Wildtype        Tumor       Wildtype
# S073  0.7000  Wildtype        Tumor       Wildtype
# S076  1.3600  Wildtype        Tumor       Wildtype
# S078  0.0656  Wildtype        Tumor       Wildtype
# S079 -0.1020  Wildtype        Tumor       Wildtype
# S080 -1.3100  Wildtype        Tumor       Wildtype
# S082  1.2400  Wildtype        Tumor       Wildtype
# S083 -1.1100  Wildtype        Tumor       Wildtype
# S085 -0.8940  Wildtype        Tumor       Wildtype
# S087 -0.3390  Wildtype        Tumor       Wildtype
# S091 -0.5150  Wildtype        Tumor       Wildtype
# S093 -0.1880  Wildtype        Tumor       Wildtype
# S094 -1.5000  Wildtype        Tumor       Wildtype
# S100  0.1680  Wildtype        Tumor       Wildtype
#           RRAS  Mutation Patient_Type Within_Hotspot
# S002 -0.854000  Wildtype        Tumor       Wildtype
# S004 -0.754000  Wildtype        Tumor       Wildtype
# S005 -0.134000  Wildtype        Tumor       Wildtype
# S006  0.315000  Wildtype        Tumor       Wildtype
# S007 -1.070000  Wildtype        Tumor       Wildtype
# S008 -0.849000  Wildtype        Tumor       Wildtype
# S011 -0.724000  Wildtype        Tumor       Wildtype
# S013  0.006320  Wildtype        Tumor       Wildtype
# S015 -0.676000  Wildtype        Tumor       Wildtype
# S016 -0.810000  Wildtype        Tumor       Wildtype
# S017 -0.805000  Wildtype        Tumor       Wildtype
# S019 -0.736000  Wildtype        Tumor       Wildtype
# S020 -0.127000  Wildtype        Tumor       Wildtype
# S025 -0.917000  Wildtype        Tumor       Wildtype
# S029 -0.138000  Wildtype        Tumor       Wildtype
# S034  0.143000  Wildtype        Tumor       Wildtype
# S035  0.885000  Wildtype        Tumor       Wildtype
# S037 -0.344000  Wildtype        Tumor       Wildtype
# S039  0.028200  Wildtype        Tumor       Wildtype
# S041  0.359000  Wildtype        Tumor       Wildtype
# S042  0.266000  Wildtype        Tumor       Wildtype
# S044  0.998000  Wildtype        Tumor       Wildtype
# S045 -0.951000  Wildtype        Tumor       Wildtype
# S046  0.031300  Wildtype        Tumor       Wildtype
# S047  0.733000  Wildtype        Tumor       Wildtype
# S048  0.234000  Wildtype        Tumor       Wildtype
# S049 -0.352000  Wildtype        Tumor       Wildtype
# S050 -0.229000  Wildtype        Tumor       Wildtype
# S051 -0.148000  Wildtype        Tumor       Wildtype
# S052 -0.455000  Wildtype        Tumor       Wildtype
# S054 -0.096100  Wildtype        Tumor       Wildtype
# S056  0.085700  Wildtype        Tumor       Wildtype
# S057 -0.729000  Wildtype        Tumor       Wildtype
# S058 -0.001790  Wildtype        Tumor       Wildtype
# S059 -0.504000  Wildtype        Tumor       Wildtype
# S062 -0.820000  Wildtype        Tumor       Wildtype
# S069 -0.811000  Wildtype        Tumor       Wildtype
# S071 -0.928000  Wildtype        Tumor       Wildtype
# S072 -0.334000  Wildtype        Tumor       Wildtype
# S073 -1.610000  Wildtype        Tumor       Wildtype
# S076 -0.994000  Wildtype        Tumor       Wildtype
# S078 -0.448000  Wildtype        Tumor       Wildtype
# S079 -0.265000  Wildtype        Tumor       Wildtype
# S080  0.085700  Wildtype        Tumor       Wildtype
# S082  0.036600  Wildtype        Tumor       Wildtype
# S083 -1.230000  Wildtype        Tumor       Wildtype
# S085 -0.505000  Wildtype        Tumor       Wildtype
# S087 -0.020500  Wildtype        Tumor       Wildtype
# S091  0.179000  Wildtype        Tumor       Wildtype
# S093  0.425000  Wildtype        Tumor       Wildtype
# S094 -0.000309  Wildtype        Tumor       Wildtype
# S100 -0.255000  Wildtype        Tumor       Wildtype
#          AKT2  Mutation Patient_Type Within_Hotspot
# S002 -0.13400  Wildtype        Tumor       Wildtype
# S004 -0.02130  Wildtype        Tumor       Wildtype
# S005  0.04400  Wildtype        Tumor       Wildtype
# S006 -0.10500  Wildtype        Tumor       Wildtype
# S007 -0.63200  Wildtype        Tumor       Wildtype
# S008 -0.16100  Wildtype        Tumor       Wildtype
# S011 -0.07690  Wildtype        Tumor       Wildtype
# S013  0.22500  Wildtype        Tumor       Wildtype
# S015  1.14000  Wildtype        Tumor       Wildtype
# S016  0.20300  Wildtype        Tumor       Wildtype
# S017 -0.09270  Wildtype        Tumor       Wildtype
# S019 -0.63600  Wildtype        Tumor       Wildtype
# S020  0.15500  Wildtype        Tumor       Wildtype
# S025 -0.26200  Wildtype        Tumor       Wildtype
# S029  0.16700  Wildtype        Tumor       Wildtype
# S034  0.00183  Wildtype        Tumor       Wildtype
# S035  0.52300  Wildtype        Tumor       Wildtype
# S037  0.33200  Wildtype        Tumor       Wildtype
# S039 -0.03250  Wildtype        Tumor       Wildtype
# S041  0.17500  Wildtype        Tumor       Wildtype
# S042  1.10000  Wildtype        Tumor       Wildtype
# S044  0.26100  Wildtype        Tumor       Wildtype
# S045  0.15500  Wildtype        Tumor       Wildtype
# S046  0.62200  Wildtype        Tumor       Wildtype
# S047  0.59200  Wildtype        Tumor       Wildtype
# S048  0.29300  Wildtype        Tumor       Wildtype
# S049 -0.32300  Wildtype        Tumor       Wildtype
# S050  0.01480  Wildtype        Tumor       Wildtype
# S051 -0.02810  Wildtype        Tumor       Wildtype
# S052  0.03310  Wildtype        Tumor       Wildtype
# S054 -0.30300  Wildtype        Tumor       Wildtype
# S056 -0.03180  Wildtype        Tumor       Wildtype
# S057 -0.49600  Wildtype        Tumor       Wildtype
# S058  0.00901  Wildtype        Tumor       Wildtype
# S059 -0.44400  Wildtype        Tumor       Wildtype
# S062 -0.29000  Wildtype        Tumor       Wildtype
# S069 -0.30000  Wildtype        Tumor       Wildtype
# S071 -0.67300  Wildtype        Tumor       Wildtype
# S072  0.13400  Wildtype        Tumor       Wildtype
# S073 -0.33300  Wildtype        Tumor       Wildtype
# S076 -0.25900  Wildtype        Tumor       Wildtype
# S078 -0.01350  Wildtype        Tumor       Wildtype
# S079  0.15400  Wildtype        Tumor       Wildtype
# S080 -0.28100  Wildtype        Tumor       Wildtype
# S082 -0.07070  Wildtype        Tumor       Wildtype
# S083 -0.23300  Wildtype        Tumor       Wildtype
# S085 -0.16300  Wildtype        Tumor       Wildtype
# S087 -0.30100  Wildtype        Tumor       Wildtype
# S091 -0.07240  Wildtype        Tumor       Wildtype
# S093 -0.00561  Wildtype        Tumor       Wildtype
# S094 -0.05010  Wildtype        Tumor       Wildtype
# S100 -0.22200  Wildtype        Tumor       Wildtype
#         NRAS  Mutation Patient_Type Within_Hotspot
# S002  0.5260  Wildtype        Tumor       Wildtype
# S004  0.4680  Wildtype        Tumor       Wildtype
# S005  0.6750  Wildtype        Tumor       Wildtype
# S006  0.2280  Wildtype        Tumor       Wildtype
# S007  0.4230  Wildtype        Tumor       Wildtype
# S008  0.5070  Wildtype        Tumor       Wildtype
# S011 -0.1150  Wildtype        Tumor       Wildtype
# S013 -0.6370  Wildtype        Tumor       Wildtype
# S015  0.7380  Wildtype        Tumor       Wildtype
# S016  0.2540  Wildtype        Tumor       Wildtype
# S017  0.0693  Wildtype        Tumor       Wildtype
# S019  0.9190  Wildtype        Tumor       Wildtype
# S020 -0.0777  Wildtype        Tumor       Wildtype
# S025  0.5210  Wildtype        Tumor       Wildtype
# S029  0.0734  Wildtype        Tumor       Wildtype
# S034  0.0497  Wildtype        Tumor       Wildtype
# S035 -0.2930  Wildtype        Tumor       Wildtype
# S037 -0.2060  Wildtype        Tumor       Wildtype
# S039  0.0597  Wildtype        Tumor       Wildtype
# S041  0.0194  Wildtype        Tumor       Wildtype
# S042 -0.1450  Wildtype        Tumor       Wildtype
# S044 -0.3650  Wildtype        Tumor       Wildtype
# S045  1.5600  Wildtype        Tumor       Wildtype
# S046 -0.0227  Wildtype        Tumor       Wildtype
# S047 -1.9200  Wildtype        Tumor       Wildtype
# S048 -0.2020  Wildtype        Tumor       Wildtype
# S049  0.4860  Wildtype        Tumor       Wildtype
# S050 -0.5020  Wildtype        Tumor       Wildtype
# S051 -0.2670  Wildtype        Tumor       Wildtype
# S052  0.4740  Wildtype        Tumor       Wildtype
# S054  0.2340  Wildtype        Tumor       Wildtype
# S056  0.2260  Wildtype        Tumor       Wildtype
# S057  0.1400  Wildtype        Tumor       Wildtype
# S058 -0.1540  Wildtype        Tumor       Wildtype
# S059 -0.6250  Wildtype        Tumor       Wildtype
# S062 -0.6250  Wildtype        Tumor       Wildtype
# S069 -0.6820  Wildtype        Tumor       Wildtype
# S071 -0.4160  Wildtype        Tumor       Wildtype
# S072 -0.6720  Wildtype        Tumor       Wildtype
# S073  0.2760  Wildtype        Tumor       Wildtype
# S076 -0.2210  Wildtype        Tumor       Wildtype
# S078  0.2840  Wildtype        Tumor       Wildtype
# S079  0.3730  Wildtype        Tumor       Wildtype
# S080  0.4280  Wildtype        Tumor       Wildtype
# S082 -0.6570  Wildtype        Tumor       Wildtype
# S083 -1.1400  Wildtype        Tumor       Wildtype
# S085  0.0860  Wildtype        Tumor       Wildtype
# S087 -0.0145  Wildtype        Tumor       Wildtype
# S091 -1.3300  Wildtype        Tumor       Wildtype
# S093  0.1730  Wildtype        Tumor       Wildtype
# S094  0.3620  Wildtype        Tumor       Wildtype
# S100  0.3860  Wildtype        Tumor       Wildtype
#          PTEN  Mutation Patient_Type Within_Hotspot
# S002 -0.83000  Wildtype        Tumor       Wildtype
# S004 -0.53600  Wildtype        Tumor       Wildtype
# S005  0.73000  Wildtype        Tumor       Wildtype
# S006 -0.37900  Wildtype        Tumor       Wildtype
# S007  0.02930  Wildtype        Tumor       Wildtype
# S008 -1.01000  Wildtype        Tumor       Wildtype
# S011  0.03010  Wildtype        Tumor       Wildtype
# S013 -0.33400  Wildtype        Tumor       Wildtype
# S015 -0.45200  Wildtype        Tumor       Wildtype
# S016 -0.53900  Wildtype        Tumor       Wildtype
# S017  0.45700  Wildtype        Tumor       Wildtype
# S019 -1.70000  Wildtype        Tumor       Wildtype
# S020  0.61700  Wildtype        Tumor       Wildtype
# S025 -1.11000  Wildtype        Tumor       Wildtype
# S029  0.29100  Wildtype        Tumor       Wildtype
# S034  0.08230  Wildtype        Tumor       Wildtype
# S035  0.67700  Wildtype        Tumor       Wildtype
# S037 -0.51000  Wildtype        Tumor       Wildtype
# S039 -0.04420  Wildtype        Tumor       Wildtype
# S041 -0.34700  Wildtype        Tumor       Wildtype
# S042  0.17600  Wildtype        Tumor       Wildtype
# S044  0.28700  Wildtype        Tumor       Wildtype
# S045 -0.51200  Wildtype        Tumor       Wildtype
# S046  0.74800  Wildtype        Tumor       Wildtype
# S047  0.64100  Wildtype        Tumor       Wildtype
# S048 -0.06010  Wildtype        Tumor       Wildtype
# S049 -1.16000  Wildtype        Tumor       Wildtype
# S050 -0.04240  Wildtype        Tumor       Wildtype
# S051 -0.58900  Wildtype        Tumor       Wildtype
# S052 -0.33300  Wildtype        Tumor       Wildtype
# S054 -0.83400  Wildtype        Tumor       Wildtype
# S056 -0.50600  Wildtype        Tumor       Wildtype
# S057 -1.01000  Wildtype        Tumor       Wildtype
# S058  0.09100  Wildtype        Tumor       Wildtype
# S059 -0.04730  Wildtype        Tumor       Wildtype
# S062 -0.88300  Wildtype        Tumor       Wildtype
# S069 -1.50000  Wildtype        Tumor       Wildtype
# S071 -0.13900  Wildtype        Tumor       Wildtype
# S072 -0.56000  Wildtype        Tumor       Wildtype
# S073 -0.37600  Wildtype        Tumor       Wildtype
# S076  0.09980  Wildtype        Tumor       Wildtype
# S078 -0.68100  Wildtype        Tumor       Wildtype
# S079 -0.00137  Wildtype        Tumor       Wildtype
# S080 -0.49100  Wildtype        Tumor       Wildtype
# S082 -0.02540  Wildtype        Tumor       Wildtype
# S083 -1.62000  Wildtype        Tumor       Wildtype
# S085 -0.60000  Wildtype        Tumor       Wildtype
# S087 -1.08000  Wildtype        Tumor       Wildtype
# S091 -0.86900  Wildtype        Tumor       Wildtype
# S093 -0.77200  Wildtype        Tumor       Wildtype
# S094 -0.43400  Wildtype        Tumor       Wildtype
# S100 -0.61600  Wildtype        Tumor       Wildtype
#          AKT1  Mutation Patient_Type Within_Hotspot
# S002  0.04530  Wildtype        Tumor       Wildtype
# S004 -1.07000  Wildtype        Tumor       Wildtype
# S005  0.09680  Wildtype        Tumor       Wildtype
# S006 -0.64100  Wildtype        Tumor       Wildtype
# S007 -0.41900  Wildtype        Tumor       Wildtype
# S008  0.14300  Wildtype        Tumor       Wildtype
# S011 -0.05910  Wildtype        Tumor       Wildtype
# S013 -0.61500  Wildtype        Tumor       Wildtype
# S015 -1.16000  Wildtype        Tumor       Wildtype
# S016 -0.69900  Wildtype        Tumor       Wildtype
# S017 -0.16200  Wildtype        Tumor       Wildtype
# S019 -0.09330  Wildtype        Tumor       Wildtype
# S020  0.25700  Wildtype        Tumor       Wildtype
# S025 -0.29600  Wildtype        Tumor       Wildtype
# S029  0.40000  Wildtype        Tumor       Wildtype
# S034  0.01540  Wildtype        Tumor       Wildtype
# S035  0.76500  Wildtype        Tumor       Wildtype
# S037  0.01140  Wildtype        Tumor       Wildtype
# S039 -0.03650  Wildtype        Tumor       Wildtype
# S041 -0.41300  Wildtype        Tumor       Wildtype
# S042 -0.13700  Wildtype        Tumor       Wildtype
# S044  0.16400  Wildtype        Tumor       Wildtype
# S045 -0.29500  Wildtype        Tumor       Wildtype
# S046  0.07410  Wildtype        Tumor       Wildtype
# S047  0.19800  Wildtype        Tumor       Wildtype
# S048  0.26900  Wildtype        Tumor       Wildtype
# S049 -0.25300  Wildtype        Tumor       Wildtype
# S050  0.08940  Wildtype        Tumor       Wildtype
# S051 -0.18000  Wildtype        Tumor       Wildtype
# S052 -1.07000  Wildtype        Tumor       Wildtype
# S054  0.31200  Wildtype        Tumor       Wildtype
# S056  0.00463  Wildtype        Tumor       Wildtype
# S057 -0.21400  Wildtype        Tumor       Wildtype
# S058  0.59700  Wildtype        Tumor       Wildtype
# S059  0.38600  Wildtype        Tumor       Wildtype
# S062 -0.24600  Wildtype        Tumor       Wildtype
# S069 -0.51000  Wildtype        Tumor       Wildtype
# S071  0.16200  Wildtype        Tumor       Wildtype
# S072  0.17300  Wildtype        Tumor       Wildtype
# S073 -0.05910  Wildtype        Tumor       Wildtype
# S076 -0.00502  Wildtype        Tumor       Wildtype
# S078 -0.30500  Wildtype        Tumor       Wildtype
# S079 -0.08190  Wildtype        Tumor       Wildtype
# S080 -0.26300  Wildtype        Tumor       Wildtype
# S082  0.13500  Wildtype        Tumor       Wildtype
# S083 -0.69000  Wildtype        Tumor       Wildtype
# S085 -0.12500  Wildtype        Tumor       Wildtype
# S087 -0.35200  Wildtype        Tumor       Wildtype
# S091 -0.08410  Wildtype        Tumor       Wildtype
# S093  0.02530  Wildtype        Tumor       Wildtype
# S094  0.29800  Wildtype        Tumor       Wildtype
# S100  0.17200  Wildtype        Tumor       Wildtype
#          MRAS  Mutation Patient_Type Within_Hotspot
# S002 -1.36000  Wildtype        Tumor       Wildtype
# S004  0.22000  Wildtype        Tumor       Wildtype
# S005 -0.76600  Wildtype        Tumor       Wildtype
# S006  1.20000  Wildtype        Tumor       Wildtype
# S007 -1.16000  Wildtype        Tumor       Wildtype
# S008 -0.81700  Wildtype        Tumor       Wildtype
# S011 -0.39900  Wildtype        Tumor       Wildtype
# S013  0.46400  Wildtype        Tumor       Wildtype
# S015  2.76000  Wildtype        Tumor       Wildtype
# S016 -1.18000  Wildtype        Tumor       Wildtype
# S017 -0.49000  Wildtype        Tumor       Wildtype
# S019 -0.22400  Wildtype        Tumor       Wildtype
# S020  0.23300  Wildtype        Tumor       Wildtype
# S025 -0.60700  Wildtype        Tumor       Wildtype
# S029 -0.26400  Wildtype        Tumor       Wildtype
# S034  0.00183  Wildtype        Tumor       Wildtype
# S035  0.34900  Wildtype        Tumor       Wildtype
# S037 -0.32000  Wildtype        Tumor       Wildtype
# S039 -0.26700  Wildtype        Tumor       Wildtype
# S041  0.75300  Wildtype        Tumor       Wildtype
# S042 -0.23200  Wildtype        Tumor       Wildtype
# S044 -0.16200  Wildtype        Tumor       Wildtype
# S045  0.35200  Wildtype        Tumor       Wildtype
# S046 -0.16500  Wildtype        Tumor       Wildtype
# S047  0.13400  Wildtype        Tumor       Wildtype
# S048  0.05690  Wildtype        Tumor       Wildtype
# S049 -0.61700  Wildtype        Tumor       Wildtype
# S050 -0.02020  Wildtype        Tumor       Wildtype
# S051 -0.40600  Wildtype        Tumor       Wildtype
# S052 -0.38100  Wildtype        Tumor       Wildtype
# S054  0.17900  Wildtype        Tumor       Wildtype
# S056 -0.43700  Wildtype        Tumor       Wildtype
# S057 -1.41000  Wildtype        Tumor       Wildtype
# S058 -0.22300  Wildtype        Tumor       Wildtype
# S059 -0.04570  Wildtype        Tumor       Wildtype
# S062 -1.12000  Wildtype        Tumor       Wildtype
# S069 -0.66100  Wildtype        Tumor       Wildtype
# S071  0.30400  Wildtype        Tumor       Wildtype
# S072 -0.50300  Wildtype        Tumor       Wildtype
# S073 -0.52100  Wildtype        Tumor       Wildtype
# S076 -0.14100  Wildtype        Tumor       Wildtype
# S078 -0.66400  Wildtype        Tumor       Wildtype
# S079 -0.28600  Wildtype        Tumor       Wildtype
# S080 -1.46000  Wildtype        Tumor       Wildtype
# S082  0.08520  Wildtype        Tumor       Wildtype
# S083 -2.25000  Wildtype        Tumor       Wildtype
# S085 -1.07000  Wildtype        Tumor       Wildtype
# S087 -0.65900  Wildtype        Tumor       Wildtype
# S091  0.01020  Wildtype        Tumor       Wildtype
# S093 -0.14700  Wildtype        Tumor       Wildtype
# S094 -0.48600  Wildtype        Tumor       Wildtype
# S100  3.21000  Wildtype        Tumor       Wildtype
#         HRAS  Mutation Patient_Type Within_Hotspot
# S004 -0.0943  Wildtype        Tumor       Wildtype
# S005 -0.3190  Wildtype        Tumor       Wildtype
# S006 -0.5110  Wildtype        Tumor       Wildtype
# S008  0.2200  Wildtype        Tumor       Wildtype
# S011 -0.2080  Wildtype        Tumor       Wildtype
# S015  0.1230  Wildtype        Tumor       Wildtype
# S016 -0.6930  Wildtype        Tumor       Wildtype
# S017 -0.4240  Wildtype        Tumor       Wildtype
# S020  0.7130  Wildtype        Tumor       Wildtype
# S025 -0.2400  Wildtype        Tumor       Wildtype
# S029  0.6100  Wildtype        Tumor       Wildtype
# S034  0.0968  Wildtype        Tumor       Wildtype
# S035 -0.0132  Wildtype        Tumor       Wildtype
# S037 -0.3550  Wildtype        Tumor       Wildtype
# S039 -0.3420  Wildtype        Tumor       Wildtype
# S041  0.4690  Wildtype        Tumor       Wildtype
# S042  0.0743  Wildtype        Tumor       Wildtype
# S044  0.3800  Wildtype        Tumor       Wildtype
# S045 -0.0150  Wildtype        Tumor       Wildtype
# S046  0.6070  Wildtype        Tumor       Wildtype
# S047  0.8850  Wildtype        Tumor       Wildtype
# S048 -0.3040  Wildtype        Tumor       Wildtype
# S049 -0.0016  Wildtype        Tumor       Wildtype
# S050  0.2810  Wildtype        Tumor       Wildtype
# S051 -0.9450  Wildtype        Tumor       Wildtype
# S052  0.8540  Wildtype        Tumor       Wildtype
# S054 -1.0500  Wildtype        Tumor       Wildtype
# S056  0.6280  Wildtype        Tumor       Wildtype
# S057 -0.3180  Wildtype        Tumor       Wildtype
# S058  0.3560  Wildtype        Tumor       Wildtype
# S062 -0.8680  Wildtype        Tumor       Wildtype
# S069 -0.9120  Wildtype        Tumor       Wildtype
# S071 -0.5530  Wildtype        Tumor       Wildtype
# S072 -1.0200  Wildtype        Tumor       Wildtype
# S073  4.3100  Wildtype        Tumor       Wildtype
# S076 -0.6110  Wildtype        Tumor       Wildtype
# S078 -0.0493  Wildtype        Tumor       Wildtype
# S079  0.3730  Wildtype        Tumor       Wildtype
# S080  0.4430  Wildtype        Tumor       Wildtype
# S082  0.0159  Wildtype        Tumor       Wildtype
# S085  0.0521  Wildtype        Tumor       Wildtype
# S087  0.1420  Wildtype        Tumor       Wildtype
# S091 -0.5030  Wildtype        Tumor       Wildtype
# S093  0.7240  Wildtype        Tumor       Wildtype
# S094  0.2710  Wildtype        Tumor       Wildtype
# S100 -0.5650  Wildtype        Tumor       Wildtype
#       RPS6KB1  Mutation Patient_Type Within_Hotspot
# S002  0.04170  Wildtype        Tumor       Wildtype
# S004  0.83900  Wildtype        Tumor       Wildtype
# S005  0.00728  Wildtype        Tumor       Wildtype
# S006 -0.13800  Wildtype        Tumor       Wildtype
# S007 -0.25700  Wildtype        Tumor       Wildtype
# S008  0.26600  Wildtype        Tumor       Wildtype
# S011 -0.11700  Wildtype        Tumor       Wildtype
# S013 -0.02800  Wildtype        Tumor       Wildtype
# S015 -0.37000  Wildtype        Tumor       Wildtype
# S016 -0.10400  Wildtype        Tumor       Wildtype
# S017 -0.34000  Wildtype        Tumor       Wildtype
# S019  0.21100  Wildtype        Tumor       Wildtype
# S020  0.34600  Wildtype        Tumor       Wildtype
# S025  0.07920  Wildtype        Tumor       Wildtype
# S029 -0.18700  Wildtype        Tumor       Wildtype
# S034 -0.40600  Wildtype        Tumor       Wildtype
# S035  0.24300  Wildtype        Tumor       Wildtype
# S037 -0.00144  Wildtype        Tumor       Wildtype
# S039 -0.20800  Wildtype        Tumor       Wildtype
# S041  0.17400  Wildtype        Tumor       Wildtype
# S042 -0.03380  Wildtype        Tumor       Wildtype
# S044  0.56600  Wildtype        Tumor       Wildtype
# S045 -0.12800  Wildtype        Tumor       Wildtype
# S046  1.04000  Wildtype        Tumor       Wildtype
# S047  0.31600  Wildtype        Tumor       Wildtype
# S048 -0.00179  Wildtype        Tumor       Wildtype
# S049 -0.10800  Wildtype        Tumor       Wildtype
# S050 -0.20200  Wildtype        Tumor       Wildtype
# S051 -0.36300  Wildtype        Tumor       Wildtype
# S052 -0.34500  Wildtype        Tumor       Wildtype
# S054 -0.52600  Wildtype        Tumor       Wildtype
# S056  0.18600  Wildtype        Tumor       Wildtype
# S057 -0.18100  Wildtype        Tumor       Wildtype
# S058  1.13000  Wildtype        Tumor       Wildtype
# S059 -0.19000  Wildtype        Tumor       Wildtype
# S062 -0.27900  Wildtype        Tumor       Wildtype
# S069 -0.07620  Wildtype        Tumor       Wildtype
# S071  0.21800  Wildtype        Tumor       Wildtype
# S072  0.37200  Wildtype        Tumor       Wildtype
# S073  0.67100  Wildtype        Tumor       Wildtype
# S076 -0.23000  Wildtype        Tumor       Wildtype
# S078 -0.23300  Wildtype        Tumor       Wildtype
# S079  0.26300  Wildtype        Tumor       Wildtype
# S080  0.56400  Wildtype        Tumor       Wildtype
# S082  1.14000  Wildtype        Tumor       Wildtype
# S083  0.29000  Wildtype        Tumor       Wildtype
# S085 -0.62800  Wildtype        Tumor       Wildtype
# S087 -0.52700  Wildtype        Tumor       Wildtype
# S091  0.22100  Wildtype        Tumor       Wildtype
# S093 -0.17900  Wildtype        Tumor       Wildtype
# S094 -0.20100  Wildtype        Tumor       Wildtype
# S100  0.18500  Wildtype        Tumor       Wildtype
#        PIK3R1  Mutation Patient_Type Within_Hotspot
# S002 -0.85500  Wildtype        Tumor       Wildtype
# S004 -0.49900  Wildtype        Tumor       Wildtype
# S005 -0.13500  Wildtype        Tumor       Wildtype
# S006 -0.61200  Wildtype        Tumor       Wildtype
# S007 -0.87500  Wildtype        Tumor       Wildtype
# S008 -1.91000  Wildtype        Tumor       Wildtype
# S011 -0.08900  Wildtype        Tumor       Wildtype
# S013 -0.64000  Wildtype        Tumor       Wildtype
# S015 -0.00314  Wildtype        Tumor       Wildtype
# S016 -0.64900  Wildtype        Tumor       Wildtype
# S017 -0.54100  Wildtype        Tumor       Wildtype
# S019 -1.01000  Wildtype        Tumor       Wildtype
# S020 -0.12800  Wildtype        Tumor       Wildtype
# S025  0.04050  Wildtype        Tumor       Wildtype
# S029 -0.16200  Wildtype        Tumor       Wildtype
# S034 -0.18000  Wildtype        Tumor       Wildtype
# S035  0.18600  Wildtype        Tumor       Wildtype
# S037  0.00690  Wildtype        Tumor       Wildtype
# S039  0.40300  Wildtype        Tumor       Wildtype
# S041  0.33900  Wildtype        Tumor       Wildtype
# S042 -0.07910  Wildtype        Tumor       Wildtype
# S044  0.09930  Wildtype        Tumor       Wildtype
# S045 -0.19900  Wildtype        Tumor       Wildtype
# S046 -0.00492  Wildtype        Tumor       Wildtype
# S047  0.21800  Wildtype        Tumor       Wildtype
# S048  0.08590  Wildtype        Tumor       Wildtype
# S049 -0.08720  Wildtype        Tumor       Wildtype
# S050 -0.36000  Wildtype        Tumor       Wildtype
# S051 -0.43500  Wildtype        Tumor       Wildtype
# S052 -0.50100  Wildtype        Tumor       Wildtype
# S054 -0.11000  Wildtype        Tumor       Wildtype
# S056  0.06150  Wildtype        Tumor       Wildtype
# S057 -0.80300  Wildtype        Tumor       Wildtype
# S058 -0.53500  Wildtype        Tumor       Wildtype
# S059  0.40800  Wildtype        Tumor       Wildtype
# S062  0.57700  Wildtype        Tumor       Wildtype
# S069 -0.04250  Wildtype        Tumor       Wildtype
# S071 -0.37100  Wildtype        Tumor       Wildtype
# S072 -0.35600  Wildtype        Tumor       Wildtype
# S073 -1.39000  Wildtype        Tumor       Wildtype
# S076 -0.16700  Wildtype        Tumor       Wildtype
# S078 -0.42400  Wildtype        Tumor       Wildtype
# S079  0.34600  Wildtype        Tumor       Wildtype
# S080  0.06770  Wildtype        Tumor       Wildtype
# S082  0.35700  Wildtype        Tumor       Wildtype
# S083  0.62200  Wildtype        Tumor       Wildtype
# S085  0.05640  Wildtype        Tumor       Wildtype
# S087 -0.29800  Wildtype        Tumor       Wildtype
# S091 -0.35000  Wildtype        Tumor       Wildtype
# S093 -0.75300  Wildtype        Tumor       Wildtype
# S094  0.55300  Wildtype        Tumor       Wildtype
# S100  0.11700  Wildtype        Tumor       Wildtype
#         MTOR  Mutation Patient_Type Within_Hotspot
# S002 -0.1560  Wildtype        Tumor       Wildtype
# S004  0.2040  Wildtype        Tumor       Wildtype
# S005  0.0904  Wildtype        Tumor       Wildtype
# S006 -0.2120  Wildtype        Tumor       Wildtype
# S007  0.0344  Wildtype        Tumor       Wildtype
# S008  0.0597  Wildtype        Tumor       Wildtype
# S011  0.0981  Wildtype        Tumor       Wildtype
# S013  0.0365  Wildtype        Tumor       Wildtype
# S015 -0.0493  Wildtype        Tumor       Wildtype
# S016 -0.0424  Wildtype        Tumor       Wildtype
# S017 -0.0497  Wildtype        Tumor       Wildtype
# S019 -0.1250  Wildtype        Tumor       Wildtype
# S020  0.0167  Wildtype        Tumor       Wildtype
# S025  0.0309  Wildtype        Tumor       Wildtype
# S029  0.0286  Wildtype        Tumor       Wildtype
# S034 -0.0635  Wildtype        Tumor       Wildtype
# S035  0.3680  Wildtype        Tumor       Wildtype
# S037  0.1300  Wildtype        Tumor       Wildtype
# S039  0.0316  Wildtype        Tumor       Wildtype
# S041  0.3210  Wildtype        Tumor       Wildtype
# S042  0.0412  Wildtype        Tumor       Wildtype
# S044  0.0810  Wildtype        Tumor       Wildtype
# S045  0.0736  Wildtype        Tumor       Wildtype
# S046 -0.0200  Wildtype        Tumor       Wildtype
# S047  0.1780  Wildtype        Tumor       Wildtype
# S048  0.2900  Wildtype        Tumor       Wildtype
# S049 -0.1260  Wildtype        Tumor       Wildtype
# S050  0.0358  Wildtype        Tumor       Wildtype
# S051 -0.1180  Wildtype        Tumor       Wildtype
# S052 -0.0220  Wildtype        Tumor       Wildtype
# S054 -0.0911  Wildtype        Tumor       Wildtype
# S056 -0.0933  Wildtype        Tumor       Wildtype
# S057 -0.1200  Wildtype        Tumor       Wildtype
# S058  0.0765  Wildtype        Tumor       Wildtype
# S059  0.1210  Wildtype        Tumor       Wildtype
# S062 -0.5110  Wildtype        Tumor       Wildtype
# S069 -0.6770  Wildtype        Tumor       Wildtype
# S071 -0.2520  Wildtype        Tumor       Wildtype
# S072  0.1360  Wildtype        Tumor       Wildtype
# S073 -0.1470  Wildtype        Tumor       Wildtype
# S076 -0.0275  Wildtype        Tumor       Wildtype
# S078 -0.1610  Wildtype        Tumor       Wildtype
# S079 -0.1710  Wildtype        Tumor       Wildtype
# S080  0.1110  Wildtype        Tumor       Wildtype
# S082 -0.0458  Wildtype        Tumor       Wildtype
# S083 -0.0650  Wildtype        Tumor       Wildtype
# S085 -0.3300  Wildtype        Tumor       Wildtype
# S087 -0.0950  Wildtype        Tumor       Wildtype
# S091  0.1110  Wildtype        Tumor       Wildtype
# S093 -0.0807  Wildtype        Tumor       Wildtype
# S094  0.0275  Wildtype        Tumor       Wildtype
# S100  0.1450  Wildtype        Tumor       Wildtype
#        ERBB3  Mutation Patient_Type Within_Hotspot
# S002  0.8190  Wildtype        Tumor       Wildtype
# S004 -0.1850  Wildtype        Tumor       Wildtype
# S005  0.5240  Wildtype        Tumor       Wildtype
# S006  0.8560  Wildtype        Tumor       Wildtype
# S007 -0.2060  Wildtype        Tumor       Wildtype
# S008 -0.2070  Wildtype        Tumor       Wildtype
# S011 -0.4120  Wildtype        Tumor       Wildtype
# S013  2.0900  Wildtype        Tumor       Wildtype
# S015 -1.0600  Wildtype        Tumor       Wildtype
# S016  0.7780  Wildtype        Tumor       Wildtype
# S017 -0.1890  Wildtype        Tumor       Wildtype
# S019  0.6840  Wildtype        Tumor       Wildtype
# S020  0.2730  Wildtype        Tumor       Wildtype
# S025 -0.2370  Wildtype        Tumor       Wildtype
# S029  0.4690  Wildtype        Tumor       Wildtype
# S034  0.1690  Wildtype        Tumor       Wildtype
# S035 -0.2090  Wildtype        Tumor       Wildtype
# S037  0.2400  Wildtype        Tumor       Wildtype
# S039 -0.5730  Wildtype        Tumor       Wildtype
# S041  1.4300  Wildtype        Tumor       Wildtype
# S042 -0.0525  Wildtype        Tumor       Wildtype
# S044 -0.2050  Wildtype        Tumor       Wildtype
# S045  0.7700  Wildtype        Tumor       Wildtype
# S046  0.2500  Wildtype        Tumor       Wildtype
# S047 -0.1290  Wildtype        Tumor       Wildtype
# S048 -0.1540  Wildtype        Tumor       Wildtype
# S049  0.1230  Wildtype        Tumor       Wildtype
# S050 -0.1470  Wildtype        Tumor       Wildtype
# S051  0.0659  Wildtype        Tumor       Wildtype
# S052 -0.3680  Wildtype        Tumor       Wildtype
# S054  0.5350  Wildtype        Tumor       Wildtype
# S056  0.3620  Wildtype        Tumor       Wildtype
# S057  0.9100  Wildtype        Tumor       Wildtype
# S058 -0.0200  Wildtype        Tumor       Wildtype
# S059  0.0978  Wildtype        Tumor       Wildtype
# S062  0.1260  Wildtype        Tumor       Wildtype
# S069 -0.5110  Wildtype        Tumor       Wildtype
# S071 -0.5360  Wildtype        Tumor       Wildtype
# S072  0.6240  Wildtype        Tumor       Wildtype
# S073  0.4770  Wildtype        Tumor       Wildtype
# S076  0.3060  Wildtype        Tumor       Wildtype
# S078  0.3910  Wildtype        Tumor       Wildtype
# S079  0.5100  Wildtype        Tumor       Wildtype
# S080  0.4210  Wildtype        Tumor       Wildtype
# S082 -0.3180  Wildtype        Tumor       Wildtype
# S083 -0.9600  Wildtype        Tumor       Wildtype
# S085 -0.1350  Wildtype        Tumor       Wildtype
# S087  0.1590  Wildtype        Tumor       Wildtype
# S091  0.6220  Wildtype        Tumor       Wildtype
# S093  0.1910  Wildtype        Tumor       Wildtype
# S094 -0.1690  Wildtype        Tumor       Wildtype
# S100  1.7100  Wildtype        Tumor       Wildtype
#          CDK5  Mutation Patient_Type Within_Hotspot
# S002 -0.01720  Wildtype        Tumor       Wildtype
# S004 -0.33400  Wildtype        Tumor       Wildtype
# S005 -0.01950  Wildtype        Tumor       Wildtype
# S006 -0.29700  Wildtype        Tumor       Wildtype
# S007  0.80700  Wildtype        Tumor       Wildtype
# S008 -0.02650  Wildtype        Tumor       Wildtype
# S011  0.17200  Wildtype        Tumor       Wildtype
# S013 -0.55300  Wildtype        Tumor       Wildtype
# S015 -0.06400  Wildtype        Tumor       Wildtype
# S016  0.18600  Wildtype        Tumor       Wildtype
# S017  0.45800  Wildtype        Tumor       Wildtype
# S019  0.52800  Wildtype        Tumor       Wildtype
# S020 -0.13700  Wildtype        Tumor       Wildtype
# S025  0.18300  Wildtype        Tumor       Wildtype
# S029  0.47600  Wildtype        Tumor       Wildtype
# S034  0.00183  Wildtype        Tumor       Wildtype
# S035 -0.21600  Wildtype        Tumor       Wildtype
# S037  0.01830  Wildtype        Tumor       Wildtype
# S039  0.01660  Wildtype        Tumor       Wildtype
# S041 -0.47000  Wildtype        Tumor       Wildtype
# S042 -0.44500  Wildtype        Tumor       Wildtype
# S044 -0.04320  Wildtype        Tumor       Wildtype
# S045 -0.11000  Wildtype        Tumor       Wildtype
# S046  0.15500  Wildtype        Tumor       Wildtype
# S047 -0.33600  Wildtype        Tumor       Wildtype
# S048 -0.20500  Wildtype        Tumor       Wildtype
# S049  0.35900  Wildtype        Tumor       Wildtype
# S050 -0.03690  Wildtype        Tumor       Wildtype
# S051  0.23000  Wildtype        Tumor       Wildtype
# S052  0.31900  Wildtype        Tumor       Wildtype
# S054  0.06000  Wildtype        Tumor       Wildtype
# S056 -0.02750  Wildtype        Tumor       Wildtype
# S057  0.22000  Wildtype        Tumor       Wildtype
# S058 -0.09880  Wildtype        Tumor       Wildtype
# S059  0.12500  Wildtype        Tumor       Wildtype
# S062 -0.01270  Wildtype        Tumor       Wildtype
# S069 -0.30400  Wildtype        Tumor       Wildtype
# S071  0.22300  Wildtype        Tumor       Wildtype
# S072  0.07390  Wildtype        Tumor       Wildtype
# S073 -0.06550  Wildtype        Tumor       Wildtype
# S076 -0.07220  Wildtype        Tumor       Wildtype
# S078 -0.16400  Wildtype        Tumor       Wildtype
# S079  0.14400  Wildtype        Tumor       Wildtype
# S080  0.28500  Wildtype        Tumor       Wildtype
# S082  0.28000  Wildtype        Tumor       Wildtype
# S083  0.09540  Wildtype        Tumor       Wildtype
# S085  0.00430  Wildtype        Tumor       Wildtype
# S087  0.31500  Wildtype        Tumor       Wildtype
# S091 -0.13800  Wildtype        Tumor       Wildtype
# S093 -0.04880  Wildtype        Tumor       Wildtype
# S094  0.16900  Wildtype        Tumor       Wildtype
# S100  0.72000  Wildtype        Tumor       Wildtype
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1-S1005": 0.1538874422084835,
#   "IRS1-S270": 0.273498035871859,
#   "IRS1-S527": 0.6576950639533548,
#   "IRS2-S1100": 0.7932403796403827,
#   "IRS2-S365": 0.2190537914574149,
#   "RRAS2-S186": 0.06560223604200595,
#   "PTEN-S467": 0.5573473385330219,
#   "AKT1-S126": 0.7527767230674126,
#   "AKT1-S129": 0.6225282061459592,
#   "AKT1S1-S222": 0.40990754364672066,
#   "AKT1S1-S223": 0.5472780915404707,
#   "AKT1S1-S232": 0.890724203697261,
#   "LAMTOR1-S27": 0.8062980865678622,
#   "RPS6KA1-S372": 0.10432653425215277,
#   "RPS6KA3-S369": 0.44692002190398494,
#   "RPS6KA3-S415": 0.4922566425312921,
#   "RPS6KA3-T365": 0.5308755964582641,
#   "RPS6KA4-S343": 0.50715754989591,
#   "RPS6KA4-S347": 0.4913203854756516,
#   "RPS6KA4-S682": 0.12699833922172207,
#   "RPS6KA4-S745": 0.5186282931858306,
#   "RPS6KC1-S423": 0.004588149271431776,
#   "RPS6KC1-S667": 0.5232936781331718,
#   "MAPK1-Y187": 0.8677251063910387,
#   "MAPK14-Y182": 0.9778508055313739,
#   "MAPK3-Y204": 0.7530383051291035,
#   "MAPKAP1-S510": 0.745676335806206,
#   "MAPKAPK5-S212": 0.8845516379019593
# }

# %% [markdown]
# ## All mutations vs cancer wildtype

# %%
print("Mutations inside hotspot: " + str(len(hotspot_patients)))
p110_mutated = somatic.loc[somatic['Gene'] == 'PIK3CA']

# 1. Use the Bonferonni correction to adjust the p-value by dividing alpha (0.05) by the number of tests. 
#   Because we are analyzing 19 proteins, we will have 19 tests. 
pcutoff = 0.05/len(protList)

# 2. Create a dictionary for significant proteins with their prespective pvalues
#    Create another dictionary for unsignificant results

sigResults = {}
unsigResults = {}

# 3. Loop through each protein to test for significant protein level
for protein in protList: 
    
    #Check to make sure that the protein is in the proteomics dataframe that we are reading from
    if protein in proteomics.columns:
        # 4. Set up a new column for mutations that are within the hotspot
        p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
        p10_mutations['Within_Hotspot'] = False
        p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
        p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)

        all_mut = p10_mutations.loc[p10_mutations['Within_Hotspot'] != 'Wildtype']
        wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
        
        # 5. Perform a two-sample ttest for mutations in hotspot vs mutations outside of the hotspot
        ttest = scipy.stats.ttest_ind(all_mut[protein], wt[protein])
        
        if ttest[1] < pcutoff:
            sigResults[protein] = ttest[1]
            
        else:
            unsigResults[protein] = ttest[1]
            
# 5. Print the results
print('SIGNIFICANT RESULTS:')
# Json is a nice package that allows you to print items in the dictionary line by line
print(json.dumps(sigResults, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigResults, indent = 2))
# Out:
# Mutations inside hotspot: 19
# 0.3035716066390899
# 0.07027134773500125
# 0.3698729088560708
# 0.0037875613802568534
# 0.8373527469808126
# 0.20302505456125847
# 0.8022219785434666
# 0.6105204981755263
# 0.5580623705425318
# 0.031195095038079188
# 0.03475975535096763
# 0.12697356066680146
# 0.26427162128979986
# 0.0158825119935403
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1": 0.3035716066390899,
#   "IRS2": 0.07027134773500125,
#   "RRAS": 0.3698729088560708,
#   "AKT2": 0.0037875613802568534,
#   "NRAS": 0.8373527469808126,
#   "PTEN": 0.20302505456125847,
#   "AKT1": 0.8022219785434666,
#   "MRAS": 0.6105204981755263,
#   "HRAS": 0.5580623705425318,
#   "RPS6KB1": 0.031195095038079188,
#   "PIK3R1": 0.03475975535096763,
#   "MTOR": 0.12697356066680146,
#   "ERBB3": 0.26427162128979986,
#   "CDK5": 0.0158825119935403
# }

# %% [markdown]
# # Phosphoproteomic Abundance

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
sites = []
pvalues = []

# 1. Use a Bonferroni cutoff to adjust the pvalue in testing for significance 
#pcutoff = 0.05/len(phos_mutations.columns)

# 2. Loop through each of the proteins in the list of interacting proteins
for protein in protList:
   # 3. Loop through each phosphorylation site in that protein to find any that show any significant changes in phosphorylation level
    #  Some proteins do not have recorded data in the phosphoproteomics data. If this is the case, we move on to the next protein in the list
    try:
        
        # 4. Set up a new column for mutations that are within the hotspot
        phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
        phos_mutations['Within_Hotspot'] = False
        phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
        phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        
        # 5. Select for tumor samples only 
        phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
       
        #6. Create a list of the phosphosites by selecting all the columns in the dataframe, excluding the last three which are categorical variables
        phos_sites = list(phos_mutations)
        # Take out the categorical variables, which are 'Mutation', 'Patient_Type', and 'Within_Hotspot'
        phos_sites = phos_sites[:(len(phos_sites) - 3)]

        # 7. Create two dataframes to test the two cases: one for phosphorylation levels when PIK3CA is mutated at a hotspot, the other when PIK3CA is mutated outside the hotspot
        #    Drop any columns that contain values of 'Nan' which means for 'Not a number'
        hotspot_mut = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True].dropna(axis = 1)
        non_hotspot_mut = phos_mutations.loc[phos_mutations['Within_Hotspot'] == False].dropna(axis = 1)

        # 8. Loop through each site to test for significant difference in phosphorylation levels between the two tested cases
        for site in phos_sites:

        # 9. Check if the site is in both dataframes. That column may have been deleted in step 4
            if site in hotspot_mut.columns and site in non_hotspot_mut.columns:
                
                # 10. Perform a two-sample ttest for mutations in hotspot vs mutations outside of the hotspot
                ttest = scipy.stats.ttest_ind(hotspot_mut[site], non_hotspot_mut[site])
                
                # 11. Append site name and pvalue in two separate lists that will be used to calculate the pvalue adjustment using Bonferroni correction
                sites.append(site)
                pvalues.append(ttest[1])
    #Error caught in the case that the protein had no data in the phosproteomics data
    except:
        print('')
        
        
# 12. After looping through all of the phosphorylation sites of each protein, filter the list of pvalues with respective sites to find those with significant results
#     Create a dictionary to pair the significant sites with their significant pvalues 
#     Create another dictionary for unsignificant results
sigSites = {}
unsigSites = {}

#     The Bonferroni correction is alpha/number of sites tested
alpha = 0.05
pcutoff = alpha/len(sites)

#     Loop through each pvalue to find those that are lower than the pcutoff
for i in range(0, len(sites) - 1):
    if pvalues[i] < pcutoff:
        sigSites[sites[i]] = pvalues[i]
    else:
        unsigSites[sites[i]] = pvalues[i]

# 13. Print your results
print('SIGNIFICANT RESULTS:')
print(json.dumps(sigSites, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigSites, indent = 2))
# Out:
# Gene MRAS not found in phosphoproteomics data
#
# Gene HRAS not found in phosphoproteomics data
#
# Gene P85A not found in phosphoproteomics data
#
# Gene P55G not found in phosphoproteomics data
#
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1-S1005": 0.17528948470055017,
#   "IRS1-S270": 0.03007352043700034,
#   "IRS1-S527": 0.8131561848131362,
#   "IRS2-S1100": 0.7645665883505008,
#   "IRS2-S365": 0.4781886740079353,
#   "RRAS2-S186": 0.17119748527873915,
#   "PTEN-S467": 0.9294994804576602,
#   "AKT1-S126": 0.7486950797373193,
#   "AKT1-S129": 0.5916370158032049,
#   "AKT1S1-S222": 0.5918285139058572,
#   "AKT1S1-S223": 0.43267755057076984,
#   "AKT1S1-S232": 0.7772468446134322,
#   "LAMTOR1-S27": 0.18293732469580826,
#   "RPS6KA1-S372": 0.05339162019092151,
#   "RPS6KA3-S369": 0.4210133831570302,
#   "RPS6KA3-S415": 0.5628514553056778,
#   "RPS6KA3-T365": 0.4558365802220815,
#   "RPS6KA4-S343": 0.7768822975837044,
#   "RPS6KA4-S347": 0.9362529697434308,
#   "RPS6KA4-S682": 0.28305324636110585,
#   "RPS6KA4-S745": 0.2643961954425618,
#   "RPS6KC1-S423": 0.0054393250678950985,
#   "RPS6KC1-S667": 0.31404984761941396,
#   "MAPK1-Y187": 0.952573076564454,
#   "MAPK14-Y182": 0.9526632688826353,
#   "MAPK3-Y204": 0.7634228819020021,
#   "MAPKAP1-S510": 0.9777425744540408,
#   "MAPKAPK5-S212": 0.5277708303676474
# }

# %% [markdown]
# ## Hotspot mutation vs cancer wildtype

# %%
sites = []
pvalues = []


# 1. Loop through each of the proteins in the list of interacting proteins
for protein in protList:
   # 2. Loop through each phosphorylation site in that protein to find any that show any significant changes in phosphorylation level
    #  Some proteins do not have recorded data in the phosphoproteomics data. If this is the case, we move on to the next protein in the list
    try:
        
        # 3. Set up a new column for mutations that are within the hotspot
        phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
        phos_mutations['Within_Hotspot'] = False
        phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
        phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        
        # 4. Select for tumor samples only 
        phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
       
        #5. Create a list of the phosphosites by selecting all the columns in the dataframe, excluding the last three which are categorical variables
        phos_sites = list(phos_mutations)
        # Take out the categorical variables, which are 'Mutation', 'Patient_Type', and 'Within_Hotspot'
        phos_sites = phos_sites[:(len(phos_sites) - 3)]

        # 6. Create two dataframes to test the two cases: one for phosphorylation levels when PIK3CA is mutated at a hotspot, the other when PIK3CA is mutated outside the hotspot
        #    Drop any columns that contain values of 'Nan' which means for 'Not a number'
        hotspot_mut = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True].dropna(axis = 1)
        wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype'].dropna(axis = 1)

        # 7. Loop through each site to test for significant difference in phosphorylation levels between the two tested cases
        for site in phos_sites:

        # 8. Check if the site is in both dataframes. That column may have been deleted in step 4
            if site in hotspot_mut.columns and site in wt.columns:
                
                # 9. Perform a two-sample ttest for mutations in hotspot vs cancer wildtype
                ttest = scipy.stats.ttest_ind(hotspot_mut[site], wt[site])
                
                # 10. Append site name and pvalue in two separate lists that will be used to calculate the pvalue adjustment using Bonferroni correction
                sites.append(site)
                pvalues.append(ttest[1])
    #Error caught in the case that the protein had no data in the phosproteomics data
    except:
        print('')
        
        
# 11. After looping through all of the phosphorylation sites of each protein, filter the list of pvalues with respective sites to find those with significant results
#     Create a dictionary to pair the significant sites with their significant pvalues 
#     Create another dictionary for unsignificant results
sigSites = {}
unsigSites = {}

#     The Bonferroni correction is alpha/number of sites tested
alpha = 0.05
pcutoff = alpha/len(sites)

#     Loop through each pvalue to find those that are lower than the pcutoff
for i in range(0, len(sites) - 1):
    if pvalues[i] < pcutoff:
        sigSites[sites[i]] = pvalues[i]
    else:
        unsigSites[sites[i]] = pvalues[i]

# 12. Print your results
print('SIGNIFICANT RESULTS:')
print(json.dumps(sigSites, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigSites, indent = 2))
# Out:
# Gene MRAS not found in phosphoproteomics data
#
# Gene HRAS not found in phosphoproteomics data
#
# Gene P85A not found in phosphoproteomics data
#
# Gene P55G not found in phosphoproteomics data
#
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1-S1005": 0.19417303251270715,
#   "IRS1-S270": 0.6123346440221398,
#   "IRS1-S527": 0.6202579866122413,
#   "IRS2-S1100": 0.5593582798259669,
#   "IRS2-S365": 0.1480060586799261,
#   "RRAS2-S186": 0.0681929188803574,
#   "PTEN-S467": 0.3443244276059154,
#   "AKT1-S126": 0.7883661163452153,
#   "AKT1-S129": 0.6794351192511748,
#   "AKT1S1-S222": 0.3638299279998196,
#   "AKT1S1-S223": 0.6732770531436207,
#   "AKT1S1-S232": 0.962703662241644,
#   "LAMTOR1-S27": 0.7161195316132374,
#   "RPS6KA1-S372": 0.2096652012691004,
#   "RPS6KA3-S369": 0.5043949130038693,
#   "RPS6KA3-S415": 0.5282218763149932,
#   "RPS6KA3-T365": 0.6360891945377386,
#   "RPS6KA4-S343": 0.4171864166971315,
#   "RPS6KA4-S347": 0.32314014370600697,
#   "RPS6KA4-S682": 0.11122422076457351,
#   "RPS6KA4-S745": 0.7614522391522289,
#   "RPS6KC1-S423": 0.017854053280120113,
#   "RPS6KC1-S667": 0.6979930196282308,
#   "MAPK1-Y187": 0.7735649000967488,
#   "MAPK14-Y182": 0.9942350500683007,
#   "MAPK3-Y204": 0.7701827755495878,
#   "MAPKAP1-S510": 0.6229688683535106,
#   "MAPKAPK5-S212": 0.554891827167844
# }

# %% [markdown]
# ## All mutations vs cancer wildtype

# %%
sites = []
pvalues = []


# 1. Loop through each of the proteins in the list of interacting proteins
for protein in protList:
   # 2. Loop through each phosphorylation site in that protein to find any that show any significant changes in phosphorylation level
    #  Some proteins do not have recorded data in the phosphoproteomics data. If this is the case, we move on to the next protein in the list
    try:
        
        # 3. Set up a new column for mutations that are within the hotspot
        phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
        phos_mutations['Within_Hotspot'] = False
        phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
        phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        
        # 4. Select for tumor samples only 
        phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
       
        #5. Create a list of the phosphosites by selecting all the columns in the dataframe, excluding the last three which are categorical variables
        phos_sites = list(phos_mutations)
        # Take out the categorical variables, which are 'Mutation', 'Patient_Type', and 'Within_Hotspot'
        phos_sites = phos_sites[:(len(phos_sites) - 3)]

        # 6. Create two dataframes to test the two cases: one for phosphorylation levels when PIK3CA is mutated at a hotspot, the other when PIK3CA is mutated outside the hotspot
        #    Drop any columns that contain values of 'Nan' which means for 'Not a number'
        all_mut = phos_mutations.loc[phos_mutations['Within_Hotspot'] != 'Wildtype'].dropna(axis = 1)
        wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype'].dropna(axis = 1)

        # 7. Loop through each site to test for significant difference in phosphorylation levels between the two tested cases
        for site in phos_sites:

        # 8. Check if the site is in both dataframes. That column may have been deleted in step 4
            if site in all_mut.columns and site in wt.columns:
                
                # 9. Perform a two-sample ttest for all mutations vs cancer wildtype
                ttest = scipy.stats.ttest_ind(all_mut[site], wt[site])
                
                # 10. Append site name and pvalue in two separate lists that will be used to calculate the pvalue adjustment using Bonferroni correction
                sites.append(site)
                pvalues.append(ttest[1])
    #Error caught in the case that the protein had no data in the phosproteomics data
    except:
        print('')
        
        
# 11. After looping through all of the phosphorylation sites of each protein, filter the list of pvalues with respective sites to find those with significant results
#     Create a dictionary to pair the significant sites with their significant pvalues 
#     Create another dictionary for unsignificant results
sigSites = {}
unsigSites = {}

#     The Bonferroni correction is alpha/number of sites tested
alpha = 0.05
pcutoff = alpha/len(sites)

#     Loop through each pvalue to find those that are lower than the pcutoff
for i in range(0, len(sites) - 1):
    if pvalues[i] < pcutoff:
        sigSites[sites[i]] = pvalues[i]
    else:
        unsigSites[sites[i]] = pvalues[i]

# 12. Print your results
print('SIGNIFICANT RESULTS:')
print(json.dumps(sigSites, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigSites, indent = 2))
# Out:
# Gene MRAS not found in phosphoproteomics data
#
# Gene HRAS not found in phosphoproteomics data
#
# Gene P85A not found in phosphoproteomics data
#
# Gene P55G not found in phosphoproteomics data
#
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1-S1005": 0.7819473288725783,
#   "IRS1-S270": 0.420671984317987,
#   "IRS1-S527": 0.6092510914703817,
#   "IRS2-S1100": 0.29051612765254076,
#   "IRS2-S365": 0.17536896672599964,
#   "RRAS2-S186": 0.17220819173708915,
#   "PTEN-S467": 0.19026606659216647,
#   "AKT1-S126": 0.9132179738567242,
#   "AKT1-S129": 0.890024535674317,
#   "AKT1S1-S222": 0.5206482315169443,
#   "AKT1S1-S223": 0.8293345010001284,
#   "AKT1S1-S232": 0.8776613495892818,
#   "LAMTOR1-S27": 0.11619202055339348,
#   "RPS6KA1-S372": 0.9288019759523318,
#   "RPS6KA3-S369": 0.8187216070129072,
#   "RPS6KA3-S415": 0.6959015001149395,
#   "RPS6KA3-T365": 0.8319894488679778,
#   "RPS6KA4-S343": 0.43504258422238407,
#   "RPS6KA4-S347": 0.2202764845546568,
#   "RPS6KA4-S682": 0.14167192742230666,
#   "RPS6KA4-S745": 0.6311328778224082,
#   "RPS6KC1-S423": 0.41403180712806764,
#   "RPS6KC1-S667": 0.7826648189596725,
#   "MAPK1-Y187": 0.6629285329040581,
#   "MAPK14-Y182": 0.968513462326037,
#   "MAPK3-Y204": 0.8856083025404158,
#   "MAPKAP1-S510": 0.48994072811564304,
#   "MAPKAPK5-S212": 0.1887723506243224
# }

# %% [markdown]
# ## Hotspot mutation v other mutations and wildtype

# %%
sites = []
pvalues = []


# 1. Loop through each of the proteins in the list of interacting proteins
for protein in protList:
   # 2. Loop through each phosphorylation site in that protein to find any that show any significant changes in phosphorylation level
    #  Some proteins do not have recorded data in the phosphoproteomics data. If this is the case, we move on to the next protein in the list
    try:
        
        # 3. Set up a new column for mutations that are within the hotspot
        phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
        phos_mutations['Within_Hotspot'] = False
        phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
        phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
        
        # 4. Select for tumor samples only 
        phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
       
        #5. Create a list of the phosphosites by selecting all the columns in the dataframe, excluding the last three which are categorical variables
        phos_sites = list(phos_mutations)
        # Take out the categorical variables, which are 'Mutation', 'Patient_Type', and 'Within_Hotspot'
        phos_sites = phos_sites[:(len(phos_sites) - 3)]

        # 6. Create two dataframes to test the two cases: one for phosphorylation levels when PIK3CA is mutated at a hotspot, the other when PIK3CA is mutated outside the hotspot
        #    Drop any columns that contain values of 'Nan' which means for 'Not a number'
        hotspot_mut = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True].dropna(axis = 1)
        wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] != True ].dropna(axis = 1)

        # 7. Loop through each site to test for significant difference in phosphorylation levels between the two tested cases
        for site in phos_sites:

        # 8. Check if the site is in both dataframes. That column may have been deleted in step 4
            if site in hotspot_mut.columns and site in wt.columns:
                
                # 9. Perform a two-sample ttest for mutations in hotspot vs mutations outside of the hotspot and cancer wildtype
                ttest = scipy.stats.ttest_ind(hotspot_mut[site], wt[site])
                
                # 10. Append site name and pvalue in two separate lists that will be used to calculate the pvalue adjustment using Bonferroni correction
                sites.append(site)
                pvalues.append(ttest[1])
    #Error caught in the case that the protein had no data in the phosproteomics data
    except:
        print('')
        
        
# 11. After looping through all of the phosphorylation sites of each protein, filter the list of pvalues with respective sites to find those with significant results
#     Create a dictionary to pair the significant sites with their significant pvalues 
#     Create another dictionary for unsignificant results
sigSites = {}
unsigSites = {}

#     The Bonferroni correction is alpha/number of sites tested
alpha = 0.05
pcutoff = alpha/len(sites)

#     Loop through each pvalue to find those that are lower than the pcutoff
for i in range(0, len(sites) - 1):
    if pvalues[i] < pcutoff:
        sigSites[sites[i]] = pvalues[i]
    else:
        unsigSites[sites[i]] = pvalues[i]

# 12. Print your results
print('SIGNIFICANT RESULTS:')
print(json.dumps(sigSites, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigSites, indent = 2))
# Out:
# Gene MRAS not found in phosphoproteomics data
#
# Gene HRAS not found in phosphoproteomics data
#
# Gene P85A not found in phosphoproteomics data
#
# Gene P55G not found in phosphoproteomics data
#
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1-S1005": 0.1538874422084835,
#   "IRS1-S270": 0.273498035871859,
#   "IRS1-S527": 0.6576950639533548,
#   "IRS2-S1100": 0.7932403796403827,
#   "IRS2-S365": 0.2190537914574149,
#   "RRAS2-S186": 0.06560223604200595,
#   "PTEN-S467": 0.5573473385330219,
#   "AKT1-S126": 0.7527767230674126,
#   "AKT1-S129": 0.6225282061459592,
#   "AKT1S1-S222": 0.40990754364672066,
#   "AKT1S1-S223": 0.5472780915404707,
#   "AKT1S1-S232": 0.890724203697261,
#   "LAMTOR1-S27": 0.8062980865678622,
#   "RPS6KA1-S372": 0.10432653425215277,
#   "RPS6KA3-S369": 0.44692002190398494,
#   "RPS6KA3-S415": 0.4922566425312921,
#   "RPS6KA3-T365": 0.5308755964582641,
#   "RPS6KA4-S343": 0.50715754989591,
#   "RPS6KA4-S347": 0.4913203854756516,
#   "RPS6KA4-S682": 0.12699833922172207,
#   "RPS6KA4-S745": 0.5186282931858306,
#   "RPS6KC1-S423": 0.004588149271431776,
#   "RPS6KC1-S667": 0.5232936781331718,
#   "MAPK1-Y187": 0.8677251063910387,
#   "MAPK14-Y182": 0.9778508055313739,
#   "MAPK3-Y204": 0.7530383051291035,
#   "MAPKAP1-S510": 0.745676335806206,
#   "MAPKAPK5-S212": 0.8845516379019593
# }

# %% [markdown]
# ### We can conclude from these results that PIK3CA mutation, neither hotspot no non-hotspot mutations, do not have a significant effect on the proteomics or phosproteomics of its interacting proteins
