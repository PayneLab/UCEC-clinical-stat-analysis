# %% [markdown]
# # PIK3CA: Effects of Hotspot Mutation on IRS2

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.stats.multitest

# %% [markdown]
# ### Import CPTAC

# %%
import CPTAC
# Out:
# Loading CPTAC data:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter CPTAC.embargo() to open the webpage for more details.

# %%
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %%
protein = 'IRS2'
gene = 'PIK3CA'

# %% [markdown]
# ## Extract the data for hotspot mutations only

# %%
#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.E545A', 'p.E545K', 'p.E545V', 'p.Q546P', 'p.Q546R', 'p.E542K']
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

# %%
p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
#print(p10_mutations)
p10_mutations['Within_Hotspot'] = False
p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)
print(len(p10_mutations.loc[(p10_mutations['Within_Hotspot'] == True)]))
# Out:
# 19

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
out_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == False]
ttest = scipy.stats.ttest_ind(in_hotspot[protein], out_hotspot[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.695495833763455, pvalue=0.09674094347736001)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] != True]
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-2.2680315646598452, pvalue=0.02552212534819076)

# %% [markdown]
# ## All mutations vs wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] != 'Wildtype']
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.8301221925077833, pvalue=0.07027134773500125)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-2.262563451390232, pvalue=0.026813917170244287)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on PIK3CA abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %% [markdown]
# # Phosphoproteomic Abundance

# %%
phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
phos_mutations['Within_Hotspot'] = False
phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True

phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
print(phos_mutations)


phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
#phos_mutations = phos_mutations.dropna(axis = 0)
#print(phos_mutations)
phos_sites = list(phos_mutations)
phos_sites = phos_sites[:(len(phos_sites) - 3)]
# Out:
#       IRS2-S1100  IRS2-S1148  IRS2-S1149  IRS2-S1162  IRS2-S1174  IRS2-S1176  \
# S001     -1.0000         NaN         NaN         NaN         NaN         NaN
# S002     -0.8950         NaN         NaN         NaN    -0.48700         NaN
# S003     -0.4790         NaN         NaN         NaN         NaN         NaN
# S004      0.8430         NaN         NaN         NaN     0.12000         NaN
# S005     -2.2600         NaN         NaN         NaN         NaN         NaN
# S006      0.4950         NaN         NaN         NaN         NaN    -0.23200
# S007     -0.0540         NaN         NaN         NaN    -0.28700         NaN
# S008     -0.8250         NaN      -0.391     -0.4085    -0.56200    -0.29300
# S009      0.5750         NaN         NaN         NaN     0.44300         NaN
# S010      0.8300         NaN         NaN         NaN         NaN    -0.03060
# S011     -0.3870         NaN         NaN         NaN         NaN         NaN
# S012     -1.0200         NaN      -0.812     -0.4316    -0.89400    -0.40100
# S013     -0.0259         NaN         NaN         NaN     2.12000     0.39600
# S014      1.2200         NaN         NaN         NaN     0.37000    -0.28600
# S015      0.4590         NaN         NaN         NaN     0.16500         NaN
# S016      1.8800         NaN         NaN         NaN     0.24100         NaN
# S017     -1.5900         NaN         NaN         NaN         NaN         NaN
# S018     -0.3880         NaN         NaN         NaN         NaN         NaN
# S019     -0.8260         NaN         NaN         NaN     0.20700    -0.03450
# S020     -0.6550         NaN         NaN         NaN         NaN         NaN
# S021     -0.4550         NaN         NaN         NaN    -0.81300         NaN
# S009         NaN         NaN     0.30900         NaN       ...
# S010         NaN         NaN    -0.16900      -0.150       ...
# S011         NaN         NaN         NaN         NaN       ...
# S012       -5.02     0.20200    -0.04900         NaN       ...
# S013         NaN     0.44750     0.74100         NaN       ...
# S014         NaN     0.43030     0.05445         NaN       ...
# S015         NaN         NaN     0.26600         NaN       ...
# S016         NaN         NaN         NaN         NaN       ...
# S017         NaN         NaN         NaN         NaN       ...
# S018         NaN    -0.48600    -0.03540         NaN       ...
# S019         NaN    -0.66650    -0.16750         NaN       ...
# S020         NaN    -0.82000    -2.64000         NaN       ...
# S021         NaN         NaN    -1.11000         NaN       ...
# S022         NaN     0.48500    -0.61750         NaN       ...
# S023         NaN    -0.14300    -0.85650         NaN       ...
# S024         NaN         NaN         NaN         NaN       ...
# S025         NaN         NaN         NaN         NaN       ...
# S026         NaN    -0.90200    -0.22000         NaN       ...
# S027         NaN         NaN         NaN         NaN       ...
# S028         NaN         NaN     0.58700         NaN       ...
# S029         NaN         NaN         NaN         NaN       ...
# S030         NaN    -0.63005    -0.67855         NaN       ...
# ...          ...         ...         ...         ...       ...
# S124         NaN     1.49000     1.53000         NaN       ...
# S125         NaN         NaN         NaN         NaN       ...
# S126         NaN     0.73100     0.58350         NaN       ...
# S127         NaN     1.17000         NaN         NaN       ...
# S128         NaN     0.37300     0.40250         NaN       ...
# S129         NaN     1.15500     0.82750         NaN       ...
# S130         NaN         NaN     0.35000         NaN       ...
# S131         NaN         NaN         NaN         NaN       ...
# S132         NaN         NaN         NaN         NaN       ...
# S133         NaN         NaN     0.56700         NaN       ...
# S134         NaN         NaN         NaN         NaN       ...
# S135         NaN         NaN         NaN         NaN       ...
# S136         NaN    -0.35100     0.14550         NaN       ...
# S137         NaN     1.32550     1.28050         NaN       ...
# S138         NaN         NaN    -0.32700      -0.394       ...
# S139         NaN         NaN    -0.28000      -0.561       ...
# S140        1.01     0.45400     0.44500         NaN       ...
# S141        3.41     1.92000     1.61000         NaN       ...
# S142        1.94     0.74800     0.71550         NaN       ...
# S143         NaN     1.03550     0.14950         NaN       ...
# S144         NaN     1.91500     0.71635         NaN       ...
# S145         NaN     0.08500     0.65100         NaN       ...
# S146         NaN    -0.45200    -0.41100         NaN       ...
# S147         NaN     0.00000     0.07950         NaN       ...
# S148         NaN    -0.18000    -0.33000         NaN       ...
# S149         NaN    -0.16700     0.37900         NaN       ...
# S150         NaN     0.02840     0.05650         NaN       ...
# S151         NaN     1.88000     1.64000         NaN       ...
# S152         NaN     1.96000     1.39000         NaN       ...
# S153         NaN    -0.19000    -0.05470         NaN       ...
#
#       IRS2-T776  IRS2-T779  IRS2-T962  IRS2-Y653  IRS2-Y675  IRS2-Y823  \
# S001        NaN        NaN        NaN        NaN    -1.2600        NaN
# S002    -0.1490        NaN  -0.120000   -0.13100        NaN        NaN
# S003        NaN        NaN        NaN        NaN        NaN        NaN
# S146    -0.2480    -0.2480   0.395000   -0.41700     0.3810    -0.0621
# S147     0.0000     0.0000  -0.914000    0.11900    -0.2250    -0.2320
# S148    -0.3080    -0.3080   0.374000   -0.54600     0.1970    -0.6750
# S149    -0.3570    -0.3570   0.195000   -0.20200     1.3400    -0.0160
# S150    -0.2270    -0.2270  -0.000523   -0.00215     1.5000     0.0155
# S151     1.7400     1.7400  -0.019400    0.70600     1.8800     0.4520
# S152     0.3700     0.3700  -0.139000    0.09990    -0.0124     0.0399
# S153     0.0132     0.0132  -0.530000   -0.01910     1.2500     0.1110
#
#       IRS2-Y919           Mutation  Patient_Type  Within_Hotspot
# S001     0.2600  Missense_Mutation         Tumor            True
# S002    -1.2500           Wildtype         Tumor        Wildtype
# S003        NaN  Missense_Mutation         Tumor            True
# S004        NaN           Wildtype         Tumor        Wildtype
# S005        NaN           Wildtype         Tumor        Wildtype
# S006        NaN           Wildtype         Tumor        Wildtype
# S007    -0.4470           Wildtype         Tumor        Wildtype
# S008        NaN           Wildtype         Tumor        Wildtype
# S009        NaN  Missense_Mutation         Tumor            True
# S010        NaN  Missense_Mutation         Tumor           False
# S011        NaN           Wildtype         Tumor        Wildtype
# S012        NaN  Missense_Mutation         Tumor           False
# S013        NaN           Wildtype         Tumor        Wildtype
# S014        NaN  Missense_Mutation         Tumor           False
# S015        NaN           Wildtype         Tumor        Wildtype
# S016        NaN           Wildtype         Tumor        Wildtype
# S017        NaN           Wildtype         Tumor        Wildtype
# S018    -0.0972  Missense_Mutation         Tumor           False
# S019        NaN           Wildtype         Tumor        Wildtype
# S020     0.2350           Wildtype         Tumor        Wildtype
# S021        NaN  Missense_Mutation         Tumor            True
# S022        NaN  Missense_Mutation         Tumor           False
# S023        NaN  Missense_Mutation         Tumor            True
# S024        NaN  Missense_Mutation         Tumor            True
# S025        NaN           Wildtype         Tumor        Wildtype
# S026    -1.1900  Missense_Mutation         Tumor           False
# S027        NaN  Missense_Mutation         Tumor           False
# S028        NaN  Missense_Mutation         Tumor           False
# S029        NaN           Wildtype         Tumor        Wildtype
# S030     0.1900  Missense_Mutation         Tumor           False
# ...         ...                ...           ...             ...
# S124    -0.5200           Wildtype        Normal        Wildtype
# S125        NaN           Wildtype        Normal        Wildtype
# S126        NaN           Wildtype        Normal        Wildtype
# S127        NaN           Wildtype        Normal        Wildtype
# S128        NaN           Wildtype        Normal        Wildtype
# S129        NaN           Wildtype        Normal        Wildtype
# S130        NaN           Wildtype        Normal        Wildtype
# S131        NaN           Wildtype        Normal        Wildtype
# S132        NaN           Wildtype        Normal        Wildtype
# S133        NaN           Wildtype        Normal        Wildtype
# S134        NaN           Wildtype        Normal        Wildtype
# S135        NaN           Wildtype        Normal        Wildtype
# S136        NaN           Wildtype        Normal        Wildtype
# S137        NaN           Wildtype        Normal        Wildtype
# S138        NaN           Wildtype        Normal        Wildtype
# S139        NaN           Wildtype        Normal        Wildtype
# S140        NaN           Wildtype        Normal        Wildtype
# S141        NaN           Wildtype        Normal        Wildtype
# S142        NaN           Wildtype        Normal        Wildtype
# S143    -0.0829           Wildtype        Normal        Wildtype
# S144     0.0829           Wildtype        Normal        Wildtype
# S145        NaN           Wildtype        Normal        Wildtype
# S146        NaN           Wildtype        Normal        Wildtype
# S147        NaN           Wildtype        Normal        Wildtype
# S148        NaN           Wildtype        Normal        Wildtype
# S149        NaN           Wildtype        Normal        Wildtype
# S150        NaN           Wildtype        Normal        Wildtype
# S151        NaN           Wildtype        Normal        Wildtype
# S152        NaN           Wildtype        Normal        Wildtype
# S153        NaN           Wildtype        Normal        Wildtype
#
# [153 rows x 68 columns]

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
p_values = []
site_names = []

for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == False]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    p_values.append(ttest[1])
    site_names.append(site)  
    
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvalues = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))


print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# []
# []
# {}
# /Users/emilyhosk/anaconda3/envs/research/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3157: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /Users/emilyhosk/anaconda3/envs/research/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/emilyhosk/anaconda3/envs/research/lib/python3.7/site-packages/statsmodels/stats/multitest.py:320: RuntimeWarning: invalid value encountered in less_equal
#   reject = pvals_sorted <= ecdffactor*alpha

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
p_values = []
site_names = []


for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] != True]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    p_values.append(ttest[1])
    site_names.append(site)  
    
    
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvalues = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))
    
print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# []
# []
# {}

# %% [markdown]
# ## All mutations vs wildtype

# %%
p_values = []
site_names = []

for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] != 'Wildtype']
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    p_values.append(ttest[1])
    site_names.append(site) 

    
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvalues = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))
    
print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# []
# []
# {}

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
p_values = []
site_names = []


for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    p_values.append(ttest[1])
    site_names.append(site) 
    
    
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvalues = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))
    
print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# []
# []
# {}

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S560', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S560', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on IRS2 phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S391', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S391', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on IRS2 phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()
