# %% [markdown]
# # PIK3R1 Effects of Mutation on IRS1

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.stats.multitest

# %%
import CPTAC
# Out:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter CPTAC.embargo() to open the webpage for more details.

# %%
somatic_mutations = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

somatic_mutations.loc[(somatic_mutations['Gene'] == "PIK3R1")]
# Out:
#       Patient_Id    Gene           Mutation            Location  \
# 2504   C3L-01282  PIK3R1  Missense_Mutation             p.K567E
# 3153   C3L-01307  PIK3R1       In_Frame_Del      p.D464_Y467del
# 3848   C3L-01311  PIK3R1  Nonsense_Mutation             p.E345*
# 5496   C3N-00322  PIK3R1    Frame_Shift_Ins                 NaN
# 5806   C3N-00389  PIK3R1       In_Frame_Del      p.V445_Y452del
# 6247   C3N-00734  PIK3R1       In_Frame_Del           p.I381del
# 6397   C3N-00850  PIK3R1    Frame_Shift_Ins             p.V662*
# 6703   C3N-00858  PIK3R1       In_Frame_Del      p.R577_Q579del
# 19723  C3L-00601  PIK3R1  Nonsense_Mutation             p.R348*
# 22095  C3L-00780  PIK3R1    Frame_Shift_Ins        p.R577Kfs*25
# 22731  C3L-01246  PIK3R1  Missense_Mutation             p.L570R
# 22732  C3L-01246  PIK3R1  Missense_Mutation             p.L573R
# 22891  C3L-01257  PIK3R1    Frame_Shift_Del        p.D578Pfs*23
# 23236  C3L-01312  PIK3R1       In_Frame_Del      p.N441_I442del
# 23682  C3N-00335  PIK3R1  Missense_Mutation             p.K567E
# 24433  C3N-00339  PIK3R1       In_Frame_Del           p.L404del
# 24479  C3N-00729  PIK3R1       In_Frame_Del      p.E462_R465del
# 24616  C3N-00866  PIK3R1    Frame_Shift_Del         p.K379Nfs*2
# 24617  C3N-00866  PIK3R1       In_Frame_Del           p.K459del
# 25264  C3N-01217  PIK3R1  Nonsense_Mutation             p.Y390*
# 25265  C3N-01217  PIK3R1        Splice_Site       p.X577_splice
# 25311  C3L-00090  PIK3R1    Frame_Shift_Ins        p.G588Rfs*14
# 25430  C3L-00145  PIK3R1       In_Frame_Del           p.T576del
# 25637  C3L-00767  PIK3R1       In_Frame_Ins      p.S460_E462dup
# 25963  C3L-00770  PIK3R1  Nonsense_Mutation             p.R348*
# 25964  C3L-00770  PIK3R1  Nonsense_Mutation             p.Y580*
# 26951  C3L-01275  PIK3R1    Frame_Shift_Del        p.D578Pfs*23
# 27923  C3L-01744  PIK3R1  Nonsense_Mutation             p.R386*
# 27924  C3L-01744  PIK3R1  Missense_Mutation             p.A483V
# 35029  C3N-00743  PIK3R1       In_Frame_Del  p.F456_S460delinsC
# 35418  C3N-00880  PIK3R1       In_Frame_Del           p.I405del
# 36448  C3N-01219  PIK3R1    Frame_Shift_Del        p.D578Pfs*23
# 36449  C3N-01219  PIK3R1    Frame_Shift_Del         p.G588Vfs*7
# 37688  C3N-01520  PIK3R1       In_Frame_Del           p.K379del
# 37689  C3N-01520  PIK3R1       In_Frame_Del           p.T576del
# 40307  C3L-00137  PIK3R1    Frame_Shift_Del        p.Q579Vfs*19
# 40308  C3L-00137  PIK3R1    Frame_Shift_Ins         p.L581Ffs*2
# 42142  C3L-00157  PIK3R1    Frame_Shift_Ins         p.Y467Ifs*2
# 43356  C3L-00781  PIK3R1  Missense_Mutation             p.Y452H
# 43357  C3L-00781  PIK3R1  Missense_Mutation             p.K567E
# 53452  C3N-00847  PIK3R1       In_Frame_Ins      p.R574_D578dup
# 53914  C3N-01537  PIK3R1  Nonsense_Mutation             p.E546*
# 53915  C3N-01537  PIK3R1  Missense_Mutation             p.D560Y
#
#       Clinical_Patient_Key
# 2504                  S050
# 3153                  S052
# 3848                  S053
# 5496                  S060
# 5806                  S076
# 6247                  S078
# 6397                  S083
# 6703                  S084
# 19723                 S022
# 22095                 S028
# 22731                 S041
# 22732                 S041
# 22891                 S048
# 23236                 S054
# 23682                 S067
# 24433                 S069
# 24479                 S077
# 24616                 S085
# 24617                 S085
# 25264                 S090
# 25265                 S090
# 25311                 S004
# 25430                 S010
# 25637                 S024
# 25963                 S026
# 25964                 S026
# 26951                 S049
# 27923                 S055
# 27924                 S055
# 35029                 S079
# 35418                 S086
# 36448                 S091
# 36449                 S091
# 37688                 S096
# 37689                 S096
# 40307                 S007
# 40308                 S007
# 42142                 S012
# 43356                 S029
# 43357                 S029
# 53452                 S081
# 53914                 S098
# 53915                 S098

# %% [markdown]
# # PIK3R1 mutation and IRS1 proteome abundance

# %% [markdown]
# #### Take out the control

# %%
proteomics = proteomics[:100]

# %% [markdown]
# ### Perform t-test wiht mutated and non-mutated protein levels

# %%
protList = ['IRS1']
pcutoff = 0.05 / len(protList)
gene = 'PIK3R1'

sigResults = [];
for protein in protList: 
    if protein in proteomics.columns:
        cross = CPTAC.compare_mutations(proteomics, protein, gene)
        cross = cross[["Mutation", protein]].dropna(axis=0)
        mutated = cross.loc[cross["Mutation"] == "Missense_Mutation"]
        wt = cross.loc[cross["Mutation"] == "Wildtype"]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(ttest[1] <= pcutoff):
            sigResults.append(protein)
            print("Test for " + protein + ": ")
            print(ttest)
         
        else:
            print("Unsignificant result for " + protein + ": ")
            print(ttest)
# Out:
# Unsignificant result for IRS1:
# Ttest_indResult(statistic=-0.5985905162139615, pvalue=0.55140604502279)

# %% [markdown]
# ## PIK3R1 mutation and IRS1 phosphoproteom abundance

# %%
sites = phos.columns
p_values = []
site_names = []


phosProtList = ['IRS1']

alpha = 0.05
p_value = alpha/len(phosProtList)



for protein in phosProtList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
        phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis = 1)
        for site in phosphositesdf.columns:
            if (site is not 'Mutation'):
                sitedf = CPTAC.compare_mutations(phos, site, gene)
                mutateddf = sitedf.loc[sitedf['Mutation'] != 'Wildtype'].dropna(axis=0)
                wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
                ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
                p_values.append(ttest[1])
                site_names.append(site)     
                
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvalues = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# ['IRS1-S1100' 'IRS1-S1101' 'IRS1-S270' 'IRS1-S312' 'IRS1-S323' 'IRS1-S337'
#  'IRS1-S348' 'IRS1-S374' 'IRS1-S413' 'IRS1-S415' 'IRS1-S527' 'IRS1-S531'
#  'IRS1-S629' 'IRS1-S636' 'IRS1-S672']
# [1.90133591e-02 8.78660408e-03 4.05325004e-02 2.35991653e-02
#  1.83299171e-02 1.03454960e-02 2.05780109e-04 2.49129562e-04
#  3.66236862e-03 4.89897188e-02 2.49129562e-04 2.49129562e-04
#  2.47805771e-04 7.48026267e-05 4.05325004e-02]
# {'IRS1-S1100': 0.01901335906305013, 'IRS1-S1101': 0.008786604078673517, 'IRS1-S270': 0.04053250041571314, 'IRS1-S312': 0.02359916529164192, 'IRS1-S323': 0.01832991713243185, 'IRS1-S337': 0.010345496014486592, 'IRS1-S348': 0.0002057801085082794, 'IRS1-S374': 0.0002491295615109647, 'IRS1-S413': 0.0036623686223662983, 'IRS1-S415': 0.048989718825997036, 'IRS1-S527': 0.0002491295615109647, 'IRS1-S531': 0.0002491295615109647, 'IRS1-S629': 0.0002478057714934905, 'IRS1-S636': 7.480262674770203e-05, 'IRS1-S672': 0.04053250041571314}

# %%
phosdf = CPTAC.compare_mutations(phos, protein, gene)

phosdf = phosdf.loc[phosdf['Patient_Type'] == 'Tumor']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

boxplt = sns.boxplot(data = phosdf, x = 'Mutation', y = 'IRS1-S1100')
boxplt = sns.stripplot(data = phosdf, x = 'Mutation', y = 'IRS1-S1100', jitter = True, color = '.3')
plt.show()
