# %% [markdown]
# # PIK3CA: Effects of Mutation on IRS1

# %% [markdown]
# <b> Standard imports for playing with and plotting data frames. </b>

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.stats.multitest

# %% [markdown]
# <b> Import CPTAC data </b>

# %%
import CPTAC

# %%
somatic_mutations = CPTAC.get_somatic()
#print(somatic_mutations)


proteomics = CPTAC.get_proteomics()
print(proteomics)


phos = CPTAC.get_phosphoproteomics()
print(phos)
# Out:
# idx     A1BG     A2M    A2ML1  A4GALT      AAAS    AACS    AADAT    AAED1  \
# S001 -1.1800 -0.8630 -0.80200  0.2220  0.256000  0.6650  1.28000 -0.33900
# S002 -0.6850 -1.0700 -0.68400  0.9840  0.135000  0.3340  1.30000  0.13900
# S003 -0.5280 -1.3200  0.43500     NaN -0.240000  1.0400 -0.02130 -0.04790
# S004  2.3500  2.8200 -1.47000     NaN  0.154000  0.0332  0.51300  0.67400
# S005 -1.6700 -1.1900 -0.44300  0.2430 -0.099300  0.7570  0.74000 -0.92900
# S006 -0.3740 -0.0206 -0.53700  0.3110  0.375000  0.0131 -1.10000      NaN
# S007 -1.0800 -0.7080 -0.12600 -0.4260 -0.114000 -0.1110  0.89500  1.26000
# S008 -1.3200 -0.7080 -0.80800 -0.0709  0.138000  0.6560 -0.28000 -0.12800
# S009 -0.4670  0.3700 -0.33900     NaN  0.434000  0.0358 -0.17500  0.18100
# S010 -1.1200 -1.3100  0.91200  0.4180 -0.076800  0.8460 -0.12100      NaN
# S011 -0.7160 -0.8850  2.82000 -0.3430  0.147000  0.4450 -0.05650 -0.83800
# S012 -0.2320 -0.0910  0.61800  1.6300 -0.250000  1.3300 -1.72000 -0.88900
# S013  1.2600  1.5500  0.85900  0.6280 -0.524000  1.0500      NaN -1.34000
# S014 -0.2690  0.0196  1.88000  0.0000  0.173000  0.2370      NaN  0.65200
# S015 -0.2570  0.5140 -0.62000     NaN  0.093600 -0.1410  0.72800 -0.36500
# S016 -0.7820 -0.6970 -1.53000 -1.1300  0.455000 -0.5950 -1.03000 -0.55000
# S017 -1.3400 -1.8700 -0.25800     NaN  0.129000  2.5600  1.03000 -0.39600
# S018 -0.9240 -0.4450  1.57000 -0.6780  0.173000  0.4360  0.22700 -0.00248
# S019  0.1500  0.9870  5.07000  0.3020 -0.169000  0.3980      NaN -0.27400
# S020  0.1810 -0.2830  0.68900  0.1040 -0.130000 -0.0683 -0.37600 -0.08380
# S021 -0.5930  0.4140  1.89000     NaN -0.019000  1.3700  0.02980 -0.10700
# S022 -0.9580 -0.3420      NaN     NaN -0.025900  0.1830  0.10900 -0.08130
# S023 -0.4540 -0.2420      NaN     NaN  0.258000  0.2190 -0.24900 -1.33000
# S024 -0.2400  0.5940  3.40000  0.1540  0.093200  0.2830 -0.07890 -0.61100
# S025 -0.8310 -0.8110 -0.32000  0.2120 -0.057800  0.1680  0.42700 -0.75000
# S026 -0.3270 -0.9530  0.54400 -0.2060 -0.200000  0.4130  0.32000  0.11700
# S027  0.0499  0.0199 -0.12500  0.4770 -0.252000  0.8380 -0.10000 -0.85100
# S028  0.7730  0.5460 -0.60300     NaN  0.055500 -0.6390 -0.39000  0.46700
# S029  0.5510  0.2030      NaN     NaN -0.493000  0.2110  1.06000 -0.28000
# S030 -0.2130  0.2780  1.43000  0.0224  0.451000  0.8730  0.90900  0.68300
# ...      ...     ...      ...     ...       ...     ...      ...      ...
# S124  1.4700  1.0100  0.95400  0.1490  0.167000 -0.7740 -0.19500  0.31400
# S125  0.5260 -0.0539  0.54600     NaN -0.102000  0.0273  0.09420  0.28700
# S126  1.6900  1.3600      NaN     NaN  0.047200 -0.2140  0.14200  1.84000
# S127  2.1400  1.1300  0.00896 -0.0781 -0.004360 -0.6580  0.46800  0.20100
# S128  1.4000  1.8200 -0.05030  1.2200  0.156000 -0.8290 -0.54100 -0.79800
# S129  1.5300  0.2450  0.78500 -0.4910 -0.104000 -0.7910      NaN -0.76200
# S130  1.4300  1.0400 -0.18400     NaN -0.144000 -0.7970 -0.00384  1.08000
# S131  0.6920  1.5600 -0.04860 -0.9520 -0.032100 -0.8340 -0.55400 -0.05310
# S132  0.9160  0.2470 -0.06220 -0.3430 -0.169000 -0.5000  0.05210  0.87400
# S133  1.0600  0.7650 -0.86900     NaN -0.061300 -0.9970 -0.27700  0.30400
# S134  1.4100 -0.1740  0.32800 -0.5010 -0.252000 -0.6720  0.66400  0.91100
# S135  2.1200  2.2100  0.29900     NaN -0.553000 -0.5950 -0.12600  0.55500
# S136  0.7790  0.6810 -0.22700  0.0724 -0.174000 -0.2010      NaN -0.30800
# S137 -0.0812  0.5230 -0.07770 -0.0572  0.019500 -0.2350      NaN -0.10500
# S138  0.5200 -0.5270 -0.16800 -0.3280 -0.182000 -0.9600  0.14400      NaN
# S139  0.7500  0.6030 -0.10800 -0.2400 -0.131000 -0.7720 -0.00473      NaN
# S140 -0.0014  0.6160 -0.64100 -0.2040  0.027600 -1.4100 -0.40500 -0.56100
# S141  0.2980  0.3950 -1.24000 -0.1780 -0.180000 -0.5910 -0.59800  0.40200
# S142  0.1110  0.2100 -0.75100 -0.3350  0.000865 -1.3700 -0.27300  0.10600
# S143  0.9280  0.9520 -1.38000 -0.3450 -0.002170 -0.6570 -0.36300  0.08070
# S144  0.8990  0.1360 -1.63000 -0.4680 -0.293000 -1.1000 -0.71200 -0.26100
# S145  1.6000  0.7600  0.68800     NaN  0.644000 -0.0780 -0.48700  1.39000
# S146  1.3200  0.9540 -0.62800     NaN  1.020000 -0.3050 -0.52300  2.18000
# S147  1.4400  1.7300 -0.22100     NaN  0.275000 -0.2700 -0.44000  2.12000
# S148  1.4600  2.0000 -0.39400     NaN  0.544000 -0.4080 -0.47400  1.77000
# S149  0.6500  0.2270  1.93000     NaN  0.239000 -0.3760 -0.11200  1.54000
# S150  0.4580  0.5200 -0.29100     NaN  0.477000 -0.1510 -0.18700  1.64000
# S151  1.1500  1.4600 -0.02290     NaN  0.252000 -0.2380 -0.59600  1.77000
# S152  0.5470  1.2700 -0.19700     NaN  0.405000  0.2840 -0.14100  1.69000
# S153  0.9400  0.9040 -0.08030     NaN  0.299000 -0.1760 -0.26700  1.31000
#
# idx    AAGAB     AAK1    ...       ZSWIM8   ZSWIM9      ZW10  ZWILCH    ZWINT  \
# S001  0.4120 -0.66400    ...    -0.087700      NaN  0.022900  0.1090      NaN
# S002  1.3300 -0.36700    ...    -0.035600      NaN  0.363000  1.0700  0.73700
# S003  0.4190 -0.50000    ...     0.001120 -0.14500  0.010500 -0.1160      NaN
# S004  0.4310  0.03670    ...    -0.538000 -0.42700  0.092600  1.2800  1.08000
# S005  0.2290 -0.22300    ...     0.072500 -0.05520 -0.071400  0.0933  0.15600
# S006  0.5650 -0.10100    ...    -0.176000      NaN -1.220000 -0.5620  0.93700
# S007  0.1570  0.72300    ...     0.455000      NaN  0.397000 -0.9990 -0.73000
# S008  0.2170 -0.13300    ...     0.015800 -0.00491  0.180000  0.5130  0.54900
# S009  0.1160 -0.05120    ...    -0.675000  0.23900  0.140000  1.0700  0.60700
# S010 -0.3110  0.20700    ...    -0.002120      NaN -1.190000 -1.2700 -1.27000
# S011  0.0490  0.17600    ...     0.084500 -0.64700  0.175000  0.2120 -0.32400
# S012  0.6330 -0.37100    ...     0.065200 -0.23600  0.501000  0.3520  0.08390
# S013  0.0102 -0.50300    ...     0.151000 -0.44600  0.105000  1.3500  1.26000
# S014 -0.2270  0.02510    ...     0.137000 -0.69700  0.393000  0.6180  0.41800
# S015  0.1470  0.39700    ...    -0.186000  0.43800  0.075400  0.4850  0.12600
# S016  0.1510 -0.11900    ...    -0.050400 -0.27500  0.217000  0.6810  0.87100
# S017 -0.0763 -0.47600    ...     0.033000 -0.41900  0.327000  0.1030      NaN
# S018  0.4790 -0.22700    ...    -0.049600      NaN  0.108000 -0.1530      NaN
# S019  1.0900  0.14700    ...     0.348000 -0.48400  0.142000  0.2500 -0.14200
# S020  0.1600  0.27700    ...     0.228000      NaN  0.020600 -0.9700      NaN
# S021 -0.1510 -0.55600    ...    -0.325000 -0.31100  0.332000 -0.4270 -0.49400
# S022  0.4510  0.09430    ...     0.012600      NaN  0.329000  0.3540  0.32200
# S023  0.2040 -0.00493    ...    -0.158000      NaN  0.667000  1.3000  0.44100
# S024  0.3700 -0.50200    ...    -0.051100 -0.01360  0.214000  0.6830  0.43300
# S025  0.1760 -0.01930    ...     0.000388  0.18400  0.086800  0.1440 -0.13700
# S026  0.1430  0.12300    ...     0.147000      NaN  0.226000 -0.2850      NaN
# S027  0.3510 -0.58200    ...     0.049100 -0.47900  0.054800  0.9330  0.00967
# S028 -0.3660  0.42700    ...    -0.008350  0.11900 -0.296000 -0.2050 -0.07650
# S029  0.2070  0.33400    ...     0.300000      NaN  0.142000 -0.5490      NaN
# S030  0.6210 -0.01070    ...     0.160000      NaN  0.247000  0.8470  0.51600
# ...      ...      ...    ...          ...      ...       ...     ...      ...
# S124 -0.4880  0.23500    ...    -0.065300      NaN -0.343000 -0.2820      NaN
# S125 -0.0535  0.22400    ...    -0.188000  0.30000 -0.273000 -0.4350      NaN
# S126 -0.6850 -0.02710    ...    -0.301000      NaN -0.255000 -0.6150 -0.34900
# S127  0.0183  0.40200    ...    -0.326000  0.87800 -0.213000 -0.2230 -0.15600
# S128 -0.6620  0.09680    ...    -0.271000  0.77800 -0.243000 -1.2600 -0.08230
# S129 -0.0353  0.37900    ...     0.005600  0.80200 -0.554000 -0.9200 -1.18000
# S130 -0.6400  0.27400    ...    -0.418000 -0.39000 -0.438000 -0.7450 -0.29600
# S131 -0.5670  0.14200    ...    -0.285000 -0.06960 -0.471000 -0.8440 -0.57100
# S132 -0.5980  0.18300    ...    -0.287000  0.36400 -0.304000 -0.0876 -0.74600
# S133 -0.6930  0.40100    ...    -0.068100  0.23300 -0.390000 -0.5640 -0.33200
# S134 -0.2150  0.55300    ...     0.015500  0.43100 -0.164000 -0.2760  0.18600
# S135  0.5040  0.32200    ...     0.342000  0.32400 -0.266000 -0.0314 -1.05000
# S136  0.5890 -0.23100    ...    -0.110000  0.35600 -0.034500 -0.2130 -0.27900
# S137  0.3420 -0.00865    ...     0.328000  0.06560  0.030400 -0.5640 -1.17000
# S138 -0.8770  0.17300    ...    -0.212000      NaN -1.430000 -1.0100 -1.41000
# S139 -0.5680 -0.17600    ...    -0.093700      NaN -1.430000 -0.8510 -1.05000
# S140 -0.3730  0.12400    ...     0.215000  0.10700 -0.190000 -1.3600 -1.10000
# S141 -0.3840  0.15200    ...     0.054700  0.19800 -0.013900 -0.8080 -0.32400
# S142 -0.7170  0.00865    ...     0.176000  0.39600 -0.364000 -1.6400 -1.48000
# S143 -0.2000  0.03500    ...    -0.135000      NaN  0.092600 -0.1550  0.15100
# S144 -0.4660  0.23100    ...    -0.009430      NaN -0.349000 -0.5490 -0.46800
# S145 -0.4520  0.18500    ...     0.001340  0.12700 -0.416000 -0.1810  0.22100
# S146 -0.1220 -0.34700    ...    -0.264000  0.26200 -0.000846  0.7470  0.85900
# S147 -0.2300 -0.22900    ...    -0.002700  0.25800 -0.129000  0.6290  0.67300
# S148 -0.1390 -0.27500    ...    -0.161000  0.33800 -0.026700  0.6890  1.03000
# S149 -0.5660 -0.45900    ...    -0.204000  0.02970 -0.151000  0.0552  0.10500
# S150 -0.2680 -0.29300    ...    -0.078200  0.22500  0.141000  0.7260  0.86800
# S151 -0.1130  0.18100    ...     0.122000  0.25500 -0.380000 -0.2970  0.04620
# S152 -0.1700 -0.00718    ...     0.060700 -0.18200 -0.126000 -0.0662 -0.01030
# S153 -0.3890 -0.41900    ...    -0.130000  0.55200  0.023400  0.4250  0.67700
#
# idx      ZXDC   ZYG11B       ZYX     ZZEF1      ZZZ3
# S001 -0.33200 -0.43300 -1.020000 -0.123000 -0.085900
# S002 -0.56400 -0.00461 -1.130000 -0.075700 -0.473000
# S003  0.15100 -0.07400 -0.540000  0.320000 -0.419000
# S004  0.06950  0.30300 -0.325000  0.236000  0.443000
# S005 -0.39800 -0.07520 -0.797000 -0.030100 -0.467000
# S006 -0.64600  0.20700 -1.850000 -0.176000  0.051300
# S007 -0.02290 -0.33100 -1.160000 -0.116000  0.002500
# S008 -0.68100 -0.28500 -0.564000 -0.087600  0.006980
# S009  0.48600  0.16900 -0.632000 -0.203000 -0.068500
# S010 -0.22200 -0.32000 -0.620000  0.363000 -0.463000
# S011 -0.35000 -0.37700  0.388000  0.011000  0.134000
# S012 -0.42800 -0.21200 -1.340000  0.317000 -0.943000
# S013  0.32900  0.16700 -0.771000 -0.112000  2.240000
# S014 -0.20100 -0.06660 -0.808000  0.026100 -0.285000
# S015  0.77000  0.11000 -0.925000 -0.343000 -0.500000
# S016  0.23900 -0.25900 -0.874000 -0.560000  0.248000
# S017  0.63800 -0.51400 -1.420000  0.218000 -0.061100
# S018  0.10900 -0.33600 -0.822000 -0.033800  0.121000
# S019  0.07700 -0.15700 -0.872000 -0.006630 -0.017500
# S020 -0.45200  0.17200  0.626000  0.342000 -0.203000
# S021 -0.11400 -0.44200 -1.550000 -0.251000  0.193000
# S022 -0.02850 -0.14200 -0.645000  0.245000  0.044700
# S023  0.13000 -0.06590 -0.923000 -0.163000  0.112000
# S024 -0.20800 -0.34700 -0.911000  0.069200 -0.232000
# S025 -0.41800 -0.18300 -0.769000 -0.256000 -0.372000
# S026  0.11100  0.08500  0.676000 -0.004570 -0.022900
# S027 -1.14000 -0.54100 -0.838000  0.023800 -0.060200
# S028  0.22800  0.23700  1.050000  0.018500  0.587000
# S029 -0.39000 -0.09720  0.001080  0.200000 -0.194000
# S030 -0.41200 -0.08090 -0.221000 -0.004300  1.560000
# ...       ...      ...       ...       ...       ...
# S124  0.36300  0.23900  1.500000 -0.177000  0.209000
# S125 -0.29000  0.01840  1.670000 -0.280000  0.203000
# S126 -0.08570  0.24800  0.407000  0.185000  0.229000
# S127 -1.03000  0.09500  0.608000 -0.104000  0.139000
# S128  1.02000  0.16600  0.876000 -0.068800  0.390000
# S129  0.42000  0.34100  1.730000 -0.151000  0.224000
# S130  0.40000  0.11400  0.649000 -0.231000  1.000000
# S131  0.27500  0.09570  1.300000 -0.060400  0.162000
# S132  0.32600  0.25000  1.580000  0.110000  0.583000
# S133  0.00086  0.14800  1.040000  0.025400  0.625000
# S134  0.47100  0.44500  2.090000  0.216000  0.165000
# S135  0.12600  0.45600  1.770000  0.120000  0.210000
# S136  0.22200 -0.10400  0.336000 -0.000242 -0.002880
# S137 -0.13500 -0.25500  0.653000  0.210000 -0.173000
# S138  0.40800  0.02600  0.858000 -0.117000  0.131000
# S139  0.13100  0.02870  0.365000 -0.033900  0.254000
# S140 -0.19700 -0.30700  0.682000  0.098400 -0.020200
# S141  0.16300 -0.14500  0.855000  0.116000 -0.000114
# S142  0.45300 -0.16800  0.411000 -0.176000  0.218000
# S143 -0.00177  0.05320  0.850000  0.044400  0.001660
# S144 -0.15400  0.10800  1.730000  0.167000 -0.059000
# S145  0.55400 -0.41700  0.955000  0.033400 -0.013400
# S146  1.49000 -0.62300 -0.000941 -0.164000 -0.004900
# S147  1.90000 -0.42800  0.191000  0.049300 -0.104000
# S148  1.00000 -0.38600  0.035800 -0.142000 -0.083200
# S149  1.33000 -0.67400 -0.840000 -0.269000  0.103000
# S150  0.66200 -0.57000 -0.399000 -0.095900 -0.063500
# S151  0.04500 -0.31900  0.835000  0.169000 -0.008090
# S152  1.05000 -0.35600  0.416000  0.273000 -0.658000
# S153  0.58700 -0.47700 -0.422000 -0.093100  0.055700
#
# [153 rows x 10999 columns]
# idx   AAAS-S495  AAAS-S541  AAAS-Y485  AACS-S618  AAED1-S12  AAGAB-S310  \
# S001        NaN        NaN        NaN    -0.8810    -1.8100         NaN
# S002        NaN        NaN        NaN        NaN     0.0840         NaN
# S003   -0.20200        NaN        NaN        NaN    -1.8800         NaN
# S004    0.25000        NaN        NaN        NaN        NaN         NaN
# S005   -0.00200        NaN     -0.407        NaN        NaN         NaN
# S006    0.55600    -0.0461        NaN        NaN     0.9410         NaN
# S007        NaN        NaN        NaN        NaN     0.0796         NaN
# S008    0.30000        NaN        NaN    -0.3710    -1.1400         NaN
# S009    0.49000        NaN        NaN        NaN        NaN         NaN
# S010   -0.23100     0.0108        NaN        NaN     0.2420         NaN
# S011    0.26800        NaN        NaN        NaN    -0.1120         NaN
# S012   -0.06200        NaN        NaN     1.8600    -1.4000         NaN
# S013   -1.49000        NaN        NaN        NaN    -2.5900         NaN
# S014    0.65400        NaN        NaN        NaN    -0.8780         NaN
# S015    1.05000        NaN        NaN        NaN        NaN         NaN
# S016    1.48000        NaN        NaN        NaN        NaN         NaN
# S017    0.78900        NaN        NaN        NaN    -1.8500         NaN
# S018        NaN        NaN        NaN     0.8440     0.2790         NaN
# S019    0.15000        NaN        NaN        NaN    -0.3490         NaN
# S020        NaN        NaN        NaN    -0.0311     0.8050         NaN
# S021    0.46600        NaN        NaN        NaN        NaN         NaN
# S022    0.62700        NaN        NaN     1.4000     0.6020       0.109
# S023    0.59400        NaN        NaN     0.0000    -0.9820      -0.276
# S024   -0.16200        NaN      0.140        NaN        NaN         NaN
# S025    0.02400        NaN     -0.160        NaN        NaN         NaN
# S026        NaN        NaN        NaN     0.2500    -0.7790         NaN
# S027   -0.76900        NaN        NaN        NaN    -0.5320         NaN
# S028   -0.01320        NaN        NaN        NaN        NaN         NaN
# S029   -0.95700        NaN        NaN        NaN     0.2720         NaN
# S030        NaN        NaN        NaN        NaN    -0.5100         NaN
# ...         ...        ...        ...        ...        ...         ...
# S124        NaN        NaN        NaN    -0.6000     0.0738         NaN
# S125   -0.27900        NaN        NaN        NaN    -1.5700         NaN
# S126   -0.27000        NaN        NaN    -1.9800     0.0638      -0.397
# S127   -0.34400        NaN        NaN        NaN    -0.9230         NaN
# S128   -0.17000        NaN        NaN        NaN     0.5470         NaN
# S129    0.00143        NaN        NaN        NaN     0.0314         NaN
# S130   -0.30700        NaN        NaN        NaN        NaN         NaN
# S131   -0.06095        NaN     -1.270        NaN        NaN         NaN
# S132   -0.52200        NaN        NaN        NaN    -0.2160         NaN
# S133   -0.15300        NaN        NaN        NaN        NaN         NaN
# S134   -0.45100        NaN        NaN        NaN    -0.3900         NaN
# S135   -1.43000        NaN        NaN        NaN        NaN         NaN
# S136   -0.57700        NaN        NaN        NaN     0.8600         NaN
# S137   -0.77700        NaN        NaN        NaN     0.4510         NaN
# S138   -0.23800     0.0178        NaN        NaN     0.6310         NaN
# S139    0.04210    -0.1220        NaN        NaN     0.2010         NaN
# S140   -0.06860        NaN        NaN     0.0516     0.3260         NaN
# S141   -0.77300        NaN        NaN     0.1650    -0.0185         NaN
# S142   -0.67600        NaN        NaN    -0.2760    -0.4930         NaN
# S143        NaN        NaN        NaN        NaN     0.3950         NaN
# S144        NaN        NaN        NaN        NaN     0.5940         NaN
# S145   -0.51000     0.0681        NaN        NaN     1.2000         NaN
# S146    0.21500    -0.3010        NaN        NaN     0.7370         NaN
# S147   -0.35900    -0.1910        NaN        NaN     0.1720         NaN
# S148    0.06060    -0.1870        NaN        NaN     1.0400         NaN
# S149   -0.27200    -0.1910        NaN        NaN     0.6310         NaN
# S150    0.22300    -0.5170        NaN        NaN     0.5220         NaN
# S151   -0.39400    -0.0108        NaN        NaN     1.0600         NaN
# S152    0.14900     0.2560        NaN        NaN     0.9510         NaN
# S153    0.07740    -0.1580        NaN        NaN    -0.3430         NaN
#
# idx   AAGAB-S311  AAK1-S14  AAK1-S18  AAK1-S20    ...      ZZZ3-S397  \
# S001         NaN       NaN -0.242000  -0.24200    ...       0.184000
# S002         NaN  -1.11000 -0.383000  -1.09000    ...      -0.171000
# S003         NaN       NaN  0.382000  -0.04160    ...            NaN
# S004         NaN       NaN  0.634000   0.41840    ...       1.066000
# S005         NaN       NaN       NaN  -0.55500    ...       0.139700
# S006     0.42900   0.36200  0.697000  -0.05290    ...      -0.158750
# S007         NaN  -1.09000 -0.090000  -0.47500    ...       0.104000
# S008    -0.04130  -0.89900 -0.444000  -1.03000    ...      -0.165000
# S009         NaN       NaN  0.398000   0.36500    ...       0.591850
# S010    -0.71000  -0.25495 -0.398000  -0.17500    ...      -0.491500
# S011         NaN       NaN  0.444000   0.08950    ...      -0.366000
# S012     1.30000   0.16100  0.292000  -0.18800    ...      -0.423000
# S013         NaN   0.96600  0.895000   0.31800    ...      -0.780000
# S014         NaN  -0.73200 -0.423500  -0.33600    ...       0.036200
# S015         NaN       NaN -0.272000   0.02850    ...       0.819050
# S016         NaN       NaN       NaN   0.90600    ...       1.350000
# S017         NaN       NaN -0.715000  -0.83600    ...            NaN
# S018         NaN       NaN -0.355000   0.13400    ...       0.080500
# S019         NaN  -0.26000 -0.383000  -0.13100    ...       0.199000
# S020         NaN       NaN  0.578000   0.21100    ...      -0.221500
# S021         NaN       NaN -0.098000   0.07750    ...       0.809850
# S022         NaN       NaN -0.379000  -0.64700    ...       0.200500
# S023         NaN       NaN -0.109000  -0.46400    ...       0.134000
# S024         NaN       NaN       NaN  -0.83150    ...       0.189000
# S025         NaN       NaN       NaN  -0.03192    ...       0.483500
# S026         NaN       NaN -0.098200   0.32100    ...       0.166500
# S027         NaN       NaN  0.410000  -0.15000    ...      -0.058400
# S028         NaN       NaN  0.053100   0.35500    ...       0.247000
# S029         NaN       NaN -0.077000   0.29700    ...      -0.264000
# S030         NaN  -1.94000  0.125500  -0.89300    ...       0.303000
# ...          ...       ...       ...       ...    ...            ...
# S124         NaN       NaN -0.343000  -0.29100    ...      -0.285535
# S125         NaN       NaN -0.327000  -0.38600    ...            NaN
# S126         NaN       NaN  0.000153  -0.54200    ...      -0.773500
# S127         NaN       NaN -0.587000  -1.07000    ...      -0.663000
# S128         NaN       NaN -0.482000   0.02300    ...      -0.592000
# S129         NaN   0.41800  0.391500   1.00000    ...       0.315000
# S130         NaN       NaN  0.336000  -0.34550    ...       0.285500
# S131         NaN       NaN       NaN  -0.19800    ...      -0.171300
# S132         NaN       NaN -0.579000   0.24900    ...      -0.305000
# S133         NaN       NaN -0.651000   0.41250    ...       0.630500
# S134         NaN       NaN  0.529000   0.52500    ...      -0.692000
# S135         NaN   0.28700 -0.343000   0.26000    ...       0.097000
# S136         NaN   0.47600  0.909000   0.49500    ...       0.427000
# S137         NaN   0.00000  0.050050   0.02680    ...      -0.558000
# S138    -1.04000   0.13950 -0.182000   0.23800    ...      -0.133300
# S139    -0.64000  -0.50350 -0.460500  -0.83300    ...      -0.424000
# S140    -1.22000  -0.26900  0.193000   0.01430    ...      -0.374000
# S141    -0.44300   0.71600  0.318000   0.78000    ...      -0.298000
# S142    -0.59200  -0.11900 -0.141000   0.07670    ...       0.032600
# S143         NaN   0.25300  0.624000  -0.06630    ...      -0.009930
# S144         NaN   0.99400  1.038500   0.88300    ...      -0.255000
# S145    -0.29000       NaN -0.276000   0.00150    ...       0.135300
# S146     0.45200       NaN  0.161000  -0.00150    ...       0.277000
# S147     0.47900       NaN -0.027100   0.26200    ...       0.363700
# S148     0.48900       NaN  0.591000  -0.23400    ...      -0.065000
# S149     0.00947       NaN -0.466000   0.00761    ...       0.347000
# S150     0.03120       NaN  0.473000  -0.19000    ...       0.249000
# S151    -0.77300       NaN -0.290000   0.51900    ...       0.438500
# S152    -0.17500       NaN -0.270000   0.44500    ...      -0.093050
# S153     0.30200       NaN  0.193000   0.07340    ...       0.085450
#
# idx   ZZZ3-S411  ZZZ3-S420  ZZZ3-S424  ZZZ3-S426  ZZZ3-S468  ZZZ3-S89  \
# S001        NaN        NaN        NaN   -0.20500        NaN       NaN
# S002        NaN        NaN    -0.3930   -0.17100        NaN    0.2900
# S003        NaN        NaN        NaN        NaN        NaN       NaN
# S004        NaN        NaN        NaN    0.32400        NaN       NaN
# S005        NaN        NaN        NaN   -0.55900        NaN       NaN
# S006        NaN        NaN     0.1960    0.06175        NaN       NaN
# S007        NaN        NaN     0.0600    0.02640        NaN   -0.0895
# S008        NaN        NaN        NaN   -0.16500        NaN       NaN
# S009        NaN        NaN        NaN    0.21785        NaN       NaN
# S010        NaN        NaN    -0.3020   -0.43400        NaN       NaN
# S011        NaN        NaN        NaN        NaN        NaN       NaN
# S012        NaN        NaN        NaN   -0.42300        NaN       NaN
# S013        NaN   -2.61000        NaN   -0.24700        NaN       NaN
# S014        NaN    0.03620        NaN    0.33300        NaN       NaN
# S015        NaN        NaN        NaN    0.39005        NaN       NaN
# S016     0.3640    1.35000        NaN    0.06600        NaN       NaN
# S017        NaN        NaN        NaN        NaN        NaN       NaN
# S018        NaN        NaN        NaN   -0.10900        NaN       NaN
# S019        NaN   -0.50500        NaN    0.26100        NaN       NaN
# S020        NaN        NaN        NaN   -0.54500        NaN       NaN
# S021        NaN        NaN        NaN    0.42435        NaN       NaN
# S022        NaN        NaN     0.2710    0.27100        NaN       NaN
# S023        NaN        NaN     0.3200    0.32000        NaN       NaN
# S024        NaN        NaN        NaN    0.38600        NaN       NaN
# S025        NaN        NaN        NaN    0.05310        NaN       NaN
# S026        NaN        NaN        NaN   -0.25300        NaN       NaN
# S027        NaN        NaN        NaN        NaN        NaN       NaN
# S028        NaN        NaN        NaN    0.19150        NaN       NaN
# S029        NaN    0.00287    -1.1200   -1.12000        NaN       NaN
# S030        NaN        NaN    -0.8970    0.14400        NaN   -0.8340
# ...         ...        ...        ...        ...        ...       ...
# S124        NaN        NaN        NaN   -0.58100        NaN       NaN
# S125        NaN        NaN        NaN        NaN        NaN       NaN
# S126        NaN        NaN    -1.6200   -1.34000        NaN       NaN
# S127        NaN        NaN        NaN   -0.66300        NaN       NaN
# S128        NaN        NaN     0.6040    0.29300        NaN       NaN
# S129        NaN   -0.24100        NaN    0.58500        NaN       NaN
# S130        NaN        NaN        NaN    0.14950        NaN       NaN
# S131        NaN        NaN        NaN    0.16400        NaN       NaN
# S132        NaN        NaN        NaN        NaN        NaN       NaN
# S133        NaN        NaN        NaN    0.25100        NaN       NaN
# S134        NaN        NaN        NaN        NaN        NaN       NaN
# S135        NaN        NaN        NaN    0.09700        NaN       NaN
# S136        NaN   -0.51500        NaN    0.42700        NaN       NaN
# S137        NaN   -0.55800        NaN    1.03000        NaN       NaN
# S138        NaN        NaN    -0.0636   -0.05550        NaN       NaN
# S139        NaN        NaN     0.1180   -0.11450        NaN       NaN
# S140        NaN        NaN        NaN   -0.12700        NaN       NaN
# S141        NaN        NaN        NaN   -0.29800        NaN       NaN
# S142        NaN        NaN        NaN   -0.25000        NaN       NaN
# S143        NaN        NaN    -0.2540   -0.23400        NaN    0.0149
# S144        NaN        NaN     0.0158   -0.10700        NaN    0.1090
# S145     0.3710        NaN        NaN   -0.15870        NaN       NaN
# S146     0.3250        NaN        NaN    0.16085        NaN       NaN
# S147    -0.1200        NaN        NaN    0.26100        NaN       NaN
# S148    -0.4130        NaN        NaN   -0.13200        NaN       NaN
# S149     0.0000        NaN        NaN   -0.05100        NaN       NaN
# S150     0.1790        NaN        NaN   -0.03150        NaN       NaN
# S151    -0.1220        NaN        NaN    0.24050        NaN       NaN
# S152    -0.3540        NaN        NaN   -0.01490        NaN       NaN
# S153     0.0216        NaN        NaN   -0.06500        NaN       NaN
#
# idx   ZZZ3-T415  ZZZ3-T418  ZZZ3-Y399
# S001        NaN        NaN        NaN
# S002        NaN     0.1605   -0.06350
# S003        NaN        NaN        NaN
# S004        NaN        NaN        NaN
# S005        NaN        NaN    0.29800
# S006        NaN        NaN   -0.29000
# S007        NaN    -0.1335   -0.13350
# S008  -0.027500        NaN   -0.11600
# S009        NaN        NaN        NaN
# S010        NaN        NaN   -0.64300
# S011        NaN        NaN        NaN
# S012  -0.218000        NaN   -0.50400
# S013        NaN        NaN        NaN
# S014        NaN        NaN        NaN
# S015        NaN        NaN        NaN
# S016        NaN        NaN        NaN
# S017        NaN        NaN        NaN
# S018        NaN        NaN        NaN
# S019        NaN        NaN        NaN
# S020        NaN        NaN        NaN
# S021        NaN        NaN        NaN
# S022        NaN        NaN        NaN
# S023        NaN        NaN        NaN
# S024        NaN        NaN    0.59600
# S025        NaN        NaN    0.69300
# S026        NaN        NaN        NaN
# S027        NaN        NaN        NaN
# S028        NaN        NaN        NaN
# S029        NaN    -1.4600    0.00287
# S030        NaN     0.5500    0.28550
# ...         ...        ...        ...
# S124        NaN        NaN        NaN
# S125        NaN        NaN        NaN
# S126        NaN        NaN        NaN
# S127        NaN        NaN        NaN
# S128        NaN        NaN        NaN
# S129        NaN        NaN        NaN
# S130        NaN        NaN        NaN
# S131        NaN        NaN    0.02040
# S132        NaN        NaN        NaN
# S133        NaN        NaN        NaN
# S134        NaN        NaN        NaN
# S135        NaN        NaN    0.06290
# S136        NaN        NaN        NaN
# S137        NaN        NaN        NaN
# S138        NaN        NaN   -0.24600
# S139        NaN        NaN   -0.50100
# S140   0.092800        NaN   -0.37400
# S141  -0.063700        NaN    0.00000
# S142  -0.000028        NaN    0.03260
# S143        NaN    -0.3685   -0.26350
# S144        NaN    -0.4385   -0.22950
# S145        NaN        NaN    0.37100
# S146        NaN        NaN    0.32500
# S147        NaN        NaN   -0.12000
# S148        NaN        NaN   -0.41300
# S149        NaN        NaN    0.00000
# S150        NaN        NaN    0.17900
# S151        NaN        NaN   -0.12200
# S152        NaN        NaN   -0.35400
# S153        NaN        NaN    0.02160
#
# [153 rows x 73212 columns]

# %% [markdown]
# # PI3KCA mutation and IRS1 proteome abundance

# %% [markdown]
# <b> Take out the control </b>

# %%
proteomics = proteomics[:100]

# %% [markdown]
# ### Perform a t-test with mutated and non-mutated protein levels

# %%
protList = ['IRS1']
pcutoff = 0.05 / len(protList)
gene = 'PIK3CA'

sigResults = [];
for protein in protList: 
    if protein in proteomics.columns:
        cross = CPTAC.compare_mutations(proteomics, protein, gene)
        cross = cross[["Mutation", protein]].dropna(axis=0)
        mutated = cross.loc[cross["Mutation"] == "Missense_Mutation"]
        wt = cross.loc[cross["Mutation"] == "Wildtype"]
        ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
        if(ttest[1] <= pcutoff):
            sigResults.append(protein)
            print("Test for " + protein + ": ")
            print(ttest) 
        else:
            print("Unsignificant result for " + protein + ": ")
            print(ttest)
# Out:
# Unsignificant result for IRS1:
# Ttest_indResult(statistic=-1.0601355321350932, pvalue=0.29177084447657115)

# %% [markdown]
#  ### We can now plot the data

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
somatic_boxplot = sns.boxplot(data=cross, x="Mutation",y='IRS1', ax = ax)
somatic_boxplot.set_title("PI3KCA gene mutation IRS1 protein abundance")
somatic_boxplot = sns.stripplot(data=cross, x="Mutation", y='IRS1',jitter=True, color=".3")
somatic_boxplot.set(xlabel="Somatic Gene Mutation",ylabel="Proteomics")
plt.show()

# %% [markdown]
# # PI3KCA mutation and IRS1 phosphoproteome abundance

# %%
sites = phos.columns
p_values = []
site_names = []
phosProtList = ['IRS1']

alpha = 0.05
p_value = alpha/len(phosProtList)


for protein in phosProtList:
    pattern = re.compile(protein)
    isInList = filter(pattern.search, sites)
    if next(isInList, None) is not None:
        phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
        phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis = 1)
        
        for site in phosphositesdf.columns:
            if (site is not 'Mutation'):
                sitedf = CPTAC.compare_mutations(phos, site, gene)
               # print(sitedf)
                mutateddf = sitedf.loc[sitedf['Mutation'] != 'Wildtype'].dropna(axis=0)
                #print(mutateddf)
                wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
                ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
                p_values.append(ttest[1])
                site_names.append(site)     
                
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1]         
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]

significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# ['IRS1-S1005' 'IRS1-S1100' 'IRS1-S1101' 'IRS1-S1133' 'IRS1-S1134'
#  'IRS1-S270' 'IRS1-S307' 'IRS1-S323' 'IRS1-S330' 'IRS1-S337' 'IRS1-S341'
#  'IRS1-S374' 'IRS1-S415' 'IRS1-S527' 'IRS1-S531' 'IRS1-S629' 'IRS1-S636'
#  'IRS1-S672' 'IRS1-S766' 'IRS1-T305' 'IRS1-T309' 'IRS1-T530']
# [0.0094718  0.00020188 0.000523   0.01426172 0.0011596  0.00118185
#  0.0481304  0.01005825 0.0094718  0.02559819 0.0481304  0.00118185
#  0.00290455 0.01092095 0.00195889 0.00091668 0.00248824 0.0094718
#  0.00248824 0.00248824 0.0094718  0.02461594]
# {'IRS1-S1005': 0.0094717950390731, 'IRS1-S1100': 0.0002018777834901376, 'IRS1-S1101': 0.0005229979400382523, 'IRS1-S1133': 0.014261718949464484, 'IRS1-S1134': 0.0011595956105361492, 'IRS1-S270': 0.0011818527960791446, 'IRS1-S307': 0.04813039926788787, 'IRS1-S323': 0.010058250340791101, 'IRS1-S330': 0.0094717950390731, 'IRS1-S337': 0.02559819374662789, 'IRS1-S341': 0.04813039926788787, 'IRS1-S374': 0.0011818527960791446, 'IRS1-S415': 0.002904550128402398, 'IRS1-S527': 0.010920950683584235, 'IRS1-S531': 0.0019588868186355066, 'IRS1-S629': 0.000916683570795187, 'IRS1-S636': 0.0024882379379975645, 'IRS1-S672': 0.0094717950390731, 'IRS1-S766': 0.0024882379379975645, 'IRS1-T305': 0.0024882379379975645, 'IRS1-T309': 0.0094717950390731, 'IRS1-T530': 0.024615944039254573}

# %%
site = 'IRS1-S1101'
sitedf = CPTAC.compare_mutations(phos, site, gene)
print(sitedf)
# Out:
#       IRS1-S1101           Mutation Patient_Type
# S001     -0.2040  Missense_Mutation        Tumor
# S002     -0.5840           Wildtype        Tumor
# S003      0.4380  Missense_Mutation        Tumor
# S004     -0.2660           Wildtype        Tumor
# S005     -0.4640           Wildtype        Tumor
# S006     -0.9885           Wildtype        Tumor
# S007      0.8265           Wildtype        Tumor
# S008     -0.3005           Wildtype        Tumor
# S009     -0.2190  Missense_Mutation        Tumor
# S010      0.1505  Missense_Mutation        Tumor
# S011     -0.1270           Wildtype        Tumor
# S012     -1.4150  Missense_Mutation        Tumor
# S013     -0.9170           Wildtype        Tumor
# S014     -1.0545  Missense_Mutation        Tumor
# S015      0.1050           Wildtype        Tumor
# S016     -0.2530           Wildtype        Tumor
# S017     -1.6345           Wildtype        Tumor
# S018      0.6350  Missense_Mutation        Tumor
# S019      1.5825           Wildtype        Tumor
# S020      0.6280           Wildtype        Tumor
# S021     -0.3800  Missense_Mutation        Tumor
# S022         NaN  Missense_Mutation        Tumor
# S023         NaN  Missense_Mutation        Tumor
# S024      0.6850  Missense_Mutation        Tumor
# S025     -0.3320           Wildtype        Tumor
# S026      0.9050  Missense_Mutation        Tumor
# S027     -0.5740  Missense_Mutation        Tumor
# S028      0.2280  Missense_Mutation        Tumor
# S029      0.2090           Wildtype        Tumor
# S030     -0.3635  Missense_Mutation        Tumor
# ...          ...                ...          ...
# S124      1.0600           Wildtype       Normal
# S125      0.5185           Wildtype       Normal
# S126         NaN           Wildtype       Normal
# S127     -0.6450           Wildtype       Normal
# S128         NaN           Wildtype       Normal
# S129      0.6595           Wildtype       Normal
# S130      0.8370           Wildtype       Normal
# S131      1.2600           Wildtype       Normal
# S132      1.1400           Wildtype       Normal
# S133      0.4170           Wildtype       Normal
# S134      0.1660           Wildtype       Normal
# S135      0.0212           Wildtype       Normal
# S136      0.1400           Wildtype       Normal
# S137      0.7165           Wildtype       Normal
# S138      0.8235           Wildtype       Normal
# S139      0.8910           Wildtype       Normal
# S140      1.0950           Wildtype       Normal
# S141      1.0005           Wildtype       Normal
# S142      1.1400           Wildtype       Normal
# S143      0.1215           Wildtype       Normal
# S144      0.4025           Wildtype       Normal
# S145      0.3400           Wildtype       Normal
# S146      0.0000           Wildtype       Normal
# S147     -0.3430           Wildtype       Normal
# S148      0.0596           Wildtype       Normal
# S149     -0.4790           Wildtype       Normal
# S150     -0.2050           Wildtype       Normal
# S151      0.7470           Wildtype       Normal
# S152      1.1500           Wildtype       Normal
# S153     -0.1170           Wildtype       Normal
#
# [153 rows x 3 columns]

# %%
phosdf = CPTAC.compare_mutations(phos, protein, gene)

phosdf = phosdf.loc[phosdf['Patient_Type'] == 'Tumor']

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

boxplt = sns.boxplot(data = phosdf, x = 'Mutation', y = 'IRS1-S1134')
boxplt = sns.stripplot(data = phosdf, x = 'Mutation', y = 'IRS1-S1134', jitter = True, color = '.3')
plt.show()

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

boxplt = sns.boxplot(data = phosdf, x = 'Mutation', y = 'IRS1-S629')
boxplt = sns.stripplot(data = phosdf, x = 'Mutation', y = 'IRS1-S629', jitter = True, color = '.3')
plt.show()

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

boxplt = sns.boxplot(data = phosdf, x = 'Mutation', y = 'IRS1-S415')
boxplt = sns.stripplot(data = phosdf, x = 'Mutation', y = 'IRS1-S415', jitter = True, color = '.3')
plt.show()

# %% [markdown]
# ## Plot all of the statistically significant phosphoproteomic measurements

# %%
protein = 'IRS1'
gene = 'PIK3CA'
phosdf = CPTAC.compare_mutations(phos, protein, gene)
phosdf = phosdf.loc[phosdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis=1)

# %%
phosdf.loc[(phosdf['Mutation'] == "Wildtype"), "Mutation"] = "Control"
phosdf.loc[(phosdf['Mutation'] != "Control"), "Mutation"] = "Mutated"

phosdf = pd.melt(phosdf, id_vars=['Mutation'], var_name='Type', value_name='Reading')
phosdf = phosdf.loc[(phosdf["Mutation"] == "Control") | (phosdf["Mutation"] == "Mutated")]
phosdf = phosdf.dropna(axis=0).sort_values(by=['Mutation'], ascending=False)
#phosdf = phosdf.loc[(phosdf['Type'] == significant_sites)]

# %%
plotdf = None
interested_sites = ['IRS1-S1101', 'IRS1-S1133', 'IRS1-S1134', 'IRS1-S672', 'IRS1-S766']

for site in interested_sites:
    print(site)
    tempdf = phosdf.loc[(phosdf['Type'] == site)]
    print(tempdf)
    if plotdf is None:
        plotdf = tempdf
    else:
        plotdf = plotdf.append(tempdf)
        
#print(plotdf)
# Out:
# IRS1-S1101
#     Mutation        Type  Reading
# 373  Mutated  IRS1-S1101 -0.58500
# 302  Mutated  IRS1-S1101  0.43800
# 369  Mutated  IRS1-S1101 -0.30100
# 367  Mutated  IRS1-S1101 -0.03340
# 308  Mutated  IRS1-S1101 -0.21900
# 309  Mutated  IRS1-S1101  0.15050
# 366  Mutated  IRS1-S1101  1.22000
# 300  Mutated  IRS1-S1101 -0.20400
# 387  Mutated  IRS1-S1101 -0.16500
# 385  Mutated  IRS1-S1101 -0.21800
# 383  Mutated  IRS1-S1101 -0.45050
# 380  Mutated  IRS1-S1101 -1.16000
# 398  Mutated  IRS1-S1101 -1.60000
# 397  Mutated  IRS1-S1101 -0.62850
# 389  Mutated  IRS1-S1101 -0.05500
# 388  Mutated  IRS1-S1101 -0.08150
# 394  Mutated  IRS1-S1101 -0.06100
# 395  Mutated  IRS1-S1101 -0.52100
# 396  Mutated  IRS1-S1101 -0.66200
# 376  Mutated  IRS1-S1101 -0.73400
# 374  Mutated  IRS1-S1101  0.02250
# 354  Mutated  IRS1-S1101  0.08860
# 332  Mutated  IRS1-S1101 -0.42100
# 352  Mutated  IRS1-S1101 -0.57800
# 325  Mutated  IRS1-S1101  0.90500
# 326  Mutated  IRS1-S1101 -0.57400
# 327  Mutated  IRS1-S1101  0.22800
# 365  Mutated  IRS1-S1101 -0.84100
# 331  Mutated  IRS1-S1101  0.19300
# 329  Mutated  IRS1-S1101 -0.36350
# ..       ...         ...      ...
# 375  Control  IRS1-S1101  0.02190
# 382  Control  IRS1-S1101 -0.74900
# 350  Control  IRS1-S1101 -0.37100
# 384  Control  IRS1-S1101 -0.23200
# 349  Control  IRS1-S1101  0.12800
# 392  Control  IRS1-S1101  0.39700
# 393  Control  IRS1-S1101 -0.91800
# 399  Control  IRS1-S1101 -0.08015
# 301  Control  IRS1-S1101 -0.58400
# 303  Control  IRS1-S1101 -0.26600
# 304  Control  IRS1-S1101 -0.46400
# 305  Control  IRS1-S1101 -0.98850
# 306  Control  IRS1-S1101  0.82650
# 324  Control  IRS1-S1101 -0.33200
# 328  Control  IRS1-S1101  0.20900
# 334  Control  IRS1-S1101 -0.05420
# 336  Control  IRS1-S1101  0.89800
# 338  Control  IRS1-S1101 -0.45800
# 341  Control  IRS1-S1101 -0.19600
# 343  Control  IRS1-S1101 -0.25700
# 344  Control  IRS1-S1101 -0.04300
# 345  Control  IRS1-S1101  0.43100
# 307  Control  IRS1-S1101 -0.30050
# 310  Control  IRS1-S1101 -0.12700
# 312  Control  IRS1-S1101 -0.91700
# 314  Control  IRS1-S1101  0.10500
# 315  Control  IRS1-S1101 -0.25300
# 316  Control  IRS1-S1101 -1.63450
# 318  Control  IRS1-S1101  1.58250
# 319  Control  IRS1-S1101  0.62800
#
# [88 rows x 3 columns]
# IRS1-S1133
#     Mutation        Type  Reading
# 609  Mutated  IRS1-S1133 -0.04800
# 611  Mutated  IRS1-S1133 -0.48400
# 617  Mutated  IRS1-S1133  0.01590
# 620  Mutated  IRS1-S1133 -0.89200
# 621  Mutated  IRS1-S1133 -0.02830
# 622  Mutated  IRS1-S1133 -0.44300
# 608  Mutated  IRS1-S1133 -0.43250
# 600  Mutated  IRS1-S1133 -0.10600
# 662  Mutated  IRS1-S1133 -0.08760
# 663  Mutated  IRS1-S1133 -0.12210
# 667  Mutated  IRS1-S1133  0.41400
# 625  Mutated  IRS1-S1133 -0.20700
# 627  Mutated  IRS1-S1133  0.08595
# 631  Mutated  IRS1-S1133 -0.44100
# 632  Mutated  IRS1-S1133 -0.48400
# 666  Mutated  IRS1-S1133 -0.08910
# 697  Mutated  IRS1-S1133  0.41700
# 696  Mutated  IRS1-S1133 -0.03550
# 691  Mutated  IRS1-S1133 -0.00191
# 683  Mutated  IRS1-S1133 -0.42350
# 672  Control  IRS1-S1133  0.76500
# 678  Control  IRS1-S1133 -0.20900
# 681  Control  IRS1-S1133 -0.11200
# 692  Control  IRS1-S1133  0.31600
# 699  Control  IRS1-S1133  0.12500
# 670  Control  IRS1-S1133  0.00525
# 648  Control  IRS1-S1133 -1.19000
# 628  Control  IRS1-S1133 -0.20900
# 634  Control  IRS1-S1133  0.55050
# 641  Control  IRS1-S1133  0.00000
# 651  Control  IRS1-S1133  0.75550
# 655  Control  IRS1-S1133 -0.01790
# 657  Control  IRS1-S1133  0.06450
# 603  Control  IRS1-S1133 -0.02000
# 605  Control  IRS1-S1133  0.47800
# 607  Control  IRS1-S1133 -0.67700
# 614  Control  IRS1-S1133 -0.19950
# 619  Control  IRS1-S1133 -0.01590
# IRS1-S1134
#     Mutation        Type   Reading
# 774  Mutated  IRS1-S1134  0.796000
# 773  Mutated  IRS1-S1134  0.026400
# 723  Mutated  IRS1-S1134 -0.457000
# 769  Mutated  IRS1-S1134 -0.292000
# 725  Mutated  IRS1-S1134  0.067000
# 726  Mutated  IRS1-S1134 -0.559000
# 727  Mutated  IRS1-S1134 -0.106000
# 767  Mutated  IRS1-S1134 -0.596000
# 766  Mutated  IRS1-S1134 -0.043175
# 722  Mutated  IRS1-S1134 -0.562000
# 783  Mutated  IRS1-S1134 -0.203000
# 709  Mutated  IRS1-S1134 -0.359000
# 711  Mutated  IRS1-S1134 -0.169000
# 785  Mutated  IRS1-S1134 -0.713000
# 713  Mutated  IRS1-S1134 -0.405000
# 780  Mutated  IRS1-S1134 -0.532000
# 720  Mutated  IRS1-S1134 -0.779000
# 721  Mutated  IRS1-S1134 -0.149000
# 776  Mutated  IRS1-S1134 -0.123000
# 737  Mutated  IRS1-S1134 -0.009190
# 739  Mutated  IRS1-S1134  0.302000
# 752  Mutated  IRS1-S1134 -0.308000
# 742  Mutated  IRS1-S1134  0.350000
# 759  Mutated  IRS1-S1134  0.092700
# 760  Mutated  IRS1-S1134 -0.977000
# 732  Mutated  IRS1-S1134 -0.019500
# 765  Mutated  IRS1-S1134 -0.983000
# 729  Mutated  IRS1-S1134 -0.506000
# 764  Mutated  IRS1-S1134  0.601000
# 763  Mutated  IRS1-S1134 -0.579000
# ..       ...         ...       ...
# 744  Control  IRS1-S1134  0.208000
# 745  Control  IRS1-S1134  0.893000
# 719  Control  IRS1-S1134 -0.587950
# 724  Control  IRS1-S1134 -0.323000
# 728  Control  IRS1-S1134  0.116000
# 746  Control  IRS1-S1134  0.377000
# 770  Control  IRS1-S1134 -0.106000
# 768  Control  IRS1-S1134  0.376000
# 771  Control  IRS1-S1134 -0.215000
# 772  Control  IRS1-S1134 -0.284000
# 775  Control  IRS1-S1134 -0.711000
# 778  Control  IRS1-S1134  0.016900
# 779  Control  IRS1-S1134  0.104000
# 748  Control  IRS1-S1134 -0.134000
# 749  Control  IRS1-S1134 -0.126000
# 750  Control  IRS1-S1134 -0.455000
# 751  Control  IRS1-S1134 -0.307000
# 753  Control  IRS1-S1134 -0.384000
# 755  Control  IRS1-S1134  0.485550
# 757  Control  IRS1-S1134  0.352500
# 758  Control  IRS1-S1134  0.046200
# 761  Control  IRS1-S1134 -0.422000
# 781  Control  IRS1-S1134  0.175000
# 782  Control  IRS1-S1134  0.005710
# 784  Control  IRS1-S1134 -0.223000
# 786  Control  IRS1-S1134  0.294000
# 799  Control  IRS1-S1134 -0.518000
# 790  Control  IRS1-S1134 -0.124000
# 792  Control  IRS1-S1134  0.271000
# 793  Control  IRS1-S1134 -1.330000
#
# [94 rows x 3 columns]
# IRS1-S672
#      Mutation       Type  Reading
# 5291  Mutated  IRS1-S672  -0.0510
# 5298  Mutated  IRS1-S672  -0.7160
# 5297  Mutated  IRS1-S672   0.7350
# 5296  Mutated  IRS1-S672  -1.0100
# 5295  Mutated  IRS1-S672  -0.7970
# 5287  Mutated  IRS1-S672  -0.4420
# 5227  Mutated  IRS1-S672  -0.3180
# 5283  Mutated  IRS1-S672  -0.2540
# 5280  Mutated  IRS1-S672  -0.4590
# 5276  Mutated  IRS1-S672  -0.6940
# 5267  Mutated  IRS1-S672   0.3320
# 5266  Mutated  IRS1-S672  -0.1280
# 5265  Mutated  IRS1-S672  -0.8330
# 5264  Mutated  IRS1-S672   1.8700
# 5263  Mutated  IRS1-S672  -0.7150
# 5262  Mutated  IRS1-S672  -0.0919
# 5239  Mutated  IRS1-S672   2.3000
# 5232  Mutated  IRS1-S672   0.3680
# 5231  Mutated  IRS1-S672  -0.1780
# 5229  Mutated  IRS1-S672  -1.4300
# 5225  Mutated  IRS1-S672  -0.6740
# 5223  Mutated  IRS1-S672   0.3330
# 5222  Mutated  IRS1-S672  -0.5930
# 5221  Mutated  IRS1-S672  -0.0418
# 5220  Mutated  IRS1-S672  -1.6100
# 5217  Mutated  IRS1-S672  -0.1070
# 5213  Mutated  IRS1-S672  -0.2195
# 5211  Mutated  IRS1-S672  -0.4340
# 5209  Mutated  IRS1-S672   0.0325
# 5208  Mutated  IRS1-S672  -0.6580
# ...       ...        ...      ...
# 5212  Control  IRS1-S672  -0.1250
# 5234  Control  IRS1-S672   0.4030
# 5233  Control  IRS1-S672   1.1600
# 5299  Control  IRS1-S672   0.5090
# 5268  Control  IRS1-S672   1.1000
# 5240  Control  IRS1-S672  -0.3350
# 5228  Control  IRS1-S672   0.0000
# 5281  Control  IRS1-S672   0.1110
# 5282  Control  IRS1-S672  -0.2750
# 5251  Control  IRS1-S672   0.7580
# 5278  Control  IRS1-S672   0.1470
# 5248  Control  IRS1-S672  -0.7520
# 5224  Control  IRS1-S672  -0.2460
# 5272  Control  IRS1-S672  -0.5970
# 5255  Control  IRS1-S672   0.3020
# 5286  Control  IRS1-S672   0.6600
# 5219  Control  IRS1-S672   0.0816
# 5241  Control  IRS1-S672  -0.4230
# 5270  Control  IRS1-S672  -0.0420
# 5292  Control  IRS1-S672   0.1490
# 5257  Control  IRS1-S672  -2.2200
# 5258  Control  IRS1-S672   0.0640
# 5214  Control  IRS1-S672  -0.0182
# 5218  Control  IRS1-S672   0.6420
# 5207  Control  IRS1-S672  -0.8610
# 5206  Control  IRS1-S672   0.3650
# 5205  Control  IRS1-S672  -1.0600
# 5204  Control  IRS1-S672  -0.4390
# 5203  Control  IRS1-S672  -0.1020
# 5201  Control  IRS1-S672  -0.3050
#
# [62 rows x 3 columns]
# IRS1-S766
#      Mutation       Type  Reading
# 5798  Mutated  IRS1-S766  -1.2900
# 5797  Mutated  IRS1-S766  -1.0900
# 5796  Mutated  IRS1-S766  -0.4850
# 5789  Mutated  IRS1-S766   1.2800
# 5787  Mutated  IRS1-S766  -0.7830
# 5783  Mutated  IRS1-S766  -0.4695
# 5780  Mutated  IRS1-S766  -1.3700
# 5773  Mutated  IRS1-S766   0.0491
# 5767  Mutated  IRS1-S766  -0.6440
# 5765  Mutated  IRS1-S766  -1.3200
# 5759  Mutated  IRS1-S766  -0.6100
# 5732  Mutated  IRS1-S766  -0.3875
# 5729  Mutated  IRS1-S766  -1.5300
# 5726  Mutated  IRS1-S766   0.4760
# 5723  Mutated  IRS1-S766  -0.0492
# 5711  Mutated  IRS1-S766  -1.0905
# 5709  Mutated  IRS1-S766  -0.8140
# 5799  Control  IRS1-S766  -0.4100
# 5701  Control  IRS1-S766  -0.3320
# 5793  Control  IRS1-S766  -1.1200
# 5782  Control  IRS1-S766  -0.5015
# 5775  Control  IRS1-S766  -0.0617
# 5772  Control  IRS1-S766   0.4000
# 5758  Control  IRS1-S766  -0.7045
# 5757  Control  IRS1-S766  -0.0675
# 5749  Control  IRS1-S766   0.2120
# 5734  Control  IRS1-S766   1.3900
# 5724  Control  IRS1-S766  -0.4540
# 5710  Control  IRS1-S766   0.5110
# 5707  Control  IRS1-S766   0.1605
# 5706  Control  IRS1-S766   1.4150
# 5705  Control  IRS1-S766  -0.9730
# 5704  Control  IRS1-S766  -0.4610

# %%
a4_dims = (50.4, 20.54)
fig, ax = plt.subplots(figsize=a4_dims)
my_pal = {"Mutated": "#009933", "Control": "#008ae6"}

#Create the plot
boxplt = sns.boxplot(x='Type', y='Reading', hue='Mutation', data=plotdf, palette=my_pal)
boxplt = sns.stripplot(data=plotdf, x='Type', y='Reading', hue='Mutation', dodge=True, jitter=True, color='.3')

#Add styling
boxplt.set_xlabel('')
boxplt.set_ylabel('Signal', fontsize='30')
boxplt.tick_params(labelsize='20')

#Adjust legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:2], ['Mutated', 'Control'], title='IRS1 Status', fontsize='20', frameon=False)
boxplt.get_legend().get_title().set_fontsize('20')
#boxplt.get_legend().set_bbox_to_anchor((1, 1, 0, 0))


fig = boxplt.get_figure()
plt.show()

# %% [markdown]
# <b> Note: IRS1-S1101 is phosphorylated by RPS6KB1 </b>
