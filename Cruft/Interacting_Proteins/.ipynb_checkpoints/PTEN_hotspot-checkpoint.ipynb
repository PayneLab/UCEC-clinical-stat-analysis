# %% [markdown]
# # PIK3CA: Effects of Hotspot Mutation on AKT1

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.stats.multitest

# %% [markdown]
# ### Import CPTAC

# %%
import CPTAC

# %%
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %%
protein = 'AKT1'
gene = 'PIK3CA'

# %% [markdown]
# ## Extract the data for hotspot mutations only

# %%
#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.E545A', 'p.E545K', 'p.E545V', 'p.Q546P', 'p.Q546R', 'p.E542K']
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

# %%
p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
#print(p10_mutations)
p10_mutations['Within_Hotspot'] = False
p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)
print(len(p10_mutations.loc[(p10_mutations['Within_Hotspot'] == True)]))
# Out:
# 19

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
out_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == False]
ttest = scipy.stats.ttest_ind(in_hotspot[protein], out_hotspot[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.330968142568657, pvalue=0.19073661013866022)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] != True]
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.4764335469303764, pvalue=0.14303369055854384)

# %% [markdown]
# ## All mutations vs wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] != 'Wildtype']
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.8003450633178396, pvalue=0.4254468321094339)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.3601668474767552, pvalue=0.1778515454056439)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on PIK3CA abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %% [markdown]
# # Phosphoproteomic Abundance

# %%
phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
phos_mutations['Within_Hotspot'] = False
phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True

phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
print(phos_mutations)


phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
#phos_mutations = phos_mutations.dropna(axis = 0)
#print(phos_mutations)
phos_sites = list(phos_mutations)
phos_sites = phos_sites[:(len(phos_sites) - 3)]
# Out:
#       AKT1-S124  AKT1-S126  AKT1-S129  AKT1S1-S108  AKT1S1-S112  AKT1S1-S203  \
# S001      -0.02      -0.02      -0.05         0.01         0.01        -0.54
# S002      -0.16      -0.10      -0.19         0.53         0.17         3.50
# S003       0.26       0.14       0.00          NaN          NaN          NaN
# S004       0.03       0.00       0.05         1.11         1.24         1.27
# S005       0.00      -0.02      -0.06         0.05         0.28          NaN
# S006       0.21       0.28       0.10        -0.21        -0.36         0.02
# S007       0.11      -0.02       0.08         0.00        -0.26         1.17
# S008       0.03       0.62      -0.01         0.13        -0.03         1.28
# S009       0.32       0.30       0.22        -0.35        -0.27          NaN
# S010      -0.13      -0.37       0.24         0.18         0.00         0.29
# S011      -0.06      -0.27      -0.28        -0.14         0.07        -1.79
# S012      -0.77      -0.39      -0.49        -0.08         0.06        -5.34
# S013       0.20       0.04       0.03        -0.37         0.16        -1.34
# S014      -0.18       0.23      -0.22        -0.14        -0.59         0.38
# S015      -0.44        NaN        NaN        -0.23        -0.05        -1.20
# S016      -0.84      -0.01       0.57          NaN          NaN          NaN
# S017       0.01       0.09      -0.04        -0.14        -0.16        -0.21
# S018      -0.40      -0.02      -0.03        -0.01         0.09        -0.23
# S019      -0.04       0.00      -0.07        -0.05        -0.30        -0.71
# S020      -0.26       0.04       0.02         0.00        -0.07         0.73
# S021        NaN      -0.14      -0.10         0.55         0.35          NaN
# S022        NaN      -0.41       0.21        -0.06        -0.22          NaN
# S023      -0.20      -0.33      -0.19         0.26         0.33         0.56
# S024      -0.38      -0.57      -0.26         0.59         0.68        -0.11
# S025       0.14       0.21       0.01        -0.08        -0.15        -0.11
# S026      -0.96      -0.58      -0.76         0.10        -0.12        -2.26
# S027       0.07       0.37      -0.05        -0.11        -0.24         1.17
# S028      -0.53       0.13      -0.21        -0.13         0.24          NaN
# S029       0.02       0.02      -0.13         0.76         0.18         0.59
# S030      -0.20      -0.09       0.44        -0.15        -0.06        -1.70
# ...         ...        ...        ...          ...          ...          ...
# S111       0.11       0.15      -0.14          NaN          NaN          NaN
# S112      -0.04       0.76      -0.10         0.28         0.15         2.76
# S113       0.00        NaN        NaN         0.00         0.32         1.81
# S114       0.25      -0.02      -0.08         0.12        -0.29          NaN
# S115        NaN       0.41       0.62        -0.07         0.17          NaN
# S116        NaN       0.36       0.52        -0.06        -0.25          NaN
# S117        NaN       0.16      -0.11         0.10         0.28          NaN
# S118       0.24        NaN        NaN         0.00         0.21         1.01
# S119      -0.43        NaN        NaN         0.40         0.34         1.90
# S120       0.47       0.46       0.43         0.16        -0.20         1.84
# S121       0.50       0.50       0.13          NaN          NaN          NaN
# S122        NaN       0.27       0.23         0.18        -0.04          NaN
# S123       0.60       0.63       0.35         0.05         0.05         2.81
# S124       0.15       0.15       0.02         0.03          NaN          NaN
# S125       0.41       0.31       0.30        -0.62        -0.39         2.57
# S126       0.38       0.20       0.26         0.34         0.09         0.54
# S127       0.47       0.40       0.36         0.38         0.14        -1.20
# S128       0.31       0.17       0.22        -0.17        -0.09          NaN
# S129       0.01       0.09      -0.15        -1.50        -1.76        -0.16
# S130       0.29       0.12       0.10        -0.57        -0.47        -0.34
# S131       0.49       0.27       0.34        -0.30        -0.25         0.20
# S132       0.24       0.12       0.17        -0.35        -0.47         0.40
# S133       0.24      -0.15       0.13        -1.24        -0.67         0.00
# S134       0.31       0.07       0.14        -0.06        -0.07          NaN
# S135      -0.01      -0.03      -0.04         0.14         0.01         1.96
# S136       0.19      -0.13      -0.11         0.40         0.58         1.12
# S137       0.48       0.04       0.29        -1.02         0.34         1.48
# S138       0.11       0.20      -0.08        -0.09        -0.28         1.31
# S139       0.73       0.69       0.67         0.50         0.22         1.07
# S140       0.47       0.34       0.15        -0.17        -0.05         1.65
#
#       AKT1S1-S222  AKT1S1-S223  AKT1S1-S231  AKT1S1-S232  AKT1S1-T110  \
# S001         0.59         0.07         0.04        -0.15        -0.42
# S002        -0.41        -0.24         0.55         0.85          NaN
# S003         1.51         0.31          NaN          NaN         0.16
# S004         0.38         0.46         0.01        -0.20        -0.12
# S005         0.19        -0.02        -0.36         0.03          NaN
# S006        -0.17        -0.01        -0.21        -0.16          NaN
# S007         0.11         0.35         0.11         0.21        -0.22
# S008         0.15         0.23        -0.02         0.38        -0.53
# S009        -0.21        -0.37        -0.85        -0.29          NaN
# S010         0.11         0.13         0.10         0.28         0.08
# S011         0.02         0.10         0.78         0.17        -0.24
# S012         0.09         0.18        -0.25         0.29          NaN
# S013        -0.60        -0.22        -0.39        -0.15          NaN
# S014        -0.05        -0.04         0.27         0.09        -0.75
# S015         0.40         0.06        -0.36        -0.19         0.09
# S016        -1.13        -0.08          NaN          NaN        -0.22
# S017        -0.28        -0.42        -0.21        -0.14        -0.47
# S018         0.24         0.20         0.05         0.40          NaN
# S019        -0.38        -0.25         0.03        -0.01        -0.21
# S020        -0.64        -0.46         0.18         0.04         0.07
# S021        -0.70         0.05        -0.08        -0.06        -0.58
# S022        -0.34        -0.13        -0.02        -0.14        -0.67
# S023        -0.29        -0.20        -0.20        -0.25         0.10
# S024        -0.58        -0.49         0.15        -0.73        -0.04
# S025         0.06         0.07        -0.02        -0.26        -0.31
# S026        -0.20        -0.20         0.32        -0.09         0.52
# S027         0.12         0.10        -0.50         0.09        -0.05
# S028        -0.23        -0.01         0.47         0.23          NaN
# S029        -0.26         0.07         0.25         0.14          NaN
# S030        -0.95        -0.46        -0.40        -0.51         0.04
# ...           ...          ...          ...          ...          ...
# S111         1.21         0.41          NaN          NaN        -0.21
# S112         0.11         0.00         0.29         0.33          NaN
# S113        -1.47        -0.25          NaN        -0.35         0.55
# S114        -0.30        -0.24         0.21        -0.36          NaN
# S115         0.08         0.00        -1.04         0.17        -0.13
# S116         0.32         0.24         0.54         0.30        -0.03
# S117         0.12         0.26         0.00         0.57         0.05
# S118        -1.62        -0.26        -0.07        -0.61         0.37
# S119          NaN         0.27          NaN          NaN         0.25
# S120         0.14        -0.25        -0.14        -0.53         0.01
# S121        -0.03         0.06          NaN          NaN         0.54
# S122         0.17        -0.56        -0.68        -0.30        -0.06
# S123         0.52         0.64          NaN         0.67          NaN
# S124         0.21        -0.25        -0.24         0.04          NaN
# S125         0.53        -0.03         0.41         0.24          NaN
# S126         0.27         0.19        -0.27         0.17          NaN
# S127         0.15         0.24        -0.19         0.25          NaN
# S128         0.23        -0.02        -0.17        -0.01          NaN
# S129        -0.37        -0.28         0.76        -0.09          NaN
# S130         0.07         0.15         1.03         0.22          NaN
# S131        -0.23         0.08         0.50        -0.06        -0.41
# S132         0.08        -0.11        -0.55        -0.10        -0.75
# S133         0.09         0.00         0.25        -0.23        -0.64
# S134         0.15        -0.06        -0.45         0.07          NaN
# S135        -0.25        -0.16        -0.54         0.00         0.34
# S136        -0.35        -0.10         0.18        -0.20        -0.22
# S137        -0.53        -0.31          NaN        -0.31          NaN
# S138        -0.15        -0.23        -0.84        -0.08        -0.09
# S139        -0.08        -0.02        -1.10         0.17         0.51
# S140         0.19         0.06         0.26         0.11         0.60
#
#       AKT1S1-T266           Mutation Patient_Type Within_Hotspot
# S001          NaN  Missense_Mutation        Tumor           True
# S002         2.14           Wildtype        Tumor       Wildtype
# S003         1.78  Missense_Mutation        Tumor           True
# S004         1.05           Wildtype        Tumor       Wildtype
# S005        -1.89           Wildtype        Tumor       Wildtype
# S006        -0.61           Wildtype        Tumor       Wildtype
# S007         0.85           Wildtype        Tumor       Wildtype
# S008        -0.26  Missense_Mutation        Tumor           True
# S009        -0.59           Wildtype        Tumor       Wildtype
# S010          NaN           Wildtype        Tumor       Wildtype
# S011        -1.75  Missense_Mutation        Tumor          False
# S012         1.17           Wildtype        Tumor       Wildtype
# S013        -1.89  Missense_Mutation        Tumor          False
# S014        -1.17           Wildtype        Tumor       Wildtype
# S015        -2.70           Wildtype        Tumor       Wildtype
# S016        -1.04           Wildtype        Tumor       Wildtype
# S017          NaN  Missense_Mutation        Tumor          False
# S018         1.32           Wildtype        Tumor       Wildtype
# S019          NaN           Wildtype        Tumor       Wildtype
# S020        -0.27  Missense_Mutation        Tumor           True
# S021        -0.83  Missense_Mutation        Tumor          False
# S022         1.54  Missense_Mutation        Tumor           True
# S023         0.17  Missense_Mutation        Tumor           True
# S024        -0.48           Wildtype        Tumor       Wildtype
# S025          NaN           Wildtype        Tumor       Wildtype
# S026          NaN  Missense_Mutation        Tumor          False
# S027         0.20  Missense_Mutation        Tumor          False
# S028         0.86           Wildtype        Tumor       Wildtype
# S029         0.60           Wildtype        Tumor       Wildtype
# S030        -1.39  Missense_Mutation        Tumor          False
# ...           ...                ...          ...            ...
# S111         0.43           Wildtype       Normal       Wildtype
# S112         0.94           Wildtype       Normal       Wildtype
# S113        -0.86           Wildtype       Normal       Wildtype
# S114        -0.35           Wildtype       Normal       Wildtype
# S115        -0.33           Wildtype       Normal       Wildtype
# S116         0.53           Wildtype       Normal       Wildtype
# S117        -0.12           Wildtype       Normal       Wildtype
# S118        -0.30           Wildtype       Normal       Wildtype
# S119         0.28           Wildtype       Normal       Wildtype
# S120          NaN           Wildtype       Normal       Wildtype
# S121         0.31           Wildtype       Normal       Wildtype
# S122         0.41           Wildtype       Normal       Wildtype
# S123         0.65           Wildtype       Normal       Wildtype
# S124         0.21           Wildtype       Normal       Wildtype
# S125         0.88           Wildtype       Normal       Wildtype
# S126         0.02           Wildtype       Normal       Wildtype
# S127         0.07           Wildtype       Normal       Wildtype
# S128        -0.94           Wildtype       Normal       Wildtype
# S129        -0.97           Wildtype       Normal       Wildtype
# S130        -0.67           Wildtype       Normal       Wildtype
# S131        -0.31           Wildtype       Normal       Wildtype
# S132        -1.01           Wildtype       Normal       Wildtype
# S133        -1.47           Wildtype       Normal       Wildtype
# S134        -0.72           Wildtype       Normal       Wildtype
# S135         0.20           Wildtype       Normal       Wildtype
# S136        -0.33           Wildtype       Normal       Wildtype
# S137          NaN           Wildtype       Normal       Wildtype
# S138         0.38           Wildtype       Normal       Wildtype
# S139          NaN           Wildtype       Normal       Wildtype
# S140         0.87           Wildtype       Normal       Wildtype
#
# [140 rows x 15 columns]

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == False]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for AKT1-S124 Ttest_indResult(statistic=-1.3224680097207935, pvalue=0.19435291644816438)
# Test for AKT1-S126 Ttest_indResult(statistic=-0.8516452586757651, pvalue=0.39961037974600766)
# Test for AKT1-S129 Ttest_indResult(statistic=-0.7687096737503176, pvalue=0.44669598983672)
# Test for AKT1S1-S108 Ttest_indResult(statistic=1.155310984261849, pvalue=0.25517614295013596)
# Test for AKT1S1-S112 Ttest_indResult(statistic=1.2111019837040642, pvalue=0.23333469534292217)
# Test for AKT1S1-S203 Ttest_indResult(statistic=0.5825707892900538, pvalue=0.5650162258807518)
# Test for AKT1S1-S222 Ttest_indResult(statistic=0.2554374348887157, pvalue=0.7996942004304326)
# Test for AKT1S1-S223 Ttest_indResult(statistic=-0.5901725475528158, pvalue=0.5583945720874708)
# Test for AKT1S1-S231 Ttest_indResult(statistic=-0.708292556440591, pvalue=0.4830860320534337)
# Test for AKT1S1-S232 Ttest_indResult(statistic=0.38195129531949856, pvalue=0.7046252130293456)
# Test for AKT1S1-T110 Ttest_indResult(statistic=-1.2647551492221967, pvalue=0.21638499894762125)
# Test for AKT1S1-T266 Ttest_indResult(statistic=-0.3883625902847011, pvalue=0.7002419923048825)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] != True]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for AKT1-S124 Ttest_indResult(statistic=-0.30580470449182806, pvalue=0.7604923671805525)
# Test for AKT1-S126 Ttest_indResult(statistic=-0.9367308777926273, pvalue=0.3513495110485564)
# Test for AKT1-S129 Ttest_indResult(statistic=-0.7508235001250423, pvalue=0.45467503730238135)
# Test for AKT1S1-S108 Ttest_indResult(statistic=1.24326919068645, pvalue=0.2168937921927297)
# Test for AKT1S1-S112 Ttest_indResult(statistic=1.538400422299091, pvalue=0.12734631696606552)
# Test for AKT1S1-S203 Ttest_indResult(statistic=0.41554079082618495, pvalue=0.6792042110201355)
# Test for AKT1S1-S222 Ttest_indResult(statistic=1.0434834159858555, pvalue=0.2992916898687158)
# Test for AKT1S1-S223 Ttest_indResult(statistic=-0.038478492799805156, pvalue=0.9693844555030708)
# Test for AKT1S1-S231 Ttest_indResult(statistic=-0.5174010928464885, pvalue=0.6061046829017929)
# Test for AKT1S1-S232 Ttest_indResult(statistic=0.7385994137207652, pvalue=0.4620102058295684)
# Test for AKT1S1-T110 Ttest_indResult(statistic=-0.6468023920718369, pvalue=0.5201863004780156)
# Test for AKT1S1-T266 Ttest_indResult(statistic=0.2118697233539534, pvalue=0.832715876379804)

# %% [markdown]
# ## All mutations vs wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] != 'Wildtype']
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for AKT1-S124 Ttest_indResult(statistic=0.6280425387291785, pvalue=0.531640346649029)
# Test for AKT1-S126 Ttest_indResult(statistic=-0.4020064075926627, pvalue=0.6886117295962362)
# Test for AKT1-S129 Ttest_indResult(statistic=-0.2234741976843904, pvalue=0.823661935424068)
# Test for AKT1S1-S108 Ttest_indResult(statistic=0.6077698447464415, pvalue=0.5448214268347861)
# Test for AKT1S1-S112 Ttest_indResult(statistic=0.7954185284994514, pvalue=0.42839555932400375)
# Test for AKT1S1-S203 Ttest_indResult(statistic=0.010600747915174496, pvalue=0.9915765794177508)
# Test for AKT1S1-S222 Ttest_indResult(statistic=1.4145532745878184, pvalue=0.1603689302651402)
# Test for AKT1S1-S223 Ttest_indResult(statistic=0.8122994826348905, pvalue=0.4185886232556425)
# Test for AKT1S1-S231 Ttest_indResult(statistic=0.18718518910376322, pvalue=0.8519232020592304)
# Test for AKT1S1-S232 Ttest_indResult(statistic=0.6588293281774983, pvalue=0.5116332761545239)
# Test for AKT1S1-T110 Ttest_indResult(statistic=0.7326320547042833, pvalue=0.46658879758068583)
# Test for AKT1S1-T266 Ttest_indResult(statistic=0.9439592887107385, pvalue=0.3478659074157382)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    print("Test for " + site, ttest)
# Out:
# Test for AKT1-S124 Ttest_indResult(statistic=-0.020255750897165168, pvalue=0.9839004673278317)
# Test for AKT1-S126 Ttest_indResult(statistic=-0.8476568559764337, pvalue=0.39951815569864313)
# Test for AKT1-S129 Ttest_indResult(statistic=-0.6541682868945128, pvalue=0.5151468952353531)
# Test for AKT1S1-S108 Ttest_indResult(statistic=1.1329197599724574, pvalue=0.26105929100796954)
# Test for AKT1S1-S112 Ttest_indResult(statistic=1.502384796525892, pvalue=0.13743261968818793)
# Test for AKT1S1-S203 Ttest_indResult(statistic=0.30205956884688906, pvalue=0.7640298650959865)
# Test for AKT1S1-S222 Ttest_indResult(statistic=1.3616255198373892, pvalue=0.17739248124728998)
# Test for AKT1S1-S223 Ttest_indResult(statistic=0.2411102744968177, pvalue=0.8101275860545372)
# Test for AKT1S1-S231 Ttest_indResult(statistic=-0.35935654713250803, pvalue=0.7203949521667103)
# Test for AKT1S1-S232 Ttest_indResult(statistic=0.7980291424557197, pvalue=0.4275147084296592)
# Test for AKT1S1-T110 Ttest_indResult(statistic=-0.2180347510451405, pvalue=0.8284100983101399)
# Test for AKT1S1-T266 Ttest_indResult(statistic=0.44824511984751475, pvalue=0.6554443824961484)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S560', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S560', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on PIK3CA phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-0e2aa28561e5> in <module>
#       1 a4_dims = (11.7, 8.27)
#       2 fig, ax = plt.subplots(figsize = a4_dims)
# ----> 3 boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S560', ax = ax)
#       4 boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS2-S560', jitter = True, color = '.3')
#       5 boxplt.set_title('Mutation location effect on PIK3CA phosphoproteomic abundance', fontsize='25')
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     444                  width, dodge, fliersize, linewidth):
#     445
# --> 446         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     447         self.establish_colors(color, palette, saturation)
#     448
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'IRS2-S560'
