# %% [markdown]
# # PIK3CA: Effects of Hotspot Mutation on IRS2

# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.stats.multitest

# %% [markdown]
# ### Import CPTAC

# %%
import CPTAC

# %%
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

# %%
protein = 'IRS1'
gene = 'PIK3CA'

# %% [markdown]
# ## Extract the data for hotspot mutations only

# %%
#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.E545A', 'p.E545K', 'p.E545V', 'p.Q546P', 'p.Q546R', 'p.E542K']
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

# %%
p10_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
#print(p10_mutations)
p10_mutations['Within_Hotspot'] = False
p10_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True
p10_mutations.loc[p10_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
p10_mutations = p10_mutations.loc[p10_mutations['Patient_Type'] == 'Tumor'].dropna(axis=0)
print(len(p10_mutations.loc[(p10_mutations['Within_Hotspot'] == True)]))
# Out:
# 19

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
in_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
out_hotspot = p10_mutations.loc[p10_mutations['Within_Hotspot'] == False]
ttest = scipy.stats.ttest_ind(in_hotspot[protein], out_hotspot[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.1811143291128672, pvalue=0.8570734994915308)

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] != True]
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.6714134122839353, pvalue=0.5035367810301701)

# %% [markdown]
# ## All mutations vs wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] != 'Wildtype']
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-1.03423533120962, pvalue=0.3035716066390899)

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
mutated = p10_mutations.loc[p10_mutations['Within_Hotspot'] == True]
wt = p10_mutations.loc[p10_mutations['Within_Hotspot'] == 'Wildtype']
ttest = scipy.stats.ttest_ind(mutated[protein], wt[protein])
print(ttest)
# Out:
# Ttest_indResult(statistic=-0.890843404844897, pvalue=0.3761090199360049)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, ax = ax)
boxplt = sns.stripplot(data = p10_mutations, x = 'Within_Hotspot', y = protein, jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on PIK3CA abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %% [markdown]
# # Phosphoproteomic Abundance

# %%
phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
phos_mutations['Within_Hotspot'] = False
phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = True

phos_mutations.loc[phos_mutations['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
#print(phos_mutations)


phos_mutations = phos_mutations.loc[phos_mutations['Patient_Type'] == 'Tumor']
#phos_mutations = phos_mutations.dropna(axis = 0)
#print(phos_mutations)
phos_sites = list(phos_mutations)
#print(phos_sites)
phos_sites = phos_sites[:(len(phos_sites) - 3)]

# %% [markdown]
# ## Hotspot mutation vs non-hotspot mutation

# %%
p_values = []
site_names = []


for site in phos_sites:
    if (site is not 'Mutation'):
        sitedf = CPTAC.compare_mutations(phos, site, gene)
        sitedf['Within_Hotspot'] = False
        sitedf.loc[sitedf, 'Within_Hotspot'] = True
            
        print(sitedf)
        sitedf.loc[sitedf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
            
        mutateddf = sitedf.loc[sitedf['Mutation'] != 'Wildtype'].dropna(axis=0)
        wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
        ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
        p_values.append(ttest[1])
        site_names.append(site)
            
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1]         
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]

significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-fcf823b01a7d> in <module>
#       7         sitedf = CPTAC.compare_mutations(phos, site, gene)
#       8         sitedf['Within_Hotspot'] = False
# ----> 9         sitedf.loc[sitedf, 'Within_Hotspot'] = True
#      10
#      11         print(sitedf)
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     186         else:
#     187             key = com._apply_if_callable(key, self.obj)
# --> 188         indexer = self._get_setitem_indexer(key)
#     189         self._setitem_with_indexer(indexer, value)
#     190
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     164         if isinstance(key, tuple):
#     165             try:
# --> 166                 return self._convert_tuple(key, is_setter=True)
#     167             except IndexingError:
#     168                 pass
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_tuple(self, key, is_setter)
#     245                 if i >= self.obj.ndim:
#     246                     raise IndexingError('Too many indexers')
# --> 247                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     248                 keyidx.append(idx)
#     249         return tuple(keyidx)
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "[('I', 'R', 'S', '1', '-', 'S', '1', '0', '0', '5')\n ('M', 'u', 't', 'a', 't', 'i', 'o', 'n')\n ('P', 'a', 't', 'i', 'e', 'n', 't', '_', 'T', 'y', 'p', 'e')\n ('W', 'i', 't', 'h', 'i', 'n', '_', 'H', 'o', 't', 's', 'p', 'o', 't')] not in index"

# %%
p_values = []
site_names = []


for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    
    #mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == False]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    p_values.append(ttest[1])
    site_names.append(site)  
    
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvalues = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))


print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# []
# []
# {}

# %% [markdown]
# ## Hotspot mutation vs other mutations and wildtype

# %%
p_values = []
site_names = []


for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] != True]
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    p_values.append(ttest[1])
    site_names.append(site)  
    
    
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvalues = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))
    
print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
# []
# []
# {}

# %% [markdown]
# ## All mutations vs wildtype

# %%
p_values = []
site_names = []

for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] != 'Wildtype']
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    #wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    p_values.append(ttest[1])
    site_names.append(site) 

    
sites = phos.columns
p_values = []
site_names = []
protein = 'IRS1'


pattern = re.compile(protein)
isInList = filter(pattern.search, sites)
if next(isInList, None) is not None:
    phosphositesdf = CPTAC.compare_mutations(phos, protein, gene)
    phosphositesdf['Within_Hotspot'] = False
    
    phosphositesdf.loc[hotspot_patients, 'Within_Hotspot'] = True
    print(phosphositesdf)
    phosphositesdf.loc[phosphositesdf['Mutation'] == 'Wildtype', 'Within_Hotspot'] = 'Wildtype'
#print(phos_mutations)


    phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor']
    phosphositesdf = phosphositesdf.loc[phosphositesdf['Patient_Type'] == 'Tumor'].drop('Patient_Type', axis = 1)
    for site in phosphositesdf.columns:
        if (site is not 'Mutation'):
            sitedf = CPTAC.compare_mutations(phos, site, gene)
            mutateddf = sitedf.loc[sitedf['Mutation'] != 'Wildtype'].dropna(axis=0)
            wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
            ttest = scipy.stats.ttest_ind(mutateddf[site], wtdf[site])
            p_values.append(ttest[1])
            site_names.append(site)     
                
    
#We need to remove all 'nan' p-values and their corresponding site names before passing it in for the fdr correction
indexesToRemove=[]

for index in range(0, len(p_values)):
    if np.isnan(p_values[index]):
        indexesToRemove.append(index)

for rem in range( len(indexesToRemove)-1, -1, -1):
    p_values.pop(indexesToRemove[rem])
    site_names.pop(indexesToRemove[rem])
#p_values and site names have now had all entries removed where the corresponding p-value is 'nan'
        

pvalues = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[1]         
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values,alpha=0.05, method='indep')[0]

significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))

print(significant_sites)
print(significant_pvalues)
print(significant_vals)
# Out:
#       IRS1-S1005  IRS1-S1078  IRS1-S1100  IRS1-S1101  IRS1-S1131  IRS1-S1132  \
# S001    -0.50100         NaN         NaN     -0.2040         NaN         NaN
# S002     0.17600         NaN     -0.3400     -0.5840         NaN         NaN
# S003     0.08390         NaN     -0.1130      0.4380         NaN         NaN
# S004     0.04480    -0.02850     -0.6880     -0.2660         NaN    -0.23100
# S005    -0.22300         NaN     -0.1900     -0.4640         NaN         NaN
# S006    -0.64900         NaN     -0.7970     -0.9885         NaN     0.47800
# S007    -0.21200         NaN      0.3930      0.8265         NaN         NaN
# S008     0.21400     0.20700     -0.2440     -0.3005         NaN         NaN
# S009     0.55400     0.79900     -0.6020     -0.2190         NaN    -0.71200
# S010    -0.08240         NaN     -0.1340      0.1505         NaN    -0.04800
# S011    -0.64400    -0.42000     -0.1270     -0.1270         NaN         NaN
# S012    -1.29000    -0.18600     -0.8270     -1.4150         NaN         NaN
# S013    -0.12500     0.44700     -0.8420     -0.9170         NaN         NaN
# S014    -0.39700     0.88700     -0.9690     -1.0545         NaN         NaN
# S015     0.37900     0.33500     -0.3455      0.1050         NaN    -0.17800
# S016    -0.77400    -1.29000     -0.2530     -0.2530         NaN         NaN
# S017    -0.90900         NaN     -1.2795     -1.6345         NaN         NaN
# S018    -0.29100         NaN         NaN      0.6350         NaN         NaN
# S019     0.01670     1.56000      0.7950      1.5825         NaN         NaN
# S020     0.04080         NaN         NaN      0.6280         NaN         NaN
# S021    -0.10300     0.00601     -0.4860     -0.3800         NaN    -1.01000
# S022    -0.26900         NaN     -0.0718         NaN         NaN         NaN
# S023    -0.41700         NaN     -0.1280         NaN         NaN         NaN
# S024    -0.06010         NaN      0.0438      0.6850         NaN         NaN
# S025     0.01470         NaN      0.5160     -0.3320         NaN         NaN
# S026     0.67000         NaN         NaN      0.9050         NaN         NaN
# S027    -0.38100     0.00925     -0.5740     -0.5740         NaN         NaN
# S028    -0.05740     0.00228      0.4040      0.2280         NaN     0.01190
# S029    -0.58400         NaN     -0.1700      0.2090         NaN         NaN
# S030    -0.42100         NaN      0.3830     -0.3635         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# S124     0.90200         NaN         NaN      1.0600         NaN         NaN
# S125     0.94200         NaN      0.5035      0.5185         NaN         NaN
# S126     0.00421         NaN      1.0700         NaN         NaN         NaN
# S127    -0.45900         NaN      0.4210     -0.6450         NaN         NaN
# S128     0.61600         NaN         NaN         NaN         NaN         NaN
# S129     0.29400     0.98600      0.5980      0.6595         NaN         NaN
# S130     0.81600    -1.22000      0.8640      0.8370         NaN    -0.00966
# S131     0.96900         NaN      1.1500      1.2600         NaN         NaN
# S132    -0.36000     0.65100      0.7640      1.1400         NaN         NaN
# S133    -0.19400     0.31300      0.4945      0.4170         NaN    -0.22200
# S134     0.46900    -1.19000      0.1660      0.1660         NaN         NaN
# S135     0.87000     0.48400     -0.3160      0.0212       0.199         NaN
# S136     0.28400     2.21000     -0.2720      0.1400         NaN         NaN
# S137    -0.05950     2.58000      0.3730      0.7165         NaN         NaN
# S138     0.28100         NaN      1.0400      0.8235         NaN     0.39400
# S139     0.68000         NaN      0.7890      0.8910         NaN     0.05760
# S140     0.42700     0.16000      1.1300      1.0950         NaN         NaN
# S141    -0.21100     0.60400      0.3080      1.0005         NaN         NaN
# S142     0.23000     1.57000      0.5730      1.1400         NaN         NaN
# S143    -0.05270         NaN      0.4110      0.1215         NaN         NaN
# S144    -0.44500         NaN      0.8620      0.4025         NaN         NaN
# S145     0.23800    -0.24400      0.4660      0.3400         NaN         NaN
# S146     0.53600     0.12900      0.0000      0.0000         NaN         NaN
# S147     0.17200     0.06460     -0.1950     -0.3430         NaN         NaN
# S148     0.80400     0.27300      0.1580      0.0596         NaN         NaN
# S149     0.10600    -0.09530     -0.4790     -0.4790         NaN         NaN
# S150     0.04280    -0.34200     -0.2050     -0.2050         NaN         NaN
# S151     0.08620    -0.09080      0.9250      0.7470         NaN         NaN
# S152     0.16900    -0.49900      1.1500      1.1500         NaN         NaN
# S153     0.22100    -0.70300     -0.0670     -0.1170         NaN         NaN
#
#       IRS1-S1133  IRS1-S1134  IRS1-S1135  IRS1-S1143       ...        \
# S001   -0.106000   -0.527000         NaN         NaN       ...
# S002         NaN   -0.160000         NaN         NaN       ...
# S003         NaN    0.499000         NaN         NaN       ...
# S004   -0.020000    0.661000         NaN         NaN       ...
# S005         NaN   -0.616000         NaN         NaN       ...
# S006    0.478000   -0.389000         NaN         NaN       ...
# S007         NaN    1.760000         NaN         NaN       ...
# S008   -0.677000   -0.199875         NaN     -0.6470       ...
# S009   -0.432500   -0.387000         NaN         NaN       ...
# S010   -0.048000   -0.359000         NaN         NaN       ...
# S011         NaN    0.257000         NaN     -0.0495       ...
# S012   -0.484000   -0.169000         NaN     -0.0265       ...
# S013         NaN   -0.303000         NaN         NaN       ...
# S014         NaN   -0.405000         NaN         NaN       ...
# S015   -0.199500    0.546000         NaN         NaN       ...
# S016         NaN         NaN         NaN         NaN       ...
# S017         NaN   -0.701000         NaN         NaN       ...
# S018    0.015900    0.258950         NaN         NaN       ...
# S019         NaN    0.692000         NaN         NaN       ...
# S020   -0.015900   -0.587950         NaN         NaN       ...
# S021   -0.892000   -0.779000         NaN         NaN       ...
# S022   -0.028300   -0.149000         NaN         NaN       ...
# S023   -0.443000   -0.562000         NaN         NaN       ...
# S024         NaN   -0.457000         NaN         NaN       ...
# S025         NaN   -0.323000         NaN         NaN       ...
# S026   -0.207000    0.067000         NaN         NaN       ...
# S027         NaN   -0.559000         NaN     -0.6020       ...
# S028    0.085950   -0.106000         NaN         NaN       ...
# S029   -0.209000    0.116000      -0.209         NaN       ...
# S030         NaN   -0.506000         NaN         NaN       ...
# ...          ...         ...         ...         ...       ...
# S124    0.094300   -0.136350         NaN         NaN       ...
# S125         NaN    0.354000         NaN         NaN       ...
# S126    0.216000   -0.127000         NaN         NaN       ...
# S127         NaN    0.372000         NaN         NaN       ...
# S128         NaN   -0.261000         NaN         NaN       ...
# S129         NaN    0.221000         NaN         NaN       ...
# S130   -0.004557    0.099300         NaN         NaN       ...
# S131         NaN    0.146000         NaN         NaN       ...
# S132         NaN   -0.641000         NaN      1.2400       ...
# S133    0.089500   -0.068800         NaN         NaN       ...
# S134         NaN    0.225000         NaN      1.6000       ...
# S135         NaN    0.080700         NaN         NaN       ...
# S136         NaN   -0.445000         NaN         NaN       ...
# S137         NaN    0.624000         NaN         NaN       ...
# S138    0.394000    1.080000         NaN         NaN       ...
# S139    0.057600    0.811000         NaN         NaN       ...
# S140    0.362500    0.788500         NaN      0.1790       ...
# S141    0.321000    0.558500         NaN      0.2880       ...
# S142    0.805000    1.054500         NaN      0.1980       ...
# S143         NaN    0.574000         NaN         NaN       ...
# S144         NaN    0.525000         NaN         NaN       ...
# S145         NaN    0.084400         NaN         NaN       ...
# S146         NaN    0.277000         NaN         NaN       ...
# S147         NaN   -0.615000         NaN         NaN       ...
# S148         NaN    0.252000         NaN         NaN       ...
# S149         NaN   -0.019900         NaN         NaN       ...
# S150         NaN   -0.283000         NaN         NaN       ...
# S151         NaN    1.920000         NaN         NaN       ...
# S152         NaN    1.040000         NaN         NaN       ...
# S153         NaN   -0.802000         NaN         NaN       ...
#
#       IRS1-T859  IRS1-Y465  IRS1-Y551  IRS1-Y582  IRS1-Y632  IRS1-Y662  \
# S001        NaN        NaN        NaN        NaN        NaN    -0.5550
# S002        NaN        NaN        NaN        NaN        NaN    -0.9510
# S003     0.2770    -0.0952        NaN        NaN      0.521        NaN
# S004        NaN        NaN        NaN        NaN        NaN        NaN
# S005        NaN        NaN        NaN    -0.1690        NaN        NaN
# S006        NaN        NaN        NaN        NaN        NaN        NaN
# S007        NaN        NaN        NaN        NaN        NaN    -0.8890
# S008        NaN        NaN     0.0648        NaN     -0.543        NaN
# S009        NaN        NaN        NaN        NaN        NaN        NaN
# S010        NaN        NaN        NaN        NaN        NaN        NaN
# S011        NaN        NaN        NaN        NaN        NaN     0.8060
# S012        NaN        NaN     0.2870        NaN     -0.742        NaN
# S013        NaN    -0.9550        NaN        NaN        NaN    -0.7080
# S014        NaN    -1.0600        NaN        NaN        NaN    -1.6280
# S015        NaN        NaN        NaN        NaN        NaN        NaN
# S016        NaN        NaN        NaN        NaN        NaN        NaN
# S017    -1.7300    -0.1170        NaN        NaN     -1.530        NaN
# S018        NaN        NaN        NaN        NaN        NaN    -0.7430
# S019        NaN     0.5560        NaN        NaN        NaN    -0.0995
# S020        NaN        NaN        NaN        NaN        NaN    -0.0352
# S021        NaN        NaN        NaN        NaN        NaN        NaN
# S022    -0.9590        NaN        NaN        NaN        NaN        NaN
# S023    -1.7900        NaN        NaN        NaN        NaN        NaN
# S024        NaN        NaN        NaN    -0.4330        NaN        NaN
# S025        NaN        NaN        NaN     0.3030        NaN        NaN
# S026        NaN        NaN        NaN        NaN        NaN     0.4860
# S027        NaN        NaN        NaN        NaN        NaN    -0.1760
# S028        NaN        NaN        NaN        NaN        NaN        NaN
# S029        NaN        NaN        NaN        NaN        NaN    -1.2000
# S030        NaN        NaN        NaN        NaN        NaN     0.2120
# ...         ...        ...        ...        ...        ...        ...
# S124        NaN        NaN        NaN        NaN        NaN     1.0800
# S125     2.1600    -0.0183        NaN        NaN      0.626        NaN
# S126     2.4600        NaN        NaN        NaN        NaN        NaN
# S127        NaN        NaN        NaN        NaN        NaN        NaN
# S128        NaN        NaN     0.6780        NaN        NaN        NaN
# S129        NaN     1.4900        NaN        NaN        NaN     1.3400
# S130        NaN        NaN        NaN        NaN        NaN        NaN
# S131        NaN        NaN        NaN     0.0011        NaN        NaN
# S132        NaN        NaN        NaN        NaN        NaN     0.5310
# S133        NaN        NaN        NaN        NaN        NaN        NaN
# S134        NaN        NaN        NaN        NaN        NaN     1.0300
# S135     0.9720        NaN        NaN        NaN        NaN        NaN
# S136        NaN     0.6450        NaN        NaN        NaN     1.1900
# S137        NaN     0.5330        NaN        NaN        NaN    -0.4928
# S138        NaN        NaN        NaN        NaN        NaN        NaN
# S139        NaN        NaN        NaN        NaN        NaN        NaN
# S140        NaN        NaN    -0.7930        NaN      1.960        NaN
# S141        NaN        NaN    -0.5250        NaN      0.720        NaN
# S142        NaN        NaN    -0.0932        NaN      1.800        NaN
# S143        NaN        NaN        NaN        NaN        NaN     0.1460
# S144        NaN        NaN        NaN        NaN        NaN    -0.4080
# S145     1.5600     0.0184        NaN        NaN        NaN     0.3920
# S146     0.2970     0.3060        NaN        NaN        NaN     0.4230
# S147    -0.1930    -0.1430        NaN        NaN        NaN     0.2060
# S148     0.1140     0.1440        NaN        NaN        NaN     0.5250
# S149     0.3880    -0.2260        NaN        NaN        NaN     0.0249
# S150    -0.0207    -0.3530        NaN        NaN        NaN     0.5360
# S151     2.5300     0.9850        NaN        NaN        NaN     0.1820
# S152    -0.8820     0.3060        NaN        NaN        NaN    -0.2160
# S153     0.0202    -0.1650        NaN        NaN        NaN    -0.0249
#
#       IRS1-Y750           Mutation  Patient_Type  Within_Hotspot
# S001        NaN  Missense_Mutation         Tumor            True
# S002        NaN           Wildtype         Tumor           False
# S003        NaN  Missense_Mutation         Tumor            True
# S004        NaN           Wildtype         Tumor           False
# S005        NaN           Wildtype         Tumor           False
# S006        NaN           Wildtype         Tumor           False
# S007        NaN           Wildtype         Tumor           False
# S008      0.000           Wildtype         Tumor           False
# S009        NaN  Missense_Mutation         Tumor            True
# S010        NaN  Missense_Mutation         Tumor           False
# S011        NaN           Wildtype         Tumor           False
# S012     -0.821  Missense_Mutation         Tumor           False
# S013        NaN           Wildtype         Tumor           False
# S014        NaN  Missense_Mutation         Tumor           False
# S015        NaN           Wildtype         Tumor           False
# S016        NaN           Wildtype         Tumor           False
# S017        NaN           Wildtype         Tumor           False
# S018        NaN  Missense_Mutation         Tumor           False
# S019        NaN           Wildtype         Tumor           False
# S020        NaN           Wildtype         Tumor           False
# S021        NaN  Missense_Mutation         Tumor            True
# S022        NaN  Missense_Mutation         Tumor           False
# S023        NaN  Missense_Mutation         Tumor            True
# S024        NaN  Missense_Mutation         Tumor            True
# S025        NaN           Wildtype         Tumor           False
# S026        NaN  Missense_Mutation         Tumor           False
# S027        NaN  Missense_Mutation         Tumor           False
# S028        NaN  Missense_Mutation         Tumor           False
# S029        NaN           Wildtype         Tumor           False
# S030        NaN  Missense_Mutation         Tumor           False
# ...         ...                ...           ...             ...
# S124        NaN           Wildtype        Normal           False
# S125        NaN           Wildtype        Normal           False
# S126        NaN           Wildtype        Normal           False
# S127        NaN           Wildtype        Normal           False
# S128        NaN           Wildtype        Normal           False
# S129        NaN           Wildtype        Normal           False
# S130        NaN           Wildtype        Normal           False
# S131        NaN           Wildtype        Normal           False
# S132        NaN           Wildtype        Normal           False
# S133        NaN           Wildtype        Normal           False
# S134        NaN           Wildtype        Normal           False
# S135        NaN           Wildtype        Normal           False
# S136        NaN           Wildtype        Normal           False
# S137        NaN           Wildtype        Normal           False
# S138        NaN           Wildtype        Normal           False
# S139        NaN           Wildtype        Normal           False
# S140      0.795           Wildtype        Normal           False
# S141      0.822           Wildtype        Normal           False
# S142      0.750           Wildtype        Normal           False
# S143        NaN           Wildtype        Normal           False
# S144        NaN           Wildtype        Normal           False
# S145        NaN           Wildtype        Normal           False
# S146        NaN           Wildtype        Normal           False
# S147        NaN           Wildtype        Normal           False
# S148        NaN           Wildtype        Normal           False
# S149        NaN           Wildtype        Normal           False
# S150        NaN           Wildtype        Normal           False
# S151        NaN           Wildtype        Normal           False
# S152        NaN           Wildtype        Normal           False
# S153        NaN           Wildtype        Normal           False
#
# [153 rows x 81 columns]
# Gene Within_Hotspot not found in phosphoproteomics data
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-aac4f55e5b3d> in <module>
#      38     for site in phosphositesdf.columns:
#      39         if (site is not 'Mutation'):
# ---> 40             sitedf = CPTAC.compare_mutations(phos, site, gene)
#      41             mutateddf = sitedf.loc[sitedf['Mutation'] != 'Wildtype'].dropna(axis=0)
#      42             wtdf = sitedf.loc[sitedf['Mutation'] == 'Wildtype'].dropna(axis=0)
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/CPTAC/__init__.py in compare_mutations(omics_data, omics_gene, mutations_gene)
#     356     """
#     357     if mutations_gene:
# --> 358         return Utilities().merge_mutations_trans(omics_data, omics_gene, somatic_maf, mutations_gene)
#     359     else:
#     360         return Utilities().merge_mutations(omics_data, somatic_maf, omics_gene)
#
# ~/anaconda3/envs/research/lib/python3.7/site-packages/CPTAC/utilities.py in merge_mutations_trans(self, omics, omicsGene, somatic, somaticGene, duplicates)
#     164         elif omics.name.split("_")[0] == "phosphoproteomics":
#     165             phosphosites = self.get_phosphosites(omics, omicsGene)
# --> 166             if len(phosphosites.columns) > 0:
#     167                 if duplicates:
#     168                     return self.merge_somatic(somatic, somaticGene, phosphosites, multiple_mutations = True)
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %% [markdown]
# ## Hotspot mutation v wildtype

# %%
p_values = []
site_names = []


for site in phos_sites:
    mutated = phos_mutations.loc[phos_mutations['Within_Hotspot'] == True]
    mutated_list = mutated[site].tolist()
    mutated_list = [x for x in mutated_list if str(x) != 'nan']
    #print(mutated_list)
    wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype']
    wt_list = wt[site].tolist()
    wt_list = [x for x in wt_list if str(x) != 'nan']
    
    ttest = scipy.stats.ttest_ind(mutated_list, wt_list)
    p_values.append(ttest[1])
    site_names.append(site) 
    
    
areSignificant = statsmodels.stats.multitest.fdrcorrection(p_values)[0]
pvalues = statsmodels.stats.multitest.fdrcorrection(p_values)[1]
significant_sites = np.array(site_names)[np.array(areSignificant)]
significant_pvalues = np.array(pvalues)[np.array(areSignificant)]

significant_vals = dict(zip(significant_sites, significant_pvalues))
    
print(significant_sites)
print(significant_pvalues)
print(significant_vals)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S1100', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S1100', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on IRS1 phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S1101', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S1101', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on IRS1 phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S766', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S766', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on IRS1 phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S1133', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S1133', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on IRS1 phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S672', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = 'IRS1-S672', jitter = True, color = '.3')
boxplt.set_title('Mutation location effect on IRS1 phosphoproteomic abundance', fontsize='25')
boxplt.set_xlabel('Mutation Within Hotspot', fontsize='20')
boxplt.set_ylabel('Protein Level', fontsize='20')
plt.show()
