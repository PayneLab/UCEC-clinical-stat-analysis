# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
import seaborn as sns
import CPTAC.Ovarian as CPTAC
# Out:
# Loading Ovarian CPTAC data:
# Loading somatic_19 data...
# Loading clinical data...
# Loading cnv data...
# Loading proteomics data...
# Loading transcriptomics data...
# Loading somatic_38 data...
# Loading phosphoproteomics data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter embargo() to open the webpage for more details.

# %%
somatic = CPTAC.get_somatic_mutations()

# %%
pd.options.display.max_columns = None
somatic.sort_index()[0:100]
# Out:
#              Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# Hugo_Symbol
# A1CF                      0      .     GRCh37      chr10        52570930
# A2M                       0      .     GRCh37      chr12         9254213
# A2ML1                     0      .     GRCh37      chr12         9009782
# A2ML1                     0      .     GRCh37      chr12         8997909
# A2ML1                     0      .     GRCh37      chr12         9001508
# A4GALT                    0      .     GRCh37      chr22        43089491
# A4GNT                     0      .     GRCh37       chr3       137843299
# A4GNT                     0      .     GRCh37       chr3       137843301
# AACS                      0      .     GRCh37      chr12       125575990
# AADAC                     0      .     GRCh37       chr3       151545433
# AADAT                     0      .     GRCh37       chr4       171008396
# AADAT                     0      .     GRCh37       chr4       170994293
# AAGAB                     0      .     GRCh37      chr15        67495233
# AAK1                      0      .     GRCh37       chr2        69870081
# AAK1                      0      .     GRCh37       chr2        69784091
# AAK1                      0      .     GRCh37       chr2        69741875
# AAK1                      0      .     GRCh37       chr2        69736576
# AANAT                     0      .     GRCh37      chr17        74465323
# AAR2                      0      .     GRCh37      chr20        34858622
# AARS2                     0      .     GRCh37       chr6        44268324
# AASS                      0      .     GRCh37       chr7       121756966
# AATF                      0      .     GRCh37      chr17        35307612
# AATK                      0      .     GRCh37      chr17        79101603
# AATK                      0      .     GRCh37      chr17        79093273
# AATK                      0      .     GRCh37      chr17        79094046
# AATK                      0      .     GRCh37      chr17        79100361
# ABAT                      0      .     GRCh37      chr16         8873414
# ABCA1                     0      .     GRCh37       chr9       107555577
# ABCA1                     0      .     GRCh37       chr9       107581112
# ABCA1                     0      .     GRCh37       chr9       107558383
# ...                     ...    ...        ...        ...             ...
# ABCA9                     0      .     GRCh37      chr17        67039797
# ABCA9                     0      .     GRCh37      chr17        67040742
# ABCB1                     0      .     GRCh37       chr7        87214903
# ABCB1                     0      .     GRCh37       chr7        87135266
# ABCB1                     0      .     GRCh37       chr7        87175339
# ABCB1                     0      .     GRCh37       chr7        87133735
# ABCB10                    0      .     GRCh37       chr1       229654110
# ABCB11                    0      .     GRCh37       chr2       169792787
# ABCB11                    0      .     GRCh37       chr2       169851954
# ABCB11                    0      .     GRCh37       chr2       169780203
# ABCB11                    0      .     GRCh37       chr2       169781174
# ABCB11                    0      .     GRCh37       chr2       169791923
# ABCB4                     0      .     GRCh37       chr7        87053350
# ABCB5                     0      .     GRCh37       chr7        20698247
# ABCB5                     0      .     GRCh37       chr7        20682999
# ABCB6                     0      .     GRCh37       chr2       220083129
# ABCB6                     0      .     GRCh37       chr2       220082504
# ABCB7                     0      .     GRCh37       chrX        74284959
# ABCB8                     0      .     GRCh37       chr7       150730992
# ABCB8                     0      .     GRCh37       chr7       150731426
# ABCB8                     0      .     GRCh37       chr7       150733690
# ABCB9                     0      .     GRCh37      chr12       123433326
# ABCC1                     0      .     GRCh37      chr16        16138401
# ABCC1                     0      .     GRCh37      chr16        16208679
# ABCC10                    0      .     GRCh37       chr6        43400414
# ABCC10                    0      .     GRCh37       chr6        43411963
# ABCC11                    0      .     GRCh37      chr16        48221308
# ABCC11                    0      .     GRCh37      chr16        48232073
# ABCC11                    0      .     GRCh37      chr16        48258279
# ABCC12                    0      .     GRCh37      chr16        48139081
#
#              End_Position Strand Variant_Classification Variant_Type  \
# Hugo_Symbol
# A1CF             52570930      +      Missense_Mutation          SNP
# A2M               9254213      +      Missense_Mutation          SNP
# A2ML1             9009782      +                 Silent          SNP
# A2ML1             8997909      +            Splice_Site          SNP
# A2ML1             9001508      +      Missense_Mutation          SNP
# A4GALT           43089491      +      Missense_Mutation          SNP
# A4GNT           137843299      +      Missense_Mutation          SNP
# A4GNT           137843301      +      Missense_Mutation          SNP
# AACS            125575990      +      Missense_Mutation          SNP
# AADAC           151545433      +      Missense_Mutation          SNP
# AADAT           171008396      +      Missense_Mutation          SNP
# AADAT           170994293      +                 Silent          SNP
# AAGAB            67495233      +      Missense_Mutation          SNP
# AAK1             69870081      +      Missense_Mutation          SNP
# AAK1             69784091      +        Frame_Shift_Del          DEL
# AAK1             69741875      +      Missense_Mutation          SNP
# AAK1             69736576      +      Missense_Mutation          SNP
# AANAT            74465323      +      Missense_Mutation          SNP
# AAR2             34858622      +      Missense_Mutation          SNP
# AARS2            44268324      +      Missense_Mutation          SNP
# AASS            121756966      +      Missense_Mutation          SNP
# AATF             35307612      +      Missense_Mutation          SNP
# AATK             79101603      +                 Silent          SNP
# AATK             79093273      +      Missense_Mutation          SNP
# AATK             79094048      +           In_Frame_Del          DEL
# AATK             79100361      +            Splice_Site          SNP
# ABAT              8873414      +                 Silent          SNP
# ABCA1           107555577      +      Missense_Mutation          SNP
# ABCA1           107581112      +                 Silent          SNP
# ABCA1           107558383      +      Missense_Mutation          SNP
# ...                   ...    ...                    ...          ...
# ABCA9            67039797      +      Missense_Mutation          SNP
# ABCA9            67040742      +            Splice_Site          SNP
# ABCB1            87214903      +      Missense_Mutation          SNP
# ABCB1            87135266      +      Missense_Mutation          SNP
# ABCB1            87175339      +      Missense_Mutation          SNP
# ABCB1            87133735      +      Nonsense_Mutation          SNP
# ABCB10          229654110      +      Missense_Mutation          SNP
# ABCB11          169792787      +      Missense_Mutation          SNP
# ABCB11          169851954      +      Missense_Mutation          SNP
# ABCB11          169780203      +      Missense_Mutation          SNP
# ABCB11          169781174      +      Missense_Mutation          SNP
# ABCB11          169791923      +      Missense_Mutation          SNP
# ABCB4            87053350      +      Missense_Mutation          SNP
# ABCB5            20698247      +      Missense_Mutation          SNP
# ABCB5            20682999      +            Splice_Site          SNP
# ABCB6           220083129      +                 Silent          SNP
# ABCB6           220082504      +      Missense_Mutation          SNP
# ABCB7            74284959      +                 Silent          SNP
# ABCB8           150730992      +                 Silent          SNP
# ABCB8           150731426      +      Missense_Mutation          SNP
# ABCB8           150733690      +        Frame_Shift_Del          DEL
# ABCB9           123433326      +      Missense_Mutation          SNP
# ABCC1            16138401      +      Missense_Mutation          SNP
# ABCC1            16208679      +      Missense_Mutation          SNP
# ABCC10           43400414      +      Missense_Mutation          SNP
# ABCC10           43411963      +      Missense_Mutation          SNP
# ABCC11           48221308      +      Missense_Mutation          SNP
# ABCC11           48232073      +      Missense_Mutation          SNP
# ABCC11           48258280      +        Frame_Shift_Ins          INS
# ABCC12           48139081      +      Missense_Mutation          SNP
#
#             Reference_Allele Tumor_Seq_Allele1 Tumor_Seq_Allele2     dbSNP_RS  \
# Hugo_Symbol
# A1CF                       C                 C                 T        novel
# A2M                        C                 C                 T          NaN
# A2ML1                      G                 G                 A  rs777118635
# A2ML1                      T                 T                 C        novel
# A2ML1                      C                 C                 T  rs200503836
# A4GALT                     G                 G                 A        novel
# A4GNT                      G                 G                 C        novel
# A4GNT                      A                 A                 T        novel
# AACS                       A                 A                 T        novel
# AADAC                      C                 C                 A        novel
# AADAT                      A                 A                 C        novel
# AADAT                      G                 G                 T  rs141752126
# AAGAB                      C                 C                 T        novel
# AAK1                       C                 C                 T          NaN
# AAK1                       A                 A                 -        novel
# AAK1                       C                 C                 A        novel
# AAK1                       C                 C                 A        novel
# AANAT                      C                 C                 A        novel
# AAR2                       T                 T                 A        novel
# AARS2                      G                 G                 A        novel
# AASS                       G                 G                 T        novel
# AATF                       C                 C                 G  rs776480713
# AATK                       C                 C                 T        novel
# AATK                       G                 G                 C  rs755987684
# AATK                     CTT               CTT                 -  rs757851302
# AATK                       C                 C                 G        novel
# ABAT                       C                 C                 A  rs748725086
# ABCA1                      C                 C                 A  rs749183492
# ABCA1                      C                 C                 T        novel
# ABCA1                      C                 C                 T        novel
# ...                      ...               ...               ...          ...
# ABCA9                      C                 C                 A        novel
# ABCA9                      C                 C                 A        novel
# ABCB1                      C                 C                 A        novel
# ABCB1                      G                 G                 A  rs769925505
# ABCB1                      G                 G                 T        novel
# ABCB1                      C                 C                 A        novel
# ABCB10                     C                 C                 G  rs185229946
# ABCB11                     T                 T                 A  rs777469571
# ABCB11                     C                 C                 A  rs371303460
# ABCB11                     T                 T                 C        novel
# ABCB11                     C                 C                 A        novel
# ABCB11                     C                 C                 A        novel
# ABCB4                      C                 C                 A        novel
# ABCB5                      C                 C                 T  rs201692652
# ABCB5                      G                 G                 T        novel
# ABCB6                      G                 G                 C  rs773709837
# ABCB6                      C                 C                 A  rs150221689
# ABCB7                      G                 G                 T        novel
# ABCB8                      G                 G                 A        novel
# ABCB8                      G                 G                 A  rs540495352
# ABCB8                      G                 G                 -  rs774801158
# ABCB9                      C                 C                 A        novel
# ABCC1                      G                 G                 A  rs546292624
# ABCC1                      C                 C                 A  rs376107020
# ABCC10                     G                 G                 T        novel
# ABCC10                     C                 C                 A  rs757623776
# ABCC11                     T                 T                 C        novel
# ABCC11                     C                 C                 A  rs774974482
# ABCC11                     -                 -                 A        novel
# ABCC12                     G                 G                 T        novel
#
#              dbSNP_Val_Status Tumor_Sample_Barcode  \
# Hugo_Symbol
# A1CF                      NaN            17OV002_T
# A2M                       NaN            17OV002_T
# A2ML1                     NaN            02OV005_T
# A2ML1                     NaN            15OV001_T
# A2ML1                     NaN            04OV058_T
# A4GALT                    NaN            17OV002_T
# A4GNT                     NaN            02OV029_T
# A4GNT                     NaN            02OV029_T
# AACS                      NaN            04OV037_T
# AADAC                     NaN            17OV002_T
# AADAT                     NaN            17OV002_T
# AADAT                     NaN            17OV002_T
# AAGAB                     NaN            04OV018_T
# AAK1                      NaN            17OV002_T
# AAK1                      NaN            02OV005_T
# AAK1                      NaN            17OV013_T
# AAK1                      NaN            17OV002_T
# AANAT                     NaN            04OV051_T
# AAR2                      NaN            17OV002_T
# AARS2                     NaN            17OV002_T
# AASS                      NaN            04OV036_T
# AATF                      NaN            04OV037_T
# AATK                      NaN            01OV026_T
# AATK                      NaN            04OV037_T
# AATK                      NaN            04OV048_T
# AATK                      NaN            04OV012_T
# ABAT                      NaN            04OV044_T
# ABCA1                     NaN            17OV002_T
# ABCA1                     NaN            04OV033_T
# ABCA1                     NaN            17OV002_T
# ...                       ...                  ...
# ABCA9                     NaN            17OV002_T
# ABCA9                     NaN            26OV009_T
# ABCB1                     NaN            04OV008_T
# ABCB1                     NaN            01OV023_T
# ABCB1                     NaN            01OV026_T
# ABCB1                     NaN            17OV002_T
# ABCB10                    NaN            04OV036_T
# ABCB11                    NaN            02OV006_T
# ABCB11                    NaN            17OV002_T
# ABCB11                    NaN            17OV002_T
# ABCB11                    NaN            04OV054_T
# ABCB11                    NaN            04OV049_T
# ABCB4                     NaN            17OV002_T
# ABCB5                     NaN            04OV058_T
# ABCB5                     NaN            01OV017_T
# ABCB6                     NaN            04OV050_T
# ABCB6                     NaN            17OV033_T
# ABCB7                     NaN            04OV004_T
# ABCB8                     NaN            04OV040_T
# ABCB8                     NaN            04OV001_T
# ABCB8                     NaN            15OV001_T
# ABCB9                     NaN            01OV041_T
# ABCC1                     NaN            15OV001_T
# ABCC1                     NaN            04OV027_T
# ABCC10                    NaN            04OV018_T
# ABCC10                    NaN            17OV002_T
# ABCC11                    NaN            01OV039_T
# ABCC11                    NaN            17OV002_T
# ABCC11                    NaN            17OV002_T
# ABCC12                    NaN            02OV032_T
#
#             Matched_Norm_Sample_Barcode Match_Norm_Seq_Allele1  \
# Hugo_Symbol
# A1CF                          17OV002_N                      C
# A2M                           17OV002_N                      C
# A2ML1                         02OV005_N                      G
# A2ML1                         15OV001_N                      T
# A2ML1                         04OV058_N                      C
# A4GALT                        17OV002_N                      G
# A4GNT                         02OV029_N                      G
# A4GNT                         02OV029_N                      A
# AACS                          04OV037_N                      A
# AADAC                         17OV002_N                      C
# AADAT                         17OV002_N                      A
# AADAT                         17OV002_N                      G
# AAGAB                         04OV018_N                      C
# AAK1                          17OV002_N                      C
# AAK1                          02OV005_N                      A
# AAK1                          17OV013_N                      C
# AAK1                          17OV002_N                      C
# AANAT                         04OV051_N                      C
# AAR2                          17OV002_N                      T
# AARS2                         17OV002_N                      G
# AASS                          04OV036_N                      G
# AATF                          04OV037_N                      C
# AATK                          01OV026_N                      C
# AATK                          04OV037_N                      G
# AATK                          04OV048_N                    CTT
# AATK                          04OV012_N                      C
# ABAT                          04OV044_N                      C
# ABCA1                         17OV002_N                      C
# ABCA1                         04OV033_N                      C
# ABCA1                         17OV002_N                      C
# ...                                 ...                    ...
# ABCA9                         17OV002_N                      C
# ABCA9                         26OV009_N                      C
# ABCB1                         04OV008_N                      C
# ABCB1                         01OV023_N                      G
# ABCB1                         01OV026_N                      G
# ABCB1                         17OV002_N                      C
# ABCB10                        04OV036_N                      C
# ABCB11                        02OV006_N                      T
# ABCB11                        17OV002_N                      C
# ABCB11                        17OV002_N                      T
# ABCB11                        04OV054_N                      C
# ABCB11                        04OV049_N                      C
# ABCB4                         17OV002_N                      C
# ABCB5                         04OV058_N                      C
# ABCB5                         01OV017_N                      G
# ABCB6                         04OV050_N                      G
# ABCB6                         17OV033_N                      C
# ABCB7                         04OV004_N                      G
# ABCB8                         04OV040_N                      G
# ABCB8                         04OV001_N                      G
# ABCB8                         15OV001_N                      G
# ABCB9                         01OV041_N                      C
# ABCC1                         15OV001_N                      G
# ABCC1                         04OV027_N                      C
# ABCC10                        04OV018_N                      G
# ABCC10                        17OV002_N                      C
# ABCC11                        01OV039_N                      T
# ABCC11                        17OV002_N                      C
# ABCC11                        17OV002_N                      -
# ABCC12                        02OV032_N                      G
#
#             Match_Norm_Seq_Allele2  Tumor_Validation_Allele1  \
# Hugo_Symbol
# A1CF                             C                       NaN
# A2M                              C                       NaN
# A2ML1                            G                       NaN
# A2ML1                            T                       NaN
# A2ML1                            C                       NaN
# A4GALT                           G                       NaN
# A4GNT                            G                       NaN
# A4GNT                            A                       NaN
# AACS                             A                       NaN
# AADAC                            C                       NaN
# AADAT                            A                       NaN
# AADAT                            G                       NaN
# AAGAB                            C                       NaN
# AAK1                             C                       NaN
# AAK1                             A                       NaN
# AAK1                             C                       NaN
# AAK1                             C                       NaN
# AANAT                            C                       NaN
# AAR2                             T                       NaN
# AARS2                            G                       NaN
# AASS                             G                       NaN
# AATF                             C                       NaN
# AATK                             C                       NaN
# AATK                             G                       NaN
# AATK                           CTT                       NaN
# AATK                             C                       NaN
# ABAT                             C                       NaN
# ABCA1                            C                       NaN
# ABCA1                            C                       NaN
# ABCA1                            C                       NaN
# ...                            ...                       ...
# ABCA9                            C                       NaN
# ABCA9                            C                       NaN
# ABCB1                            C                       NaN
# ABCB1                            G                       NaN
# ABCB1                            G                       NaN
# ABCB1                            C                       NaN
# ABCB10                           C                       NaN
# ABCB11                           T                       NaN
# ABCB11                           C                       NaN
# ABCB11                           T                       NaN
# ABCB11                           C                       NaN
# ABCB11                           C                       NaN
# ABCB4                            C                       NaN
# ABCB5                            C                       NaN
# ABCB5                            G                       NaN
# ABCB6                            G                       NaN
# ABCB6                            C                       NaN
# ABCB7                            G                       NaN
# ABCB8                            G                       NaN
# ABCB8                            G                       NaN
# ABCB8                            G                       NaN
# ABCB9                            C                       NaN
# ABCC1                            G                       NaN
# ABCC1                            C                       NaN
# ABCC10                           G                       NaN
# ABCC10                           C                       NaN
# ABCC11                           T                       NaN
# ABCC11                           C                       NaN
# ABCC11                           -                       NaN
# ABCC12                           G                       NaN
#
#              Tumor_Validation_Allele2  Match_Norm_Validation_Allele1  \
# Hugo_Symbol
# A1CF                              NaN                            NaN
# A2M                               NaN                            NaN
# A2ML1                             NaN                            NaN
# A2ML1                             NaN                            NaN
# A2ML1                             NaN                            NaN
# A4GALT                            NaN                            NaN
# A4GNT                             NaN                            NaN
# A4GNT                             NaN                            NaN
# AACS                              NaN                            NaN
# AADAC                             NaN                            NaN
# AADAT                             NaN                            NaN
# AADAT                             NaN                            NaN
# AAGAB                             NaN                            NaN
# AAK1                              NaN                            NaN
# AAK1                              NaN                            NaN
# AAK1                              NaN                            NaN
# AAK1                              NaN                            NaN
# AANAT                             NaN                            NaN
# AAR2                              NaN                            NaN
# AARS2                             NaN                            NaN
# AASS                              NaN                            NaN
# AATF                              NaN                            NaN
# AATK                              NaN                            NaN
# AATK                              NaN                            NaN
# AATK                              NaN                            NaN
# AATK                              NaN                            NaN
# ABAT                              NaN                            NaN
# ABCA1                             NaN                            NaN
# ABCA1                             NaN                            NaN
# ABCA1                             NaN                            NaN
# ...                               ...                            ...
# ABCA9                             NaN                            NaN
# ABCA9                             NaN                            NaN
# ABCB1                             NaN                            NaN
# ABCB1                             NaN                            NaN
# ABCB1                             NaN                            NaN
# ABCB1                             NaN                            NaN
# ABCB10                            NaN                            NaN
# ABCB11                            NaN                            NaN
# ABCB11                            NaN                            NaN
# ABCB11                            NaN                            NaN
# ABCB11                            NaN                            NaN
# ABCB11                            NaN                            NaN
# ABCB4                             NaN                            NaN
# ABCB5                             NaN                            NaN
# ABCB5                             NaN                            NaN
# ABCB6                             NaN                            NaN
# ABCB6                             NaN                            NaN
# ABCB7                             NaN                            NaN
# ABCB8                             NaN                            NaN
# ABCB8                             NaN                            NaN
# ABCB8                             NaN                            NaN
# ABCB9                             NaN                            NaN
# ABCC1                             NaN                            NaN
# ABCC1                             NaN                            NaN
# ABCC10                            NaN                            NaN
# ABCC10                            NaN                            NaN
# ABCC11                            NaN                            NaN
# ABCC11                            NaN                            NaN
# ABCC11                            NaN                            NaN
# ABCC12                            NaN                            NaN
#
#              Match_Norm_Validation_Allele2  Verification_Status  \
# Hugo_Symbol
# A1CF                                   NaN                  NaN
# A2M                                    NaN                  NaN
# A2ML1                                  NaN                  NaN
# A2ML1                                  NaN                  NaN
# A2ML1                                  NaN                  NaN
# A4GALT                                 NaN                  NaN
# A4GNT                                  NaN                  NaN
# A4GNT                                  NaN                  NaN
# AACS                                   NaN                  NaN
# AADAC                                  NaN                  NaN
# AADAT                                  NaN                  NaN
# AADAT                                  NaN                  NaN
# AAGAB                                  NaN                  NaN
# AAK1                                   NaN                  NaN
# AAK1                                   NaN                  NaN
# AAK1                                   NaN                  NaN
# AAK1                                   NaN                  NaN
# AANAT                                  NaN                  NaN
# AAR2                                   NaN                  NaN
# AARS2                                  NaN                  NaN
# AASS                                   NaN                  NaN
# AATF                                   NaN                  NaN
# AATK                                   NaN                  NaN
# AATK                                   NaN                  NaN
# AATK                                   NaN                  NaN
# AATK                                   NaN                  NaN
# ABAT                                   NaN                  NaN
# ABCA1                                  NaN                  NaN
# ABCA1                                  NaN                  NaN
# ABCA1                                  NaN                  NaN
# ...                                    ...                  ...
# ABCA9                                  NaN                  NaN
# ABCA9                                  NaN                  NaN
# ABCB1                                  NaN                  NaN
# ABCB1                                  NaN                  NaN
# ABCB1                                  NaN                  NaN
# ABCB1                                  NaN                  NaN
# ABCB10                                 NaN                  NaN
# ABCB11                                 NaN                  NaN
# ABCB11                                 NaN                  NaN
# ABCB11                                 NaN                  NaN
# ABCB11                                 NaN                  NaN
# ABCB11                                 NaN                  NaN
# ABCB4                                  NaN                  NaN
# ABCB5                                  NaN                  NaN
# ABCB5                                  NaN                  NaN
# ABCB6                                  NaN                  NaN
# ABCB6                                  NaN                  NaN
# ABCB7                                  NaN                  NaN
# ABCB8                                  NaN                  NaN
# ABCB8                                  NaN                  NaN
# ABCB8                                  NaN                  NaN
# ABCB9                                  NaN                  NaN
# ABCC1                                  NaN                  NaN
# ABCC1                                  NaN                  NaN
# ABCC10                                 NaN                  NaN
# ABCC10                                 NaN                  NaN
# ABCC11                                 NaN                  NaN
# ABCC11                                 NaN                  NaN
# ABCC11                                 NaN                  NaN
# ABCC12                                 NaN                  NaN
#
#              Validation_Status  Mutation_Status  Sequencing_Phase  \
# Hugo_Symbol
# A1CF                       NaN              NaN               NaN
# A2M                        NaN              NaN               NaN
# A2ML1                      NaN              NaN               NaN
# A2ML1                      NaN              NaN               NaN
# A2ML1                      NaN              NaN               NaN
# A4GALT                     NaN              NaN               NaN
# A4GNT                      NaN              NaN               NaN
# A4GNT                      NaN              NaN               NaN
# AACS                       NaN              NaN               NaN
# AADAC                      NaN              NaN               NaN
# AADAT                      NaN              NaN               NaN
# AADAT                      NaN              NaN               NaN
# AAGAB                      NaN              NaN               NaN
# AAK1                       NaN              NaN               NaN
# AAK1                       NaN              NaN               NaN
# AAK1                       NaN              NaN               NaN
# AAK1                       NaN              NaN               NaN
# AANAT                      NaN              NaN               NaN
# AAR2                       NaN              NaN               NaN
# AARS2                      NaN              NaN               NaN
# AASS                       NaN              NaN               NaN
# AATF                       NaN              NaN               NaN
# AATK                       NaN              NaN               NaN
# AATK                       NaN              NaN               NaN
# AATK                       NaN              NaN               NaN
# AATK                       NaN              NaN               NaN
# ABAT                       NaN              NaN               NaN
# ABCA1                      NaN              NaN               NaN
# ABCA1                      NaN              NaN               NaN
# ABCA1                      NaN              NaN               NaN
# ...                        ...              ...               ...
# ABCA9                      NaN              NaN               NaN
# ABCA9                      NaN              NaN               NaN
# ABCB1                      NaN              NaN               NaN
# ABCB1                      NaN              NaN               NaN
# ABCB1                      NaN              NaN               NaN
# ABCB1                      NaN              NaN               NaN
# ABCB10                     NaN              NaN               NaN
# ABCB11                     NaN              NaN               NaN
# ABCB11                     NaN              NaN               NaN
# ABCB11                     NaN              NaN               NaN
# ABCB11                     NaN              NaN               NaN
# ABCB11                     NaN              NaN               NaN
# ABCB4                      NaN              NaN               NaN
# ABCB5                      NaN              NaN               NaN
# ABCB5                      NaN              NaN               NaN
# ABCB6                      NaN              NaN               NaN
# ABCB6                      NaN              NaN               NaN
# ABCB7                      NaN              NaN               NaN
# ABCB8                      NaN              NaN               NaN
# ABCB8                      NaN              NaN               NaN
# ABCB8                      NaN              NaN               NaN
# ABCB9                      NaN              NaN               NaN
# ABCC1                      NaN              NaN               NaN
# ABCC1                      NaN              NaN               NaN
# ABCC10                     NaN              NaN               NaN
# ABCC10                     NaN              NaN               NaN
# ABCC11                     NaN              NaN               NaN
# ABCC11                     NaN              NaN               NaN
# ABCC11                     NaN              NaN               NaN
# ABCC12                     NaN              NaN               NaN
#
#              Sequence_Source  Validation_Method  Score  BAM_File  Sequencer  \
# Hugo_Symbol
# A1CF                     NaN                NaN    NaN       NaN        NaN
# A2M                      NaN                NaN    NaN       NaN        NaN
# A2ML1                    NaN                NaN    NaN       NaN        NaN
# A2ML1                    NaN                NaN    NaN       NaN        NaN
# A2ML1                    NaN                NaN    NaN       NaN        NaN
# A4GALT                   NaN                NaN    NaN       NaN        NaN
# A4GNT                    NaN                NaN    NaN       NaN        NaN
# A4GNT                    NaN                NaN    NaN       NaN        NaN
# AACS                     NaN                NaN    NaN       NaN        NaN
# AADAC                    NaN                NaN    NaN       NaN        NaN
# AADAT                    NaN                NaN    NaN       NaN        NaN
# AADAT                    NaN                NaN    NaN       NaN        NaN
# AAGAB                    NaN                NaN    NaN       NaN        NaN
# AAK1                     NaN                NaN    NaN       NaN        NaN
# AAK1                     NaN                NaN    NaN       NaN        NaN
# AAK1                     NaN                NaN    NaN       NaN        NaN
# AAK1                     NaN                NaN    NaN       NaN        NaN
# AANAT                    NaN                NaN    NaN       NaN        NaN
# AAR2                     NaN                NaN    NaN       NaN        NaN
# AARS2                    NaN                NaN    NaN       NaN        NaN
# AASS                     NaN                NaN    NaN       NaN        NaN
# AATF                     NaN                NaN    NaN       NaN        NaN
# AATK                     NaN                NaN    NaN       NaN        NaN
# AATK                     NaN                NaN    NaN       NaN        NaN
# AATK                     NaN                NaN    NaN       NaN        NaN
# AATK                     NaN                NaN    NaN       NaN        NaN
# ABAT                     NaN                NaN    NaN       NaN        NaN
# ABCA1                    NaN                NaN    NaN       NaN        NaN
# ABCA1                    NaN                NaN    NaN       NaN        NaN
# ABCA1                    NaN                NaN    NaN       NaN        NaN
# ...                      ...                ...    ...       ...        ...
# ABCA9                    NaN                NaN    NaN       NaN        NaN
# ABCA9                    NaN                NaN    NaN       NaN        NaN
# ABCB1                    NaN                NaN    NaN       NaN        NaN
# ABCB1                    NaN                NaN    NaN       NaN        NaN
# ABCB1                    NaN                NaN    NaN       NaN        NaN
# ABCB1                    NaN                NaN    NaN       NaN        NaN
# ABCB10                   NaN                NaN    NaN       NaN        NaN
# ABCB11                   NaN                NaN    NaN       NaN        NaN
# ABCB11                   NaN                NaN    NaN       NaN        NaN
# ABCB11                   NaN                NaN    NaN       NaN        NaN
# ABCB11                   NaN                NaN    NaN       NaN        NaN
# ABCB11                   NaN                NaN    NaN       NaN        NaN
# ABCB4                    NaN                NaN    NaN       NaN        NaN
# ABCB5                    NaN                NaN    NaN       NaN        NaN
# ABCB5                    NaN                NaN    NaN       NaN        NaN
# ABCB6                    NaN                NaN    NaN       NaN        NaN
# ABCB6                    NaN                NaN    NaN       NaN        NaN
# ABCB7                    NaN                NaN    NaN       NaN        NaN
# ABCB8                    NaN                NaN    NaN       NaN        NaN
# ABCB8                    NaN                NaN    NaN       NaN        NaN
# ABCB8                    NaN                NaN    NaN       NaN        NaN
# ABCB9                    NaN                NaN    NaN       NaN        NaN
# ABCC1                    NaN                NaN    NaN       NaN        NaN
# ABCC1                    NaN                NaN    NaN       NaN        NaN
# ABCC10                   NaN                NaN    NaN       NaN        NaN
# ABCC10                   NaN                NaN    NaN       NaN        NaN
# ABCC11                   NaN                NaN    NaN       NaN        NaN
# ABCC11                   NaN                NaN    NaN       NaN        NaN
# ABCC11                   NaN                NaN    NaN       NaN        NaN
# ABCC12                   NaN                NaN    NaN       NaN        NaN
#
#              Tumor_Sample_UUID  Matched_Norm_Sample_UUID              HGVSc  \
# Hugo_Symbol
# A1CF                       NaN                       NaN          c.1354G>A
# A2M                        NaN                       NaN          c.1324G>A
# A2ML1                      NaN                       NaN          c.2871G>A
# A2ML1                      NaN                       NaN          c.12+2T>C
# A2ML1                      NaN                       NaN          c.2026C>T
# A4GALT                     NaN                       NaN           c.467C>T
# A4GNT                      NaN                       NaN           c.830C>G
# A4GNT                      NaN                       NaN           c.828T>A
# AACS                       NaN                       NaN           c.491A>T
# AADAC                      NaN                       NaN           c.673C>A
# AADAT                      NaN                       NaN           c.240T>G
# AADAT                      NaN                       NaN           c.648C>A
# AAGAB                      NaN                       NaN           c.874G>A
# AAK1                       NaN                       NaN            c.92G>A
# AAK1                       NaN                       NaN          c.183delT
# AAK1                       NaN                       NaN          c.1504G>T
# AAK1                       NaN                       NaN          c.1793G>T
# AANAT                      NaN                       NaN           c.367C>A
# AAR2                       NaN                       NaN          c.1155T>A
# AARS2                      NaN                       NaN          c.2918C>T
# AASS                       NaN                       NaN           c.733C>A
# AATF                       NaN                       NaN           c.190C>G
# AATK                       NaN                       NaN           c.522G>A
# AATK                       NaN                       NaN          c.3991C>G
# AATK                       NaN                       NaN  c.3688_3690delAAG
# AATK                       NaN                       NaN         c.622-1G>C
# ABAT                       NaN                       NaN          c.1348C>A
# ABCA1                      NaN                       NaN          c.5511G>T
# ABCA1                      NaN                       NaN          c.3294G>A
# ABCA1                      NaN                       NaN          c.5333G>A
# ...                        ...                       ...                ...
# ABCA9                      NaN                       NaN           c.633G>T
# ABCA9                      NaN                       NaN         c.470-1G>T
# ABCB1                      NaN                       NaN           c.211G>T
# ABCB1                      NaN                       NaN          c.3583C>T
# ABCB1                      NaN                       NaN          c.1727C>A
# ABCB1                      NaN                       NaN          c.3667G>T
# ABCB10                     NaN                       NaN          c.2033G>C
# ABCB11                     NaN                       NaN          c.2767A>T
# ABCB11                     NaN                       NaN           c.516G>T
# ABCB11                     NaN                       NaN          c.3895A>G
# ABCB11                     NaN                       NaN          c.3758G>T
# ABCB11                     NaN                       NaN          c.2827G>T
# ABCB4                      NaN                       NaN          c.2083G>T
# ABCB5                      NaN                       NaN          c.1655C>T
# ABCB5                      NaN                       NaN         c.506+1G>T
# ABCB6                      NaN                       NaN           c.267C>G
# ...
# AANAT                 NaN            .            .          NaN
# AAR2                  NaN            .            .          NaN
# AARS2                 NaN            .            .          NaN
# AASS                  NaN            .            .          NaN
# AATF                  NaN            .            .          NaN
# AATK                  NaN            .            .          NaN
# AATK                  NaN            .            .          NaN
# AATK                  NaN            .            .     0.000010
# AATK                  NaN            .            .          NaN
# ABAT                  NaN            .            .          NaN
# ABCA1                 NaN            .            .          NaN
# ABCA1                 NaN            .            .          NaN
# ABCA1                 NaN            .            .          NaN
# ...                   ...          ...          ...          ...
# ABCA9                 NaN            .            .          NaN
# ABCA9                 NaN            .            .          NaN
# ABCB1                 NaN            .            .          NaN
# ABCB1                 NaN            .            .          NaN
# ABCB1                 NaN            .            .          NaN
# ABCB1                 NaN            .            .          NaN
# ABCB10                NaN  rs185229946            .          NaN
# ABCB11                NaN            .            .          NaN
# ABCB11                NaN  rs371303460            .          NaN
# ABCB11                NaN            .            .          NaN
# ABCB11                NaN            .            .          NaN
# ABCB11                NaN            .            .          NaN
# ABCB4                 NaN            .            .          NaN
# ABCB5                 NaN  rs201692652            .     0.000066
# ABCB5                 NaN            .            .          NaN
# ABCB6                 NaN            .            .          NaN
# ABCB6                 NaN  rs150221689            .          NaN
# ABCB7                 NaN            .            .          NaN
# ABCB8                 NaN            .            .          NaN
# ABCB8                 NaN  rs540495352            .     0.000028
# ABCB8                 NaN            .            .          NaN
# ABCB9                 NaN            .            .          NaN
# ABCC1                 NaN  rs546292624            .     0.000019
# ABCC1                 NaN  rs376107020            .     0.000010
# ABCC10                NaN            .            .          NaN
# ABCC10                NaN            .            .          NaN
# ABCC11                NaN            .            .          NaN
# ABCC11                NaN            .            .          NaN
# ABCC11                NaN            .            .          NaN
# ABCC12                NaN            .            .          NaN
#
#             ExAC_AC_AN_Adj ExAC_AC_AN ExAC_AC_AN_AFR ExAC_AC_AN_AMR  \
# Hugo_Symbol
# A1CF                   NaN        NaN            NaN            NaN
# A2M                    NaN        NaN            NaN            NaN
# A2ML1             1/105376   1/105716         0/8466        0/11212
# A2ML1                  NaN        NaN            NaN            NaN
# A2ML1            53/103196  53/105658         0/8434        1/11192
# A4GALT                 NaN        NaN            NaN            NaN
# A4GNT                  NaN        NaN            NaN            NaN
# A4GNT                  NaN        NaN            NaN            NaN
# AACS                   NaN        NaN            NaN            NaN
# AADAC                  NaN        NaN            NaN            NaN
# AADAT                  NaN        NaN            NaN            NaN
# AADAT                  NaN        NaN            NaN            NaN
# AAGAB                  NaN        NaN            NaN            NaN
# AAK1                   NaN        NaN            NaN            NaN
# AAK1                   NaN        NaN            NaN            NaN
# AAK1                   NaN        NaN            NaN            NaN
# AAK1                   NaN        NaN            NaN            NaN
# AANAT                  NaN        NaN            NaN            NaN
# AAR2                   NaN        NaN            NaN            NaN
# AARS2                  NaN        NaN            NaN            NaN
# AASS                   NaN        NaN            NaN            NaN
# AATF                   NaN        NaN            NaN            NaN
# AATK                   NaN        NaN            NaN            NaN
# AATK                   NaN        NaN            NaN            NaN
# AATK              1/101442   1/105854         0/7714        1/10996
# AATK                   NaN        NaN            NaN            NaN
# ABAT                   NaN        NaN            NaN            NaN
# ABCA1                  NaN        NaN            NaN            NaN
# ABCA1                  NaN        NaN            NaN            NaN
# ABCA1                  NaN        NaN            NaN            NaN
# ...                    ...        ...            ...            ...
# ABCA9                  NaN        NaN            NaN            NaN
# ABCA9                  NaN        NaN            NaN            NaN
# ABCB1                  NaN        NaN            NaN            NaN
# ABCB1                  NaN        NaN            NaN            NaN
# ABCB1                  NaN        NaN            NaN            NaN
# ABCB1                  NaN        NaN            NaN            NaN
# ABCB10                 NaN        NaN            NaN            NaN
# ABCB11                 NaN        NaN            NaN            NaN
# ABCB11                 NaN        NaN            NaN            NaN
# ABCB11                 NaN        NaN            NaN            NaN
# ABCB11                 NaN        NaN            NaN            NaN
# ABCB11                 NaN        NaN            NaN            NaN
# ABCB4                  NaN        NaN            NaN            NaN
# ABCB5             7/106172   7/106210         0/9066        0/11186
# ABCB5                  NaN        NaN            NaN            NaN
# ABCB6                  NaN        NaN            NaN            NaN
# ABCB6                  NaN        NaN            NaN            NaN
# ABCB7                  NaN        NaN            NaN            NaN
# ABCB8                  NaN        NaN            NaN            NaN
# ABCB8             3/106170   3/106210         0/9066        0/11214
# ABCB8                  NaN        NaN            NaN            NaN
# ABCB9                  NaN        NaN            NaN            NaN
# ABCC1             2/105578   2/105782         0/8470        0/11210
# ABCC1             1/104498   3/106026         0/8374        0/11110
# ABCC10                 NaN        NaN            NaN            NaN
# ABCC10                 NaN        NaN            NaN            NaN
# ABCC11                 NaN        NaN            NaN            NaN
# ABCC11                 NaN        NaN            NaN            NaN
# ABCC11                 NaN        NaN            NaN            NaN
# ABCC12                 NaN        NaN            NaN            NaN
#
#             ExAC_AC_AN_EAS ExAC_AC_AN_FIN ExAC_AC_AN_NFE ExAC_AC_AN_OTH  \
# Hugo_Symbol
# A1CF                   NaN            NaN            NaN            NaN
# A2M                    NaN            NaN            NaN            NaN
# A2ML1               0/7846         0/6614        1/54240          0/690
# A2ML1                  NaN            NaN            NaN            NaN
# A2ML1               0/7844         0/6612       28/53760          0/664
# A4GALT                 NaN            NaN            NaN            NaN
# A4GNT                  NaN            NaN            NaN            NaN
# A4GNT                  NaN            NaN            NaN            NaN
# AACS                   NaN            NaN            NaN            NaN
# AADAC                  NaN            NaN            NaN            NaN
# AADAT                  NaN            NaN            NaN            NaN
# AADAT                  NaN            NaN            NaN            NaN
# AAGAB                  NaN            NaN            NaN            NaN
# AAK1                   NaN            NaN            NaN            NaN
# AAK1                   NaN            NaN            NaN            NaN
# AAK1                   NaN            NaN            NaN            NaN
# AAK1                   NaN            NaN            NaN            NaN
# AANAT                  NaN            NaN            NaN            NaN
# AAR2                   NaN            NaN            NaN            NaN
# AARS2                  NaN            NaN            NaN            NaN
# AASS                   NaN            NaN            NaN            NaN
# AATF                   NaN            NaN            NaN            NaN
# AATK                   NaN            NaN            NaN            NaN
# AATK                   NaN            NaN            NaN            NaN
# AATK                0/7746         0/6412        0/52674          0/662
# AATK                   NaN            NaN            NaN            NaN
# ABAT                   NaN            NaN            NaN            NaN
# ABCA1                  NaN            NaN            NaN            NaN
# ABCA1                  NaN            NaN            NaN            NaN
# ABCA1                  NaN            NaN            NaN            NaN
# ...                    ...            ...            ...            ...
# ABCA9                  NaN            NaN            NaN            NaN
# ABCA9                  NaN            NaN            NaN            NaN
# ABCB1                  NaN            NaN            NaN            NaN
# ABCB1                  NaN            NaN            NaN            NaN
# ABCB1                  NaN            NaN            NaN            NaN
# ABCB1                  NaN            NaN            NaN            NaN
# ABCB10                 NaN            NaN            NaN            NaN
# ABCB11                 NaN            NaN            NaN            NaN
# ABCB11                 NaN            NaN            NaN            NaN
# ABCB11                 NaN            NaN            NaN            NaN
# ABCB11                 NaN            NaN            NaN            NaN
# ABCB11                 NaN            NaN            NaN            NaN
# ABCB4                  NaN            NaN            NaN            NaN
# ABCB5               2/7866         0/6614        0/54338          0/694
# ABCB5                  NaN            NaN            NaN            NaN
# ABCB6                  NaN            NaN            NaN            NaN
# ABCB6                  NaN            NaN            NaN            NaN
# ABCB7                  NaN            NaN            NaN            NaN
# ABCB8                  NaN            NaN            NaN            NaN
# ABCB8               1/7866         0/6612        0/54310          0/694
# ABCB8                  NaN            NaN            NaN            NaN
# ABCB9                  NaN            NaN            NaN            NaN
# ABCC1               0/7844         0/6614        0/54344          0/690
# ABCC1               1/7828         0/6430        0/53982          0/682
# ABCC10                 NaN            NaN            NaN            NaN
# ABCC10                 NaN            NaN            NaN            NaN
# ABCC11                 NaN            NaN            NaN            NaN
# ABCC11                 NaN            NaN            NaN            NaN
# ABCC11                 NaN            NaN            NaN            NaN
# ABCC12                 NaN            NaN            NaN            NaN
#
#             ExAC_AC_AN_SAS                   ExAC_FILTER
# Hugo_Symbol
# A1CF                   NaN                           NaN
# A2M                    NaN                           NaN
# A2ML1              0/16308                          PASS
# A2ML1                  NaN                           NaN
# A2ML1             24/14690                          PASS
# A4GALT                 NaN                           NaN
# A4GNT                  NaN                           NaN
# A4GNT                  NaN                           NaN
# AACS                   NaN                           NaN
# AADAC                  NaN                           NaN
# AADAT                  NaN                           NaN
# AADAT                  NaN                          PASS
# AAGAB                  NaN                           NaN
# AAK1                   NaN                           NaN
# AAK1                   NaN                           NaN
# AAK1                   NaN                           NaN
# AAK1                   NaN                           NaN
# AANAT                  NaN                           NaN
# AAR2                   NaN                           NaN
# AARS2                  NaN                           NaN
# AASS                   NaN                           NaN
# AATF                   NaN                          PASS
# AATK                   NaN                           NaN
# AATK                   NaN                           NaN
# AATK               0/15238  VQSRTrancheINDEL99.00to99.50
# AATK                   NaN                           NaN
# ABAT                   NaN                          PASS
# ABCA1                  NaN                          PASS
# ABCA1                  NaN                           NaN
# ABCA1                  NaN                           NaN
# ...                    ...                           ...
# ABCA9                  NaN                           NaN
# ABCA9                  NaN                           NaN
# ABCB1                  NaN                           NaN
# ABCB1                  NaN                           NaN
# ABCB1                  NaN                           NaN
# ABCB1                  NaN                           NaN
# ABCB10                 NaN                           NaN
# ABCB11                 NaN                          PASS
# ABCB11                 NaN                          PASS
# ABCB11                 NaN                           NaN
# ABCB11                 NaN                           NaN
# ABCB11                 NaN                           NaN
# ABCB4                  NaN                           NaN
# ABCB5              5/16408                          PASS
# ABCB5                  NaN                          PASS
# ABCB6                  NaN                          PASS
# ABCB6                  NaN                          PASS
# ABCB7                  NaN                           NaN
# ABCB8                  NaN                           NaN
# ABCB8              2/16408                          PASS
# ABCB8                  NaN                          PASS
# ABCB9                  NaN                           NaN
# ABCC1              2/16406                          PASS
# ABCC1              0/16092                          PASS
# ABCC10                 NaN                           NaN
# ABCC10                 NaN                          PASS
# ABCC11                 NaN                           NaN
# ABCC11                 NaN                          PASS
# ABCC11                 NaN                           NaN
# ABCC12                 NaN                           NaN
#
# [100 rows x 123 columns]

# %%
CPTAC.get_proteomics().transpose()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2d86cc86378c> in <module>()
# ----> 1 CPTAC.get_proteomics().transpose()
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     255             self.start_displayhook()
#     256             self.write_output_prompt()
# --> 257             format_dict, md_dict = self.compute_format_data(result)
#     258             self.update_user_ns(result)
#     259             self.fill_exec_result(result)
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     694
#     695             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 696                                 show_dimensions=show_dimensions, notebook=True)
#     697         else:
#     698             return None
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2035                                            decimal=decimal, table_id=table_id)
#    2036         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2037         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2038
#    2039         if buf is None:
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
#     753                                       table_id=self.table_id)
#     754         if hasattr(self.buf, 'write'):
# --> 755             html_renderer.write_result(self.buf)
#     756         elif isinstance(self.buf, compat.string_types):
#     757             with open(self.buf, 'w') as f:
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/html.py in write_result(self, buf)
#     178         indent += self.indent_delta
#     179         indent = self._write_header(indent)
# --> 180         indent = self._write_body(indent)
#     181
#     182         self.write('</table>', indent)
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     341                 self._write_hierarchical_rows(fmt_values, indent)
#     342             else:
# --> 343                 self._write_regular_rows(fmt_values, indent)
#     344         else:
#     345             for i in range(min(len(self.frame), self.max_rows)):
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_regular_rows(self, fmt_values, indent)
#     381                 row.insert(dot_col_ix, '...')
#     382             self.write_tr(row, indent, self.indent_delta, tags=None,
# --> 383                           nindex_levels=1)
#     384
#     385     def _write_hierarchical_rows(self, fmt_values, indent):
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/html.py in write_tr(self, line, indent, indent_delta, header, align, tags, nindex_levels)
#      95                 self.write_th(s, indent, tags=val_tag)
#      96             else:
# ---> 97                 self.write_td(s, indent, tags=val_tag)
#      98
#      99         indent -= indent_delta
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/html.py in write_td(self, s, indent, tags)
#      60
#      61     def write_td(self, s, indent=0, tags=None):
# ---> 62         return self._write_cell(s, kind='td', indent=indent, tags=tags)
#      63
#      64     def _write_cell(self, s, kind='td', indent=0, tags=None):
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_cell(self, s, kind, indent, tags)
#      74         else:
#      75             esc = {}
# ---> 76         rs = pprint_thing(s, escape_chars=esc).strip()
#      77         self.write(u'{start}{rs}</{kind}>'
#      78                    .format(start=start_tag, rs=rs, kind=kind), indent)
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     223         result = fmt.format(thing=as_escaped_unicode(thing))
#     224     else:
# --> 225         result = as_escaped_unicode(thing)
#     226
#     227     return compat.text_type(result)  # always unicode
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/io/formats/printing.py in as_escaped_unicode(thing, escape_chars)
#     197             else:
#     198                 translate = escape_chars
# --> 199             escape_chars = list(escape_chars.keys())
#     200         else:
#     201             escape_chars = escape_chars or tuple()
#
# KeyboardInterrupt:
