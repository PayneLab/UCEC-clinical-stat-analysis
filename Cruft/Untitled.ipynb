# %%
import CPTAC.Endometrial as CPTAC
import pandas as pd

# %%
pd.options.display.max_columns = None
display(CPTAC.get_clinical())
# Out:
#      Proteomics_Participant_ID  Proteomics_TMT_batch  Proteomics_TMT_plex  \
# idx
# S001                 C3L-00006                     2                    5
# S002                 C3L-00008                     4                   16
# S003                 C3L-00032                     1                    2
# S004                 C3L-00084                     3                   11
# S005                 C3L-00090                     3                   12
# S006                 C3L-00098                     4                   14
# S007                 C3L-00136                     4                   16
# S008                 C3L-00137                     4                   15
# S009                 C3L-00139                     3                   11
# S010                 C3L-00143                     4                   14
# S011                 C3L-00145                     3                    9
# S012                 C3L-00156                     4                   15
# ...

# %%
pd.options.display.max_columns = None
